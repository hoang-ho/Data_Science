# %% [markdown]
# # Content - Based Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import run_content_based
import utils

# %%
business = pd.read_csv("business_cleaned.csv")
business.shape
# Out:
# (9900, 21)

# %%
user = pd.read_csv("user_cleaned.csv")
user.shape
# Out:
# (33105, 22)

# %%
review = pd.read_csv("review_cleaned.csv")
review.shape
# Out:
# (407592, 9)

# %%
user.head()
# Out:
#   yelping_since  useful  compliment_photos  compliment_list  compliment_funny  \
# 0    2015-05-18       5                  0                0                 0
# 1    2013-10-04       0                  0                0                 0
# 2    2016-10-21       1                  0                0                 0
# 3    2014-03-17      51                  4                0                13
# 4    2017-01-30       4                  0                0                 0
#
#    compliment_plain                     elite  fans  compliment_note  funny  \
# 0                 1                        []     0                1      2
# 1                 0                        []     0                0      0
# 2                 0                        []     0                0      0
# 3                16  [2016, 2017, 2014, 2015]    13                5     12
# 4                 0                        []     0                0      0
#
#        ...       average_stars                 user_id  compliment_more  \
# 0      ...                2.00  1iIebpwPVifig9Xi0EI8Dg                0
# 1      ...                4.36  soTbfMymlIGp9nTLiYKtxQ                0
# 2      ...                4.50  WnI11IQwx-pcjTOEejGJsg                0
# 3      ...                3.71  i5jSTSpXJtvM-ExWRttglw                1
# 4      ...                3.92  2f_pVxImXu2Y6SclpAEXZg                0
#
#                                              friends  compliment_hot cool  \
# 0                                                 []               0    0
# 1                                                 []               0    0
# 2                                                 []               0    0
# 3  [u'aLvxbF2DueKFOqul9eVWCw', u'JesJ-LaNfr3pKhL7...              10   33
# 4                                                 []               0    0
#
#       name  compliment_profile compliment_cool  review_count
# 0     Ella                   0               0             4
# 1   Heaton                   0               0             3
# 2    Alexa                   0               0             3
# 3  Evelina                   0              13            55
# 4     Alex                   0               0            11
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Because of time limitted, I cannot apply the model on all users. So I decide to apply the model on a subset of users who has more than 100 reviews on Yelp.

# %%
sample = user[user['review_count'] > 100]
sample.shape
# Out:
# (429, 22)

# %% [markdown]
# ## Notice
#
# The building time recorded below is the time needed to build 3 models for a particular user: Decision Tree with AdaBoost, ElasticNet CV and Lasso CV. It will take much shorter to build only one model. We output the result to compare the efficiency of each model for each user. Model accuracy can be as bad as having Mean Absolute Error of above 1.0 but can also be extremely good for some users, with Mean Absolute Error below 0.5. To avoid memory issue and speed up computation, I decide to divide the dataset into smaller chunks and run each chunk separately

# %%
chunks = np.array_split(sample, 10)

# %%
chunks[0]
# Out:
#      yelping_since  useful  compliment_photos  compliment_list  \
# 15      2014-06-21    4749                 41                2
# 18      2011-10-01     108                  0                1
# 22      2015-07-27     316                  8                0
# 23      2013-10-03       8                  3                0
# 24      2012-11-07      77                  1                0
# 25      2010-10-27     238                  2                8
# 37      2015-02-15      39                 19                0
# 62      2012-08-21     182                  4                0
# 65      2014-03-06      50                  3                0
# 107     2012-02-04       7                  2                0
# 142     2010-01-06      91                  0                1
# 206     2011-04-08      19                  0                0
# 285     2014-12-24      23                  0                0
# 315     2015-03-22      42                  3                0
# 332     2013-02-21      11                  2                0
# 530     2011-10-02       8                  3                0
# 687     2015-11-20       3                  0                0
# 800     2010-09-13     253                  2                1
# 841     2012-03-11      74                  6                0
# 855     2013-09-28     152                 19                0
# 916     2011-03-30      56                 16                1
# 1087    2014-09-13     421                  8                0
# 1104    2014-09-06     126                  6                1
# 1189    2010-02-21      45                  1                0
# 1273    2014-02-27       2                  0                0
# 1384    2010-04-01       3                  1                3
# 1450    2008-08-23       0                  3                0
# 1533    2010-05-28      37                  3                0
# 1962    2010-03-21      31                  0                0
# 2162    2010-03-30    2492                281               20
# 2232    2010-11-01     176                  2                3
# 2233    2008-09-27     451                 15                2
# 2237    2014-10-09      47                  0                0
# 2308    2017-02-08     222                  7                0
# 2455    2016-01-28      37                  1                0
# 2741    2014-07-09      70                  3                0
# 2990    2009-03-04     886                 16               21
# 2996    2013-07-20      67                  1                0
# 3018    2010-11-17    1280                 48                6
# 3085    2009-04-23    1814                  7                2
# 3100    2014-08-20      33                  2                0
# 3102    2011-08-13     145                  1                0
# 3372    2017-04-15      38                106                0
#
#       compliment_funny  compliment_plain  \
# 15                  54                49
# 18                  10                 7
# 22                   7                 2
# 23                   8                 8
# 24                  10                12
# 25                  19                21
# 37                   9                 8
# 62                   6                13
# 65                   6                12
# 107                 14                20
# 142                  7                14
# 206                 17                16
# 285                  1                 2
# 315                  3                 0
# 332                  6                 9
# 530                  0                 1
# 687                  2                 2
# 800                 13                21
# 841                 14                 8
# 855                 20                19
# 916                 20                22
# 1087                 5                13
# 1104                13                14
# 1189                 6                15
# 1273                53                17
# 1384                18                10
# 1450                14                 8
# 1533                21                13
# 1962                22                 4
# 2162               328              1515
# 2232                25                37
# 2233               150               128
# 2237                 5                 4
# 2308                 6                 5
# 2455                 3                 0
# 2741                 3                 6
# 2990               192               206
# 2996                10                 8
# 3018               136               380
# 3085               145               323
# 3100                 0                 1
# 3102                23                16
# 3372                69                73
#
#                                                   elite  fans  \
# 15                                   [2016, 2015, 2017]   119
# 18                       [2017, 2016, 2015, 2013, 2014]    13
# 22                                   [2016, 2015, 2017]    17
# 23                                   [2017, 2015, 2016]    12
# 24                       [2014, 2013, 2016, 2015, 2017]    22
# 25                             [2010, 2011, 2012, 2013]    17
# 37                                   [2015, 2017, 2016]    30
# 62                                   [2016, 2017, 2015]     8
# 65                             [2014, 2015, 2017, 2016]    26
# 107                            [2014, 2016, 2017, 2015]    30
# 142          [2015, 2011, 2013, 2012, 2010, 2017, 2014]     6
# 206          [2013, 2012, 2015, 2016, 2011, 2017, 2014]    14
# 285                                                  []     4
# 315                                              [2017]     9
# 332                                  [2015, 2017, 2016]     8
# 530                                                  []     6
# 687                                              [2017]     8
# 800                                        [2012, 2013]    13
# 841                            [2016, 2015, 2017, 2014]    18
# 855                                              [2017]    21
# 916          [2014, 2012, 2017, 2013, 2016, 2011, 2015]    38
# 1087                                 [2016, 2017, 2015]    14
# 1104                           [2014, 2015, 2016, 2017]    30
# 1189                                 [2015, 2017, 2016]    10
# 1273                                 [2016, 2017, 2015]    39
# 1384                     [2012, 2010, 2014, 2011, 2013]     8
# 1450                                                 []    66
# 1533               [2015, 2016, 2012, 2011, 2013, 2017]     8
# 1962                           [2010, 2011, 2012, 2013]     8
# 2162   [2015, 2017, 2010, 2011, 2012, 2013, 2014, 2016]    86
# 2232                     [2015, 2012, 2011, 2016, 2013]    14
# 2233         [2015, 2013, 2011, 2009, 2010, 2012, 2014]    49
# 2237                                 [2015, 2016, 2017]    12
# 2308                                             [2017]    18
# 2455                                             [2016]     4
# 2741                                       [2016, 2015]    10
# 2990  [2013, 2011, 2012, 2016, 2017, 2014, 2009, 201...    83
# 2996                                 [2016, 2015, 2017]     7
# 3018         [2013, 2017, 2011, 2015, 2012, 2016, 2014]    49
# 3085                     [2011, 2009, 2010, 2013, 2012]    29
# 3100                                                 []     3
# 3102         [2012, 2015, 2011, 2016, 2013, 2014, 2017]    10
# 3372                                             [2017]    59
#
#       compliment_note  funny      ...       average_stars  \
# 15                 18    312      ...                3.43
# 18                  2     18      ...                3.64
# 22                  2     27      ...                3.76
# 23                  1      4      ...                3.62
# 24                  5     35      ...                3.73
# 25                 17     47      ...                3.73
# 37                  6     14      ...                3.41
# 62                  5     27      ...                3.75
# 65                  1     30      ...                3.70
# 107                 8      6      ...                3.75
# 142                16     14      ...                3.59
# 206                 9     27      ...                3.66
# 285                13      7      ...                3.85
# 315                 2      0      ...                3.80
# 332                 1      6      ...                3.69
# 530                 4      3      ...                3.81
# 687                 0      2      ...                3.63
# 800                 6    265      ...                3.46
# 841                 9     96      ...                3.43
# 855                49     37      ...                3.86
# 916                24      4      ...                3.68
# 1087                4     74      ...                3.72
# 1104                2     97      ...                3.73
# 1189               13     10      ...                3.43
# 1273               23      2      ...                3.52
# 1384               20      0      ...                3.30
# 1450               10      0      ...                3.87
# 1533               12     14      ...                3.59
# 1962               13      6      ...                3.44
# 2162              626   4991      ...                3.20
# 2232               45     77      ...                3.81
# 2233               43    316      ...                3.79
# 2237                1      9      ...                3.18
# 2308                2     11      ...                3.78
# 2455                1      3      ...                3.09
# 2741                8     13      ...                3.32
# 2990              121    424      ...                3.32
# 2996                3     61      ...                3.84
# 3018              133    269      ...                3.16
# 3085               80    983      ...                3.90
# 3100                2     13      ...                3.69
# 3102               14     22      ...                3.77
# 3372               17      9      ...                4.11
#
#                      user_id  compliment_more  \
# 15    keLUgL_4y60BkppiAsIk8Q                5
# 18    dEDId4Rp2JpblIfYIoH00w                1
# 22    AVVEFYHmFUa9oUhy2DIQFA                2
# 23    PRJMe-RgFnCEhyy7tf3DmQ                2
# 24    VHc1yqBhsE-l3JQFXuWydQ                0
# 25    _RvEDmpbQZulEdAV590QKg                2
# 37    xYciRtVZ1PW4IxSX4oJ1aw                2
# 62    oPVY6-CJt2EI335lKWwxmg                2
# 65    t-0_us3OTzs_ZhKy6fcamg                0
# 107   7_RaCe5zzPBYWm9znlffUA                1
# 142   gSLQ-2A7b_d1JmXzN5jFzw                2
# 206   Yl7OYdHuYmr7K-IW9_ayng                4
# 285   0uNxhZAFbkalQImzJ6UDUA                0
# 315   FEg8v92qx3kK4Hu4TF28Fg                0
# 332   -od707p4FHGul0gte29AoQ                0
# 530   UByCy7oxeiqFKOLmGUVm3g                1
# 687   8Dvr-U6jCZTVGD52LwC2qA                0
# 800   -tdsrQ3QIkGmmP2n6-DTeg                3
# 841   bKTB22B8f1o7q25Sn8aN2Q                3
# 855   8C8Ml7hj1zxyhcChk1TESQ                1
# 916   NzlqN1Ca9SW5z780thoiAg                3
# 1087  t5nWD3Ya10ntwt3iWx5Kbg                0
# 1104  QlRsVCCytArycuuKSyUBLg                0
# 1189  X-VOe5bzT9EJu_L_Bt0nLQ                2
# 1273  z6gseuVl0cR7tRLQa_DXuQ                5
# 1384  C8W0VzsXaTg4YvciNTy3bg                1
# 1450  HikPdCQGk1mk5JsPjur7Nw                4
# 1533  xsBjO0GTAvZK8i2A8_z20g                2
# 1962  X5whw8WcB8dVZGZ5vGnSLg                5
# 2162  Wu0yySWcHQ5tZ_59HNiamg               68
# 2232  H3tbSSoX5FbCyKxl4Fu6gA                4
# 2233  TZelLnaGbHgaG7LBI6rfgg               11
# 2237  wky4BZxCELi4PZcvb11qYQ                0
# 2308  Plqi4pG84PA_vBM8OfDPDg                2
# 2455  d3EqggaHzuON2t7k1Z30Fg                1
# 2741  JDwWpPAaKiLpwGVjsvxAHA                1
# 2990  GERRIWMslcP4-O6mLErPSQ               31
# 2996  Tjv5bBtJ-Z_CLiY-rheG2g                0
# 3018  gwIqbXEXijQNgdESVc07hg                6
# 3085  AhoxHm569hH_PRkoegDwcA               13
# 3100  XrYTMhY9YJvzX2pMepIz7A                1
# 3102  VVm-TFCpi9M1-k8ED0l1eA                0
# 3372  TibBhm-fbksozIDFD8wjPQ                5
#
#                                                 friends  compliment_hot  cool  \
# 15    [u'vbvGTfxCNPU0Owja1h-_MQ', u'crMMCGbeSwO_hEYo...              23  5215
# 18    [u'KBVL9aPlcLVwqyFQ__EeIA', u'PGx4HvY5joEeqXza...               6    19
# 22    [u'JesJ-LaNfr3pKhL7gWhDrw', u'xttaWX-oTAK3fMoT...               6    11
# 23    [u'coGgrWwOpIqLLoa62ac6rw', u'2IEY9Qg-oljs0kaO...               5     5
# 24    [u'HARSjOK-mr6vcxTL7Rbfdw', u'alUuOskFSl1bODjn...              10    31
# 25    [u'IRZifXidb51Uh-tb17wegg', u'CIT2QNZ_i4DGjTVz...               6    49
# 37    [u'UX0Lh2n7gOiH5PVsCo1psA', u'GM7NRYBXxl3ELf8y...               8     0
# 62    [u'fiAZB5jSD_JMoq_BZbQoQw', u'0J9mtVJ4_QGsXYVK...               0    29
# 65    [u'IEB8DtKWbZFwypDHoZAB6w', u'F1FGwl41pZLnZddq...               8    13
# 107   [u'-HM3BPKTncDJlkAbGKztNw', u'hTZb1INhnCG8URaF...              12     3
# 142   [u'9wXqx1AaSeUQHe4aP1am7A', u'0yVqgzy8lkwZKzDa...               2    11
# 206   [u'0FVcoJko1kfZCrJRfssfIA', u'zvQM_xPJcLZtpeMF...              39     6
# 285   [u'h935h9SKEp62NBlrBfxczQ', u'uoLakv_DexPX4n1m...               1     2
# 315   [u'PuAsxSkm2-LRzKql373-vw', u'7GHIIZYaBp-VTNj3...               1     0
# 332   [u'C3aIEUOx-vrHAeGVDnMAjg', u'w7p4puBdqKeNv3Ed...               5     3
# 530   [u'ew1a_P9w5PMR9X3uSWxEwA', u'R72J-x5pD6K2DE7Z...               0     7
# 687   [u'ntadyQ9G0vwa7rs0AVWlNw', u'0Hv9RBOGFSFY00hh...               1     2
# 800   [u'-fEe8XBeJ6pGLIeAyAWzfw', u'p2lIWB4wG1kiOh14...               8   191
# 841   [u'fEElH8y0NX6ekcjpDnEeAQ', u'BJKWprcdWcx07bah...               8   109
# 855   [u'CjbfWpCRLbA-L_eS_ztd6Q', u'PGeiszoVusiv0wTH...               6    65
# 916   [u'rGd8YUtvhSdMm8-9cMdQ4Q', u'jrMxBHW3SlUGVGYW...              10     3
# 1087  [u'aLvxbF2DueKFOqul9eVWCw', u'XQPGXEHOpyPjPQAs...               6    21
# 1104  [u'eRDWzHCldd6YXypRECvHYg', u'0MhyfXT5yVIDeqPP...              12    53
# 1189  [u'cbODyCZEhob9eGrY_vhWoA', u'djtDYpvsNMSwz4Jp...               0    13
# 1273  [u'NamVpUTErhGNTwCVLpXooQ', u'0J9mtVJ4_QGsXYVK...               8     1
# 1384  [u'2wALX0yuVovR2kCF4hlsxw', u'SJJWIZLPGXtGTy9U...               8     0
# 1450  [u'JnPIjvC0cmooNDfsa9BmXg', u'5BcwMi-PXvjivcgC...              24     0
# 1533  [u'qQJwxCEClhscmt-W5_Be_w', u'y91UFIMOZaY6J3QV...               9    27
# 1962  [u'BGzavA_ddMr-jGmhArv7fg', u'Q9mA60HnY87C1TW5...              11     5
# 2162  [u'RqR1bGDgdOPyHDnI73LeFw', u'cPQZQGC_Rb6-xzKo...             317  2687
# 2232  [u'eEgeuz6Gg12HZkFZTfbb8A', u'mb_8jXannipO5T5V...              19   118
# 2233  [u'PhmneRPozf2cDIiFyGGlOg', u'_FXrHJ3Q5vjFKDhB...              54   233
# 2237  [u'6eCgSb66TE1LeiWPPBPnTg', u'_1UbhUyIKUxBV3pK...               5     2
# 2308  [u'J_tWHP2vBryzTkRQcgEQOw', u'Q9mA60HnY87C1TW5...               1    11
# 2455  [u'gIGdonekINnT2n_8lw-pAw', u'XCDxUzBSY8-JOvcp...               0     8
# 2741  [u'WeVkkF5L39888IPPlRhNpg', u'RpUzPj7MGSux9mZb...               2    90
# 2990  [u'mXRomu-YuObER_HJtpf_UA', u'BGzavA_ddMr-jGmh...             114   409
# 2996  [u'JesJ-LaNfr3pKhL7gWhDrw', u'bCLqNCdhUdsmTj9B...               2    45
# 3018  [u'jVYzrVblDFSuL3GHtt8ZSA', u'kbB1FfCf1NsJN-PZ...              42   962
# 3085  [u'hv3hpcM2XMbZdYN3VQLmhg', u'VMKn920nDRBFNwp-...             106  1627
# 3100  [u'zFK_l484kC5qzb4AZamIfA', u'KBVL9aPlcLVwqyFQ...               1     3
# 3102  [u'GYLIjGosx4F-ZUu7MEl8aw', u'NrpIRvSP7eonXYu_...              13    16
# 3372  [u'IjCRl0u_ZMhV8K5IG2FsGQ', u'zFYs8gSUYDvXkb6O...              26  1572
#
#              name  compliment_profile compliment_cool  review_count
# 15          Hazel                   3              54           148
# 18          Diana                   0              10           106
# 22         Andrea                   0               7           187
# 23          Ellen                   0               8           177
# 24           Paul                   0              10           175
# 25    Leslie-Anne                   0              19           101
# 37            Anh                   0               9           153
# 62        Shannon                   1               6           135
# 65           Dawn                   1               6           103
# 107         Joyce                   0              14           169
# 142         Jason                   1               7           133
# 206         Alana                   0              17           146
# 285             S                   0               1           158
# 315       Cynthia                   0               3           104
# 332         Nisha                   0               6           116
# 530           Lee                   0               0           204
# 687           Amy                   0               2           147
# 800         Julia                   1              13           110
# 841       Kristyn                   1              14           162
# 855        Danica                   1              20           144
# 916           Mel                   1              20           262
# 1087     Patricia                   0               5           110
# 1104      Shirley                   1              13           208
# 1189         Cher                   0               6           172
# 1273         Joey                   1              53           231
# 1384        Erwin                   4              18           158
# 1450         Anna                   2              14           150
# 1533       Ayesha                   0              21           156
# 1962        Leeor                   1              22           122
# 2162        WaYnE                   7             328           540
# 2232         Anni                   1              25           116
# 2233     Jonathan                  10             150           117
# 2237          Mei                   0               5           101
# 2308      Anthony                   0               6           136
# 2455         Eric                   0               3           151
# 2741        Cindy                   0               3           120
# 2990      Melissa                   8             192           279
# 2996         Lana                   1              10           162
# 3018        Elvis                   4             136           483
# 3085      Melanie                   6             145           116
# 3100        Yukie                   0               0           167
# 3102      Juliana                   0              23           220
# 3372        Wendy                   4              69           133
#
# [43 rows x 22 columns]

# %%
run_content_based.runML("Lasso", chunks[0], review, business)
# Out:
# Finish building model for user  0 , id  keLUgL_4y60BkppiAsIk8Q  in  1.0893876552581787
# Lasso mae 0.714572680789 rmse 0.8520437784228372
#
#
# Finish building model for user  1 , id  dEDId4Rp2JpblIfYIoH00w  in  0.695199728012085
# Lasso mae 0.785306275759 rmse 0.9527832775790795
#
#
# Finish building model for user  2 , id  AVVEFYHmFUa9oUhy2DIQFA  in  1.405531406402588
# Lasso mae 0.749714042341 rmse 0.933302446294179
#
#
# Finish building model for user  3 , id  PRJMe-RgFnCEhyy7tf3DmQ  in  0.8233134746551514
# Lasso mae 0.618232890705 rmse 0.7145143360711446
#
#
# Finish building model for user  4 , id  VHc1yqBhsE-l3JQFXuWydQ  in  0.8418660163879395
# Lasso mae 0.862305622804 rmse 1.0674867663034684
#
#
# Finish building model for user  5 , id  _RvEDmpbQZulEdAV590QKg  in  0.39905214309692383
# Lasso mae 0.895659589311 rmse 1.1032607666604946
#
#
# Finish building model for user  6 , id  xYciRtVZ1PW4IxSX4oJ1aw  in  0.5665521621704102
# Lasso mae 0.891141078516 rmse 1.0834118601306897
#
#
# Finish building model for user  7 , id  oPVY6-CJt2EI335lKWwxmg  in  0.6456549167633057
# Lasso mae 0.884649269836 rmse 1.0686051222978923
#
#
# Finish building model for user  8 , id  t-0_us3OTzs_ZhKy6fcamg  in  0.39959001541137695
# Lasso mae 0.824136323262 rmse 1.017519041745032
#
#
# Finish building model for user  9 , id  7_RaCe5zzPBYWm9znlffUA  in  0.9530644416809082
# Lasso mae 0.877675316452 rmse 1.1085969230159782
#
#
# Finish building model for user  10 , id  gSLQ-2A7b_d1JmXzN5jFzw  in  0.7017757892608643
# Lasso mae 0.962787561479 rmse 1.131626332222091
#
#
# Finish building model for user  11 , id  Yl7OYdHuYmr7K-IW9_ayng  in  0.7018017768859863
# Lasso mae 0.906873418586 rmse 1.0751615700739068
#
#
# Finish building model for user  12 , id  0uNxhZAFbkalQImzJ6UDUA  in  0.7792439460754395
# Lasso mae 0.672696265689 rmse 0.7862982887142901
#
#
# Finish building model for user  13 , id  FEg8v92qx3kK4Hu4TF28Fg  in  0.3903815746307373
# Lasso mae 0.774722621267 rmse 0.9504525215124497
#
#
# Finish building model for user  14 , id  -od707p4FHGul0gte29AoQ  in  0.48783040046691895
# Lasso mae 0.828228635143 rmse 1.0003424478525729
#
#
# Finish building model for user  15 , id  UByCy7oxeiqFKOLmGUVm3g  in  1.1046111583709717
# Lasso mae 0.614378969181 rmse 0.7657678006956337
#
#
# Finish building model for user  16 , id  8Dvr-U6jCZTVGD52LwC2qA  in  0.663811445236206
# Lasso mae 0.751560852044 rmse 0.945481995936849
#
#
# Finish building model for user  17 , id  -tdsrQ3QIkGmmP2n6-DTeg  in  0.5334477424621582
# Lasso mae 1.00713939887 rmse 1.1845436938362353
#
#
# Finish building model for user  18 , id  bKTB22B8f1o7q25Sn8aN2Q  in  0.8930528163909912
# Lasso mae 1.02076109192 rmse 1.2090870432977776
#
#
# Finish building model for user  19 , id  8C8Ml7hj1zxyhcChk1TESQ  in  0.7097041606903076
# Lasso mae 0.661690892715 rmse 0.8638594239775726
#
#
# Finish building model for user  20 , id  NzlqN1Ca9SW5z780thoiAg  in  3.6148643493652344
# Lasso mae 0.604685041664 rmse 0.7116421118692413
#
#
# Finish building model for user  21 , id  t5nWD3Ya10ntwt3iWx5Kbg  in  0.4655578136444092
# Lasso mae 0.827352952197 rmse 1.0471214725364475
#
#
# Finish building model for user  22 , id  QlRsVCCytArycuuKSyUBLg  in  1.7703289985656738
# Lasso mae 0.705208525393 rmse 0.8518997512657216
#
#
# Finish building model for user  23 , id  X-VOe5bzT9EJu_L_Bt0nLQ  in  1.5879840850830078
# Lasso mae 0.898361973931 rmse 1.0616253460884262
#
#
# Finish building model for user  24 , id  z6gseuVl0cR7tRLQa_DXuQ  in  2.0091006755828857
# Lasso mae 1.12152827589 rmse 1.3144956027300498
#
#
# Finish building model for user  25 , id  C8W0VzsXaTg4YvciNTy3bg  in  1.2733123302459717
# Lasso mae 0.794263739785 rmse 0.9500006875910565
#
#
# Finish building model for user  26 , id  HikPdCQGk1mk5JsPjur7Nw  in  0.6258862018585205
# Lasso mae 0.567292978706 rmse 0.7884732906254985
#
#
# Finish building model for user  27 , id  xsBjO0GTAvZK8i2A8_z20g  in  0.726837158203125
# Lasso mae 0.678868730823 rmse 0.8354322658175506
#
#
# Finish building model for user  28 , id  X5whw8WcB8dVZGZ5vGnSLg  in  0.5959949493408203
# Lasso mae 0.927604648207 rmse 1.1022732918791711
#
#
# Finish building model for user  29 , id  Wu0yySWcHQ5tZ_59HNiamg  in  3.0647826194763184
# Lasso mae 0.510931345929 rmse 0.6789345472224417
#
#
# Finish building model for user  30 , id  H3tbSSoX5FbCyKxl4Fu6gA  in  0.6781885623931885
# Lasso mae 0.792806183115 rmse 1.0263043511385783
#
#
# Finish building model for user  31 , id  TZelLnaGbHgaG7LBI6rfgg  in  0.7461538314819336
# Lasso mae 0.651957919345 rmse 0.7734394552202994
#
#
# Finish building model for user  32 , id  wky4BZxCELi4PZcvb11qYQ  in  0.3834192752838135
# Lasso mae 0.925536077983 rmse 1.0869754343375304
#
#
# Finish building model for user  33 , id  Plqi4pG84PA_vBM8OfDPDg  in  0.8473114967346191
# Lasso mae 0.613850655156 rmse 0.7941328227133462
#
#
# Finish building model for user  34 , id  d3EqggaHzuON2t7k1Z30Fg  in  0.6545839309692383
# Lasso mae 0.922075810011 rmse 1.1042141859971206
#
#
# Finish building model for user  35 , id  JDwWpPAaKiLpwGVjsvxAHA  in  0.4975454807281494
# Lasso mae 0.74 rmse 0.8920537402207567
#
#
# Finish building model for user  36 , id  GERRIWMslcP4-O6mLErPSQ  in  3.215003728866577
# Lasso mae 0.793591177725 rmse 0.9495952853887399
#
#
# Finish building model for user  37 , id  Tjv5bBtJ-Z_CLiY-rheG2g  in  0.795612096786499
# Lasso mae 0.601406891271 rmse 0.7236075624986225
#
#
# Finish building model for user  38 , id  gwIqbXEXijQNgdESVc07hg  in  4.041738271713257
# Lasso mae 0.668267252748 rmse 0.8220489971341245
#
#
# Finish building model for user  39 , id  AhoxHm569hH_PRkoegDwcA  in  0.5243852138519287
# Lasso mae 0.712607011533 rmse 0.9551000520584108
#
#
# Finish building model for user  40 , id  XrYTMhY9YJvzX2pMepIz7A  in  1.000624418258667
# Lasso mae 0.836804475146 rmse 1.01292830200487
#
#
# Finish building model for user  41 , id  VVm-TFCpi9M1-k8ED0l1eA  in  1.7563669681549072
# Lasso mae 0.795732096554 rmse 0.9937804128542622
#
#
# Finish building model for user  42 , id  TibBhm-fbksozIDFD8wjPQ  in  0.6392726898193359
# Lasso mae 0.448876410485 rmse 0.6364168977161386
# {'Lasso': {'mae': 0.77776379000643503, 'rmse': 0.9517823558964789}}

# %%
run_content_based.runML("ElasticNet",chunks[0], review, business)
# Out:
# Finish building model for user  0 , id  keLUgL_4y60BkppiAsIk8Q  in  0.771228551864624
# ElasticNet mae 0.714572680789 rmse 0.8520437784228372
#
#
# Finish building model for user  1 , id  dEDId4Rp2JpblIfYIoH00w  in  0.6398591995239258
# ElasticNet mae 0.786321601013 rmse 0.9546617269719768
#
#
# Finish building model for user  2 , id  AVVEFYHmFUa9oUhy2DIQFA  in  1.4038844108581543
# ElasticNet mae 0.749792521079 rmse 0.9320969887358531
#
#
# Finish building model for user  3 , id  PRJMe-RgFnCEhyy7tf3DmQ  in  0.7305912971496582
# ElasticNet mae 0.618232890705 rmse 0.7145143360711446
#
#
# Finish building model for user  4 , id  VHc1yqBhsE-l3JQFXuWydQ  in  0.5723516941070557
# ElasticNet mae 0.863234056095 rmse 1.0677456137002381
#
#
# Finish building model for user  5 , id  _RvEDmpbQZulEdAV590QKg  in  0.4393491744995117
# ElasticNet mae 0.894204960767 rmse 1.1011165493583164
#
#
# Finish building model for user  6 , id  xYciRtVZ1PW4IxSX4oJ1aw  in  0.5558981895446777
# ElasticNet mae 0.8975216841 rmse 1.095413587983877
#
#
# Finish building model for user  7 , id  oPVY6-CJt2EI335lKWwxmg  in  0.601409912109375
# ElasticNet mae 0.885429594903 rmse 1.0641397873315848
#
#
# Finish building model for user  8 , id  t-0_us3OTzs_ZhKy6fcamg  in  0.4384274482727051
# ElasticNet mae 0.824304313864 rmse 1.018613380062602
#
#
# Finish building model for user  9 , id  7_RaCe5zzPBYWm9znlffUA  in  0.6346609592437744
# ElasticNet mae 0.921024155853 rmse 1.1410303807682973
#
#
# Finish building model for user  10 , id  gSLQ-2A7b_d1JmXzN5jFzw  in  0.40991854667663574
# ElasticNet mae 0.955524395556 rmse 1.1198474447171638
#
#
# Finish building model for user  11 , id  Yl7OYdHuYmr7K-IW9_ayng  in  0.5672259330749512
# ElasticNet mae 0.903974362362 rmse 1.0770595121369375
#
#
# Finish building model for user  12 , id  0uNxhZAFbkalQImzJ6UDUA  in  0.7843868732452393
# ElasticNet mae 0.673438016028 rmse 0.7856792748159789
#
#
# Finish building model for user  13 , id  FEg8v92qx3kK4Hu4TF28Fg  in  0.3417031764984131
# ElasticNet mae 0.765735580032 rmse 0.9458832908146875
#
#
# Finish building model for user  14 , id  -od707p4FHGul0gte29AoQ  in  0.3905332088470459
# ElasticNet mae 0.830003223576 rmse 0.9998943175381036
#
#
# Finish building model for user  15 , id  UByCy7oxeiqFKOLmGUVm3g  in  0.8883769512176514
# ElasticNet mae 0.609998369283 rmse 0.7640635340139961
#
#
# Finish building model for user  16 , id  8Dvr-U6jCZTVGD52LwC2qA  in  0.4215362071990967
# ElasticNet mae 0.743666873629 rmse 0.9370585552588448
#
#
# Finish building model for user  17 , id  -tdsrQ3QIkGmmP2n6-DTeg  in  0.43131542205810547
# ElasticNet mae 1.00681510156 rmse 1.1852778704352152
#
#
# Finish building model for user  18 , id  bKTB22B8f1o7q25Sn8aN2Q  in  0.6535604000091553
# ElasticNet mae 1.02121510783 rmse 1.2051104879797514
#
#
# Finish building model for user  19 , id  8C8Ml7hj1zxyhcChk1TESQ  in  0.6687793731689453
# ElasticNet mae 0.655173118333 rmse 0.8568255003071457
#
#
# Finish building model for user  20 , id  NzlqN1Ca9SW5z780thoiAg  in  1.977067470550537
# ElasticNet mae 0.604685041664 rmse 0.7116421118692413
#
#
# Finish building model for user  21 , id  t5nWD3Ya10ntwt3iWx5Kbg  in  0.47015929222106934
# ElasticNet mae 0.828482912928 rmse 1.0439855239995133
#
#
# Finish building model for user  22 , id  QlRsVCCytArycuuKSyUBLg  in  1.0179367065429688
# ElasticNet mae 0.718158967984 rmse 0.8639170490412451
#
#
# Finish building model for user  23 , id  X-VOe5bzT9EJu_L_Bt0nLQ  in  0.7638504505157471
# ElasticNet mae 0.899189235773 rmse 1.0620847742985235
#
#
# Finish building model for user  24 , id  z6gseuVl0cR7tRLQa_DXuQ  in  1.215069055557251
# ElasticNet mae 1.11882831935 rmse 1.3098292461873076
#
#
# Finish building model for user  25 , id  C8W0VzsXaTg4YvciNTy3bg  in  1.1192874908447266
# ElasticNet mae 0.794263739785 rmse 0.9500006875910565
#
#
# Finish building model for user  26 , id  HikPdCQGk1mk5JsPjur7Nw  in  0.9529564380645752
# ElasticNet mae 0.58337922112 rmse 0.8027986743412372
#
#
# Finish building model for user  27 , id  xsBjO0GTAvZK8i2A8_z20g  in  0.5661160945892334
# ElasticNet mae 0.686395995388 rmse 0.8113984256312088
#
#
# Finish building model for user  28 , id  X5whw8WcB8dVZGZ5vGnSLg  in  0.3382275104522705
# ElasticNet mae 0.92409896332 rmse 1.0984114742796165
#
#
# Finish building model for user  29 , id  Wu0yySWcHQ5tZ_59HNiamg  in  2.043855905532837
# ElasticNet mae 0.512277948244 rmse 0.6856299044694658
#
#
# Finish building model for user  30 , id  H3tbSSoX5FbCyKxl4Fu6gA  in  0.49277353286743164
# ElasticNet mae 0.788806839785 rmse 1.0317604271573064
#
#
# Finish building model for user  31 , id  TZelLnaGbHgaG7LBI6rfgg  in  0.4628288745880127
# ElasticNet mae 0.651957919345 rmse 0.7734394552202994
#
#
# Finish building model for user  32 , id  wky4BZxCELi4PZcvb11qYQ  in  0.3037078380584717
# ElasticNet mae 0.924768330804 rmse 1.0846443551517726
#
#
# Finish building model for user  33 , id  Plqi4pG84PA_vBM8OfDPDg  in  0.42306995391845703
# ElasticNet mae 0.617863920127 rmse 0.7974850346308117
#
#
# Finish building model for user  34 , id  d3EqggaHzuON2t7k1Z30Fg  in  0.4281575679779053
# ElasticNet mae 0.922143893625 rmse 1.1041876386654987
#
#
# Finish building model for user  35 , id  JDwWpPAaKiLpwGVjsvxAHA  in  0.3124246597290039
# ElasticNet mae 0.736448277911 rmse 0.8889141509071852
#
#
# Finish building model for user  36 , id  GERRIWMslcP4-O6mLErPSQ  in  2.1278040409088135
# ElasticNet mae 0.822809070772 rmse 0.9815124138034788
#
#
# Finish building model for user  37 , id  Tjv5bBtJ-Z_CLiY-rheG2g  in  0.7296204566955566
# ElasticNet mae 0.602445670846 rmse 0.7332929301446194
#
#
# Finish building model for user  38 , id  gwIqbXEXijQNgdESVc07hg  in  3.5871684551239014
# ElasticNet mae 0.669089895706 rmse 0.828587067933317
#
#
# Finish building model for user  39 , id  AhoxHm569hH_PRkoegDwcA  in  0.3158261775970459
# ElasticNet mae 0.737514863258 rmse 0.9733615966705782
#
#
# Finish building model for user  40 , id  XrYTMhY9YJvzX2pMepIz7A  in  0.9562745094299316
# ElasticNet mae 0.853529074965 rmse 1.0308480945546377
#
#
# Finish building model for user  41 , id  VVm-TFCpi9M1-k8ED0l1eA  in  2.120957612991333
# ElasticNet mae 0.804560416018 rmse 1.0050754744023793
#
#
# Finish building model for user  42 , id  TibBhm-fbksozIDFD8wjPQ  in  0.5766141414642334
# ElasticNet mae 0.454234436728 rmse 0.638481911067952
# {'ElasticNet': {'mae': 0.78083989680936561, 'rmse': 0.9541712637079721}}

# %%
run_content_based.runML("Lasso", chunks[1], review, business)
# Out:
# Finish building model for user  0 , id  hrA2TKOiPrJ0Va3ceAgq9g  in  0.4223482608795166
# Lasso mae 0.856392219497 rmse 1.1328327507207516
#
#
# Finish building model for user  1 , id  7HFkF9A2xaHxLqwcFnJ0JQ  in  0.5073573589324951
# Lasso mae 0.870419714589 rmse 1.0891128263929963
#
#
# Finish building model for user  2 , id  VswgrudhENYcAr8KpE4JOw  in  0.6542892456054688
# Lasso mae 1.00595041322 rmse 1.1934298351506676
#
#
# Finish building model for user  3 , id  m7z-tX6XDZ27xGhGjnI21w  in  3.6502017974853516
# Lasso mae 0.899516818627 rmse 1.1106848270104883
#
#
# Finish building model for user  4 , id  pn_flI3EBNugBEYFp9okxQ  in  1.2376806735992432
# Lasso mae 0.702080278084 rmse 0.8233245429978403
#
#
# Finish building model for user  5 , id  GQ8l3o7-_jL0WNHUkNlhJA  in  1.387911081314087
# Lasso mae 0.608086419288 rmse 0.7279508328817785
#
#
# Finish building model for user  6 , id  KnkiyXZDt8hVdq_kw1iWuw  in  0.4756333827972412
# Lasso mae 1.17136422298 rmse 1.339658619386098
#
#
# Finish building model for user  7 , id  4bxhIKz9ePWqD93UkEjnbg  in  0.7309324741363525
# Lasso mae 0.953257976963 rmse 1.1402108371534565
#
#
# Finish building model for user  8 , id  TvenTNXyYtMNtED0i2tXfA  in  0.6257426738739014
# Lasso mae 0.67234375 rmse 0.7928596690363312
#
#
# Finish building model for user  9 , id  j55ySt8CuDQ0bahoVBAb_A  in  0.584650993347168
# Lasso mae 0.691913566496 rmse 0.9090129975258527
#
#
# Finish building model for user  10 , id  PGx4HvY5joEeqXzam6tO7A  in  0.8207700252532959
# Lasso mae 0.944406314345 rmse 1.1202684176420608
#
#
# Finish building model for user  11 , id  697iJkhX1mkVF9RNhn114Q  in  0.4212629795074463
# Lasso mae 1.05749155798 rmse 1.2399392681665793
#
#
# Finish building model for user  12 , id  4hiLotPELiIRugUtWC9L6A  in  0.514348030090332
# Lasso mae 0.929999659745 rmse 1.1143491836309374
#
#
# Finish building model for user  13 , id  LiNx18WUre9WFCEQlUhtKA  in  0.36211538314819336
# Lasso mae 0.59011932932 rmse 0.8203511679843339
#
#
# Finish building model for user  14 , id  BFcBwoxpkKGUIeUzOU0rRA  in  0.673445463180542
# Lasso mae 0.815754431382 rmse 1.0471363536963578
#
#
# Finish building model for user  15 , id  clmrlflES5HrXS-gl_YmrQ  in  2.6425156593322754
# Lasso mae 0.666420841996 rmse 0.8694500660124438
#
#
# Finish building model for user  16 , id  gPK2AKr-UA_7hZus80SSng  in  1.0478477478027344
# Lasso mae 0.758929771569 rmse 0.9339487951980541
#
#
# Finish building model for user  17 , id  bPUpO-bP6BmAGvSwPyDsng  in  0.5150976181030273
# Lasso mae 0.62585733882 rmse 0.7272750915360826
#
#
# Finish building model for user  18 , id  e0AUdCu-jeOkLImiEzlTDg  in  0.7478513717651367
# Lasso mae 0.719037548287 rmse 0.8689023205759279
#
#
# Finish building model for user  19 , id  3uWCWMWcrn8YSH_qBvlr6w  in  0.7209873199462891
# Lasso mae 0.748323214469 rmse 0.9152544450635869
#
#
# Finish building model for user  20 , id  fM9LC2P8jQrQGGsXKccLQw  in  0.46888065338134766
# Lasso mae 0.781957633309 rmse 0.9600330538785433
#
#
# Finish building model for user  21 , id  TbhyP24zYZqZ2VJZgu1wrg  in  4.4337122440338135
# Lasso mae 0.690255486111 rmse 0.8439260771287959
#
#
# Finish building model for user  22 , id  CvIEHZF79KLrpNachZzDjA  in  0.6925904750823975
# Lasso mae 0.744757899111 rmse 0.9505333630905453
#
#
# Finish building model for user  23 , id  8HCEPF0IflyB690Q745fKg  in  3.0321478843688965
# Lasso mae 0.634285144554 rmse 0.7898701800392178
#
#
# Finish building model for user  24 , id  E1hLHq6LZ6AoSJzW-oT4FQ  in  0.43547654151916504
# Lasso mae 1.45388888889 rmse 1.6205606012804474
#
#
# Finish building model for user  25 , id  dn56tvnl3NIWcAE5-r-oJw  in  0.5327563285827637
# Lasso mae 0.735230021185 rmse 0.8599151258547226
#
#
# Finish building model for user  26 , id  RrLRd9M2Q6iYCNnKMZsdtw  in  1.2133400440216064
# Lasso mae 0.972222222222 rmse 1.1605848149574907
#
#
# Finish building model for user  27 , id  jwctwzboGhQmtC50Juxa9A  in  2.2650415897369385
# Lasso mae 0.610145385588 rmse 0.8393642938925011
#
#
# Finish building model for user  28 , id  vJGLEHyhCs9V-5fAe-xx3w  in  0.6668140888214111
# Lasso mae 0.953041509077 rmse 1.1273379269767092
#
#
# Finish building model for user  29 , id  -pXs08gJq9ExIk275YLvPg  in  0.8323280811309814
# Lasso mae 0.873439571542 rmse 1.0960480456709516
#
#
# Finish building model for user  30 , id  bi50oVCy6pJBCEXHdhyOFA  in  0.9633753299713135
# Lasso mae 0.747599451303 rmse 0.9711852044628572
#
#
# Finish building model for user  31 , id  k58KNO8Rya-q8njKq8-uBQ  in  0.3576807975769043
# Lasso mae 0.881833821142 rmse 1.0587761882602622
#
#
# Finish building model for user  32 , id  1FB1Vc4zne5AJAliqdMeWA  in  0.4937422275543213
# Lasso mae 0.857241964212 rmse 1.0383516374159643
#
#
# Finish building model for user  33 , id  bJTKxBIvb_AR8d4SuLPV8g  in  0.4961874485015869
# Lasso mae 0.664337543671 rmse 0.7705361891662104
#
#
# Finish building model for user  34 , id  Xrkgx8ImTTwVGk5fTaLyBw  in  0.3130977153778076
# Lasso mae 0.716140251449 rmse 0.8559677117299478
#
#
# Finish building model for user  35 , id  dmXpg_unok3cL3eW3RI0fA  in  0.6814320087432861
# Lasso mae 0.737332927696 rmse 0.9914618451292707
#
#
# Finish building model for user  36 , id  eSc8pCT0H1ThVV89dfq6Qw  in  0.6425471305847168
# Lasso mae 0.704737321094 rmse 0.866322693976529
#
#
# Finish building model for user  37 , id  DKolrsBSwMTpTJL22dqJRQ  in  0.49848437309265137
# Lasso mae 0.774981219382 rmse 0.9369790512739417
#
#
# Finish building model for user  38 , id  Uwu72w77MPox942_GnCS7g  in  0.8856611251831055
# Lasso mae 0.845264019026 rmse 1.0260026060981546
#
#
# Finish building model for user  39 , id  nyl_1VcRIAyI55bb_scpdw  in  0.8134849071502686
# Lasso mae 0.590902219823 rmse 0.7818685109160379
#
#
# Finish building model for user  40 , id  WBCG29Wa-amEZPnoAGqYgg  in  0.8506577014923096
# Lasso mae 1.00667505568 rmse 1.2233604434551122
#
#
# Finish building model for user  41 , id  J_RQWDyPi_Gd2bbJREkxbw  in  0.4638054370880127
# Lasso mae 0.907407407407 rmse 1.0875373661915946
#
#
# Finish building model for user  42 , id  h3SfoZcs04WnJErnFaeBpQ  in  0.6404750347137451
# Lasso mae 0.7274078478 rmse 0.8583835414918435
# {'Lasso': {'mae': 0.81159884183555997, 'rmse': 0.991415333025588}}

# %%
run_content_based.runML("ElasticNet", chunks[1], review, business)
# Out:
# Finish building model for user  0 , id  hrA2TKOiPrJ0Va3ceAgq9g  in  0.3314840793609619
# ElasticNet mae 0.896730438223 rmse 1.1751297701473105
#
#
# Finish building model for user  1 , id  7HFkF9A2xaHxLqwcFnJ0JQ  in  0.3507866859436035
# ElasticNet mae 0.871571105647 rmse 1.0899699226473112
#
#
# Finish building model for user  2 , id  VswgrudhENYcAr8KpE4JOw  in  0.32793235778808594
# ElasticNet mae 1.00595041322 rmse 1.1934298351506676
#
#
# Finish building model for user  3 , id  m7z-tX6XDZ27xGhGjnI21w  in  2.033470869064331
# ElasticNet mae 0.902943947016 rmse 1.1035792185000939
#
#
# Finish building model for user  4 , id  pn_flI3EBNugBEYFp9okxQ  in  0.9394357204437256
# ElasticNet mae 0.703400513081 rmse 0.8235851506097747
#
#
# Finish building model for user  5 , id  GQ8l3o7-_jL0WNHUkNlhJA  in  1.1027348041534424
# ElasticNet mae 0.640740606843 rmse 0.7562513505833819
#
#
# Finish building model for user  6 , id  KnkiyXZDt8hVdq_kw1iWuw  in  0.4791388511657715
# ElasticNet mae 1.17811282581 rmse 1.346855009472239
#
#
# Finish building model for user  7 , id  4bxhIKz9ePWqD93UkEjnbg  in  0.4804799556732178
# ElasticNet mae 0.950546321647 rmse 1.1411966084425917
#
#
# Finish building model for user  8 , id  TvenTNXyYtMNtED0i2tXfA  in  0.5978672504425049
# ElasticNet mae 0.67234375 rmse 0.7928596690363312
#
#
# Finish building model for user  9 , id  j55ySt8CuDQ0bahoVBAb_A  in  0.428727388381958
# ElasticNet mae 0.693609563724 rmse 0.9098267037321313
#
#
# Finish building model for user  10 , id  PGx4HvY5joEeqXzam6tO7A  in  0.6317610740661621
# ElasticNet mae 0.944406314345 rmse 1.1202684176420608
#
#
# Finish building model for user  11 , id  697iJkhX1mkVF9RNhn114Q  in  0.3124508857727051
# ElasticNet mae 1.05409930172 rmse 1.23727078088016
#
#
# Finish building model for user  12 , id  4hiLotPELiIRugUtWC9L6A  in  0.3374924659729004
# ElasticNet mae 0.930799823184 rmse 1.1152769182131816
#
#
# Finish building model for user  13 , id  LiNx18WUre9WFCEQlUhtKA  in  0.32807207107543945
# ElasticNet mae 0.593438480447 rmse 0.8092589972537239
#
#
# Finish building model for user  14 , id  BFcBwoxpkKGUIeUzOU0rRA  in  0.5006942749023438
# ElasticNet mae 0.810587269477 rmse 1.0409682220278043
#
#
# Finish building model for user  15 , id  clmrlflES5HrXS-gl_YmrQ  in  1.5531361103057861
# ElasticNet mae 0.665278151035 rmse 0.868010996839885
#
#
# Finish building model for user  16 , id  gPK2AKr-UA_7hZus80SSng  in  0.793447732925415
# ElasticNet mae 0.759496955602 rmse 0.9374208720552648
#
#
# Finish building model for user  17 , id  bPUpO-bP6BmAGvSwPyDsng  in  0.4218013286590576
# ElasticNet mae 0.62585733882 rmse 0.7272750915360826
#
#
# Finish building model for user  18 , id  e0AUdCu-jeOkLImiEzlTDg  in  0.46062302589416504
# ElasticNet mae 0.717404086939 rmse 0.8681034639313429
#
#
# Finish building model for user  19 , id  3uWCWMWcrn8YSH_qBvlr6w  in  0.4999074935913086
# ElasticNet mae 0.734959486563 rmse 0.8981926590153244
#
#
# Finish building model for user  20 , id  fM9LC2P8jQrQGGsXKccLQw  in  0.4237799644470215
# ElasticNet mae 0.781957633309 rmse 0.9600330538785433
#
#
# Finish building model for user  21 , id  TbhyP24zYZqZ2VJZgu1wrg  in  3.202636241912842
# ElasticNet mae 0.720364823901 rmse 0.8722225254116975
#
#
# Finish building model for user  22 , id  CvIEHZF79KLrpNachZzDjA  in  0.46541428565979004
# ElasticNet mae 0.757656074533 rmse 0.9521221485762146
#
#
# Finish building model for user  23 , id  8HCEPF0IflyB690Q745fKg  in  1.8275935649871826
# ElasticNet mae 0.68146294915 rmse 0.8402870293918128
#
#
# Finish building model for user  24 , id  E1hLHq6LZ6AoSJzW-oT4FQ  in  0.34394216537475586
# ElasticNet mae 1.45388888889 rmse 1.6205606012804474
#
#
# Finish building model for user  25 , id  dn56tvnl3NIWcAE5-r-oJw  in  0.34995102882385254
# ElasticNet mae 0.736946899344 rmse 0.8625840176787206
#
#
# Finish building model for user  26 , id  RrLRd9M2Q6iYCNnKMZsdtw  in  0.9679641723632812
# ElasticNet mae 0.972222222222 rmse 1.1605848149574907
#
#
# Finish building model for user  27 , id  jwctwzboGhQmtC50Juxa9A  in  1.4544503688812256
# ElasticNet mae 0.610145385588 rmse 0.8393642938925011
#
#
# Finish building model for user  28 , id  vJGLEHyhCs9V-5fAe-xx3w  in  0.46864843368530273
# ElasticNet mae 0.951874678331 rmse 1.1273611286261698
#
#
# Finish building model for user  29 , id  -pXs08gJq9ExIk275YLvPg  in  0.6573834419250488
# ElasticNet mae 0.847999752935 rmse 1.0653333536133667
#
#
# Finish building model for user  30 , id  bi50oVCy6pJBCEXHdhyOFA  in  0.6814911365509033
# ElasticNet mae 0.747599451303 rmse 0.9711852044628572
#
#
# Finish building model for user  31 , id  k58KNO8Rya-q8njKq8-uBQ  in  0.31790590286254883
# ElasticNet mae 0.877656679158 rmse 1.05311707921022
#
#
# Finish building model for user  32 , id  1FB1Vc4zne5AJAliqdMeWA  in  0.3584578037261963
# ElasticNet mae 0.862481661633 rmse 1.0388119736629826
#
#
# Finish building model for user  33 , id  bJTKxBIvb_AR8d4SuLPV8g  in  0.40452051162719727
# ElasticNet mae 0.664337543671 rmse 0.7705361891662104
#
#
# Finish building model for user  34 , id  Xrkgx8ImTTwVGk5fTaLyBw  in  0.2796299457550049
# ElasticNet mae 0.715795062098 rmse 0.8570786309735896
#
#
# Finish building model for user  35 , id  dmXpg_unok3cL3eW3RI0fA  in  0.3905344009399414
# ElasticNet mae 0.735622173528 rmse 0.98053994701671
#
#
# Finish building model for user  36 , id  eSc8pCT0H1ThVV89dfq6Qw  in  0.488386869430542
# ElasticNet mae 0.704455533668 rmse 0.8663322854739375
#
#
# Finish building model for user  37 , id  DKolrsBSwMTpTJL22dqJRQ  in  0.34995126724243164
# ElasticNet mae 0.774657475301 rmse 0.9367933634662498
#
#
# Finish building model for user  38 , id  Uwu72w77MPox942_GnCS7g  in  0.6784114837646484
# ElasticNet mae 0.85693207491 rmse 1.0277073492251252
#
#
# Finish building model for user  39 , id  nyl_1VcRIAyI55bb_scpdw  in  0.6524720191955566
# ElasticNet mae 0.60561126553 rmse 0.7803137931823458
#
#
# Finish building model for user  40 , id  WBCG29Wa-amEZPnoAGqYgg  in  0.48334455490112305
# ElasticNet mae 0.996476337035 rmse 1.2110822835935275
#
#
# Finish building model for user  41 , id  J_RQWDyPi_Gd2bbJREkxbw  in  0.30367159843444824
# ElasticNet mae 0.907927786373 rmse 1.0880365027218684
#
#
# Finish building model for user  42 , id  h3SfoZcs04WnJErnFaeBpQ  in  0.3551497459411621
# ElasticNet mae 0.7274078478 rmse 0.8583835414918435
# {'ElasticNet': {'mae': 0.81497109054797012, 'rmse': 0.9929093202016535}}

# %%
run_content_based.runML("Lasso", chunks[2], review, business)
# Out:
# Finish building model for user  0 , id  4D6LLuJfao_eHGA6XZR-bA  in  0.5578606128692627
# Lasso mae 0.80141128214 rmse 1.0326875663166746
#
#
# Finish building model for user  1 , id  dSTRQSeCqMTbs7l8KF_xJg  in  0.6844873428344727
# Lasso mae 0.740531688995 rmse 0.9873650610778315
#
#
# Finish building model for user  2 , id  Vqp0dpug9Db-kFHO3PkAaQ  in  0.6152808666229248
# Lasso mae 0.607897153352 rmse 0.755058950237318
#
#
# Finish building model for user  3 , id  MylxjEKiTeaWb-GAaPA-zA  in  0.5622203350067139
# Lasso mae 0.639228181343 rmse 0.7945165567607853
#
#
# Finish building model for user  4 , id  eY6TPklHTeOaQt9F8a_SGQ  in  2.6102893352508545
# Lasso mae 0.819008264463 rmse 0.9679563171765793
#
#
# Finish building model for user  5 , id  EGJXgD6YPieaUCQxfOdXbg  in  2.771695852279663
# Lasso mae 0.805606139438 rmse 0.9795044230314403
#
#
# Finish building model for user  6 , id  1tVRQliYQ_Xw4YGy52njwg  in  0.6031460762023926
# Lasso mae 0.543442972511 rmse 0.7671036318419044
#
#
# Finish building model for user  7 , id  DkLSyxogCcJXY5DbTZ-f2A  in  0.44398021697998047
# Lasso mae 0.72616114779 rmse 0.9450259392935524
#
#
# Finish building model for user  8 , id  26WgdHfEjWj4BrN-cUNhVw  in  0.810297966003418
# Lasso mae 0.66342236306 rmse 0.8393770228405841
#
#
# Finish building model for user  9 , id  nCRPCQE7E1PV83uQrIf7Cw  in  1.2515804767608643
# Lasso mae 0.685155708168 rmse 0.8311573554168579
#
#
# Finish building model for user  10 , id  0gtEsazPeHr5rj2IAsZePg  in  1.5816574096679688
# Lasso mae 0.606741573034 rmse 0.753570415784665
#
#
# Finish building model for user  11 , id  UmTMCfPlhA6kJLAsLycSfg  in  0.470531702041626
# Lasso mae 0.587484784236 rmse 0.7253733095838091
#
#
# Finish building model for user  12 , id  zh7csWc3GAUksnShzGp-WQ  in  0.6358094215393066
# Lasso mae 0.722136284925 rmse 0.8693710134919528
#
#
# Finish building model for user  13 , id  Nq6e5N8bjgD9B46O4va_zA  in  2.4988415241241455
# Lasso mae 0.5554428542 rmse 0.7502708029029932
#
#
# Finish building model for user  14 , id  ltg5Pgd5x7K7zpYtXxMPZA  in  0.6796026229858398
# Lasso mae 0.906057663954 rmse 1.0780827219267353
#
#
# Finish building model for user  15 , id  Ko4y7jIissMR8ZGQlMdpaA  in  0.5067074298858643
# Lasso mae 0.973871437829 rmse 1.179328921150302
#
#
# Finish building model for user  16 , id  6btMczuTVuoJnmarbkWP_A  in  0.8414962291717529
# Lasso mae 1.01631825626 rmse 1.1766398319872526
#
#
# Finish building model for user  17 , id  djpMXOA1ic5wv3FPtubHNw  in  0.6363959312438965
# Lasso mae 0.766953997012 rmse 0.9047809541451431
#
#
# Finish building model for user  18 , id  P2E31XC7SP4v_3hXC2o0Xw  in  1.6139514446258545
# Lasso mae 0.691686034101 rmse 0.8574247448925212
#
#
# Finish building model for user  19 , id  mXMVfThnmi6dnKq9NlC2ug  in  0.427349328994751
# Lasso mae 0.830959419511 rmse 1.038051399514834
#
#
# Finish building model for user  20 , id  xXyZPAbfQzYTCig7jnZO0A  in  0.7170915603637695
# Lasso mae 0.826203397222 rmse 0.9977278348885299
#
#
# Finish building model for user  21 , id  0rDG0uZHpqxJbdu-FJ3IgA  in  0.44076108932495117
# Lasso mae 0.914744933613 rmse 1.113121848974638
#
#
# Finish building model for user  22 , id  wskTNZjwiqMJOvM_-XAQZw  in  0.6990668773651123
# Lasso mae 0.524182157178 rmse 0.7943108252199619
#
#
# Finish building model for user  23 , id  Hci2c0qo98CO-Pv-VmV7gg  in  1.8748087882995605
# Lasso mae 0.648851361293 rmse 0.8437347721052398
#
#
# Finish building model for user  24 , id  DuzZ68TZWlQ3mALJZ0ASVQ  in  0.38327550888061523
# Lasso mae 0.751109467456 rmse 0.9128757252935299
#
#
# Finish building model for user  25 , id  pvwEROiu2kfTqyp6cG2HIA  in  0.9330196380615234
# Lasso mae 1.12600751795 rmse 1.3253261941347505
#
#
# Finish building model for user  26 , id  yeX7tzZZWCnphQifRJglUg  in  0.8969936370849609
# Lasso mae 1.13591695502 rmse 1.3102225177966167
#
#
# Finish building model for user  27 , id  BGzavA_ddMr-jGmhArv7fg  in  3.422483205795288
# Lasso mae 0.655291151091 rmse 0.7955130174825283
#
#
# Finish building model for user  28 , id  Z09rco1enQXNCd9H0u7kvg  in  0.7882006168365479
# Lasso mae 0.65991398823 rmse 0.8524665662788649
#
#
# Finish building model for user  29 , id  mnJvynzRIYptrjyKtEBiTA  in  1.1247141361236572
# Lasso mae 0.81494108225 rmse 0.9746759202604043
#
#
# Finish building model for user  30 , id  t2O6rs4fZeY9o6ZY52RyJA  in  0.9622480869293213
# Lasso mae 0.713684616868 rmse 0.8745527496792469
#
#
# Finish building model for user  31 , id  QPJJohtGqkMkaN0Gt3TRIg  in  0.7349238395690918
# Lasso mae 0.619167412474 rmse 0.8551585718906869
#
#
# Finish building model for user  32 , id  Q9mA60HnY87C1TW5kjAZ6Q  in  3.076956033706665
# Lasso mae 0.56879992973 rmse 0.7198820719574346
#
#
# Finish building model for user  33 , id  YRcaNlwQ6XXPFDXWtuMGdA  in  3.5305869579315186
# Lasso mae 0.810577695667 rmse 0.956431258875901
#
#
# Finish building model for user  34 , id  pJYRi9MB06aiuL-w8Ms-Og  in  1.098139762878418
# Lasso mae 0.762875320768 rmse 0.9320436025901969
#
#
# Finish building model for user  35 , id  jlu4CztcSxrKx56ba1a5AQ  in  1.09248948097229
# Lasso mae 0.776279670297 rmse 0.9560232823080308
#
#
# Finish building model for user  36 , id  BqAMAM9wkjUyOJzqYOHg5g  in  0.36934947967529297
# Lasso mae 0.643586118186 rmse 0.8163176410546774
#
#
# Finish building model for user  37 , id  CxDOIDnH8gp9KXzpBHJYXw  in  7.621370792388916
# Lasso mae 0.503788144768 rmse 0.6336498556667836
#
#
# Finish building model for user  38 , id  V4TPbscN8JsFbEFiwOVBKw  in  3.268573760986328
# Lasso mae 0.703219538875 rmse 0.8437208126924831
#
#
# Finish building model for user  39 , id  FFFeLM5rk29RZn6FmGlHYQ  in  1.5438251495361328
# Lasso mae 0.805504500549 rmse 0.9640497632844802
#
#
# Finish building model for user  40 , id  FREeRQtjdJU83AFtdETBBw  in  4.47902774810791
# Lasso mae 0.716632302211 rmse 0.8380174014399556
#
#
# Finish building model for user  41 , id  cCpiu1GqdzxlvANKuiAp0Q  in  0.7684762477874756
# Lasso mae 0.641346083845 rmse 0.7947905486328257
#
#
# Finish building model for user  42 , id  wdeWt5VqTW26PAeQsVg73g  in  0.5892441272735596
# Lasso mae 0.530388471178 rmse 0.7526661179282432
# {'Lasso': {'mae': 0.73354718658234785, 'rmse': 0.909068042786273}}

# %%
run_content_based.runML("ElasticNet", chunks[2], review, business)
# Out:
# Finish building model for user  0 , id  4D6LLuJfao_eHGA6XZR-bA  in  0.5325782299041748
# ElasticNet mae 0.794844144002 rmse 1.0320717451132446
#
#
# Finish building model for user  1 , id  dSTRQSeCqMTbs7l8KF_xJg  in  0.5398688316345215
# ElasticNet mae 0.751839384624 rmse 1.0072435750250541
#
#
# Finish building model for user  2 , id  Vqp0dpug9Db-kFHO3PkAaQ  in  0.6093266010284424
# ElasticNet mae 0.607897153352 rmse 0.755058950237318
#
#
# Finish building model for user  3 , id  MylxjEKiTeaWb-GAaPA-zA  in  0.49607276916503906
# ElasticNet mae 0.702189179576 rmse 0.8679710432396515
#
#
# Finish building model for user  4 , id  eY6TPklHTeOaQt9F8a_SGQ  in  2.5785202980041504
# ElasticNet mae 0.819008264463 rmse 0.9679563171765793
#
#
# Finish building model for user  5 , id  EGJXgD6YPieaUCQxfOdXbg  in  2.0681426525115967
# ElasticNet mae 0.805606139438 rmse 0.9795044230314403
#
#
# Finish building model for user  6 , id  1tVRQliYQ_Xw4YGy52njwg  in  0.5407052040100098
# ElasticNet mae 0.552838486741 rmse 0.7733805019953917
#
#
# Finish building model for user  7 , id  DkLSyxogCcJXY5DbTZ-f2A  in  0.45697617530822754
# ElasticNet mae 0.715005751497 rmse 0.9372918167651131
#
#
# Finish building model for user  8 , id  26WgdHfEjWj4BrN-cUNhVw  in  0.5443267822265625
# ElasticNet mae 0.66342236306 rmse 0.8393770228405841
#
#
# Finish building model for user  9 , id  nCRPCQE7E1PV83uQrIf7Cw  in  0.8341693878173828
# ElasticNet mae 0.690973158244 rmse 0.8397094856581417
#
#
# Finish building model for user  10 , id  0gtEsazPeHr5rj2IAsZePg  in  1.420067548751831
# ElasticNet mae 0.606741573034 rmse 0.753570415784665
#
#
# Finish building model for user  11 , id  UmTMCfPlhA6kJLAsLycSfg  in  0.6691839694976807
# ElasticNet mae 0.593662449912 rmse 0.714245245644691
#
#
# Finish building model for user  12 , id  zh7csWc3GAUksnShzGp-WQ  in  0.7675924301147461
# ElasticNet mae 0.708461184106 rmse 0.876284722337896
#
#
# Finish building model for user  13 , id  Nq6e5N8bjgD9B46O4va_zA  in  1.3340599536895752
# ElasticNet mae 0.589567544529 rmse 0.8143540144925341
#
#
# Finish building model for user  14 , id  ltg5Pgd5x7K7zpYtXxMPZA  in  0.46268248558044434
# ElasticNet mae 0.917547841748 rmse 1.1000755586318616
#
#
# Finish building model for user  15 , id  Ko4y7jIissMR8ZGQlMdpaA  in  0.39693379402160645
# ElasticNet mae 0.985795068587 rmse 1.1739144962053722
#
#
# Finish building model for user  16 , id  6btMczuTVuoJnmarbkWP_A  in  0.6176037788391113
# ElasticNet mae 1.01409674306 rmse 1.1725808365637445
#
#
# Finish building model for user  17 , id  djpMXOA1ic5wv3FPtubHNw  in  0.538372278213501
# ElasticNet mae 0.800235218065 rmse 0.9718538516896641
#
#
# Finish building model for user  18 , id  P2E31XC7SP4v_3hXC2o0Xw  in  0.9637444019317627
# ElasticNet mae 0.692243017135 rmse 0.8565664669476745
#
#
# Finish building model for user  19 , id  mXMVfThnmi6dnKq9NlC2ug  in  0.4105849266052246
# ElasticNet mae 0.830959419511 rmse 1.038051399514834
#
#
# Finish building model for user  20 , id  xXyZPAbfQzYTCig7jnZO0A  in  0.42734217643737793
# ElasticNet mae 0.82466157364 rmse 0.9966499166773164
#
#
# Finish building model for user  21 , id  0rDG0uZHpqxJbdu-FJ3IgA  in  0.3267335891723633
# ElasticNet mae 0.914744933613 rmse 1.113121848974638
#
#
# Finish building model for user  22 , id  wskTNZjwiqMJOvM_-XAQZw  in  0.5044753551483154
# ElasticNet mae 0.520781852207 rmse 0.7941222435346726
#
#
# Finish building model for user  23 , id  Hci2c0qo98CO-Pv-VmV7gg  in  1.3126277923583984
# ElasticNet mae 0.683906039081 rmse 0.8885645133754929
#
#
# Finish building model for user  24 , id  DuzZ68TZWlQ3mALJZ0ASVQ  in  0.4030296802520752
# ElasticNet mae 0.751109467456 rmse 0.9128757252935299
#
#
# Finish building model for user  25 , id  pvwEROiu2kfTqyp6cG2HIA  in  0.5554590225219727
# ElasticNet mae 1.12595115637 rmse 1.3253207410936356
#
#
# Finish building model for user  26 , id  yeX7tzZZWCnphQifRJglUg  in  0.7069365978240967
# ElasticNet mae 1.13545915314 rmse 1.3096887494796832
#
#
# Finish building model for user  27 , id  BGzavA_ddMr-jGmhArv7fg  in  2.524193525314331
# ElasticNet mae 0.675059935653 rmse 0.8107442827486246
#
#
# Finish building model for user  28 , id  Z09rco1enQXNCd9H0u7kvg  in  0.6711177825927734
# ElasticNet mae 0.65991398823 rmse 0.8524665662788649
#
#
# Finish building model for user  29 , id  mnJvynzRIYptrjyKtEBiTA  in  0.8006658554077148
# ElasticNet mae 0.818316880964 rmse 0.9751683145961387
#
#
# Finish building model for user  30 , id  t2O6rs4fZeY9o6ZY52RyJA  in  0.9105556011199951
# ElasticNet mae 0.71854560041 rmse 0.890899098782491
#
#
# Finish building model for user  31 , id  QPJJohtGqkMkaN0Gt3TRIg  in  0.538776159286499
# ElasticNet mae 0.614170548694 rmse 0.8517146174013488
#
#
# Finish building model for user  32 , id  Q9mA60HnY87C1TW5kjAZ6Q  in  2.3707027435302734
# ElasticNet mae 0.591685595403 rmse 0.7471227849289533
#
#
# Finish building model for user  33 , id  YRcaNlwQ6XXPFDXWtuMGdA  in  2.639681100845337
# ElasticNet mae 0.810901267002 rmse 0.9566501296032383
#
#
# Finish building model for user  34 , id  pJYRi9MB06aiuL-w8Ms-Og  in  0.9044177532196045
# ElasticNet mae 0.810271007145 rmse 0.9838619157532789
#
#
# Finish building model for user  35 , id  jlu4CztcSxrKx56ba1a5AQ  in  0.7659091949462891
# ElasticNet mae 0.775790072097 rmse 0.9552312511339714
#
#
# Finish building model for user  36 , id  BqAMAM9wkjUyOJzqYOHg5g  in  0.34357714653015137
# ElasticNet mae 0.660358709931 rmse 0.8259235156777631
#
#
# Finish building model for user  37 , id  CxDOIDnH8gp9KXzpBHJYXw  in  7.284421443939209
# ElasticNet mae 0.502072863898 rmse 0.6328900510159406
#
#
# Finish building model for user  38 , id  V4TPbscN8JsFbEFiwOVBKw  in  2.4383111000061035
# ElasticNet mae 0.703891694363 rmse 0.8436420905496933
#
#
# Finish building model for user  39 , id  FFFeLM5rk29RZn6FmGlHYQ  in  0.8990581035614014
# ElasticNet mae 0.801925394754 rmse 0.957041642320618
#
#
# Finish building model for user  40 , id  FREeRQtjdJU83AFtdETBBw  in  3.3350670337677
# ElasticNet mae 0.71521847271 rmse 0.8376675711336614
#
#
# Finish building model for user  41 , id  cCpiu1GqdzxlvANKuiAp0Q  in  0.4701409339904785
# ElasticNet mae 0.641984236188 rmse 0.7898472200444902
#
#
# Finish building model for user  42 , id  wdeWt5VqTW26PAeQsVg73g  in  0.46729159355163574
# ElasticNet mae 0.533038469827 rmse 0.754045173156768
# {'ElasticNet': {'mae': 0.74029518598749577, 'rmse': 0.9180539965686114}}

# %%
run_content_based.runML("Lasso", chunks[3], review, business)
# Out:
# Finish building model for user  0 , id  JInn7zPqOxhea4l8PUsBPA  in  0.5936694145202637
# Lasso mae 0.875508494804 rmse 1.0961559608244227
#
#
# Finish building model for user  1 , id  Y1N7LPhi3xAq3UBLKWpWNQ  in  0.5268685817718506
# Lasso mae 0.881755319434 rmse 1.1018118905584133
#
#
# Finish building model for user  2 , id  L8GB1sEXJrVfR-UsDRjI-g  in  0.46357083320617676
# Lasso mae 0.912083233584 rmse 1.1147131308363003
#
#
# Finish building model for user  3 , id  6X9PioodbNo5nnkZTFWhWQ  in  0.4136984348297119
# Lasso mae 0.656512105504 rmse 0.8853239285656931
#
#
# Finish building model for user  4 , id  Kj9cFO70zZOQorN0mgeLWA  in  3.1892974376678467
# Lasso mae 0.55442966779 rmse 0.6802320282532992
#
#
# Finish building model for user  5 , id  DOZtiJTh6ZYsZJcXgPrdBg  in  1.1902046203613281
# Lasso mae 0.616389058136 rmse 0.8140457753301638
#
#
# Finish building model for user  6 , id  KBh4r16e9Grc1HI9pG4wTg  in  3.2156879901885986
# Lasso mae 0.738508608962 rmse 0.8595205244943023
#
#
# Finish building model for user  7 , id  Yp7_GeD6KTRoo4Nteqv4SA  in  0.7956752777099609
# Lasso mae 0.778146493226 rmse 1.003374721419017
#
#
# Finish building model for user  8 , id  7hAhYoMPjHnxKCz6MQ95Bg  in  1.5897791385650635
# Lasso mae 0.688316626075 rmse 0.9032130908298087
#
#
# Finish building model for user  9 , id  KmHtoogKhK-ID7FWGOPvag  in  0.38521528244018555
# Lasso mae 0.968702865762 rmse 1.2206006775600888
#
#
# Finish building model for user  10 , id  uf95iifC_TQ-DtDs0rtiXg  in  0.350536584854126
# Lasso mae 0.949735703679 rmse 1.206440803960589
#
#
# Finish building model for user  11 , id  XChCfeJ6Yx2NDJIpIgRhyg  in  2.1427159309387207
# Lasso mae 0.846333787881 rmse 1.0313869814736547
#
#
# Finish building model for user  12 , id  _zPT9ZmR5-nUfsprzIiRew  in  1.0474848747253418
# Lasso mae 0.637061929766 rmse 0.7932387661657678
#
#
# Finish building model for user  13 , id  i6V3NyTdkBVwPpH7r2BINA  in  3.08817720413208
# Lasso mae 0.943641405844 rmse 1.1243797048055084
#
#
# Finish building model for user  14 , id  CmahoXBP17HudYGYt2Brdg  in  0.6810967922210693
# Lasso mae 0.705610858496 rmse 0.8913287633136502
#
#
# Finish building model for user  15 , id  O3pSxv1SyHpY4qi4Q16KzA  in  3.354621171951294
# Lasso mae 0.676897676676 rmse 0.850130276025457
#
#
# Finish building model for user  16 , id  fZ7fLMqArGTemvXPH9H3FA  in  0.63916015625
# Lasso mae 0.790236768639 rmse 0.954393090417676
#
#
# Finish building model for user  17 , id  1ickSuyOWWKWdQpauKmkEw  in  1.4068825244903564
# Lasso mae 0.872389300909 rmse 1.0125115484700569
#
#
# Finish building model for user  18 , id  _oCiEDUZqu91P0Tzdl_wMA  in  1.640324592590332
# Lasso mae 0.810940219922 rmse 1.0178535339491868
#
#
# Finish building model for user  19 , id  S10Q9h_W-MKyog8IdcCNCQ  in  0.8059561252593994
# Lasso mae 0.812128418549 rmse 0.946185119421928
#
#
# Finish building model for user  20 , id  pF1k48uCdLv3clPQXp0d7A  in  0.7352123260498047
# Lasso mae 0.995082460127 rmse 1.14847882679029
#
#
# Finish building model for user  21 , id  OucFS92pVsGBwzELoBnWvA  in  0.47466158866882324
# Lasso mae 0.951560314644 rmse 1.1172477852460094
#
#
# Finish building model for user  22 , id  MFnXQb1R1IGLL_-W4oflJw  in  1.8356046676635742
# Lasso mae 0.694962302484 rmse 0.8573555801777195
#
#
# Finish building model for user  23 , id  g9MYC0QTNPPmbIdrtdan9A  in  1.2336134910583496
# Lasso mae 0.93982422622 rmse 1.1862096061841454
#
#
# Finish building model for user  24 , id  2e5V6M4GNufEnbGJpVdCjw  in  1.4247705936431885
# Lasso mae 0.575044149932 rmse 0.7031377503442229
#
#
# Finish building model for user  25 , id  DBHCFW3mSmmOEpONHVu1rQ  in  0.39376139640808105
# Lasso mae 0.715584415584 rmse 0.918241818232288
#
#
# Finish building model for user  26 , id  aLvxbF2DueKFOqul9eVWCw  in  0.35040926933288574
# Lasso mae 0.933838266429 rmse 1.108951502269309
#
#
# Finish building model for user  27 , id  Qsu2EtNn99_oVG9bS4Miaw  in  0.4240396022796631
# Lasso mae 0.893802208168 rmse 1.0740493702854528
#
#
# Finish building model for user  28 , id  KgFOJnWXxVuz0b-xfo6jjw  in  1.2014076709747314
# Lasso mae 0.399630137929 rmse 0.5670587516211272
#
#
# Finish building model for user  29 , id  8D8mjeNaJ3DGhl0WX8copA  in  3.061532735824585
# Lasso mae 0.733342539185 rmse 0.8889999853007975
#
#
# Finish building model for user  30 , id  CSA-YFyZWlxPTeAZRJqMWA  in  0.8671951293945312
# Lasso mae 0.670809236998 rmse 0.8891348021543233
#
#
# Finish building model for user  31 , id  qQ4bfJmrfK0iWCZjl8cavQ  in  0.8046205043792725
# Lasso mae 0.900242099154 rmse 1.083574749891579
#
#
# Finish building model for user  32 , id  rK4I1CJLXCQSZIhigdJcnQ  in  0.7917282581329346
# Lasso mae 0.827560921462 rmse 0.9752487841296549
#
#
# Finish building model for user  33 , id  yT_QCcnq-QGipWWuzIpvtw  in  6.10550856590271
# Lasso mae 0.703995271932 rmse 0.8667197762788075
#
#
# Finish building model for user  34 , id  G-6X-llgA_qAxGxocykHzQ  in  1.1735138893127441
# Lasso mae 0.862098998403 rmse 1.0083103572701613
#
#
# Finish building model for user  35 , id  C7lXOTSLUAHG3gkG_Q_39w  in  3.436107635498047
# Lasso mae 0.62632294345 rmse 0.7705800010807099
#
#
# Finish building model for user  36 , id  eZeBuiVZWT7u3SktO7mv9w  in  0.5170588493347168
# Lasso mae 0.844010112716 rmse 1.0316993580719591
#
#
# Finish building model for user  37 , id  SVC0CajvmYfH5uAq4JnGvg  in  0.35068202018737793
# Lasso mae 0.653039832285 rmse 0.7418230969561295
#
#
# Finish building model for user  38 , id  PFNZVn73upq3oZDG2KnAqA  in  0.856198787689209
# Lasso mae 0.698978590173 rmse 0.8230503517796179
#
#
# Finish building model for user  39 , id  AghKXr53xNvKjh_A5Ur1GQ  in  0.5011534690856934
# Lasso mae 0.722830085436 rmse 0.9207519945745288
#
#
# Finish building model for user  40 , id  zN7UEYPQwUQdDULm_pDWdQ  in  0.712777853012085
# Lasso mae 0.84437751004 rmse 1.0572074966956753
#
#
# Finish building model for user  41 , id  j6wLUT0ZXi-x0otelYIFpA  in  4.443260192871094
# Lasso mae 0.769657350168 rmse 0.9263135833477003
#
#
# Finish building model for user  42 , id  lqUgcd3YhOX3GjowDn_Hqg  in  0.6128036975860596
# Lasso mae 0.782351929317 rmse 0.9405711758322516
# {'Lasso': {'mae': 0.77800638246219755, 'rmse': 0.9560827167718478}}

# %%
run_content_based.runML("ElasticNet", chunks[3], review, business)
# Out:
# Finish building model for user  0 , id  JInn7zPqOxhea4l8PUsBPA  in  0.46844959259033203
# ElasticNet mae 0.870574374689 rmse 1.0840358590849175
#
#
# Finish building model for user  1 , id  Y1N7LPhi3xAq3UBLKWpWNQ  in  0.4039936065673828
# ElasticNet mae 0.913429498822 rmse 1.1362042048370622
#
#
# Finish building model for user  2 , id  L8GB1sEXJrVfR-UsDRjI-g  in  0.4086470603942871
# ElasticNet mae 0.912763442313 rmse 1.1170784623102472
#
#
# Finish building model for user  3 , id  6X9PioodbNo5nnkZTFWhWQ  in  0.40876245498657227
# ElasticNet mae 0.656277436348 rmse 0.8854987391845238
#
#
# Finish building model for user  4 , id  Kj9cFO70zZOQorN0mgeLWA  in  2.506288766860962
# ElasticNet mae 0.592700764067 rmse 0.7090984456956233
#
#
# Finish building model for user  5 , id  DOZtiJTh6ZYsZJcXgPrdBg  in  1.0199663639068604
# ElasticNet mae 0.616759885622 rmse 0.813398782389056
#
#
# Finish building model for user  6 , id  KBh4r16e9Grc1HI9pG4wTg  in  2.0206353664398193
# ElasticNet mae 0.738457874495 rmse 0.8596213675102847
#
#
# Finish building model for user  7 , id  Yp7_GeD6KTRoo4Nteqv4SA  in  0.5016005039215088
# ElasticNet mae 0.754398494421 rmse 0.9755415917894293
#
#
# Finish building model for user  8 , id  7hAhYoMPjHnxKCz6MQ95Bg  in  0.884915828704834
# ElasticNet mae 0.687207967864 rmse 0.9081123265973023
#
#
# Finish building model for user  9 , id  KmHtoogKhK-ID7FWGOPvag  in  0.308168888092041
# ElasticNet mae 0.968702865762 rmse 1.2206006775600888
#
#
# Finish building model for user  10 , id  uf95iifC_TQ-DtDs0rtiXg  in  0.26978325843811035
# ElasticNet mae 0.944319477957 rmse 1.1947256419691874
#
#
# Finish building model for user  11 , id  XChCfeJ6Yx2NDJIpIgRhyg  in  1.4327054023742676
# ElasticNet mae 0.853406455845 rmse 1.0394104337658054
#
#
# Finish building model for user  12 , id  _zPT9ZmR5-nUfsprzIiRew  in  0.7347118854522705
# ElasticNet mae 0.636102151702 rmse 0.7929318857223708
#
#
# Finish building model for user  13 , id  i6V3NyTdkBVwPpH7r2BINA  in  1.7780711650848389
# ElasticNet mae 0.943135971223 rmse 1.1235670198694487
#
#
# Finish building model for user  14 , id  CmahoXBP17HudYGYt2Brdg  in  0.6811575889587402
# ElasticNet mae 0.707256995635 rmse 0.892218329212663
#
#
# Finish building model for user  15 , id  O3pSxv1SyHpY4qi4Q16KzA  in  2.779977321624756
# ElasticNet mae 0.680799370636 rmse 0.8534287856523632
#
#
# Finish building model for user  16 , id  fZ7fLMqArGTemvXPH9H3FA  in  0.4950368404388428
# ElasticNet mae 0.782891042521 rmse 0.9535258559832076
#
#
# Finish building model for user  17 , id  1ickSuyOWWKWdQpauKmkEw  in  0.950899600982666
# ElasticNet mae 0.867344371766 rmse 1.0089099961649426
#
#
# Finish building model for user  18 , id  _oCiEDUZqu91P0Tzdl_wMA  in  1.1306788921356201
# ElasticNet mae 0.831219086437 rmse 1.0413605757148565
#
#
# Finish building model for user  19 , id  S10Q9h_W-MKyog8IdcCNCQ  in  0.6350734233856201
# ElasticNet mae 0.812128418549 rmse 0.946185119421928
#
#
# Finish building model for user  20 , id  pF1k48uCdLv3clPQXp0d7A  in  0.571312427520752
# ElasticNet mae 1.00354541876 rmse 1.1642689995900144
#
#
# Finish building model for user  21 , id  OucFS92pVsGBwzELoBnWvA  in  0.426891565322876
# ElasticNet mae 0.953360093413 rmse 1.1192774857251644
#
#
# Finish building model for user  22 , id  MFnXQb1R1IGLL_-W4oflJw  in  1.3050894737243652
# ElasticNet mae 0.707542697696 rmse 0.8622789299560514
#
#
# Finish building model for user  23 , id  g9MYC0QTNPPmbIdrtdan9A  in  0.7880408763885498
# ElasticNet mae 0.937682681725 rmse 1.186735648700302
#
#
# Finish building model for user  24 , id  2e5V6M4GNufEnbGJpVdCjw  in  1.6189844608306885
# ElasticNet mae 0.594461062854 rmse 0.7174032511006949
#
#
# Finish building model for user  25 , id  DBHCFW3mSmmOEpONHVu1rQ  in  0.36289310455322266
# ElasticNet mae 0.715584415584 rmse 0.918241818232288
#
#
# Finish building model for user  26 , id  aLvxbF2DueKFOqul9eVWCw  in  0.3205831050872803
# ElasticNet mae 0.927152719223 rmse 1.1150976686664542
#
#
# Finish building model for user  27 , id  Qsu2EtNn99_oVG9bS4Miaw  in  0.3686356544494629
# ElasticNet mae 0.891457593213 rmse 1.0695363114248222
#
#
# Finish building model for user  28 , id  KgFOJnWXxVuz0b-xfo6jjw  in  0.9025249481201172
# ElasticNet mae 0.422274440928 rmse 0.6119527241956304
#
#
# Finish building model for user  29 , id  8D8mjeNaJ3DGhl0WX8copA  in  1.9687371253967285
# ElasticNet mae 0.759048292208 rmse 0.9313609367405038
#
#
# Finish building model for user  30 , id  CSA-YFyZWlxPTeAZRJqMWA  in  0.7796854972839355
# ElasticNet mae 0.645245050308 rmse 0.8674668354590493
#
#
# Finish building model for user  31 , id  qQ4bfJmrfK0iWCZjl8cavQ  in  0.9792261123657227
# ElasticNet mae 0.900481512716 rmse 1.0840173848704144
#
#
# Finish building model for user  32 , id  rK4I1CJLXCQSZIhigdJcnQ  in  0.8222620487213135
# ElasticNet mae 0.829815781935 rmse 0.9766175714322154
#
#
# Finish building model for user  33 , id  yT_QCcnq-QGipWWuzIpvtw  in  3.7685699462890625
# ElasticNet mae 0.71482286796 rmse 0.8781113952972393
#
#
# Finish building model for user  34 , id  G-6X-llgA_qAxGxocykHzQ  in  0.8427402973175049
# ElasticNet mae 0.862098998403 rmse 1.0083103572701613
#
#
# Finish building model for user  35 , id  C7lXOTSLUAHG3gkG_Q_39w  in  2.0117554664611816
# ElasticNet mae 0.637973534613 rmse 0.7769406689860847
#
#
# Finish building model for user  36 , id  eZeBuiVZWT7u3SktO7mv9w  in  0.3510904312133789
# ElasticNet mae 0.843536182667 rmse 1.031394671928474
#
#
# Finish building model for user  37 , id  SVC0CajvmYfH5uAq4JnGvg  in  0.44293212890625
# ElasticNet mae 0.653039832285 rmse 0.7418230969561295
#
#
# Finish building model for user  38 , id  PFNZVn73upq3oZDG2KnAqA  in  0.5206897258758545
# ElasticNet mae 0.699040276147 rmse 0.8229957294316459
#
#
# Finish building model for user  39 , id  AghKXr53xNvKjh_A5Ur1GQ  in  0.34606456756591797
# ElasticNet mae 0.748055829503 rmse 0.9223416215703548
#
#
# Finish building model for user  40 , id  zN7UEYPQwUQdDULm_pDWdQ  in  0.48926806449890137
# ElasticNet mae 0.844241712309 rmse 1.0574935006695316
#
#
# Finish building model for user  41 , id  j6wLUT0ZXi-x0otelYIFpA  in  3.5548818111419678
# ElasticNet mae 0.795922488965 rmse 0.9480732404523673
#
#
# Finish building model for user  42 , id  lqUgcd3YhOX3GjowDn_Hqg  in  0.4918828010559082
# ElasticNet mae 0.784816792962 rmse 0.9475658590125191
# {'ElasticNet': {'mae': 0.78235060983832405, 'rmse': 0.9608083676303122}}

# %%
run_content_based.runML("Lasso", chunks[4], review, business)
# Out:
# Finish building model for user  0 , id  Jt1zgNmwz_jheOSmEsljPQ  in  1.230039358139038
# Lasso mae 0.680631431737 rmse 0.9066166940515954
#
#
# Finish building model for user  1 , id  TaJ3hRYUW9Z82HF0qc4hFQ  in  2.4893157482147217
# Lasso mae 0.738831754119 rmse 0.9133713041889997
#
#
# Finish building model for user  2 , id  R6NNz2Zb2yqpRWJNKIWldg  in  0.6183457374572754
# Lasso mae 1.12765137687 rmse 1.3370171618337272
#
#
# Finish building model for user  3 , id  _t3BJzyGaqr9mcDazYiYAQ  in  2.0907888412475586
# Lasso mae 1.02167029312 rmse 1.2395783766154413
#
#
# Finish building model for user  4 , id  LmWO_u9v7e1vMJlNykjUoA  in  0.9997055530548096
# Lasso mae 0.761688175369 rmse 0.9335476876895632
#
#
# Finish building model for user  5 , id  1kNsEAhGU8d8xugMuXJGFA  in  1.3676302433013916
# Lasso mae 0.476277879026 rmse 0.5586328456830194
#
#
# Finish building model for user  6 , id  kbB1FfCf1NsJN-PZAQ0xwQ  in  0.6585829257965088
# Lasso mae 1.22121212121 rmse 1.394286475387673
#
#
# Finish building model for user  7 , id  ukp5bUGNcvl2OWU5CPG7fw  in  1.1142988204956055
# Lasso mae 0.625392542934 rmse 0.7699010669511995
#
#
# Finish building model for user  8 , id  Hk7n0zKhcrRwkvqgb_MQ3Q  in  0.5811901092529297
# Lasso mae 0.755689733079 rmse 0.9308667311080125
#
#
# Finish building model for user  9 , id  HWLr60IBXAy9HD23W3Xmfg  in  1.5844635963439941
# Lasso mae 0.60183017062 rmse 0.8444126956434728
#
#
# Finish building model for user  10 , id  YDAL4CBJcp3xrYgAGVGgaQ  in  2.825263023376465
# Lasso mae 0.727742725434 rmse 0.9309449707751802
#
#
# Finish building model for user  11 , id  YBT3EKUNN4IP8m4x7sGu1g  in  2.052623748779297
# Lasso mae 1.06793441036 rmse 1.2274554368279127
#
#
# Finish building model for user  12 , id  65yB0ydGXOZ_-T6J_GbKfw  in  1.8685047626495361
# Lasso mae 0.658556312626 rmse 0.7889827566583076
#
#
# Finish building model for user  13 , id  drmTj6FQRWgek_VooTDqZg  in  0.3572089672088623
# Lasso mae 1.00648870762 rmse 1.1736436978870843
#
#
# Finish building model for user  14 , id  WXlxViTwXHPBvhioljN9PQ  in  1.951737403869629
# Lasso mae 0.615106252991 rmse 0.7594006205237926
#
#
# Finish building model for user  15 , id  1bgWnqxHdMCIvmuRcJWKIA  in  0.9630446434020996
# Lasso mae 0.667005237616 rmse 0.8295405412739196
#
#
# Finish building model for user  16 , id  JnPIjvC0cmooNDfsa9BmXg  in  3.297081708908081
# Lasso mae 0.779629724348 rmse 1.0001934474655054
#
#
# Finish building model for user  17 , id  aX6_Pf3njB-H3FrqgnNJ2g  in  0.6576831340789795
# Lasso mae 0.423822222222 rmse 0.6199575247875413
#
#
# Finish building model for user  18 , id  nXehm6zt294ZswIgh5LpbA  in  0.3826334476470947
# Lasso mae 0.943061840121 rmse 1.102266230687989
#
#
# Finish building model for user  19 , id  2VKVhy1SwaixHCeiWglLUQ  in  1.4707238674163818
# Lasso mae 0.936403508772 rmse 1.1027331951386756
#
#
# Finish building model for user  20 , id  YOOsYiXGEtGFX_wSeZNcww  in  0.9901392459869385
# Lasso mae 0.66373300335 rmse 0.8133006817546908
#
#
# Finish building model for user  21 , id  i7QG1ixeuFwpemeLvmRKHA  in  0.4983482360839844
# Lasso mae 0.757658021041 rmse 0.9500467951896474
#
#
# Finish building model for user  22 , id  J4ZLNtDFRMN5lCwvFs9zww  in  0.9293866157531738
# Lasso mae 1.01851330736 rmse 1.204317455377927
#
#
# Finish building model for user  23 , id  SxMBY64n31UHPjxzIastUg  in  2.0911595821380615
# Lasso mae 0.82611636022 rmse 1.0398877837220377
#
#
# Finish building model for user  24 , id  BF7rMYMH6OvJOBIQhsnQvg  in  0.6346206665039062
# Lasso mae 0.811231191459 rmse 0.9718595719387941
#
#
# Finish building model for user  25 , id  xVV86BToDOQGxE1gt9MMvg  in  2.334658145904541
# Lasso mae 0.739345011952 rmse 0.9474956864172158
#
#
# Finish building model for user  26 , id  fAfGwjh5A_ydd0A4ZdGenw  in  3.43129301071167
# Lasso mae 0.96884986539 rmse 1.1548601848384643
#
#
# Finish building model for user  27 , id  z66KKknqWzFBWZb0GbEi2g  in  1.0301110744476318
# Lasso mae 0.76750261233 rmse 0.912785076388757
#
#
# Finish building model for user  28 , id  J56C7Dc9E7Q0mpMTJGW6Qw  in  1.21311354637146
# Lasso mae 0.749351572364 rmse 0.9649502474266402
#
#
# Finish building model for user  29 , id  zCnJQKvZgET4llBbJD1aiw  in  1.2613468170166016
# Lasso mae 1.04619855005 rmse 1.2970623575439295
#
#
# Finish building model for user  30 , id  PGeiszoVusiv0wTHVdWklA  in  2.4607841968536377
# Lasso mae 0.663178607607 rmse 0.8122796741438477
#
#
# Finish building model for user  31 , id  KE3fPgfxEmfsutKxMlssvQ  in  0.5522377490997314
# Lasso mae 1.04527826653 rmse 1.26826715068673
#
#
# Finish building model for user  32 , id  iJCtRAlSvxiUuKlVAnsq0A  in  0.897221565246582
# Lasso mae 0.722647418928 rmse 0.8650911797755424
#
#
# Finish building model for user  33 , id  Obs2jspE9KpZQHLzNcuqxw  in  0.36357879638671875
# Lasso mae 0.72836863349 rmse 0.9384978982097071
#
#
# Finish building model for user  34 , id  m5b84-nPPVNLlDtZyVGZ3w  in  4.15218186378479
# Lasso mae 0.692962595825 rmse 0.8440012227473064
#
#
# Finish building model for user  35 , id  bPQMtrXUy8dMCJu6SHxxaA  in  0.7262649536132812
# Lasso mae 0.815250662564 rmse 0.980879809727337
#
#
# Finish building model for user  36 , id  R-xGsTpwlwuOe_vAbg_aeA  in  0.975196123123169
# Lasso mae 0.961102994887 rmse 1.1994341320079904
#
#
# Finish building model for user  37 , id  VrMaL32wWNed_DjOcsO3Ng  in  1.6950414180755615
# Lasso mae 0.875077303649 rmse 1.115654429043017
#
#
# Finish building model for user  38 , id  skxAQWpAe1VL_3F4pxqK2A  in  0.48928403854370117
# Lasso mae 0.664092009801 rmse 0.7989354777119275
#
#
# Finish building model for user  39 , id  4sGwJy5Oplz8QXLgD8dr2w  in  0.34733128547668457
# Lasso mae 0.776627218935 rmse 0.913729580486626
#
#
# Finish building model for user  40 , id  OiRnzvW40RQ6tqcgk4jv1Q  in  0.7369260787963867
# Lasso mae 0.718577594363 rmse 0.8372480583622721
#
#
# Finish building model for user  41 , id  gSO_NFz9zJaddMbldkfOfw  in  1.0923447608947754
# Lasso mae 0.855386545722 rmse 1.0449470585202176
#
#
# Finish building model for user  42 , id  Tf3VaWx72MWrLJiuaEbftw  in  0.442523717880249
# Lasso mae 1.06913910049 rmse 1.2545132200866913
# {'Lasso': {'mae': 0.80867011322077387, 'rmse': 0.9882184696113006}}

# %%
run_content_based.runML("ElasticNet", chunks[4], review, business)
# Out:
# Finish building model for user  0 , id  Jt1zgNmwz_jheOSmEsljPQ  in  1.052137851715088
# ElasticNet mae 0.681511206497 rmse 0.9073204588348106
#
#
# Finish building model for user  1 , id  TaJ3hRYUW9Z82HF0qc4hFQ  in  1.589554786682129
# ElasticNet mae 0.745233464407 rmse 0.9210817424620947
#
#
# Finish building model for user  2 , id  R6NNz2Zb2yqpRWJNKIWldg  in  0.5841784477233887
# ElasticNet mae 1.13251965157 rmse 1.3390600337120195
#
#
# Finish building model for user  3 , id  _t3BJzyGaqr9mcDazYiYAQ  in  2.0464792251586914
# ElasticNet mae 1.02346148706 rmse 1.2427658567595619
#
#
# Finish building model for user  4 , id  LmWO_u9v7e1vMJlNykjUoA  in  1.0336170196533203
# ElasticNet mae 0.757060607758 rmse 0.9288442249526491
#
#
# Finish building model for user  5 , id  1kNsEAhGU8d8xugMuXJGFA  in  2.009746551513672
# ElasticNet mae 0.50053329197 rmse 0.5777115779728221
#
#
# Finish building model for user  6 , id  kbB1FfCf1NsJN-PZAQ0xwQ  in  0.5989425182342529
# ElasticNet mae 1.22040786576 rmse 1.394116742650395
#
#
# Finish building model for user  7 , id  ukp5bUGNcvl2OWU5CPG7fw  in  1.1193866729736328
# ElasticNet mae 0.634115264574 rmse 0.7712364457846541
#
#
# Finish building model for user  8 , id  Hk7n0zKhcrRwkvqgb_MQ3Q  in  0.6211166381835938
# ElasticNet mae 0.749001459823 rmse 0.9226065573907059
#
#
# Finish building model for user  9 , id  HWLr60IBXAy9HD23W3Xmfg  in  0.8971214294433594
# ElasticNet mae 0.600290602248 rmse 0.8436172083680181
#
#
# Finish building model for user  10 , id  YDAL4CBJcp3xrYgAGVGgaQ  in  1.3879187107086182
# ElasticNet mae 0.739546870888 rmse 0.939713591831862
#
#
# Finish building model for user  11 , id  YBT3EKUNN4IP8m4x7sGu1g  in  1.089008092880249
# ElasticNet mae 1.0859583693 rmse 1.251017214589524
#
#
# Finish building model for user  12 , id  65yB0ydGXOZ_-T6J_GbKfw  in  1.3433659076690674
# ElasticNet mae 0.674486166201 rmse 0.8424834718568458
#
#
# Finish building model for user  13 , id  drmTj6FQRWgek_VooTDqZg  in  0.6329991817474365
# ElasticNet mae 1.00220309788 rmse 1.1704403286093354
#
#
# Finish building model for user  14 , id  WXlxViTwXHPBvhioljN9PQ  in  1.867915153503418
# ElasticNet mae 0.614981741629 rmse 0.7591726974158989
#
#
# Finish building model for user  15 , id  1bgWnqxHdMCIvmuRcJWKIA  in  0.6590976715087891
# ElasticNet mae 0.677285817952 rmse 0.8504335888872991
#
#
# Finish building model for user  16 , id  JnPIjvC0cmooNDfsa9BmXg  in  2.2936434745788574
# ElasticNet mae 0.796611326952 rmse 1.0052951027839194
#
#
# Finish building model for user  17 , id  aX6_Pf3njB-H3FrqgnNJ2g  in  0.8282146453857422
# ElasticNet mae 0.423822222222 rmse 0.6199575247875413
#
#
# Finish building model for user  18 , id  nXehm6zt294ZswIgh5LpbA  in  0.32134485244750977
# ElasticNet mae 0.943061840121 rmse 1.102266230687989
#
#
# Finish building model for user  19 , id  2VKVhy1SwaixHCeiWglLUQ  in  1.601745843887329
# ElasticNet mae 0.936403508772 rmse 1.1027331951386756
#
#
# Finish building model for user  20 , id  YOOsYiXGEtGFX_wSeZNcww  in  1.1759324073791504
# ElasticNet mae 0.681150391661 rmse 0.8292480514406422
#
#
# Finish building model for user  21 , id  i7QG1ixeuFwpemeLvmRKHA  in  0.6373012065887451
# ElasticNet mae 0.762243225896 rmse 0.9604648040175656
#
#
# Finish building model for user  22 , id  J4ZLNtDFRMN5lCwvFs9zww  in  0.568845272064209
# ElasticNet mae 1.02283102211 rmse 1.2070946833248972
#
#
# Finish building model for user  23 , id  SxMBY64n31UHPjxzIastUg  in  1.258634328842163
# ElasticNet mae 0.861259110856 rmse 1.079172609276419
#
#
# Finish building model for user  24 , id  BF7rMYMH6OvJOBIQhsnQvg  in  0.4177210330963135
# ElasticNet mae 0.811389520591 rmse 0.9718309607261355
#
#
# Finish building model for user  25 , id  xVV86BToDOQGxE1gt9MMvg  in  1.5339775085449219
# ElasticNet mae 0.769602666007 rmse 0.976051677766281
#
#
# Finish building model for user  26 , id  fAfGwjh5A_ydd0A4ZdGenw  in  4.065845727920532
# ElasticNet mae 1.02689393178 rmse 1.2057227940851831
#
#
# Finish building model for user  27 , id  z66KKknqWzFBWZb0GbEi2g  in  0.7240622043609619
# ElasticNet mae 0.76750261233 rmse 0.912785076388757
#
#
# Finish building model for user  28 , id  J56C7Dc9E7Q0mpMTJGW6Qw  in  0.7975554466247559
# ElasticNet mae 0.75013758941 rmse 0.9652465727327302
#
#
# Finish building model for user  29 , id  zCnJQKvZgET4llBbJD1aiw  in  0.8857598304748535
# ElasticNet mae 1.03940311297 rmse 1.256121287983075
#
#
# Finish building model for user  30 , id  PGeiszoVusiv0wTHVdWklA  in  1.8012056350708008
# ElasticNet mae 0.683868613978 rmse 0.8384489149646783
#
#
# Finish building model for user  31 , id  KE3fPgfxEmfsutKxMlssvQ  in  0.3699774742126465
# ElasticNet mae 1.0415850221 rmse 1.2635224408564953
#
#
# Finish building model for user  32 , id  iJCtRAlSvxiUuKlVAnsq0A  in  0.7162830829620361
# ElasticNet mae 0.723074249906 rmse 0.8646218988707006
#
#
# Finish building model for user  33 , id  Obs2jspE9KpZQHLzNcuqxw  in  0.3723635673522949
# ElasticNet mae 0.725912566131 rmse 0.9367954230654238
#
#
# Finish building model for user  34 , id  m5b84-nPPVNLlDtZyVGZ3w  in  2.4997403621673584
# ElasticNet mae 0.704129172467 rmse 0.8447388896985275
#
#
# Finish building model for user  35 , id  bPQMtrXUy8dMCJu6SHxxaA  in  0.4893195629119873
# ElasticNet mae 0.815917720781 rmse 0.9865227560845309
#
#
# Finish building model for user  36 , id  R-xGsTpwlwuOe_vAbg_aeA  in  0.5476458072662354
# ElasticNet mae 0.961102994887 rmse 1.1994341320079904
#
#
# Finish building model for user  37 , id  VrMaL32wWNed_DjOcsO3Ng  in  1.1035385131835938
# ElasticNet mae 0.875077303649 rmse 1.115654429043017
#
#
# Finish building model for user  38 , id  skxAQWpAe1VL_3F4pxqK2A  in  0.3150057792663574
# ElasticNet mae 0.66492366085 rmse 0.7999517363334216
#
#
# Finish building model for user  39 , id  4sGwJy5Oplz8QXLgD8dr2w  in  0.27175092697143555
# ElasticNet mae 0.776627218935 rmse 0.913729580486626
#
#
# Finish building model for user  40 , id  OiRnzvW40RQ6tqcgk4jv1Q  in  0.41883420944213867
# ElasticNet mae 0.717227230625 rmse 0.8339844357590412
#
#
# Finish building model for user  41 , id  gSO_NFz9zJaddMbldkfOfw  in  0.6589393615722656
# ElasticNet mae 0.85567652993 rmse 1.0430122445587293
#
#
# Finish building model for user  42 , id  Tf3VaWx72MWrLJiuaEbftw  in  0.40381526947021484
# ElasticNet mae 1.06586441899 rmse 1.2541730886228746
# {'ElasticNet': {'mae': 0.81492780814965005, 'rmse': 0.9941907507807064}}

# %%
run_content_based.runML("Lasso", chunks[5], review, business)
# Out:
# Finish building model for user  0 , id  nDQEwuw5u6iQHYXEsQXsxg  in  0.8691561222076416
# Lasso mae 0.95520014524 rmse 1.14450272304375
#
#
# Finish building model for user  1 , id  HAv4iHgSyMS4HKwl5hb98w  in  0.4861319065093994
# Lasso mae 0.915820513387 rmse 1.0834777886537306
#
#
# Finish building model for user  2 , id  ryI5QW93_-CfCEUX1jpW-g  in  0.3760068416595459
# Lasso mae 0.651672433679 rmse 0.7585386061713244
#
#
# Finish building model for user  3 , id  yK6wyLZ2I66B5-MJcS88xg  in  1.3245069980621338
# Lasso mae 0.921464760545 rmse 1.1401538246596674
#
#
# Finish building model for user  4 , id  hFvLG_m26hYMx1UGQSpaEg  in  1.005734920501709
# Lasso mae 0.9597304405 rmse 1.159915816764471
#
#
# Finish building model for user  5 , id  X4cwQL_JZZnAUyCbOwz3pw  in  1.0511066913604736
# Lasso mae 1.04018141736 rmse 1.2374973284032835
#
#
# Finish building model for user  6 , id  l1VoG-0-bDF-us7xbWxfeg  in  0.9078147411346436
# Lasso mae 0.693831915837 rmse 0.8561952756235336
#
#
# Finish building model for user  7 , id  mb_8jXannipO5T5V5kGXiQ  in  2.759864091873169
# Lasso mae 0.81060394826 rmse 0.986538455669419
#
#
# Finish building model for user  8 , id  qOdmye8UQdqloVNE059PkQ  in  1.0694890022277832
# Lasso mae 1.03505182238 rmse 1.2562748798301113
#
#
# Finish building model for user  9 , id  OmBHPdD3UhTeO3UHq6kBjA  in  1.2203686237335205
# Lasso mae 1.03677988366 rmse 1.28983960222968
#
#
# Finish building model for user  10 , id  mFwRTTDW0Yr-rFkTF2cFsw  in  0.6097507476806641
# Lasso mae 0.752070824855 rmse 0.9173263596819272
#
#
# Finish building model for user  11 , id  yfhchNS9zMnnIGYnRC218g  in  0.3536641597747803
# Lasso mae 0.603550295858 rmse 0.926347286409656
#
#
# Finish building model for user  12 , id  A9PzIlg1jlezCcpuN9V8UQ  in  0.546231746673584
# Lasso mae 0.90172073633 rmse 1.1054013998210641
#
#
# Finish building model for user  13 , id  QyOjGyQS6mI-o8HVpVq8fQ  in  0.620455265045166
# Lasso mae 0.890941282242 rmse 1.1186676029926503
#
#
# Finish building model for user  14 , id  -d2daWmftYumOaYpbD5D8Q  in  0.9463405609130859
# Lasso mae 0.807648677694 rmse 0.9532588345237143
#
#
# Finish building model for user  15 , id  YEDnTf7d6RyXKEHDGqi9tg  in  0.6400551795959473
# Lasso mae 0.774491492968 rmse 1.0098606922038613
#
#
# Finish building model for user  16 , id  vCbYnQ0DdpHb-vGRZVMkxg  in  0.7795536518096924
# Lasso mae 0.90266267217 rmse 1.0695387372193954
#
#
# Finish building model for user  17 , id  F3dKpfp0EpxkL-rDZSKzvA  in  0.3390045166015625
# Lasso mae 0.967781937116 rmse 1.1414617261942177
#
#
# Finish building model for user  18 , id  Qx8WMsFNHBfx6rIH_G0nBw  in  0.6132106781005859
# Lasso mae 0.741090724967 rmse 0.9083249844505499
#
#
# Finish building model for user  19 , id  6pDCqee5g6jFB402L15kmg  in  0.7516624927520752
# Lasso mae 0.582187588613 rmse 0.7335451674567435
#
#
# Finish building model for user  20 , id  9W73B44Iw8WslrTNB2CdCg  in  2.1876115798950195
# Lasso mae 0.704011451639 rmse 0.8501326205977975
#
#
# Finish building model for user  21 , id  kB9QPxar7HLKIpK7qeMnFA  in  0.6599502563476562
# Lasso mae 0.859152638948 rmse 1.050250766916221
#
#
# Finish building model for user  22 , id  _3WlbW1RkJmyKMMqLPYorA  in  0.5427076816558838
# Lasso mae 0.879385442749 rmse 1.10138455872737
#
#
# Finish building model for user  23 , id  JVbqMyicxGWlEVPpyo6gpQ  in  0.5360686779022217
# Lasso mae 0.853176909462 rmse 1.0337965138355005
#
#
# Finish building model for user  24 , id  zWWcik1fRPZviBCQLC26FQ  in  2.5058295726776123
# Lasso mae 0.817138772105 rmse 1.00444519378709
#
#
# Finish building model for user  25 , id  1fNQRju9gmoCEvbPQBSo7w  in  4.707221031188965
# Lasso mae 0.618617368368 rmse 0.7899172190307642
#
#
# Finish building model for user  26 , id  EC5TGpxONfz4IZIjML0DpQ  in  1.5916924476623535
# Lasso mae 0.722088336512 rmse 0.8960419073211037
#
#
# Finish building model for user  27 , id  --Qh8yKWAvIP4V4K8ZPfHA  in  2.903282880783081
# Lasso mae 0.697430097511 rmse 0.9355199838045001
#
#
# Finish building model for user  28 , id  EyYVD9n7PlYYLTSEQ5t14w  in  0.919379472732544
# Lasso mae 0.513647366355 rmse 0.5387377254187375
#
#
# Finish building model for user  29 , id  HFItzRohDHZvcKDrM6ABZg  in  5.566621541976929
# Lasso mae 0.747836493325 rmse 0.902336895935855
#
#
# Finish building model for user  30 , id  j6Kv_wLQzZMWobLIyijX3A  in  2.2286131381988525
# Lasso mae 0.854749696167 rmse 1.0171289863663837
#
#
# Finish building model for user  31 , id  hTZb1INhnCG8URaFywVoYQ  in  1.2631473541259766
# Lasso mae 0.664765056177 rmse 0.8166823964743172
#
#
# Finish building model for user  32 , id  8P2LkzPGV4ID_fE7gJGKGg  in  0.8227560520172119
# Lasso mae 0.803265306122 rmse 0.9554862434488507
#
#
# Finish building model for user  33 , id  GvIJqIr7GcbGUUxxrgXg2A  in  0.31111884117126465
# Lasso mae 0.987933634992 rmse 1.1533869801696963
#
#
# Finish building model for user  34 , id  xDed_RrQv7xuwOp9hESt9Q  in  0.3225569725036621
# Lasso mae 0.675253991292 rmse 0.9215078192485462
#
#
# Finish building model for user  35 , id  P7EV3yrn1PLHDBX6rF6qIg  in  0.6381146907806396
# Lasso mae 0.756844924404 rmse 0.9269636759977181
#
#
# Finish building model for user  36 , id  CjbfWpCRLbA-L_eS_ztd6Q  in  0.31488585472106934
# Lasso mae 0.946943483276 rmse 1.1544452314091318
#
#
# Finish building model for user  37 , id  0J9mtVJ4_QGsXYVK8qJzOQ  in  1.6938841342926025
# Lasso mae 0.798727549482 rmse 1.0090791063186197
#
#
# Finish building model for user  38 , id  pMefTWo6gMdx8WhYSA2u3w  in  2.773552656173706
# Lasso mae 0.65927506364 rmse 0.8071783159618625
#
#
# Finish building model for user  39 , id  IgPXs-Vpd3p_POXau4szFg  in  0.49020934104919434
# Lasso mae 1.06448372054 rmse 1.275877963030171
#
#
# Finish building model for user  40 , id  R1PCyy2n0NLWr1NlTz4fmQ  in  0.5184447765350342
# Lasso mae 0.938606916821 rmse 1.215453066958838
#
#
# Finish building model for user  41 , id  0LMHrFTQtUoY42AZl1MH6g  in  1.5594215393066406
# Lasso mae 0.883206630765 rmse 1.0514268013065544
#
#
# Finish building model for user  42 , id  i7mBC7m7k2FLrdVUx0UqUg  in  0.9779129028320312
# Lasso mae 0.948775510204 rmse 1.2037459285744125
# {'Lasso': {'mae': 0.82185581103504302, 'rmse': 1.0094789068056464}}

# %%
run_content_based.runML("ElasticNet", chunks[5], review, business)
# Out:
# Finish building model for user  0 , id  nDQEwuw5u6iQHYXEsQXsxg  in  0.7081687450408936
# ElasticNet mae 0.951255444962 rmse 1.1421904040442228
#
#
# Finish building model for user  1 , id  HAv4iHgSyMS4HKwl5hb98w  in  0.4456968307495117
# ElasticNet mae 0.908289241623 rmse 1.0688801927173723
#
#
# Finish building model for user  2 , id  ryI5QW93_-CfCEUX1jpW-g  in  0.3569767475128174
# ElasticNet mae 0.651672433679 rmse 0.7585386061713244
#
#
# Finish building model for user  3 , id  yK6wyLZ2I66B5-MJcS88xg  in  0.8639335632324219
# ElasticNet mae 0.914901258962 rmse 1.137263709013095
#
#
# Finish building model for user  4 , id  hFvLG_m26hYMx1UGQSpaEg  in  0.6378974914550781
# ElasticNet mae 0.96009590478 rmse 1.1566330040057662
#
#
# Finish building model for user  5 , id  X4cwQL_JZZnAUyCbOwz3pw  in  0.8976988792419434
# ElasticNet mae 1.04749792352 rmse 1.2380467461964588
#
#
# Finish building model for user  6 , id  l1VoG-0-bDF-us7xbWxfeg  in  0.780717134475708
# ElasticNet mae 0.698435609347 rmse 0.8405878457657985
#
#
# Finish building model for user  7 , id  mb_8jXannipO5T5V5kGXiQ  in  2.270953893661499
# ElasticNet mae 0.814086786379 rmse 0.9881862476502161
#
#
# Finish building model for user  8 , id  qOdmye8UQdqloVNE059PkQ  in  0.6461048126220703
# ElasticNet mae 1.02380524757 rmse 1.2440835257940284
#
#
# Finish building model for user  9 , id  OmBHPdD3UhTeO3UHq6kBjA  in  0.540233850479126
# ElasticNet mae 1.03677988366 rmse 1.28983960222968
#
#
# Finish building model for user  10 , id  mFwRTTDW0Yr-rFkTF2cFsw  in  0.6255958080291748
# ElasticNet mae 0.751920030391 rmse 0.9163600228951123
#
#
# Finish building model for user  11 , id  yfhchNS9zMnnIGYnRC218g  in  0.3110084533691406
# ElasticNet mae 0.603550295858 rmse 0.926347286409656
#
#
# Finish building model for user  12 , id  A9PzIlg1jlezCcpuN9V8UQ  in  0.5207536220550537
# ElasticNet mae 0.906375952609 rmse 1.1060978821831071
#
#
# Finish building model for user  13 , id  QyOjGyQS6mI-o8HVpVq8fQ  in  0.3974461555480957
# ElasticNet mae 0.891637949129 rmse 1.1170602491969217
#
#
# Finish building model for user  14 , id  -d2daWmftYumOaYpbD5D8Q  in  0.673072338104248
# ElasticNet mae 0.806444709446 rmse 0.952593021666583
#
#
# Finish building model for user  15 , id  YEDnTf7d6RyXKEHDGqi9tg  in  0.3861880302429199
# ElasticNet mae 0.764991530942 rmse 1.0055276393184467
#
#
# Finish building model for user  16 , id  vCbYnQ0DdpHb-vGRZVMkxg  in  0.49118804931640625
# ElasticNet mae 0.895129281451 rmse 1.0641896695655482
#
#
# Finish building model for user  17 , id  F3dKpfp0EpxkL-rDZSKzvA  in  0.3090829849243164
# ElasticNet mae 0.957859482669 rmse 1.1328078263796222
#
#
# Finish building model for user  18 , id  Qx8WMsFNHBfx6rIH_G0nBw  in  0.5199358463287354
# ElasticNet mae 0.743231204221 rmse 0.9084184245950657
#
#
# Finish building model for user  19 , id  6pDCqee5g6jFB402L15kmg  in  0.6079168319702148
# ElasticNet mae 0.58861976163 rmse 0.7347870454066472
#
#
# Finish building model for user  20 , id  9W73B44Iw8WslrTNB2CdCg  in  1.6111817359924316
# ElasticNet mae 0.737546079881 rmse 0.8845906559730286
#
#
# Finish building model for user  21 , id  kB9QPxar7HLKIpK7qeMnFA  in  0.43767523765563965
# ElasticNet mae 0.859584754452 rmse 1.051265181283896
#
#
# Finish building model for user  22 , id  _3WlbW1RkJmyKMMqLPYorA  in  0.339813232421875
# ElasticNet mae 0.87736633502 rmse 1.103347682917216
#
#
# Finish building model for user  23 , id  JVbqMyicxGWlEVPpyo6gpQ  in  0.6254653930664062
# ElasticNet mae 0.853154504699 rmse 1.0394315873031452
#
#
# Finish building model for user  24 , id  zWWcik1fRPZviBCQLC26FQ  in  1.4958829879760742
# ElasticNet mae 0.847142697148 rmse 1.0364753285539559
#
#
# Finish building model for user  25 , id  1fNQRju9gmoCEvbPQBSo7w  in  3.5223567485809326
# ElasticNet mae 0.625909888982 rmse 0.8075681403214119
#
#
# Finish building model for user  26 , id  EC5TGpxONfz4IZIjML0DpQ  in  1.3754403591156006
# ElasticNet mae 0.720275705691 rmse 0.8945116305816901
#
#
# Finish building model for user  27 , id  --Qh8yKWAvIP4V4K8ZPfHA  in  1.8722915649414062
# ElasticNet mae 0.695809988566 rmse 0.934358989516713
#
#
# Finish building model for user  28 , id  EyYVD9n7PlYYLTSEQ5t14w  in  0.6561992168426514
# ElasticNet mae 0.512812264222 rmse 0.5379267992018668
#
#
# Finish building model for user  29 , id  HFItzRohDHZvcKDrM6ABZg  in  2.9355592727661133
# ElasticNet mae 0.757206433233 rmse 0.9093630540592321
#
#
# Finish building model for user  30 , id  j6Kv_wLQzZMWobLIyijX3A  in  1.1520771980285645
# ElasticNet mae 0.855645854635 rmse 1.0178771785063145
#
#
# Finish building model for user  31 , id  hTZb1INhnCG8URaFywVoYQ  in  0.6211256980895996
# ElasticNet mae 0.669153745629 rmse 0.8215387645182157
#
#
# Finish building model for user  32 , id  8P2LkzPGV4ID_fE7gJGKGg  in  0.4547383785247803
# ElasticNet mae 0.803265306122 rmse 0.9554862434488507
#
#
# Finish building model for user  33 , id  GvIJqIr7GcbGUUxxrgXg2A  in  0.28830909729003906
# ElasticNet mae 0.987933634992 rmse 1.1533869801696963
#
#
# Finish building model for user  34 , id  xDed_RrQv7xuwOp9hESt9Q  in  0.3053462505340576
# ElasticNet mae 0.675253991292 rmse 0.9215078192485462
#
#
# Finish building model for user  35 , id  P7EV3yrn1PLHDBX6rF6qIg  in  0.5049009323120117
# ElasticNet mae 0.752239196098 rmse 0.9246247433566416
#
#
# Finish building model for user  36 , id  CjbfWpCRLbA-L_eS_ztd6Q  in  0.34744930267333984
# ElasticNet mae 0.946943483276 rmse 1.1544452314091318
#
#
# Finish building model for user  37 , id  0J9mtVJ4_QGsXYVK8qJzOQ  in  1.3459174633026123
# ElasticNet mae 0.739182865927 rmse 0.949230917449672
#
#
# Finish building model for user  38 , id  pMefTWo6gMdx8WhYSA2u3w  in  3.321425199508667
# ElasticNet mae 0.702948663728 rmse 0.8357541850303625
#
#
# Finish building model for user  39 , id  IgPXs-Vpd3p_POXau4szFg  in  0.3991053104400635
# ElasticNet mae 1.07417140836 rmse 1.282054559025892
#
#
# Finish building model for user  40 , id  R1PCyy2n0NLWr1NlTz4fmQ  in  0.6703922748565674
# ElasticNet mae 0.937584877791 rmse 1.2147088916152597
#
#
# Finish building model for user  41 , id  0LMHrFTQtUoY42AZl1MH6g  in  1.023763656616211
# ElasticNet mae 0.882967945612 rmse 1.0497371198183003
#
#
# Finish building model for user  42 , id  i7mBC7m7k2FLrdVUx0UqUg  in  0.8234710693359375
# ElasticNet mae 0.948775510204 rmse 1.2037459285744125
# {'ElasticNet': {'mae': 0.82277802484625484, 'rmse': 1.0095668968160032}}

# %%
run_content_based.runML("Lasso", chunks[6], review, business)
# Out:
# Finish building model for user  0 , id  69xsJFjiOAd8Ld7WWk_tEw  in  0.482236385345459
# Lasso mae 0.746428571429 rmse 0.9088619125643369
#
#
# Finish building model for user  1 , id  LB5ViGU59ww2XRCx803t0w  in  0.7358224391937256
# Lasso mae 0.808284840658 rmse 1.0293602480134303
#
#
# Finish building model for user  2 , id  ehzvSXsijzgxsYHvXeaS-Q  in  2.01694393157959
# Lasso mae 0.750714105545 rmse 0.9683753023528673
#
#
# Finish building model for user  3 , id  kqyCQG4c5dwNt2cTkMcvGA  in  0.5725131034851074
# Lasso mae 0.884289829747 rmse 1.0615443541449445
#
#
# Finish building model for user  4 , id  Zd3wzNdevk15CwMIJdbjZw  in  0.5364842414855957
# Lasso mae 0.755456248807 rmse 0.8787095573364404
#
#
# Finish building model for user  5 , id  Tc3GAQdAfOW542ROdyCZPg  in  0.43622660636901855
# Lasso mae 0.631476708998 rmse 0.7497861249976969
#
#
# Finish building model for user  6 , id  kxz6Q2AERQeo9x6nnbHZNg  in  1.5637176036834717
# Lasso mae 0.612856045185 rmse 0.7097497326350011
#
#
# Finish building model for user  7 , id  F-XkGoU9tZxZLdGI6JAtZw  in  1.4122884273529053
# Lasso mae 1.06963064295 rmse 1.2910679072515627
#
#
# Finish building model for user  8 , id  RX1D12KuO7FDcLZR5AOVrQ  in  1.0386700630187988
# Lasso mae 0.941335129168 rmse 1.1270829147367873
#
#
# Finish building model for user  9 , id  CA1N8B5ZkSiUJeOXYcWImg  in  0.5846543312072754
# Lasso mae 1.15970961887 rmse 1.3660863850640832
#
#
# Finish building model for user  10 , id  O3q-nwYZykMmacxjru01Zg  in  1.146303415298462
# Lasso mae 0.984674046153 rmse 1.1492748817299159
#
#
# Finish building model for user  11 , id  HyXK2GNR9i4SWpLQGOqQYQ  in  2.5494065284729004
# Lasso mae 0.696825531302 rmse 0.8352006004022787
#
#
# Finish building model for user  12 , id  jnB_saJqNfOmVoCWquhAzg  in  2.869488477706909
# Lasso mae 0.701474273061 rmse 0.8579691073548066
#
#
# Finish building model for user  13 , id  4Urg4tXL_m6nYsOt34mAeQ  in  1.1609644889831543
# Lasso mae 0.830956425058 rmse 0.9865080534499526
#
#
# Finish building model for user  14 , id  FTNaQZ3t0dsVWw1WZUQGFg  in  0.5320358276367188
# Lasso mae 0.748200241505 rmse 0.9174043070783315
#
#
# Finish building model for user  15 , id  iRQ_YKpCBdaCwvc2X8_3NQ  in  1.3358135223388672
# Lasso mae 0.963321585162 rmse 1.133393103439379
#
#
# Finish building model for user  16 , id  QRsuZ_LqrRU65dTs5CL4Lw  in  0.44247937202453613
# Lasso mae 0.701369389701 rmse 0.8798735295002349
#
#
# Finish building model for user  17 , id  oBc0gQ4RpFrqzpNlH6_epA  in  0.31288766860961914
# Lasso mae 0.546889094433 rmse 0.9064477089403091
#
#
# Finish building model for user  18 , id  m-2OHy6aP26oefPIiiTocg  in  0.7303292751312256
# Lasso mae 0.58701754386 rmse 0.6796417283699591
#
#
# Finish building model for user  19 , id  mrru6hbeQLvagU4vkfuqmw  in  1.2371020317077637
# Lasso mae 0.921009012108 rmse 1.0898981626583621
#
#
# Finish building model for user  20 , id  VnKj044Tt5doqaVDIJbWsw  in  1.5278527736663818
# Lasso mae 0.820407949006 rmse 0.9969673546232253
#
#
# Finish building model for user  21 , id  3G0J15bNMGEDlR9K_EAFdA  in  0.4381413459777832
# Lasso mae 1.16290726817 rmse 1.331456104457127
#
#
# Finish building model for user  22 , id  _1UbhUyIKUxBV3pKwPCB9Q  in  0.46010518074035645
# Lasso mae 0.963133640553 rmse 1.1748797014958723
#
#
# Finish building model for user  23 , id  XNs2G2K0LFMmaP1ceUZQfA  in  0.6013278961181641
# Lasso mae 0.86836663646 rmse 1.0833498478277928
#
#
# Finish building model for user  24 , id  bCLqNCdhUdsmTj9Braespg  in  0.4128084182739258
# Lasso mae 0.671440584306 rmse 0.8784452013430637
#
#
# Finish building model for user  25 , id  J3ucveGKKJDvtuCNnb_x0g  in  2.501277208328247
# Lasso mae 0.631223624822 rmse 0.7861693278684521
#
#
# Finish building model for user  26 , id  F8I0FAZxzWJjcLoajsYK3Q  in  0.3928818702697754
# Lasso mae 1.00322880881 rmse 1.182384651246668
#
#
# Finish building model for user  27 , id  qCYSdhsOzHBKT-V72BiYNA  in  1.780168056488037
# Lasso mae 0.67356441521 rmse 0.7998147837159022
#
#
# Finish building model for user  28 , id  UgWvxLS9xFvOxLILqxez2Q  in  0.8532562255859375
# Lasso mae 0.71907627831 rmse 0.9704423110072349
#
#
# Finish building model for user  29 , id  f1-ADSATZKZRdKznOcIpOQ  in  1.3318159580230713
# Lasso mae 0.840424446485 rmse 1.0017744134002626
#
#
# Finish building model for user  30 , id  buv4fFmsJhDfFWvOgUWxtw  in  1.0674636363983154
# Lasso mae 0.515425447199 rmse 0.737594799962132
#
#
# Finish building model for user  31 , id  G-9ujgKmc1J2k7HSqXszsw  in  1.2807800769805908
# Lasso mae 0.618500789693 rmse 0.7613716310038217
#
#
# Finish building model for user  32 , id  Gaj5UjugtJL2aCWO6wmY1Q  in  0.5170528888702393
# Lasso mae 0.808431952663 rmse 0.9838811869592186
#
#
# Finish building model for user  33 , id  KgJdBWS3ReP6TVhYWJRKmg  in  0.5307683944702148
# Lasso mae 0.828774026621 rmse 0.9777572713561724
#
#
# Finish building model for user  34 , id  PW_75-OTzdPzQvNrAkNqBA  in  0.3970682621002197
# Lasso mae 1.19818970676 rmse 1.4253794430162263
#
#
# Finish building model for user  35 , id  R_evEjQUmtzNalScjk2_Zg  in  0.531031608581543
# Lasso mae 0.831360946746 rmse 1.077266995766235
#
#
# Finish building model for user  36 , id  fm6vvm-T6ojK41Cw6Je3WA  in  0.5743117332458496
# Lasso mae 0.658425154528 rmse 0.8284422218727883
#
#
# Finish building model for user  37 , id  SkpCulULgiBfLc4lV8vx2g  in  1.201655626296997
# Lasso mae 0.767915106117 rmse 0.9800856444848562
#
#
# Finish building model for user  38 , id  m4fBjPA4SSIzQaNtr45Uow  in  0.304276704788208
# Lasso mae 0.772681525842 rmse 0.960708666767484
#
#
# Finish building model for user  39 , id  eRDWzHCldd6YXypRECvHYg  in  2.0932347774505615
# Lasso mae 0.790509420827 rmse 0.9417367640973469
#
#
# Finish building model for user  40 , id  d_uSfozaAZR4OpDNa8IiZQ  in  0.40068817138671875
# Lasso mae 1.10688196847 rmse 1.3325731229979942
#
#
# Finish building model for user  41 , id  surYJl8z-WOxqroyYgvmYg  in  0.3821091651916504
# Lasso mae 0.704664262942 rmse 0.8498659098732013
#
#
# Finish building model for user  42 , id  -_2h2cJlBOWAYrfplMU-Cg  in  1.13643479347229
# Lasso mae 0.660198667333 rmse 0.8120352546662051
# {'Lasso': {'mae': 0.80599189561840801, 'rmse': 0.9860608891123251}}

# %%
run_content_based.runML("ElasticNet", chunks[6], review, business)
# Out:
# Finish building model for user  0 , id  69xsJFjiOAd8Ld7WWk_tEw  in  0.5471558570861816
# ElasticNet mae 0.746428571429 rmse 0.9088619125643369
#
#
# Finish building model for user  1 , id  LB5ViGU59ww2XRCx803t0w  in  0.5039477348327637
# ElasticNet mae 0.809187996537 rmse 1.0246055040969275
#
#
# Finish building model for user  2 , id  ehzvSXsijzgxsYHvXeaS-Q  in  1.149970531463623
# ElasticNet mae 0.746304182186 rmse 0.9666891495623628
#
#
# Finish building model for user  3 , id  kqyCQG4c5dwNt2cTkMcvGA  in  0.6670050621032715
# ElasticNet mae 0.889091007145 rmse 1.0612570233053553
#
#
# Finish building model for user  4 , id  Zd3wzNdevk15CwMIJdbjZw  in  0.4484074115753174
# ElasticNet mae 0.74589100346 rmse 0.8704152183609581
#
#
# Finish building model for user  5 , id  Tc3GAQdAfOW542ROdyCZPg  in  0.44730544090270996
# ElasticNet mae 0.634675204504 rmse 0.7491800498220234
#
#
# Finish building model for user  6 , id  kxz6Q2AERQeo9x6nnbHZNg  in  0.9092645645141602
# ElasticNet mae 0.613712518537 rmse 0.7138943065846188
#
#
# Finish building model for user  7 , id  F-XkGoU9tZxZLdGI6JAtZw  in  0.8807804584503174
# ElasticNet mae 1.06963064295 rmse 1.2910679072515627
#
#
# Finish building model for user  8 , id  RX1D12KuO7FDcLZR5AOVrQ  in  0.6232364177703857
# ElasticNet mae 0.946680130486 rmse 1.1436421263587588
#
#
# Finish building model for user  9 , id  CA1N8B5ZkSiUJeOXYcWImg  in  0.35124683380126953
# ElasticNet mae 1.15970961887 rmse 1.3660863850640832
#
#
# Finish building model for user  10 , id  O3q-nwYZykMmacxjru01Zg  in  0.8849966526031494
# ElasticNet mae 0.983547569528 rmse 1.1484515229534624
#
#
# Finish building model for user  11 , id  HyXK2GNR9i4SWpLQGOqQYQ  in  1.7890138626098633
# ElasticNet mae 0.714295471621 rmse 0.8417136039694462
#
#
# Finish building model for user  12 , id  jnB_saJqNfOmVoCWquhAzg  in  1.6202504634857178
# ElasticNet mae 0.701474273061 rmse 0.8579691073548066
#
#
# Finish building model for user  13 , id  4Urg4tXL_m6nYsOt34mAeQ  in  0.702002763748169
# ElasticNet mae 0.827237577369 rmse 0.9760283540909979
#
#
# Finish building model for user  14 , id  FTNaQZ3t0dsVWw1WZUQGFg  in  0.4874553680419922
# ElasticNet mae 0.745539728861 rmse 0.9108206256171008
#
#
# Finish building model for user  15 , id  iRQ_YKpCBdaCwvc2X8_3NQ  in  0.9394869804382324
# ElasticNet mae 0.968060045082 rmse 1.1386469911717518
#
#
# Finish building model for user  16 , id  QRsuZ_LqrRU65dTs5CL4Lw  in  0.41521501541137695
# ElasticNet mae 0.700435067274 rmse 0.8810402867948586
#
#
# Finish building model for user  17 , id  oBc0gQ4RpFrqzpNlH6_epA  in  0.2937018871307373
# ElasticNet mae 0.536207716695 rmse 0.8729209421655838
#
#
# Finish building model for user  18 , id  m-2OHy6aP26oefPIiiTocg  in  0.5332121849060059
# ElasticNet mae 0.58701754386 rmse 0.6796417283699591
#
#
# Finish building model for user  19 , id  mrru6hbeQLvagU4vkfuqmw  in  0.8452050685882568
# ElasticNet mae 0.9385220742 rmse 1.1064924519309212
#
#
# Finish building model for user  20 , id  VnKj044Tt5doqaVDIJbWsw  in  1.1539318561553955
# ElasticNet mae 0.823561737843 rmse 1.0010181399903568
#
#
# Finish building model for user  21 , id  3G0J15bNMGEDlR9K_EAFdA  in  0.4994316101074219
# ElasticNet mae 1.16290726817 rmse 1.331456104457127
#
#
# Finish building model for user  22 , id  _1UbhUyIKUxBV3pKwPCB9Q  in  0.47623562812805176
# ElasticNet mae 0.963133640553 rmse 1.1748797014958723
#
#
# Finish building model for user  23 , id  XNs2G2K0LFMmaP1ceUZQfA  in  0.4445061683654785
# ElasticNet mae 0.870007297014 rmse 1.0926106891167824
#
#
# Finish building model for user  24 , id  bCLqNCdhUdsmTj9Braespg  in  0.3914339542388916
# ElasticNet mae 0.666838801887 rmse 0.873065051893722
#
#
# Finish building model for user  25 , id  J3ucveGKKJDvtuCNnb_x0g  in  2.1690139770507812
# ElasticNet mae 0.646732113319 rmse 0.7938359234157704
#
#
# Finish building model for user  26 , id  F8I0FAZxzWJjcLoajsYK3Q  in  0.41776466369628906
# ElasticNet mae 1.02364450011 rmse 1.218651487073294
#
#
# Finish building model for user  27 , id  qCYSdhsOzHBKT-V72BiYNA  in  1.0295417308807373
# ElasticNet mae 0.672891008098 rmse 0.7995107037142184
#
#
# Finish building model for user  28 , id  UgWvxLS9xFvOxLILqxez2Q  in  0.5884017944335938
# ElasticNet mae 0.70963719051 rmse 0.9544201878968965
#
#
# Finish building model for user  29 , id  f1-ADSATZKZRdKznOcIpOQ  in  0.9471187591552734
# ElasticNet mae 0.840922384403 rmse 1.0035720783779336
#
#
# Finish building model for user  30 , id  buv4fFmsJhDfFWvOgUWxtw  in  0.6601176261901855
# ElasticNet mae 0.520151225725 rmse 0.7412835283222408
#
#
# Finish building model for user  31 , id  G-9ujgKmc1J2k7HSqXszsw  in  0.7723801136016846
# ElasticNet mae 0.616355987738 rmse 0.7597951310860556
#
#
# Finish building model for user  32 , id  Gaj5UjugtJL2aCWO6wmY1Q  in  0.42638683319091797
# ElasticNet mae 0.808431952663 rmse 0.9838811869592186
#
#
# Finish building model for user  33 , id  KgJdBWS3ReP6TVhYWJRKmg  in  0.433851957321167
# ElasticNet mae 0.811913212067 rmse 0.9666254070727165
#
#
# Finish building model for user  34 , id  PW_75-OTzdPzQvNrAkNqBA  in  0.39165234565734863
# ElasticNet mae 1.19985809689 rmse 1.421458969864522
#
#
# Finish building model for user  35 , id  R_evEjQUmtzNalScjk2_Zg  in  0.5613865852355957
# ElasticNet mae 0.831360946746 rmse 1.077266995766235
#
#
# Finish building model for user  36 , id  fm6vvm-T6ojK41Cw6Je3WA  in  0.4162888526916504
# ElasticNet mae 0.658425154528 rmse 0.8284422218727883
#
#
# Finish building model for user  37 , id  SkpCulULgiBfLc4lV8vx2g  in  0.8210289478302002
# ElasticNet mae 0.771247846411 rmse 0.9807025007222674
#
#
# Finish building model for user  38 , id  m4fBjPA4SSIzQaNtr45Uow  in  0.49006175994873047
# ElasticNet mae 0.768834322203 rmse 0.9701306968403797
#
#
# Finish building model for user  39 , id  eRDWzHCldd6YXypRECvHYg  in  1.6768786907196045
# ElasticNet mae 0.790796985048 rmse 0.9418658173261867
#
#
# Finish building model for user  40 , id  d_uSfozaAZR4OpDNa8IiZQ  in  0.42282629013061523
# ElasticNet mae 1.10688196847 rmse 1.3325731229979942
#
#
# Finish building model for user  41 , id  surYJl8z-WOxqroyYgvmYg  in  0.42235803604125977
# ElasticNet mae 0.704380836947 rmse 0.8440567275637839
#
#
# Finish building model for user  42 , id  -_2h2cJlBOWAYrfplMU-Cg  in  1.1344552040100098
# ElasticNet mae 0.654752193274 rmse 0.8075447450532383
# {'ElasticNet': {'mae': 0.80668173521596698, 'rmse': 0.9862342399132438}}

# %%
run_content_based.runML("Lasso", chunks[7], review, business)
# Out:
# Finish building model for user  0 , id  MkFySOILZ4yhADa-0tZWZw  in  0.5045530796051025
# Lasso mae 0.855055523086 rmse 1.0856386287543534
#
#
# Finish building model for user  1 , id  Oxe8DXjBOi6C-cR2w64zOg  in  0.5837640762329102
# Lasso mae 0.893013999716 rmse 1.1302168976718256
#
#
# Finish building model for user  2 , id  5gYF8vCPu6bs7kJ4dIB-9A  in  0.3487257957458496
# Lasso mae 0.706882282917 rmse 0.9364383365761422
#
#
# Finish building model for user  3 , id  qJZCiO3qSOygLLxzX8l1wg  in  0.5108230113983154
# Lasso mae 0.977723609999 rmse 1.2039864138347556
#
#
# Finish building model for user  4 , id  aIg29snwGTFBzkV7HtDHfg  in  0.9063296318054199
# Lasso mae 0.697731755424 rmse 0.8292350636560892
#
#
# Finish building model for user  5 , id  4PQhC-zTQ4ACEN0-r39JuQ  in  0.8472721576690674
# Lasso mae 0.898496240602 rmse 1.0879241932399322
#
#
# Finish building model for user  6 , id  oXvYpri1ofscaiEqmCjknA  in  0.7598876953125
# Lasso mae 0.909569798068 rmse 1.144312733344207
#
#
# Finish building model for user  7 , id  tWBLn4k1M7PLBtAtwAg73g  in  3.4158554077148438
# Lasso mae 0.645076350692 rmse 0.7555875321384551
#
#
# Finish building model for user  8 , id  0w03V5AjlO_EHnRRorlLFQ  in  0.7103486061096191
# Lasso mae 0.883981123135 rmse 1.0361399717777755
#
#
# Finish building model for user  9 , id  L0JvK1BtEe5Yz_rmclfcQA  in  0.9224483966827393
# Lasso mae 0.825675607275 rmse 0.9888535757688413
#
#
# Finish building model for user  10 , id  eeBt7Uo5FOXwvaLIeW3fGA  in  1.0142948627471924
# Lasso mae 0.7924066771 rmse 0.9477719937869544
#
#
# Finish building model for user  11 , id  0uacsMYppmm3Kl1bpWIOxQ  in  0.8960621356964111
# Lasso mae 0.787582696566 rmse 1.0556531930099706
#
#
# Finish building model for user  12 , id  AlXx0P-OhUylep0jNi773g  in  0.7729799747467041
# Lasso mae 0.95551508845 rmse 1.1376628091051164
#
#
# Finish building model for user  13 , id  uz5-sq6wHrXScrIWb8r1Mg  in  0.4431488513946533
# Lasso mae 0.889732874339 rmse 1.0809716662314077
#
#
# Finish building model for user  14 , id  aNmrSw98PhdvZkLgxP2PWg  in  0.7035927772521973
# Lasso mae 0.86160646243 rmse 1.115159356711482
#
#
# Finish building model for user  15 , id  Ao-6FYE29-I8WwPg67806A  in  1.5403988361358643
# Lasso mae 0.675409259027 rmse 0.80767853455176
#
#
# Finish building model for user  16 , id  0l3x4EgoWVYdla3CPpAKag  in  1.3681657314300537
# Lasso mae 0.8598494233 rmse 1.0610770696793754
#
#
# Finish building model for user  17 , id  U5YQX_vMl_xQy8EQDqlNQQ  in  2.700451135635376
# Lasso mae 0.643086143705 rmse 0.7688872078292404
#
#
# Finish building model for user  18 , id  w5bwTIjGTebtlWEEAxfKhg  in  0.6659529209136963
# Lasso mae 0.888116144413 rmse 1.0713468434658
#
#
# Finish building model for user  19 , id  1HFkcIGKY7-e9vCsc8PX5g  in  0.7046604156494141
# Lasso mae 0.731514291042 rmse 0.8829015894893799
#
#
# Finish building model for user  20 , id  hYnq9-wO-RzmiTTGMCNJgA  in  0.6765012741088867
# Lasso mae 0.534326719015 rmse 0.7847142687058313
#
#
# Finish building model for user  21 , id  Gf8Jew6GZHKCk2F6kPZh5Q  in  0.7334935665130615
# Lasso mae 0.784607077992 rmse 0.9357072101688282
#
#
# Finish building model for user  22 , id  l0uKMipnY5z1aPltLWePOw  in  0.49949049949645996
# Lasso mae 0.717614853365 rmse 0.9632701910296582
#
#
# Finish building model for user  23 , id  tfcWQ_mKwgLkWu5pvpmsvg  in  0.4006474018096924
# Lasso mae 0.825255102041 rmse 0.9931462897178152
#
#
# Finish building model for user  24 , id  4KbUaerUBoiUwZGMHKVFxQ  in  1.3128225803375244
# Lasso mae 0.829223129366 rmse 0.9906455791867468
#
#
# Finish building model for user  25 , id  TUu4SppnJ1S3lQ_jTxMpOw  in  0.5540399551391602
# Lasso mae 0.749956289587 rmse 0.9116300942650912
#
#
# Finish building model for user  26 , id  DNlzbI54zCOa4to-vTWBJQ  in  1.6026864051818848
# Lasso mae 0.773328299937 rmse 0.9426183127064613
#
#
# Finish building model for user  27 , id  WHmabbfgdSW-JrOU9ePMrA  in  2.8538877964019775
# Lasso mae 0.603371302907 rmse 0.7665837156663575
#
#
# Finish building model for user  28 , id  Omhu17Pu7pGbO7KjbYLj1A  in  1.371091604232788
# Lasso mae 0.665041192528 rmse 0.7901671144701805
#
#
# Finish building model for user  29 , id  WeVkkF5L39888IPPlRhNpg  in  4.71190071105957
# Lasso mae 0.605918770882 rmse 0.7781207931862457
#
#
# Finish building model for user  30 , id  UXpTrzITc0yg08sXftsa-w  in  1.4644808769226074
# Lasso mae 0.744206818415 rmse 0.8663684858160559
#
#
# Finish building model for user  31 , id  0sOleKBI26BKfpW0SEG6Fw  in  0.5293054580688477
# Lasso mae 0.695919393279 rmse 0.8223206609035996
#
#
# Finish building model for user  32 , id  zPmSHgYVv3-izp6wIQ8ylA  in  0.3851752281188965
# Lasso mae 0.98992922748 rmse 1.1997765973076744
#
#
# Finish building model for user  33 , id  GqLTKz0YsSkX-DTc9oHrBg  in  0.6962873935699463
# Lasso mae 0.771609184577 rmse 0.9695897578119076
#
#
# Finish building model for user  34 , id  IL1-dyCe_zSqhmt0ExL_Jg  in  0.4665842056274414
# Lasso mae 0.563939271731 rmse 0.7984547195785766
#
#
# Finish building model for user  35 , id  v5o9CV8nFMfaCwAzEmkR2Q  in  0.3322291374206543
# Lasso mae 1.02948901254 rmse 1.227826592038289
#
#
# Finish building model for user  36 , id  Nvpx9fUIAB3oddqgRLEPfg  in  1.617351770401001
# Lasso mae 1.08531453819 rmse 1.260597640276691
#
#
# Finish building model for user  37 , id  sWKaLjpYG6VABf23CXDhyA  in  1.3438363075256348
# Lasso mae 0.894989416063 rmse 1.072366922015921
#
#
# Finish building model for user  38 , id  K3bzEv1h7CP-B92bNPhFUA  in  1.043884515762329
# Lasso mae 0.556722415283 rmse 0.7065979444808944
#
#
# Finish building model for user  39 , id  y05H_1uQhO4frLTJ5_tGCQ  in  1.3877716064453125
# Lasso mae 0.717032775479 rmse 0.8744605129520566
#
#
# Finish building model for user  40 , id  YvzoOqfBProz9SveFwJYOw  in  0.4208836555480957
# Lasso mae 0.457871147449 rmse 0.5920702154155519
#
#
# Finish building model for user  41 , id  HNrz6Xe7PoLjUp8kBUDykQ  in  0.3133683204650879
# Lasso mae 0.657542743978 rmse 0.808742674844977
#
#
# Finish building model for user  42 , id  LQG9wFTmscbAATp8QWj1hg  in  1.1090435981750488
# Lasso mae 0.76087478216 rmse 0.9448452610600444
# {'Lasso': {'mae': 0.77656067012837982, 'rmse': 0.9564666317262402}}

# %%
run_content_based.runML("ElasticNet", chunks[7], review, business)
# Out:
# Finish building model for user  0 , id  MkFySOILZ4yhADa-0tZWZw  in  0.417402982711792
# ElasticNet mae 0.855055523086 rmse 1.0856386287543534
#
#
# Finish building model for user  1 , id  Oxe8DXjBOi6C-cR2w64zOg  in  0.4137864112854004
# ElasticNet mae 0.89901796705 rmse 1.1351223695928603
#
#
# Finish building model for user  2 , id  5gYF8vCPu6bs7kJ4dIB-9A  in  0.32803916931152344
# ElasticNet mae 0.717365762098 rmse 0.9447045247808563
#
#
# Finish building model for user  3 , id  qJZCiO3qSOygLLxzX8l1wg  in  0.41791605949401855
# ElasticNet mae 0.976518948343 rmse 1.2026659937608013
#
#
# Finish building model for user  4 , id  aIg29snwGTFBzkV7HtDHfg  in  0.4686398506164551
# ElasticNet mae 0.697731755424 rmse 0.8292350636560891
#
#
# Finish building model for user  5 , id  4PQhC-zTQ4ACEN0-r39JuQ  in  0.41760873794555664
# ElasticNet mae 0.898496240602 rmse 1.0879241932399322
#
#
# Finish building model for user  6 , id  oXvYpri1ofscaiEqmCjknA  in  0.4917731285095215
# ElasticNet mae 0.909569798068 rmse 1.144312733344207
#
#
# Finish building model for user  7 , id  tWBLn4k1M7PLBtAtwAg73g  in  3.271070957183838
# ElasticNet mae 0.658983177268 rmse 0.7657629308509916
#
#
# Finish building model for user  8 , id  0w03V5AjlO_EHnRRorlLFQ  in  0.5305585861206055
# ElasticNet mae 0.883436752979 rmse 1.0320882491738606
#
#
# Finish building model for user  9 , id  L0JvK1BtEe5Yz_rmclfcQA  in  0.5841357707977295
# ElasticNet mae 0.831305022119 rmse 1.019660954855893
#
#
# Finish building model for user  10 , id  eeBt7Uo5FOXwvaLIeW3fGA  in  0.7962090969085693
# ElasticNet mae 0.792971481009 rmse 0.9482535967531527
#
#
# Finish building model for user  11 , id  0uacsMYppmm3Kl1bpWIOxQ  in  0.7123394012451172
# ElasticNet mae 0.812081236198 rmse 1.0771009909631077
#
#
# Finish building model for user  12 , id  AlXx0P-OhUylep0jNi773g  in  0.6247272491455078
# ElasticNet mae 0.95551508845 rmse 1.1376628091051164
#
#
# Finish building model for user  13 , id  uz5-sq6wHrXScrIWb8r1Mg  in  0.3816201686859131
# ElasticNet mae 0.891043397969 rmse 1.0821501443132204
#
#
# Finish building model for user  14 , id  aNmrSw98PhdvZkLgxP2PWg  in  0.49410176277160645
# ElasticNet mae 0.86160646243 rmse 1.115159356711482
#
#
# Finish building model for user  15 , id  Ao-6FYE29-I8WwPg67806A  in  1.0734009742736816
# ElasticNet mae 0.678066139998 rmse 0.8012919855309328
#
#
# Finish building model for user  16 , id  0l3x4EgoWVYdla3CPpAKag  in  1.0512466430664062
# ElasticNet mae 0.860332032478 rmse 1.061737830269136
#
#
# Finish building model for user  17 , id  U5YQX_vMl_xQy8EQDqlNQQ  in  2.465207815170288
# ElasticNet mae 0.660940123662 rmse 0.7823904922184683
#
#
# Finish building model for user  18 , id  w5bwTIjGTebtlWEEAxfKhg  in  0.4695258140563965
# ElasticNet mae 0.891294281048 rmse 1.0780119128514738
#
#
# Finish building model for user  19 , id  1HFkcIGKY7-e9vCsc8PX5g  in  0.6191895008087158
# ElasticNet mae 0.730260976594 rmse 0.8842280217721739
#
#
# Finish building model for user  20 , id  hYnq9-wO-RzmiTTGMCNJgA  in  0.7021770477294922
# ElasticNet mae 0.562184620401 rmse 0.8118155873791117
#
#
# Finish building model for user  21 , id  Gf8Jew6GZHKCk2F6kPZh5Q  in  0.5728588104248047
# ElasticNet mae 0.785208609649 rmse 0.9364973221900807
#
#
# Finish building model for user  22 , id  l0uKMipnY5z1aPltLWePOw  in  0.41074419021606445
# ElasticNet mae 0.716269420677 rmse 0.964124700726392
#
#
# Finish building model for user  23 , id  tfcWQ_mKwgLkWu5pvpmsvg  in  0.38628101348876953
# ElasticNet mae 0.825255102041 rmse 0.9931462897178152
#
#
# Finish building model for user  24 , id  4KbUaerUBoiUwZGMHKVFxQ  in  1.2723610401153564
# ElasticNet mae 0.829223129366 rmse 0.9906455791867468
#
#
# Finish building model for user  25 , id  TUu4SppnJ1S3lQ_jTxMpOw  in  0.6284053325653076
# ElasticNet mae 0.746114617458 rmse 0.9086658697230541
#
#
# Finish building model for user  26 , id  DNlzbI54zCOa4to-vTWBJQ  in  1.7700085639953613
# ElasticNet mae 0.773834758036 rmse 0.9401263721100227
#
#
# Finish building model for user  27 , id  WHmabbfgdSW-JrOU9ePMrA  in  2.285998821258545
# ElasticNet mae 0.631757846483 rmse 0.7807799073810809
#
#
# Finish building model for user  28 , id  Omhu17Pu7pGbO7KjbYLj1A  in  1.1528797149658203
# ElasticNet mae 0.664495063699 rmse 0.7881950311795931
#
#
# Finish building model for user  29 , id  WeVkkF5L39888IPPlRhNpg  in  3.53686785697937
# ElasticNet mae 0.618042643348 rmse 0.7990595244705424
#
#
# Finish building model for user  30 , id  UXpTrzITc0yg08sXftsa-w  in  0.9703443050384521
# ElasticNet mae 0.745521643 rmse 0.8667475052158131
#
#
# Finish building model for user  31 , id  0sOleKBI26BKfpW0SEG6Fw  in  0.4459691047668457
# ElasticNet mae 0.694388265955 rmse 0.8195907152525
#
#
# Finish building model for user  32 , id  zPmSHgYVv3-izp6wIQ8ylA  in  0.3507390022277832
# ElasticNet mae 0.985768849258 rmse 1.1985569702219114
#
#
# Finish building model for user  33 , id  GqLTKz0YsSkX-DTc9oHrBg  in  0.5435032844543457
# ElasticNet mae 0.771030050869 rmse 0.9616676855521478
#
#
# Finish building model for user  34 , id  IL1-dyCe_zSqhmt0ExL_Jg  in  0.33730125427246094
# ElasticNet mae 0.560870983157 rmse 0.7970206729177487
#
#
# Finish building model for user  35 , id  v5o9CV8nFMfaCwAzEmkR2Q  in  0.29683494567871094
# ElasticNet mae 0.981309654523 rmse 1.1938808106523529
#
#
# Finish building model for user  36 , id  Nvpx9fUIAB3oddqgRLEPfg  in  0.9167144298553467
# ElasticNet mae 1.08531453819 rmse 1.260597640276691
#
#
# Finish building model for user  37 , id  sWKaLjpYG6VABf23CXDhyA  in  1.0005934238433838
# ElasticNet mae 0.895138381625 rmse 1.0730528342542445
#
#
# Finish building model for user  38 , id  K3bzEv1h7CP-B92bNPhFUA  in  0.7394602298736572
# ElasticNet mae 0.557219136969 rmse 0.7069728370901271
#
#
# Finish building model for user  39 , id  y05H_1uQhO4frLTJ5_tGCQ  in  1.0816590785980225
# ElasticNet mae 0.728701068471 rmse 0.8875028975335992
#
#
# Finish building model for user  40 , id  YvzoOqfBProz9SveFwJYOw  in  0.7084569931030273
# ElasticNet mae 0.460194787552 rmse 0.5928219659699066
#
#
# Finish building model for user  41 , id  HNrz6Xe7PoLjUp8kBUDykQ  in  0.6873586177825928
# ElasticNet mae 0.655772048235 rmse 0.8070287538031911
#
#
# Finish building model for user  42 , id  LQG9wFTmscbAATp8QWj1hg  in  1.390977144241333
# ElasticNet mae 0.762212218575 rmse 0.9471921899420771
# {'ElasticNet': {'mae': 0.77900975824193008, 'rmse': 0.959088196401043}}

# %%
run_content_based.runML("Lasso", chunks[8], review, business)
# Out:
# Finish building model for user  0 , id  fkMiipV4j_DG5nSoBnZvbg  in  2.871121883392334
# Lasso mae 0.554992267616 rmse 0.7520402393099657
#
#
# Finish building model for user  1 , id  EgotOxec2MuH4xvIv_KRIA  in  1.206425428390503
# Lasso mae 0.684484317079 rmse 0.856165690113283
#
#
# Finish building model for user  2 , id  w2wFvtGWp7ZGMe-T9fsRIA  in  0.32226014137268066
# Lasso mae 0.674733710031 rmse 0.8187792772791775
#
#
# Finish building model for user  3 , id  Em4XpeXTKXVy4GjBL291pA  in  0.38243603706359863
# Lasso mae 1.04997077732 rmse 1.226438443793225
#
#
# Finish building model for user  4 , id  v-_wEl7yiX_MkmIqPq2BLQ  in  0.43565940856933594
# Lasso mae 0.579478067762 rmse 0.6940682651559681
#
#
# Finish building model for user  5 , id  JLv2Dmfj73-I0d9N41tz1A  in  1.6776025295257568
# Lasso mae 1.23084730897 rmse 1.493936593551003
#
#
# Finish building model for user  6 , id  dqKGX-Zz61Cz62S86mHNmg  in  0.380321741104126
# Lasso mae 0.765879895253 rmse 0.9519258325157468
#
#
# Finish building model for user  7 , id  veqfgg2AkKs_L70fx1Quag  in  1.5563454627990723
# Lasso mae 0.872975206612 rmse 1.08582022650879
#
#
# Finish building model for user  8 , id  tU94-C1zpBsfGFvpsJJr2w  in  1.5419878959655762
# Lasso mae 0.720371026281 rmse 0.8641474558733253
#
#
# Finish building model for user  9 , id  6cW8GuKZyFjpg29djEJoPg  in  0.46984052658081055
# Lasso mae 1.04717627032 rmse 1.2284213544619214
#
#
# Finish building model for user  10 , id  uSMK7y_H2DzRX7WcKXtFgQ  in  0.5625605583190918
# Lasso mae 0.850965694072 rmse 1.028536470424108
#
#
# Finish building model for user  11 , id  OzGlDEQ_vzH8QU9NBRs-pw  in  0.3040797710418701
# Lasso mae 0.744086352318 rmse 0.9054173492468134
#
#
# Finish building model for user  12 , id  rLl5jjjUK1crVfzbXoQrTA  in  1.8866510391235352
# Lasso mae 0.760467780613 rmse 0.9296166509340449
#
#
# Finish building model for user  13 , id  73-0YwihQK87y7oH_pO_1w  in  0.5730361938476562
# Lasso mae 0.578932755066 rmse 0.6946218526760726
#
#
# Finish building model for user  14 , id  AQ68GdYacVeqqqroAh9eOA  in  1.1685712337493896
# Lasso mae 0.853454883968 rmse 1.0563172513043781
#
#
# Finish building model for user  15 , id  yzwOcVyWuXQpmDlPXWw0Mw  in  1.168959140777588
# Lasso mae 0.985595702007 rmse 1.2016162381103699
#
#
# Finish building model for user  16 , id  A-IkCqnYosZa49XD9qiSww  in  1.1364541053771973
# Lasso mae 0.932375352113 rmse 1.136419090369864
#
#
# Finish building model for user  17 , id  syCxRdiP-0XJenWpJ8L02g  in  0.6339099407196045
# Lasso mae 0.924493043565 rmse 1.1101240565428598
#
#
# Finish building model for user  18 , id  OZWskTOKCWvYejhu63gFmQ  in  0.6088669300079346
# Lasso mae 0.623267783364 rmse 0.8272811875010159
#
#
# Finish building model for user  19 , id  ulk3n0JW8tWnQ83C7m8z9A  in  0.4657633304595947
# Lasso mae 0.518543645409 rmse 0.5447908628485154
#
#
# Finish building model for user  20 , id  _VtgrnnPVIE3ahJ2R8RW6Q  in  0.6572589874267578
# Lasso mae 0.84775091171 rmse 1.0064909984548747
#
#
# Finish building model for user  21 , id  jI43jHCXx1R-gg_vYcQWww  in  1.2222132682800293
# Lasso mae 0.667037037037 rmse 0.7795291351612744
#
#
# Finish building model for user  22 , id  XbiKsujS_qxU3xsr0xUqmQ  in  1.9467625617980957
# Lasso mae 0.616512161984 rmse 0.7269830622021032
#
#
# Finish building model for user  23 , id  JesJ-LaNfr3pKhL7gWhDrw  in  2.6647346019744873
# Lasso mae 0.918580022528 rmse 1.1189434518132058
#
#
# Finish building model for user  24 , id  N0qq4upibIRvLzE2SzVPtQ  in  1.6552107334136963
# Lasso mae 0.867906935169 rmse 1.0892720662834325
#
#
# Finish building model for user  25 , id  leJEG7VNrgaU1Ck0zAO-DQ  in  0.5916471481323242
# Lasso mae 0.986320180944 rmse 1.1479679603447939
#
#
# Finish building model for user  26 , id  orh0HRUNCWuQMt9Iia_osg  in  2.5661709308624268
# Lasso mae 0.731063739024 rmse 0.8977884443335589
#
#
# Finish building model for user  27 , id  qIIWAMJ_LwlJi0fntUpsjg  in  0.4621005058288574
# Lasso mae 1.0917003062 rmse 1.2579208647964681
#
#
# Finish building model for user  28 , id  ic-tyi1jElL_umxZVh8KNA  in  2.24098539352417
# Lasso mae 1.03639090226 rmse 1.2156072073560458
#
#
# Finish building model for user  29 , id  pVj37cy4Y6FfH9YIlEhsZA  in  0.4057180881500244
# Lasso mae 0.910150891632 rmse 1.0879541231555043
#
#
# Finish building model for user  30 , id  CQ67NJigSe5-uBDX3b_CUw  in  0.8235824108123779
# Lasso mae 0.63722422046 rmse 0.7510657706042836
#
#
# Finish building model for user  31 , id  SDAjElWg3R5x8AGo5guKRA  in  0.5150878429412842
# Lasso mae 1.06131189449 rmse 1.3044118667902405
#
#
# Finish building model for user  32 , id  Z_9dBipXbBldN3Er2og1MQ  in  0.3746321201324463
# Lasso mae 0.628219915417 rmse 0.7978704410367804
#
#
# Finish building model for user  33 , id  GZODRhmi-uUWKmWntTXujw  in  0.5579290390014648
# Lasso mae 0.732983894452 rmse 0.915789789965684
#
#
# Finish building model for user  34 , id  XNbrAATnVNAg1eTjMjn-pA  in  1.3018887042999268
# Lasso mae 0.641546521506 rmse 0.9045328293956528
#
#
# Finish building model for user  35 , id  nOSWGrjT4HIpDohLAOpgLw  in  0.6411514282226562
# Lasso mae 1.09700441813 rmse 1.3085314143936233
#
#
# Finish building model for user  36 , id  SJJWIZLPGXtGTy9UECbVjA  in  0.5293104648590088
# Lasso mae 0.890030895652 rmse 1.0707210034818626
#
#
# Finish building model for user  37 , id  ZrN6jjXI41GP7Oieae6CNQ  in  0.7345318794250488
# Lasso mae 0.642794702549 rmse 0.7681412753392445
#
#
# Finish building model for user  38 , id  rGd8YUtvhSdMm8-9cMdQ4Q  in  2.4613335132598877
# Lasso mae 0.706076876233 rmse 0.8438640062703094
#
#
# Finish building model for user  39 , id  tjTrsF-CpDnTcclX-3sCTw  in  1.4503450393676758
# Lasso mae 0.774078478002 rmse 0.9499932820286633
#
#
# Finish building model for user  40 , id  gS4QCL6j_umAyfJXBGAZJQ  in  1.5819764137268066
# Lasso mae 0.517761315934 rmse 0.6569567283258175
#
#
# Finish building model for user  41 , id  x6_9RC7Mc0SsFUcWxEoN_Q  in  0.6702039241790771
# Lasso mae 0.96049165935 rmse 1.1877118425958892
#
#
# Finish building model for user  42 , id  uHZr3XbjKvRTwdXLXrFuvg  in  1.321631908416748
# Lasso mae 0.901534119607 rmse 1.0793905395177208
# {'Lasso': {'mae': 0.80971078697683241, 'rmse': 0.9831144765620345}}

# %%
run_content_based.runML("ElasticNet", chunks[8], review, business)
# Out:
# Finish building model for user  0 , id  fkMiipV4j_DG5nSoBnZvbg  in  1.9356634616851807
# ElasticNet mae 0.573284055194 rmse 0.7741272682716482
#
#
# Finish building model for user  1 , id  EgotOxec2MuH4xvIv_KRIA  in  0.8765578269958496
# ElasticNet mae 0.684431915869 rmse 0.8690696611447
#
#
# Finish building model for user  2 , id  w2wFvtGWp7ZGMe-T9fsRIA  in  0.35819578170776367
# ElasticNet mae 0.671657549338 rmse 0.8160732819206691
#
#
# Finish building model for user  3 , id  Em4XpeXTKXVy4GjBL291pA  in  0.44020748138427734
# ElasticNet mae 1.04997077732 rmse 1.226438443793225
#
#
# Finish building model for user  4 , id  v-_wEl7yiX_MkmIqPq2BLQ  in  0.3280484676361084
# ElasticNet mae 0.577482787612 rmse 0.6912173455766154
#
#
# Finish building model for user  5 , id  JLv2Dmfj73-I0d9N41tz1A  in  1.0737426280975342
# ElasticNet mae 1.21130115325 rmse 1.5095557386258243
#
#
# Finish building model for user  6 , id  dqKGX-Zz61Cz62S86mHNmg  in  0.3493926525115967
# ElasticNet mae 0.791389632514 rmse 0.9865923586286736
#
#
# Finish building model for user  7 , id  veqfgg2AkKs_L70fx1Quag  in  1.1064419746398926
# ElasticNet mae 0.872975206612 rmse 1.08582022650879
#
#
# Finish building model for user  8 , id  tU94-C1zpBsfGFvpsJJr2w  in  0.9334394931793213
# ElasticNet mae 0.721514009835 rmse 0.8656862624293651
#
#
# Finish building model for user  9 , id  6cW8GuKZyFjpg29djEJoPg  in  0.3712165355682373
# ElasticNet mae 0.986006294378 rmse 1.1745212193479642
#
#
# Finish building model for user  10 , id  uSMK7y_H2DzRX7WcKXtFgQ  in  0.44948554039001465
# ElasticNet mae 0.85261333617 rmse 1.02937011768465
#
#
# Finish building model for user  11 , id  OzGlDEQ_vzH8QU9NBRs-pw  in  0.3408374786376953
# ElasticNet mae 0.737429549741 rmse 0.8985934526152441
#
#
# Finish building model for user  12 , id  rLl5jjjUK1crVfzbXoQrTA  in  1.1032030582427979
# ElasticNet mae 0.763640498041 rmse 0.9361026656775986
#
#
# Finish building model for user  13 , id  73-0YwihQK87y7oH_pO_1w  in  0.3708622455596924
# ElasticNet mae 0.576904667622 rmse 0.693013041250272
#
#
# Finish building model for user  14 , id  AQ68GdYacVeqqqroAh9eOA  in  0.5400054454803467
# ElasticNet mae 0.872140610911 rmse 1.0732477597889512
#
#
# Finish building model for user  15 , id  yzwOcVyWuXQpmDlPXWw0Mw  in  0.7833473682403564
# ElasticNet mae 0.960461342703 rmse 1.1283001903109646
#
#
# Finish building model for user  16 , id  A-IkCqnYosZa49XD9qiSww  in  0.7179279327392578
# ElasticNet mae 0.936251708878 rmse 1.1414351745623326
#
#
# Finish building model for user  17 , id  syCxRdiP-0XJenWpJ8L02g  in  0.4312417507171631
# ElasticNet mae 0.923652179704 rmse 1.1086180834651098
#
#
# Finish building model for user  18 , id  OZWskTOKCWvYejhu63gFmQ  in  0.4530181884765625
# ElasticNet mae 0.616866859917 rmse 0.8190447620399894
#
#
# Finish building model for user  19 , id  ulk3n0JW8tWnQ83C7m8z9A  in  0.4401836395263672
# ElasticNet mae 0.518543645409 rmse 0.5447908628485154
#
#
# Finish building model for user  20 , id  _VtgrnnPVIE3ahJ2R8RW6Q  in  0.4605851173400879
# ElasticNet mae 0.848832179931 rmse 1.0064808381437405
#
#
# Finish building model for user  21 , id  jI43jHCXx1R-gg_vYcQWww  in  0.8711912631988525
# ElasticNet mae 0.667037037037 rmse 0.7795291351612744
#
#
# Finish building model for user  22 , id  XbiKsujS_qxU3xsr0xUqmQ  in  1.7231166362762451
# ElasticNet mae 0.613484051798 rmse 0.7323018014464302
#
#
# Finish building model for user  23 , id  JesJ-LaNfr3pKhL7gWhDrw  in  1.7143425941467285
# ElasticNet mae 0.968389741174 rmse 1.1706005888163096
#
#
# Finish building model for user  24 , id  N0qq4upibIRvLzE2SzVPtQ  in  0.9913651943206787
# ElasticNet mae 0.925907109012 rmse 1.1392054068232973
#
#
# Finish building model for user  25 , id  leJEG7VNrgaU1Ck0zAO-DQ  in  0.5454270839691162
# ElasticNet mae 0.986712321291 rmse 1.1482804235140318
#
#
# Finish building model for user  26 , id  orh0HRUNCWuQMt9Iia_osg  in  1.3834593296051025
# ElasticNet mae 0.738448385084 rmse 0.9008841366209366
#
#
# Finish building model for user  27 , id  qIIWAMJ_LwlJi0fntUpsjg  in  0.3605375289916992
# ElasticNet mae 1.09353960695 rmse 1.259338405567616
#
#
# Finish building model for user  28 , id  ic-tyi1jElL_umxZVh8KNA  in  1.301494836807251
# ElasticNet mae 1.04456059784 rmse 1.2289909145031999
#
#
# Finish building model for user  29 , id  pVj37cy4Y6FfH9YIlEhsZA  in  0.35387635231018066
# ElasticNet mae 0.910150891632 rmse 1.0879541231555043
#
#
# Finish building model for user  30 , id  CQ67NJigSe5-uBDX3b_CUw  in  0.5665380954742432
# ElasticNet mae 0.651156779797 rmse 0.7651538552632247
#
#
# Finish building model for user  31 , id  SDAjElWg3R5x8AGo5guKRA  in  0.5086419582366943
# ElasticNet mae 1.01385659104 rmse 1.2427063194934274
#
#
# Finish building model for user  32 , id  Z_9dBipXbBldN3Er2og1MQ  in  0.4290783405303955
# ElasticNet mae 0.628219915417 rmse 0.7978704410367804
#
#
# Finish building model for user  33 , id  GZODRhmi-uUWKmWntTXujw  in  0.45781922340393066
# ElasticNet mae 0.744334215295 rmse 0.9243007896782923
#
#
# Finish building model for user  34 , id  XNbrAATnVNAg1eTjMjn-pA  in  0.8645801544189453
# ElasticNet mae 0.63442027158 rmse 0.9051205254095149
#
#
# Finish building model for user  35 , id  nOSWGrjT4HIpDohLAOpgLw  in  0.5116384029388428
# ElasticNet mae 1.09384203683 rmse 1.3056512054743994
#
#
# Finish building model for user  36 , id  SJJWIZLPGXtGTy9UECbVjA  in  0.3834848403930664
# ElasticNet mae 0.84335133333 rmse 1.0333142741274588
#
#
# Finish building model for user  37 , id  ZrN6jjXI41GP7Oieae6CNQ  in  0.5318655967712402
# ElasticNet mae 0.708005028262 rmse 0.8417036112289504
#
#
# Finish building model for user  38 , id  rGd8YUtvhSdMm8-9cMdQ4Q  in  1.3117544651031494
# ElasticNet mae 0.724864655558 rmse 0.8646735153514742
#
#
# Finish building model for user  39 , id  tjTrsF-CpDnTcclX-3sCTw  in  0.6544358730316162
# ElasticNet mae 0.774078478002 rmse 0.9499932820286633
#
#
# Finish building model for user  40 , id  gS4QCL6j_umAyfJXBGAZJQ  in  1.030008316040039
# ElasticNet mae 0.518751735893 rmse 0.656180081889879
#
#
# Finish building model for user  41 , id  x6_9RC7Mc0SsFUcWxEoN_Q  in  0.5196185111999512
# ElasticNet mae 0.963021941417 rmse 1.1886922546448087
#
#
# Finish building model for user  42 , id  uHZr3XbjKvRTwdXLXrFuvg  in  0.82460618019104
# ElasticNet mae 0.903611833078 rmse 1.0805372681987646
# {'ElasticNet': {'mae': 0.81156033763395674, 'rmse': 0.9856065375364903}}

# %%
run_content_based.runML("Lasso", chunks[9], review, business)
# Out:
# Finish building model for user  0 , id  WnUDyIE3YWdHcON-i-1MKw  in  0.4667701721191406
# Lasso mae 0.549473396277 rmse 0.7472271266211026
#
#
# Finish building model for user  1 , id  i8A3MWU33_mtMu3LUMlnWQ  in  0.38193726539611816
# Lasso mae 0.628809869376 rmse 0.7811167377974098
#
#
# Finish building model for user  2 , id  Kt-dsblXQnsUv3GjA_DFvg  in  0.9653246402740479
# Lasso mae 0.606240043853 rmse 0.8334016537486613
#
#
# Finish building model for user  3 , id  5sH6Rcahm4R0CdXfSIdOOA  in  0.5159080028533936
# Lasso mae 0.68515037594 rmse 0.784827016474088
#
#
# Finish building model for user  4 , id  52MlnjkvSLLqKKSRrbrH0w  in  0.9219212532043457
# Lasso mae 0.809072020736 rmse 0.9845695940413027
#
#
# Finish building model for user  5 , id  JmMXYQJio5eXgOvVZl_xGw  in  0.820319652557373
# Lasso mae 0.573775985744 rmse 0.6664520845536321
#
#
# Finish building model for user  6 , id  uO1w3qNo21c1bVHHFTYW0w  in  0.6234619617462158
# Lasso mae 1.0495594819 rmse 1.2496779789271213
#
#
# Finish building model for user  7 , id  7RCz4Ln_FaTvNrdwe251Dg  in  1.5350732803344727
# Lasso mae 0.789620615936 rmse 0.9726079779307446
#
#
# Finish building model for user  8 , id  ZKPCtlsIMjvMxmdskoCVmA  in  0.3724701404571533
# Lasso mae 0.731084280153 rmse 0.8807110553074944
#
#
# Finish building model for user  9 , id  uDPgnEv6jZa4CSv6NX49TQ  in  0.41290950775146484
# Lasso mae 1.05648332548 rmse 1.2829423085476517
#
#
# Finish building model for user  10 , id  2vJ2e51kdbdAmAo_HTr4KQ  in  1.852694034576416
# Lasso mae 0.755059171702 rmse 0.9151173655838194
#
#
# Finish building model for user  11 , id  alUuOskFSl1bODjnce2PpQ  in  3.0481622219085693
# Lasso mae 0.565328317478 rmse 0.7118089755618284
#
#
# Finish building model for user  12 , id  0BBUmH7Krcax1RZgbH4fSA  in  4.3204591274261475
# Lasso mae 0.680291050922 rmse 0.8470181838988418
#
#
# Finish building model for user  13 , id  oLLYmkej2TMHaTbudug5eA  in  1.137218952178955
# Lasso mae 0.614084340446 rmse 0.7087135346011857
#
#
# Finish building model for user  14 , id  0IwZb1ePNpSVYcCdMtGoQw  in  0.7576539516448975
# Lasso mae 0.67931547619 rmse 0.8694445968487876
#
#
# Finish building model for user  15 , id  Bf-X9oxiiRvzgrwguUWoeg  in  1.262603521347046
# Lasso mae 1.01433367769 rmse 1.173401230857558
#
#
# Finish building model for user  16 , id  GlxJs5r01_yqIgb4CYtiog  in  2.1519856452941895
# Lasso mae 0.874878664337 rmse 1.0316193332682073
#
#
# Finish building model for user  17 , id  fiz9Y2dagXIEq0w8FGOGnQ  in  0.6414411067962646
# Lasso mae 0.93307199707 rmse 1.1062104952540917
#
#
# Finish building model for user  18 , id  NAcOrPUT_8kze3cXhym_SQ  in  0.3778419494628906
# Lasso mae 0.826199367998 rmse 1.0335124867757566
#
#
# Finish building model for user  19 , id  EiP1OFgs-XGcKZux0OKWIA  in  2.0472447872161865
# Lasso mae 0.61195934804 rmse 0.7248832923579371
#
#
# Finish building model for user  20 , id  zo2vscKNvDzXWj7YOrdJVA  in  0.6715230941772461
# Lasso mae 0.927485161311 rmse 1.116423475493078
#
#
# Finish building model for user  21 , id  JrXC_MDp38BWwLn2SFdNsA  in  4.020885229110718
# Lasso mae 0.629931014122 rmse 0.789561095878738
#
#
# Finish building model for user  22 , id  7cHcDwzMSJMRaI_pgFNeZQ  in  0.40483880043029785
# Lasso mae 0.656898738323 rmse 0.770762670078919
#
#
# Finish building model for user  23 , id  mOVyk3O18VY5nrUMTZgM1w  in  0.892357587814331
# Lasso mae 1.02175589806 rmse 1.1969525134867025
#
#
# Finish building model for user  24 , id  eMcT_F41kJzVtAiTPDzIUA  in  0.5347118377685547
# Lasso mae 1.05453324517 rmse 1.3195953907595128
#
#
# Finish building model for user  25 , id  SBsQvmEEYJsD6xeRzHxf8Q  in  1.0283210277557373
# Lasso mae 0.604076191121 rmse 0.8073848930454983
#
#
# Finish building model for user  26 , id  ma6206bmu-a_Ja7Iv-yRCw  in  0.5374324321746826
# Lasso mae 0.634319330553 rmse 0.9039087225880582
#
#
# Finish building model for user  27 , id  SAdffUxscHOEygtbQqREIA  in  1.0770986080169678
# Lasso mae 0.553482221569 rmse 0.7792422807378112
#
#
# Finish building model for user  28 , id  ouS-Douov6w19Xly4aKLHQ  in  0.4622988700866699
# Lasso mae 0.723161259348 rmse 0.8625268094829601
#
#
# Finish building model for user  29 , id  2Rw4bXIrKd94be-BXMzoyw  in  1.2335615158081055
# Lasso mae 0.772360877521 rmse 0.9740909330144789
#
#
# Finish building model for user  30 , id  h9y55WNNg7SYg3kQwzTMmQ  in  0.46136975288391113
# Lasso mae 0.750244140625 rmse 0.9573183728913
#
#
# Finish building model for user  31 , id  2pVj1Hid6_Iq3Th9xI0aOQ  in  0.3202085494995117
# Lasso mae 0.407843137255 rmse 0.7058488276604351
#
#
# Finish building model for user  32 , id  XIkPvspzRAoEp7McGt9rdw  in  1.4890823364257812
# Lasso mae 0.759615384615 rmse 0.8949981412232457
#
#
# Finish building model for user  33 , id  eWD-kLqwCf1MaZxvO4yDLA  in  0.4939460754394531
# Lasso mae 0.884067495714 rmse 1.142620271482417
#
#
# Finish building model for user  34 , id  yaWnpONXlvdXbi36aKcznw  in  0.36138153076171875
# Lasso mae 1.03402107747 rmse 1.2900833189116643
#
#
# Finish building model for user  35 , id  0xRAAStEi_dBFLD-1xSMHQ  in  0.5318207740783691
# Lasso mae 0.893658760693 rmse 1.1276080353359164
#
#
# Finish building model for user  36 , id  lCmvpQfFpdxhbWVM59eUCg  in  0.5177097320556641
# Lasso mae 0.674843394407 rmse 0.8364389004130603
#
#
# Finish building model for user  37 , id  YqMpcRUA0OMw1WNLDGoj-A  in  2.0130274295806885
# Lasso mae 0.949319978378 rmse 1.1743714861732322
#
#
# Finish building model for user  38 , id  aomkMAGFrL-gD6cqQjB4bw  in  0.5683889389038086
# Lasso mae 0.724665097783 rmse 0.8719127841610109
#
#
# Finish building model for user  39 , id  7-WeMrvOxCH3oJfEWkC5rw  in  0.5765650272369385
# Lasso mae 0.849041107782 rmse 1.090485766160079
#
#
# Finish building model for user  40 , id  dwFgmKO-PzJalyHDSGAT8A  in  1.2679109573364258
# Lasso mae 0.632609095297 rmse 0.9023425170873411
#
#
# Finish building model for user  41 , id  4yGImSwdU9FZxVQIbZql3w  in  1.0324516296386719
# Lasso mae 0.830155337297 rmse 1.0126810558793546
# {'Lasso': {'mae': 0.76194949408767054, 'rmse': 0.9483909831167154}}

# %%
run_content_based.runML("ElasticNet", chunks[9], review, business)
# Out:
# Finish building model for user  0 , id  WnUDyIE3YWdHcON-i-1MKw  in  0.3103973865509033
# ElasticNet mae 0.555188843287 rmse 0.7529500742846594
#
#
# Finish building model for user  1 , id  i8A3MWU33_mtMu3LUMlnWQ  in  0.3443000316619873
# ElasticNet mae 0.628809869376 rmse 0.7811167377974098
#
#
# Finish building model for user  2 , id  Kt-dsblXQnsUv3GjA_DFvg  in  0.6876509189605713
# ElasticNet mae 0.604649294111 rmse 0.8325052369637367
#
#
# Finish building model for user  3 , id  5sH6Rcahm4R0CdXfSIdOOA  in  0.39718055725097656
# ElasticNet mae 0.68515037594 rmse 0.784827016474088
#
#
# Finish building model for user  4 , id  52MlnjkvSLLqKKSRrbrH0w  in  0.8809814453125
# ElasticNet mae 0.811133949822 rmse 0.9912159234400839
#
#
# Finish building model for user  5 , id  JmMXYQJio5eXgOvVZl_xGw  in  0.8210980892181396
# ElasticNet mae 0.595021867459 rmse 0.6907308982404362
#
#
# Finish building model for user  6 , id  uO1w3qNo21c1bVHHFTYW0w  in  0.6391386985778809
# ElasticNet mae 1.06366150983 rmse 1.2698892973778009
#
#
# Finish building model for user  7 , id  7RCz4Ln_FaTvNrdwe251Dg  in  1.0705506801605225
# ElasticNet mae 0.780983129149 rmse 0.975440772119399
#
#
# Finish building model for user  8 , id  ZKPCtlsIMjvMxmdskoCVmA  in  0.3083827495574951
# ElasticNet mae 0.73079308297 rmse 0.8822753215544255
#
#
# Finish building model for user  9 , id  uDPgnEv6jZa4CSv6NX49TQ  in  0.3978753089904785
# ElasticNet mae 1.05353322033 rmse 1.270732675947139
#
#
# Finish building model for user  10 , id  2vJ2e51kdbdAmAo_HTr4KQ  in  1.5975651741027832
# ElasticNet mae 0.756061609408 rmse 0.9201118192028125
#
#
# Finish building model for user  11 , id  alUuOskFSl1bODjnce2PpQ  in  2.28299880027771
# ElasticNet mae 0.607012535484 rmse 0.7547606702733602
#
#
# Finish building model for user  12 , id  0BBUmH7Krcax1RZgbH4fSA  in  3.601270914077759
# ElasticNet mae 0.74426208145 rmse 0.8893874447135116
#
#
# Finish building model for user  13 , id  oLLYmkej2TMHaTbudug5eA  in  0.6559510231018066
# ElasticNet mae 0.620222174546 rmse 0.7152710093839967
#
#
# Finish building model for user  14 , id  0IwZb1ePNpSVYcCdMtGoQw  in  0.6317920684814453
# ElasticNet mae 0.67931547619 rmse 0.8694445968487876
#
#
# Finish building model for user  15 , id  Bf-X9oxiiRvzgrwguUWoeg  in  0.8209691047668457
# ElasticNet mae 1.01433367769 rmse 1.173401230857558
#
#
# Finish building model for user  16 , id  GlxJs5r01_yqIgb4CYtiog  in  1.277738094329834
# ElasticNet mae 0.876017363091 rmse 1.0350879335560812
#
#
# Finish building model for user  17 , id  fiz9Y2dagXIEq0w8FGOGnQ  in  0.4747579097747803
# ElasticNet mae 0.930933816296 rmse 1.1018443122241863
#
#
# Finish building model for user  18 , id  NAcOrPUT_8kze3cXhym_SQ  in  0.3320186138153076
# ElasticNet mae 0.826199367998 rmse 1.0335124867757566
#
#
# Finish building model for user  19 , id  EiP1OFgs-XGcKZux0OKWIA  in  2.172513008117676
# ElasticNet mae 0.61946263351 rmse 0.7310651344530532
#
#
# Finish building model for user  20 , id  zo2vscKNvDzXWj7YOrdJVA  in  0.5526783466339111
# ElasticNet mae 0.934200619282 rmse 1.1238045957904568
#
#
# Finish building model for user  21 , id  JrXC_MDp38BWwLn2SFdNsA  in  3.0692245960235596
# ElasticNet mae 0.64933030971 rmse 0.8236097611963937
#
#
# Finish building model for user  22 , id  7cHcDwzMSJMRaI_pgFNeZQ  in  0.35073423385620117
# ElasticNet mae 0.656448926414 rmse 0.7702817804377259
#
#
# Finish building model for user  23 , id  mOVyk3O18VY5nrUMTZgM1w  in  0.8440935611724854
# ElasticNet mae 1.02196214014 rmse 1.198090765072703
#
#
# Finish building model for user  24 , id  eMcT_F41kJzVtAiTPDzIUA  in  0.6831333637237549
# ElasticNet mae 1.0349190289 rmse 1.2985312059832625
#
#
# Finish building model for user  25 , id  SBsQvmEEYJsD6xeRzHxf8Q  in  0.580970287322998
# ElasticNet mae 0.603902851732 rmse 0.8016887843094116
#
#
# Finish building model for user  26 , id  ma6206bmu-a_Ja7Iv-yRCw  in  0.38221073150634766
# ElasticNet mae 0.634328037712 rmse 0.9031724786216007
#
#
# Finish building model for user  27 , id  SAdffUxscHOEygtbQqREIA  in  0.9394705295562744
# ElasticNet mae 0.553482221569 rmse 0.7792422807378112
#
#
# Finish building model for user  28 , id  ouS-Douov6w19Xly4aKLHQ  in  0.39217638969421387
# ElasticNet mae 0.717172353801 rmse 0.8484969555878353
#
#
# Finish building model for user  29 , id  2Rw4bXIrKd94be-BXMzoyw  in  0.7990074157714844
# ElasticNet mae 0.768843730916 rmse 0.9706177801557978
#
#
# Finish building model for user  30 , id  h9y55WNNg7SYg3kQwzTMmQ  in  0.5654878616333008
# ElasticNet mae 0.743099410013 rmse 0.951662548069235
#
#
# Finish building model for user  31 , id  2pVj1Hid6_Iq3Th9xI0aOQ  in  0.5654888153076172
# ElasticNet mae 0.407843137255 rmse 0.7058488276604351
#
#
# Finish building model for user  32 , id  XIkPvspzRAoEp7McGt9rdw  in  1.1804254055023193
# ElasticNet mae 0.758213176118 rmse 0.8937119879324006
#
#
# Finish building model for user  33 , id  eWD-kLqwCf1MaZxvO4yDLA  in  0.4009280204772949
# ElasticNet mae 0.893291257611 rmse 1.145630384309618
#
#
# Finish building model for user  34 , id  yaWnpONXlvdXbi36aKcznw  in  0.4577784538269043
# ElasticNet mae 1.0257596351 rmse 1.279277824961641
#
#
# Finish building model for user  35 , id  0xRAAStEi_dBFLD-1xSMHQ  in  0.5951159000396729
# ElasticNet mae 0.902486896732 rmse 1.128644430598953
#
#
# Finish building model for user  36 , id  lCmvpQfFpdxhbWVM59eUCg  in  0.44750356674194336
# ElasticNet mae 0.701176272669 rmse 0.8376806074049077
#
#
# Finish building model for user  37 , id  YqMpcRUA0OMw1WNLDGoj-A  in  1.512467861175537
# ElasticNet mae 0.949668791817 rmse 1.1745690171136975
#
#
# Finish building model for user  38 , id  aomkMAGFrL-gD6cqQjB4bw  in  0.5634317398071289
# ElasticNet mae 0.733949754019 rmse 0.882682020713407
#
#
# Finish building model for user  39 , id  7-WeMrvOxCH3oJfEWkC5rw  in  0.8006491661071777
# ElasticNet mae 0.857732353278 rmse 1.1042612927383042
#
#
# Finish building model for user  40 , id  dwFgmKO-PzJalyHDSGAT8A  in  0.9901657104492188
# ElasticNet mae 0.638250432315 rmse 0.9103557191675393
#
#
# Finish building model for user  41 , id  4yGImSwdU9FZxVQIbZql3w  in  0.6905977725982666
# ElasticNet mae 0.819458167425 rmse 1.006048488737679
# {'ElasticNet': {'mae': 0.76638727101095172, 'rmse': 0.9522257173759309}}

# %%
run_content_based.runML("DecisionTreeRegressor", chunks[0], review, business)
# Out:
# Finish building model for user  0 , id  keLUgL_4y60BkppiAsIk8Q  in  21.666412115097046
# DecisionTreeRegressor mae 0.673789661303 rmse 0.8668530364313973
#
#
# Finish building model for user  1 , id  dEDId4Rp2JpblIfYIoH00w  in  16.05313205718994
# DecisionTreeRegressor mae 0.770365203455 rmse 0.9674682901544973
#
#
# Finish building model for user  2 , id  AVVEFYHmFUa9oUhy2DIQFA  in  18.058570861816406
# DecisionTreeRegressor mae 0.799763629515 rmse 1.0282114008484264
#
#
# Finish building model for user  3 , id  PRJMe-RgFnCEhyy7tf3DmQ  in  18.065688133239746
# DecisionTreeRegressor mae 0.616376855677 rmse 0.7592439865957386
#
#
# Finish building model for user  4 , id  VHc1yqBhsE-l3JQFXuWydQ  in  17.073627710342407
# DecisionTreeRegressor mae 0.855853845473 rmse 1.0823275730806015
#
#
# Finish building model for user  5 , id  _RvEDmpbQZulEdAV590QKg  in  9.363756895065308
# DecisionTreeRegressor mae 0.839284222858 rmse 1.0942899943567679
#
#
# Finish building model for user  6 , id  xYciRtVZ1PW4IxSX4oJ1aw  in  16.575325965881348
# DecisionTreeRegressor mae 0.826151456067 rmse 1.0539431926358844
#
#
# Finish building model for user  7 , id  oPVY6-CJt2EI335lKWwxmg  in  16.283435821533203
# DecisionTreeRegressor mae 0.875905965651 rmse 1.083513761588794
#
#
# Finish building model for user  8 , id  t-0_us3OTzs_ZhKy6fcamg  in  16.499452590942383
# DecisionTreeRegressor mae 0.848380252074 rmse 1.0258969224916559
#
#
# Finish building model for user  9 , id  7_RaCe5zzPBYWm9znlffUA  in  16.96949577331543
# DecisionTreeRegressor mae 0.915823644039 rmse 1.140952208071714
#
#
# Finish building model for user  10 , id  gSLQ-2A7b_d1JmXzN5jFzw  in  12.8347647190094
# DecisionTreeRegressor mae 0.958808653796 rmse 1.149963166920318
#
#
# Finish building model for user  11 , id  Yl7OYdHuYmr7K-IW9_ayng  in  16.586931705474854
# DecisionTreeRegressor mae 0.945405281653 rmse 1.12899280731826
#
#
# Finish building model for user  12 , id  0uNxhZAFbkalQImzJ6UDUA  in  17.219202995300293
# DecisionTreeRegressor mae 0.645811738597 rmse 0.7913306744965489
#
#
# Finish building model for user  13 , id  FEg8v92qx3kK4Hu4TF28Fg  in  12.459287881851196
# DecisionTreeRegressor mae 0.748380647131 rmse 0.950983243960585
#
#
# Finish building model for user  14 , id  -od707p4FHGul0gte29AoQ  in  16.224525213241577
# DecisionTreeRegressor mae 0.812208633705 rmse 1.0641001467130993
#
#
# Finish building model for user  15 , id  UByCy7oxeiqFKOLmGUVm3g  in  17.15910577774048
# DecisionTreeRegressor mae 0.693289373828 rmse 0.8441816449641244
#
#
# Finish building model for user  16 , id  8Dvr-U6jCZTVGD52LwC2qA  in  14.40311336517334
# DecisionTreeRegressor mae 0.729631046788 rmse 0.9744981441377831
#
#
# Finish building model for user  17 , id  -tdsrQ3QIkGmmP2n6-DTeg  in  6.800387620925903
# DecisionTreeRegressor mae 0.8604043541 rmse 1.111256217475268
#
#
# Finish building model for user  18 , id  bKTB22B8f1o7q25Sn8aN2Q  in  11.037370920181274
# DecisionTreeRegressor mae 1.15331609553 rmse 1.3811574885387992
#
#
# Finish building model for user  19 , id  8C8Ml7hj1zxyhcChk1TESQ  in  16.490776300430298
# DecisionTreeRegressor mae 0.646399771607 rmse 0.8553394637170957
#
#
# Finish building model for user  20 , id  NzlqN1Ca9SW5z780thoiAg  in  18.240240335464478
# DecisionTreeRegressor mae 0.600854528788 rmse 0.7197013797386848
#
#
# Finish building model for user  21 , id  t5nWD3Ya10ntwt3iWx5Kbg  in  15.18850064277649
# DecisionTreeRegressor mae 0.793178345718 rmse 1.0200947098684776
#
#
# Finish building model for user  22 , id  QlRsVCCytArycuuKSyUBLg  in  17.324164867401123
# DecisionTreeRegressor mae 0.6731797733 rmse 0.8355173569221035
#
#
# Finish building model for user  23 , id  X-VOe5bzT9EJu_L_Bt0nLQ  in  16.96362042427063
# DecisionTreeRegressor mae 0.910117053567 rmse 1.1170909018230732
#
#
# Finish building model for user  24 , id  z6gseuVl0cR7tRLQa_DXuQ  in  18.16619110107422
# DecisionTreeRegressor mae 1.11953457794 rmse 1.3504745290530313
#
#
# Finish building model for user  25 , id  C8W0VzsXaTg4YvciNTy3bg  in  4.128770589828491
# DecisionTreeRegressor mae 0.837675441123 rmse 1.0226530865191337
#
#
# Finish building model for user  26 , id  HikPdCQGk1mk5JsPjur7Nw  in  16.56409001350403
# DecisionTreeRegressor mae 0.694179245256 rmse 0.892702248524028
#
#
# Finish building model for user  27 , id  xsBjO0GTAvZK8i2A8_z20g  in  16.905200481414795
# DecisionTreeRegressor mae 0.697791377117 rmse 0.8914189483955548
#
#
# Finish building model for user  28 , id  X5whw8WcB8dVZGZ5vGnSLg  in  16.13363814353943
# DecisionTreeRegressor mae 0.999783295514 rmse 1.1841204905498786
#
#
# Finish building model for user  29 , id  Wu0yySWcHQ5tZ_59HNiamg  in  26.96082830429077
# DecisionTreeRegressor mae 0.561169367871 rmse 0.715357229865758
#
#
# Finish building model for user  30 , id  H3tbSSoX5FbCyKxl4Fu6gA  in  9.634418249130249
# DecisionTreeRegressor mae 0.856344955978 rmse 1.114706357440608
#
#
# Finish building model for user  31 , id  TZelLnaGbHgaG7LBI6rfgg  in  16.104387998580933
# DecisionTreeRegressor mae 0.665319911017 rmse 0.8132309866711493
#
#
# Finish building model for user  32 , id  wky4BZxCELi4PZcvb11qYQ  in  5.901196479797363
# DecisionTreeRegressor mae 1.04477345127 rmse 1.2468197915700672
#
#
# Finish building model for user  33 , id  Plqi4pG84PA_vBM8OfDPDg  in  16.36777687072754
# DecisionTreeRegressor mae 0.638437890008 rmse 0.7908754626114662
#
#
# Finish building model for user  34 , id  d3EqggaHzuON2t7k1Z30Fg  in  16.492268085479736
# DecisionTreeRegressor mae 0.891455088532 rmse 1.1117834992804796
#
#
# Finish building model for user  35 , id  JDwWpPAaKiLpwGVjsvxAHA  in  15.86569595336914
# DecisionTreeRegressor mae 0.788170720344 rmse 0.9724403152286176
#
#
# Finish building model for user  36 , id  GERRIWMslcP4-O6mLErPSQ  in  19.180577516555786
# DecisionTreeRegressor mae 0.801567966679 rmse 0.9932959833198118
#
#
# Finish building model for user  37 , id  Tjv5bBtJ-Z_CLiY-rheG2g  in  17.365769863128662
# DecisionTreeRegressor mae 0.57009272701 rmse 0.6946922668346971
#
#
# Finish building model for user  38 , id  gwIqbXEXijQNgdESVc07hg  in  24.743178129196167
# DecisionTreeRegressor mae 0.729765641223 rmse 0.8631016453747973
#
#
# Finish building model for user  39 , id  AhoxHm569hH_PRkoegDwcA  in  9.769583702087402
# DecisionTreeRegressor mae 0.71574187142 rmse 0.9361996557736525
#
#
# Finish building model for user  40 , id  XrYTMhY9YJvzX2pMepIz7A  in  13.64366626739502
# DecisionTreeRegressor mae 0.780645504473 rmse 0.9868665509533796
#
#
# Finish building model for user  41 , id  VVm-TFCpi9M1-k8ED0l1eA  in  18.97394323348999
# DecisionTreeRegressor mae 0.73864566585 rmse 0.9657210843149087
#
#
# Finish building model for user  42 , id  TibBhm-fbksozIDFD8wjPQ  in  16.086504220962524
# DecisionTreeRegressor mae 0.525774939375 rmse 0.6702762567657561
# {'DecisionTreeRegressor': {'mae': 0.78719882958637466,
#   'rmse': 0.9828754442301504}}

# %%
user_test = pd.DataFrame(sample.iloc[0]).T

# %%
for i, user_id in enumerate(list(user_test["user_id"].unique())):
    print(user_id)
# Out:
# keLUgL_4y60BkppiAsIk8Q

# %%
run_content_based.runML("Lasso", user_test, review, business, getTop = True, topN = 15)
# Out:
# Finish building model for user  0 , id  keLUgL_4y60BkppiAsIk8Q  in  0.872692346572876
# Lasso mae 0.714572680789 rmse 0.8520437784228372
#
#
# [('kNZJMnTNXj42EfUGX3eRcw', 3.4189189189189189), ('j4htyBDNBzrog6A_byqdDw', 3.4189189189189189), ('JxSHELGkkI3x6mbgIKBNnw', 3.4189189189189189), ('L_thK7r3K_h5M4tV7amEKQ', 3.4189189189189189), ('o80WsixApYT1enf3AH6N2Q', 3.4189189189189189), ('gn3YqxYN8KQZsDVvchFeBQ', 3.4189189189189189), ('PGde9ygfV_a5oLQDNVedJg', 3.4189189189189189), ('-TjzQsimpriXVYaH3HdtQA', 3.4189189189189189), ('MLYy937DjHHtE5Cwpg3NEQ', 3.4189189189189189), ('tzl4KHt6ZAwyUJIEyemrtQ', 3.4189189189189189), ('YEILyeHAQTgEGogF46HYiw', 3.4189189189189189), ('Q42PBQkiRwj4k5pU29ZhgQ', 3.4189189189189189), ('RwRNR4z3kY-4OsFqigY5sw', 3.4189189189189189), ('Cr5CLpmVrmzFyz_RfQ6rmA', 3.4189189189189189), ('kBsSWymU6HwFGkLEQLrOdg', 3.4189189189189189)]
# {'Lasso': {'mae': 0.71457268078889702, 'rmse': 0.8520437784228372}}

# %%
review[review["user_id"] == sample.iloc[0].user_id].sort_values(by = ["stars"], ascending = False)[["business_id", "stars"]][:15]
# Out:
#                  business_id  stars
# 2324  fnLiPkJL0ur4-pS99bgqGA      5
# 5864  ixGb4NLfgD90wZHlw94rLw      5
# 2255  lUIKCofKNVMluW0LAw1eEQ      5
# 2299  URvh6DgFyA-d6Z7OVKxczg      5
# 5887  xRmVk44t0zza2TNld29TzQ      5
# 2238  Q42PBQkiRwj4k5pU29ZhgQ      5
# 2236  tzl4KHt6ZAwyUJIEyemrtQ      5
# 2271  ZGgUJmpRbh2VXftRhQmUSA      5
# 2230  L_thK7r3K_h5M4tV7amEKQ      5
# 2327  oVtnnGat2Wco0ksQT1cGCA      5
# 5878  vazCBq6DH9LnCQ3cH7E4Og      5
# 2315  n0JifoI1yWxaBiv7VLRc4Q      4
# 2305  GddF9NCklDiGDk-d9xtTNg      4
# 2313  330HJ6PP0faybQt5u95kTQ      4
# 2317  Eaxf3bmxnMljIylk_2ZW2Q      4
