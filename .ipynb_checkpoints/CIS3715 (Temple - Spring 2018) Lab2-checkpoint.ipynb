# %% [markdown]
# # Lab 2
# ## Using Python for Exploratory Data Analysis (EDA)
#
# The first part of Lab2 is to go through a demo for EDA of a relatively clean tabular data called *Auto MPG data*. This data set comes from the UCI Machine Learning Data Repository (http://archive.ics.uci.edu/ml/) and can be found at http://archive.ics.uci.edu/ml/datasets/Auto+MPG. We provide a slightly modified version of this data set as file `cars.csv`.
#
# To load this data set and pursue EDA, it is a good idea to use several popular Python packages, which come preloaded with the Anaconda software:
# - pandas (http://pandas.pydata.org/) -- a library for data science
# - numpy (http://www.numpy.org/) -- a library for data computations
# - matplotlib (http://matplotlib.org/) -- a library for data visualization
#
# The main feature of *pandas* is its `DataFrame` data structure that provides an intuitive way of handling tabular data. The main feature of *numpy* is its `array` data structure that represents matrices and allows us to perform matrix algebra operations. *matplotlib* allows visualizing data stored in `DataFrame` or `array` objects.
#
# As you will soon realize, each new Python library requires spending some time to learn about it. There are several nice tutorials that you can find on the web that get you started with the 3 libraries. A particularly great resource for learning about those libraries is your textbook *Python for Data Analysis*, so please take some time to browse its contents and try to run the code provided in it. When learning about the new libraries, you are best advised to jump in and immediatelly start tinkering with the code. The more time you spend using the library, the more you will uncover about all the great features and posibilities the library offers you.
#
# Let us start by loading the 3 libraries in a particular way that many data scientists prefer.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# the following line allows ipython to display plots
# %matplotlib inline

# %% [markdown]
# **Question 1**: What are we accomplishing with `as` reserved word?

# %% [markdown]
# #### Question 1 Answer
#
# import statement binds the module name in the local namespace to the module object, and then goes on to import the next identifier, if any. If the module name is followed by as, the name following as is used as the local name for the module.

# %% [markdown]
# `cars.csv` is in an easy-to-read comma separated format and the following *pandas* functionality makes it easy to read it into a `DataFrame` object.

# %%
# read this csv file, remember to put the full path to 
# the directory where you saved the data
df = pd.read_csv('cars.csv')  # df is DataFrame object
print (df.head())    # see the first 5 rows of the loaded table
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %% [markdown]
# **Question 2**: How can you display the first 10 rows using method `head`? What are the types of each of the columns in `df`?

# %% [markdown]
# #### Question 2

# %%
print(df.head(10))
print('\n')
print(df.dtypes) #display types of columns
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
# 5           Ford Galaxie 500  15.0          8         429.0         198
# 6           Chevrolet Impala  14.0          8         454.0         220
# 7          Plymouth Fury iii  14.0          8         440.0         215
# 8           Pontiac Catalina  14.0          8         455.0         225
# 9         AMC Ambassador DPL  15.0          8         390.0         190
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US
# 5    4341          10.0     70     US
# 6    4354           9.0     70     US
# 7    4312           8.5     70     US
# 8    4425          10.0     70     US
# 9    3850           8.5     70     US
#
#
# Car              object
# MPG             float64
# Cylinders         int64
# Displacement    float64
# Horsepower        int64
# Weight            int64
# Acceleration    float64
# Model             int64
# Origin           object
# dtype: object

# %% [markdown]
# There are different ways of exploring and indexing the table. Here are some examples.

# %%
print (list(df.columns))
print (df[0:5])         # print the first 5 rows, same outcome as df.head()
print (df[['Car', 'MPG']][:10])  # print the first 10 rows for selected columns
print (df[df['MPG'] > 40])   # using Boolean condition, print only cars with MPG > 40
print (df.iloc[[0,1,5],0:5])   # uses 'iloc' indexing, selects rows and columns based on their location in the table
# Out:
# ['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model', 'Origin']
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US
#                          Car   MPG
# 0  Chevrolet Chevelle Malibu  18.0
# 1          Buick Skylark 320  15.0
# 2         Plymouth Satellite  18.0
# 3              AMC Rebel SST  16.0
# 4                Ford Torino  17.0
# 5           Ford Galaxie 500  15.0
# 6           Chevrolet Impala  14.0
# 7          Plymouth Fury iii  14.0
# 8           Pontiac Catalina  14.0
# 9         AMC Ambassador DPL  15.0
#                                  Car   MPG  Cylinders  Displacement  \
# 251  Volkswagen Rabbit Custom Diesel  43.1          4          90.0
# 316                Volkswagen Rabbit  41.5          4          98.0
# 329                        Mazda GLC  46.6          4          86.0
# 331                       Datsun 210  40.8          4          85.0
# 332     Volkswagen Rabbit C (Diesel)  44.3          4          90.0
# 333       Volkswagen Dasher (diesel)  43.4          4          90.0
# 336              Honda Civic 1500 gl  44.6          4          91.0
# 337             Renault Lecar Deluxe  40.9          4          85.0
# 402                Volkswagen Pickup  44.0          4          97.0
#
#      Horsepower  Weight  Acceleration  Model  Origin
# 251          48    1985          21.5     78  Europe
# 316          76    2144          14.7     80  Europe
# 329          65    2110          17.9     80   Japan
# 331          65    2110          19.2     80   Japan
# 332          48    2085          21.7     80  Europe
# 333          48    2335          23.7     80  Europe
# 336          67    1850          13.8     80   Japan
# 337           0    1835          17.3     80  Europe
# 402          52    2130          24.6     82  Europe
#                          Car   MPG  Cylinders  Displacement  Horsepower
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 5           Ford Galaxie 500  15.0          8         429.0         198

# %% [markdown]
# **Question 3**: Show two ways of printing the last 5 rows of `df`. Print the names of the cars with 3 cilinders.

# %%
print(df[-5:]) #first way
print(df.tail(5)) #second way
print('\n')
print(df[df['Cylinders'] == 3]['Car']) #cars with 3 cylinders
# Out:
#                    Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 401    Ford Mustang GL  27.0          4         140.0          86    2790
# 402  Volkswagen Pickup  44.0          4          97.0          52    2130
# 403      Dodge Rampage  32.0          4         135.0          84    2295
# 404        Ford Ranger  28.0          4         120.0          79    2625
# 405         Chevy S-10  31.0          4         119.0          82    2720
#
#      Acceleration  Model  Origin
# 401          15.6     82      US
# 402          24.6     82  Europe
# 403          11.6     82      US
# 404          18.6     82      US
# 405          19.4     82      US
#                    Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 401    Ford Mustang GL  27.0          4         140.0          86    2790
# 402  Volkswagen Pickup  44.0          4          97.0          52    2130
# 403      Dodge Rampage  32.0          4         135.0          84    2295
# 404        Ford Ranger  28.0          4         120.0          79    2625
# 405         Chevy S-10  31.0          4         119.0          82    2720
#
#      Acceleration  Model  Origin
# 401          15.6     82      US
# 402          24.6     82  Europe
# 403          11.6     82      US
# 404          18.6     82      US
# 405          19.4     82      US
#
#
# 78     Mazda RX2 Coupe
# 118          Mazda RX3
# 250         Mazda RX-4
# 341      Mazda RX-7 GS
# Name: Car, dtype: object

# %% [markdown]
# Now, we are ready to start plotting the data.

# %%
plt.figure(figsize=(6,2))  # can control the size of the display
plt.plot(df['Horsepower'])      # display 'Model' attribute

# %% [markdown]
# **Question 4**: Plot *Horsepower* attribute, but only for the US cars.

# %%
data_power = df[df['Origin'] == 'US']
plt.figure(figsize = (10,4))
plt.plot(data_power['Horsepower'])

# %% [markdown]
# To plot the histogram of a selected attribute:

# %%
fig = plt.figure(figsize=(5,2))
plt.hist(df['MPG'], bins=20);   # ; suppresses Out
# plt.hist(df['Cylinders'], bins=20)

# %% [markdown]
# **Question 5**: What can we conclude by looking at the histogram? Explain in one-two sentences. Figure out what is your preferred number of bins for *MPG* and *Cylinders* and argue why.

# %% [markdown]
# #### Question 5
#
# Most cars have MPG around 15 and above. Only a few cars have lower than 10 MPG. After the highest MPG threshold, as MPG increases, number of cars in each bin decreases.

# %%
# Question 5 Continue

print(df['MPG'].max())
print(df['MPG'].min())
mpgplot = plt.figure(figsize = (10,5))
plt.hist(df['MPG'], bins = 20) 
# the range of MPG is (0,46.6), so the number of bins should be around 20 
# so that one bin allows for a difference of 2-3 MPG. 
cylplt = plt.figure(figsize = (6,5))
numbin = df['Cylinders'].nunique()
plt.hist(df['Cylinders'], bins = numbin) #let the number of bins to equal the number of types of Cylinders.
# Out:
# 46.6
# 0.0
# (array([  4., 207.,   3.,  84., 108.]),
#  array([3., 4., 5., 6., 7., 8.]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# The following code provides statistics for number of cylinders.

# %%
t = pd.crosstab(index=df["Cylinders"],  # Make a crosstab
                     columns="count")     # Name the count column
t['percentage']= (t/t.sum())*100
print (t)
# Out:
# col_0      count  percentage
# Cylinders
# 3              4    0.985222
# 4            207   50.985222
# 5              3    0.738916
# 6             84   20.689655
# 8            108   26.600985

# %% [markdown]
# **Question 6**: Try to learn more about `crosstab` method (by doing Google search) and write a line of code that uses it in a different way on `df` data.

# %%
origindf = pd.crosstab(index = [df['Origin'], df['Cylinders']], columns = 'count')
origindf['percentage'] = (origindf/origindf.sum()) * 100
print(origindf)
# Out:
# col_0             count  percentage
# Origin Cylinders
# Europe 4             66   16.256158
#        5              3    0.738916
#        6              4    0.985222
# Japan  3              4    0.985222
#        4             69   16.995074
#        6              6    1.477833
# US     4             72   17.733990
#        6             74   18.226601
#        8            108   26.600985

# %% [markdown]
# Horizontal bar plot:

# %%
plt.figure(figsize=(5,2))
plt.barh(t.index,t["count"]);

# %% [markdown]
# **Question 7**: How about a horizontal bar plot? Can you learn how to control the width of bars and make a plot that has thinner bars?

# %%
plt.figure(figsize = (10,5))
plt.barh(t.index, t['count'], height = 0.5) #use the parameter height to make a plot that has thinner bars.
# Out:
# <BarContainer object of 5 artists>

# %%
another = pd.crosstab(index = df["Origin"], columns = "count")
another["percentage"] = (another / another.sum()) * 100
another
# Out:
# col_0   count  percentage
# Origin
# Europe     73   17.980296
# Japan      79   19.458128
# US        254   62.561576

# %%
plt.figure(figsize = (10,5))
plt.barh(another.index, another['count'], height = 0.5)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Pie chart:

# %%
plt.figure(figsize=(5,2))
plt.axis("equal")
plt.pie(t["count"],labels=t.index,startangle=90);

# %% [markdown]
# **Question 8**: Do you prefer bar or pie displayed chart and why?

# %% [markdown]
# #### Question 8
#
# I prefer bar chart because with the bar chart we can see clearly how many cars are in each group of cylinder, and thus it is easier to compare differences between each group of cylinders. In pie chart, we can only see which group of cylinder have more cars than others, but still that doesn't tell us how much the difference is. In the bar chart, it is clear that the number of cars with 4 cylinders is about twice as many as the number of cars with 8 cylinders

# %% [markdown]
# The following is a boxplot of MPG values for each of the model years. Pay attention that matplotlib is not used here. Instead, we called a panda `boxplot` method

# %%
df.boxplot(column='MPG',by='Model');

# %% [markdown]
# **Question 9**: Discuss what can you learn from the displayed boxplot. Plot another boxplot using `df` data that you think is very useful and explain what can we learn from it?

# %% [markdown]
# #### Question 9
#
# With boxplot we can learn get the attribute's range of value, maximum (that is not an outlier), minimum value (that is not an outlier), the median, the first and the third quantile and the outliers. In particular, for the graph above, for each of the model, we can know what is the range of MPG excluding the outliers, the 1st and 3rd quantile and the median value. In the graph above, we can learn that MPG generally increases as the time went by.

# %%
df.boxplot(column = 'MPG', by = 'Origin')

# %% [markdown]
# From the above graph we can see that, US cars' MPG range is lower than that of European cars and Japanese cars: lower maximum value, lower minimum value and lower median.

# %% [markdown]
# Scatterplot between MPG and Weight attributes:

# %%
plt.figure(figsize=(5,3))
plt.scatter(df['MPG'],df['Weight']);

# %% [markdown]
# **Question 10**: Discuss what can we learn from the displayed scatterplot.

# %% [markdown]
# #### Question 10
#
# With a scatterplot we can learn the relationship between two attributes. In the above example, cars with higher MPG have lower weights. But the relationship seem to be non-linear. Using scatter plot, we can learn the relationship between 2 up to 4 attributes. The blelow graph is an example.

# %% [markdown]
# We can decide on the size and collor of circles to represent some of data properties. Here, the size is proportional to Cylinders and color is related to Horsepower:

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['MPG'],df['Weight'],df['Cylinders']*30,df['Horsepower']);
plt.colorbar()

# %% [markdown]
# **Question 11**: Discuss what additional insight we can get from this scatterplot as compared to the previous scatterplot. Plot another scatterplot by picking a different set of attributes that you think is providing a useful view at the data. Discuss what can be concluded from that plot.

# %% [markdown]
# #### Question 11
#
# With the new plot, we can also obtain relationship between MPG, weight, cylinders and horsepower. In particular, cars with higher MPG have lower weights, fewer cylinders and lower horsepower.

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['MPG'], df['Horsepower'], df['Displacement'], df['Acceleration'])
plt.colorbar()

# %% [markdown]
# #### Question 11 continue
#
# Overall, Cars with higher MPG have lower horsepower, higher acceleration and lower displacement. The relationship between MPG and horsepower is non-linear. The relation between 4 attributes obtained from the graph is intuitive!

# %% [markdown]
# Pandas `scatter_matrix` method allows us to plot all scatterplots for a data set (it would take a few seconds to display):

# %%
pd.scatter_matrix(df);
# Out:
# /Users/Hoang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# In this plot, what we are seeing is a matrix of plots that plots the each attribute against all attributes. To make it clear, it is plotting MPG against Model, Accelertion, Horsepower, Displacement, Cylinders and MPG itself (all of these plots are in the first column), then it repeat the same process for other attributes. It is hard to see things clear from this matrix. But this matrix of plots is still helpful in some ways. For instance, from this matrix of plots we can look for the plot thats catch the most attention. E.g. the plot of MPG against horsepower, MPG against Weight, MPG against Displacement,....

# %% [markdown]
# **Question 12**: Explain what are we seeing from this plot and discuss about the insights you obtained from it.
#
# When you are done with running and playing with the code provided in this file and answering Questions 1-12, **submit** `.ipynb` file containing modifications of this file together with your answers and comments. Feel free to modify the provided code or produce new lines of code.
#
# **Question 13**: Produce a 2 page word document titled "Exploratory Analysis of MPG Data Set". In this document you should combine your own discussion and figures produced by Python to provide a coherent story about the properties of the MPG data set and the most important and interesting insights about the data. You can feel free to frame your story around some known historical facts about the cars and U.S. and World economy during the 1970-1982 period. **Submit** the document as `.pdf` file.

# %% [markdown]
# #### Question 13

# %%
import seaborn as sns

# %%
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
newdf = df.groupby(['Origin', 'Model'])['MPG', 'Acceleration', 'Weight', 'Horsepower', 'Displacement'].mean()
newdf.reset_index(inplace=True)
newdf
# Out:
#     Origin  Model        MPG  Acceleration       Weight  Horsepower  \
# 0   Europe     70  21.000000     16.666667  2439.333333   91.000000
# 1   Europe     71  23.000000     17.400000  2014.800000   68.800000
# 2   Europe     72  22.000000     18.700000  2573.200000   79.600000
# 3   Europe     73  24.000000     16.428571  2335.714286   81.857143
# 4   Europe     74  27.000000     15.333333  2139.333333   74.166667
# 5   Europe     75  24.500000     15.083333  2571.166667   89.500000
# 6   Europe     76  24.250000     16.050000  2611.000000   87.625000
# 7   Europe     77  29.250000     15.000000  2138.750000   81.000000
# 8   Europe     78  24.950000     16.233333  2691.666667   99.166667
# 9   Europe     79  30.450000     18.400000  2693.750000   72.000000
# 10  Europe     80  37.288889     18.366667  2348.000000   59.333333
# 11  Europe     81  25.260000     17.080000  2740.000000   68.000000
# 12  Europe     82  40.000000     19.950000  2055.000000   63.000000
# 13   Japan     70  25.500000     14.750000  2251.000000   91.500000
# 14   Japan     71  29.500000     16.375000  1936.000000   79.250000
# 15   Japan     72  24.200000     15.400000  2300.400000   93.800000
# 16   Japan     73  20.000000     15.625000  2397.250000   98.500000
# 17   Japan     74  29.333333     17.666667  2053.000000   72.500000
# 18   Japan     75  27.500000     16.000000  2303.250000   80.250000
# 19   Japan     76  28.000000     16.575000  2217.500000   76.500000
# 20   Japan     77  27.416667     16.316667  2295.833333   81.166667
# 21   Japan     78  29.687500     16.200000  2221.250000   79.250000
# 22   Japan     79  32.950000     17.200000  1997.500000   65.000000
# 23   Japan     80  35.400000     16.015385  2290.307692   78.846154
# 24   Japan     81  32.958333     16.183333  2269.166667   78.333333
# 25   Japan     82  34.888889     15.833333  2132.777778   74.000000
# 26      US     70  12.444444     11.685185  3752.148148  165.962963
# 27      US     71  18.100000     14.575000  3401.600000  113.850000
# 28      US     72  16.277778     14.055556  3682.666667  138.777778
# 29      US     73  15.034483     13.620690  3821.448276  146.620690
# 30      US     74  18.333333     15.966667  3503.333333  104.666667
# 31      US     75  17.550000     16.350000  3533.200000  108.700000
# 32      US     76  19.431818     15.786364  3405.409091  110.500000
# 33      US     77  20.722222     15.238889  3422.000000  118.388889
# 34      US     78  21.772727     15.545455  3141.136364  107.272727
# 35      US     79  23.478261     15.243478  3210.217391  109.434783
# 36      US     80  25.914286     16.800000  2822.428571   76.142857
# 37      US     81  27.530769     16.053846  2695.000000   84.538462
# 38      US     82  29.450000     16.670000  2637.750000   82.600000
#
#     Displacement
# 0     112.000000
# 1      95.400000
# 2     111.000000
# 3     105.000000
# 4      93.166667
# 5     109.500000
# 6     116.125000
# 7      98.500000
# 8     126.166667
# 9     126.000000
# 10    104.222222
# 11    122.400000
# 12    101.000000
# 13    105.000000
# 14     88.250000
# 15     99.400000
# 16    107.750000
# 17     89.500000
# 18    110.250000
# 19    107.250000
# 20    100.500000
# 21    107.250000
# 22     85.500000
# 23    104.615385
# 24    107.500000
# 25    103.777778
# 26    339.185185
# 27    257.000000
# 28    281.250000
# 29    314.103448
# 30    236.066667
# 31    253.400000
# 32    243.954545
# 33    242.333333
# 34    217.545455
# 35    231.260870
# 36    151.571429
# 37    164.846154
# 38    142.950000

# %%
mpgDf = newdf.pivot(index="Origin", columns="Model", values="MPG")
mpgDf
# Out:
# Model          70    71         72         73         74     75         76  \
# Origin
# Europe  21.000000  23.0  22.000000  24.000000  27.000000  24.50  24.250000
# Japan   25.500000  29.5  24.200000  20.000000  29.333333  27.50  28.000000
# US      12.444444  18.1  16.277778  15.034483  18.333333  17.55  19.431818
#
# Model          77         78         79         80         81         82
# Origin
# Europe  29.250000  24.950000  30.450000  37.288889  25.260000  40.000000
# Japan   27.416667  29.687500  32.950000  35.400000  32.958333  34.888889
# US      20.722222  21.772727  23.478261  25.914286  27.530769  29.450000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(mpgDf, annot=True, fmt="g", cmap="viridis")
plt.title("Heatmap for MPG controlling on Origin and Model")
plt.show()

# %%
horseDf = newdf.pivot(index="Origin", columns="Model", values="Horsepower")
horseDf
# Out:
# Model           70      71          72          73          74      75  \
# Origin
# Europe   91.000000   68.80   79.600000   81.857143   74.166667   89.50
# Japan    91.500000   79.25   93.800000   98.500000   72.500000   80.25
# US      165.962963  113.85  138.777778  146.620690  104.666667  108.70
#
# Model        76          77          78          79         80         81  \
# Origin
# Europe   87.625   81.000000   99.166667   72.000000  59.333333  68.000000
# Japan    76.500   81.166667   79.250000   65.000000  78.846154  78.333333
# US      110.500  118.388889  107.272727  109.434783  76.142857  84.538462
#
# Model     82
# Origin
# Europe  63.0
# Japan   74.0
# US      82.6

# %%
plt.figure(figsize=(12,7))
sns.heatmap(horseDf, annot=True, fmt="g", cmap="viridis")
plt.title("Heatmap for Horspower controlling on Origin and Model")
plt.show()

# %%
acceDf = newdf.pivot(index="Origin", columns="Model", values="Acceleration")
acceDf
# Out:
# Model          70      71         72         73         74         75  \
# Origin
# Europe  16.666667  17.400  18.700000  16.428571  15.333333  15.083333
# Japan   14.750000  16.375  15.400000  15.625000  17.666667  16.000000
# US      11.685185  14.575  14.055556  13.620690  15.966667  16.350000
#
# Model          76         77         78         79         80         81  \
# Origin
# Europe  16.050000  15.000000  16.233333  18.400000  18.366667  17.080000
# Japan   16.575000  16.316667  16.200000  17.200000  16.015385  16.183333
# US      15.786364  15.238889  15.545455  15.243478  16.800000  16.053846
#
# Model          82
# Origin
# Europe  19.950000
# Japan   15.833333
# US      16.670000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(acceDf, annot=True, fmt="g", cmap="viridis")
plt.title("Heatmap for Acceleration controlling on Origin and Model")
plt.show()

# %%
displDf = newdf.pivot(index="Origin", columns="Model", values="Displacement")
displDf
# Out:
# Model           70      71      72          73          74      75  \
# Origin
# Europe  112.000000   95.40  111.00  105.000000   93.166667  109.50
# Japan   105.000000   88.25   99.40  107.750000   89.500000  110.25
# US      339.185185  257.00  281.25  314.103448  236.066667  253.40
#
# Model           76          77          78         79          80          81  \
# Origin
# Europe  116.125000   98.500000  126.166667  126.00000  104.222222  122.400000
# Japan   107.250000  100.500000  107.250000   85.50000  104.615385  107.500000
# US      243.954545  242.333333  217.545455  231.26087  151.571429  164.846154
#
# Model           82
# Origin
# Europe  101.000000
# Japan   103.777778
# US      142.950000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(displDf, annot=True, fmt="g", cmap="viridis")
plt.title("Heatmap for Displacement controlling on Origin and Model")
plt.show()
