# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A: Homework 1
#
#
#
# **Harvard University**<br/>
# **Fall 2017**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine
#
# ---
#
# ### INSTRUCTIONS
#
# **WARNING**: There is web page scraping in this homework. It takes about 40 minutes. **Do not wait till the last minute** to do this homework.
#
# - To submit your assignment follow the instructions given in canvas.
# - Restart the kernel and run the whole notebook again before you submit. There is an important CAVEAT to this. DO NOT run the web-page fetching cells again. (We have provided hints like `# DO NOT RERUN THIS CELL WHEN SUBMITTING` on some of the cells where we provide the code). Instead load your data structures from the JSON files we will ask you to save below. Otherwise you will be waiting for a long time. (Another reason to not wait until the last moment to submit.)
#
# - Do not include your name in the notebook.
#
# ---

# %% [markdown]
# # Homework 1: Rihanna or Mariah?

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will:
#
# 1. Scrape Wikipedia to obtain infprmation about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to clean this data. Along the way you will learn how to save data in json files to avoid repeated scraping.
# 2. Scrape Wikipedia to obtain information on these singers. You will have to scrape the web pages, this time using a cache to guard against network timeouts (or your laptop going to sleep). You will again clean the data, and save it to a json file.
# 3. Use pandas to represent these two datasets and merge them.
# 4. Use the individual and merged datasets to visualize the performance of the artists and their songs. We have kept the amount of analysis limited here for reasons of time; but you might enjoy exploring music genres and other aspects of the music business you can find on these wikipedia pages at your own leisure.

# %% [markdown]
# You should have worked through Lab0 and Lab 1, and Lecture 2.  Lab 2 will help as well.

# %% [markdown]
# As usual, first we import the necessary libraries.  In particular, we use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape Wikipedia for the Billboard's top 100 singles.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using  [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/), and suggest that you use Python's built in `requests` library to fetch the web page.

# %% [markdown]
# #### 1.1 Parsing the Billboard Wikipedia page for 1970

# %% [markdown]
# Obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970 using a HTTP GET request. From this web page we'll extract the top 100 singles and their rankings. Create a list of dictionaries, 100 of them to be precise, with entries like
#
# `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# If you look at that web page, you'll see a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# *HINT: look for a table with class `wikitable`.*

# %% [markdown]
# You should get something similar to this (where songs is the aforementioned list):
#
# ```
# songs[2:4]
# ```
#
# ```
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]
# ```

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970')
page = req.text
soup = BeautifulSoup(page, 'html.parser')
table = soup.find('table', class_='wikitable')
rows = table.find_all('tr')[1:]
rows[0].find_all('td')

def cleaner(r):
    #parameter r is a list of 'td' at row level
    ranking = int(r[0].get_text())
    song = r[1].get_text()
    band_singer = r[2].get_text()
    url = r[2].find('a').get('href')
    return [band_singer, ranking, song, url]

columns = ['band_singer', 'ranking', 'song', 'url']
[{col: val for col, val in zip(columns,cleaner(row.find_all('td')))} for row in rows]
# Out:
# [{'band_singer': 'Simon & Garfunkel',
#   'ranking': 1,
#   'song': '"Bridge over Troubled Water"',
#   'url': '/wiki/Simon_%26_Garfunkel'},
#  {'band_singer': 'The Carpenters',
#   'ranking': 2,
#   'song': '"(They Long to Be) Close to You"',
#   'url': '/wiki/The_Carpenters'},
#  {'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'song': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'song': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'},
#  {'band_singer': 'Edwin Starr',
#   'ranking': 5,
#   'song': '"War"',
#   'url': '/wiki/Edwin_Starr'},
#  {'band_singer': 'Diana Ross',
#   'ranking': 6,
#   'song': '"Ain\'t No Mountain High Enough"',
#   'url': '/wiki/Diana_Ross'},
#  {'band_singer': 'The Jackson 5',
#   'ranking': 7,
#   'song': '"I\'ll Be There"',
#   'url': '/wiki/The_Jackson_5'},
#  {'band_singer': 'Rare Earth',
#   'ranking': 8,
#   'song': '"Get Ready"',
#   'url': '/wiki/Rare_Earth_(band)'},
#  {'band_singer': 'The Beatles',
#   'ranking': 9,
#   'song': '"Let It Be"',
#   'url': '/wiki/The_Beatles'},
#  {'band_singer': 'Freda Payne',
#   'ranking': 10,
#   'song': '"Band of Gold"',
#   'url': '/wiki/Freda_Payne'},
#  {'band_singer': 'Three Dog Night',
#   'ranking': 11,
#   'song': '"Mama Told Me (Not to Come)"',
#   'url': '/wiki/Three_Dog_Night'},
#  {'band_singer': 'Ray Stevens',
#   'ranking': 12,
#   'song': '"Everything Is Beautiful"',
#   'url': '/wiki/Ray_Stevens'},
#  {'band_singer': 'Bread',
#   'ranking': 13,
#   'song': '"Make It with You"',
#   'url': '/wiki/Bread_(band)'},
#  {'band_singer': 'Vanity Fare',
#   'ranking': 14,
#   'song': '"Hitchin\' a Ride"',
#   'url': '/wiki/Vanity_Fare'},
#  {'band_singer': 'The Jackson 5',
#   'ranking': 15,
#   'song': '"ABC"',
#   'url': '/wiki/The_Jackson_5'},
#  {'band_singer': 'The Jackson 5',
#   'ranking': 16,
#   'song': '"The Love You Save"',
#   'url': '/wiki/The_Jackson_5'},
#  {'band_singer': 'Neil Diamond',
#   'ranking': 17,
#   'song': '"Cracklin\' Rosie"',
#   'url': '/wiki/Neil_Diamond'},
#  {'band_singer': 'Dawn',
#   'ranking': 18,
#   'song': '"Candida"',
#   'url': '/wiki/Tony_Orlando_and_Dawn'},
#  {'band_singer': 'Sly & the Family Stone',
#   'ranking': 19,
#   'song': '"Thank You (Falettinme Be Mice Elf Agin)"',
#   'url': '/wiki/Sly_%26_the_Family_Stone'},
#  {'band_singer': 'Eric Burdon & War',
#   'ranking': 20,
#   'song': '"Spill the Wine"',
#   'url': '/wiki/Eric_Burdon'},
#  {'band_singer': 'Five Stairsteps',
#   'ranking': 21,
#   'song': '"O-o-h Child"',
#   'url': '/wiki/Five_Stairsteps'},
#  {'band_singer': 'Norman Greenbaum',
#   'ranking': 22,
#   'song': '"Spirit in the Sky"',
#   'url': '/wiki/Norman_Greenbaum'},
#  {'band_singer': 'Melanie',
#   'ranking': 23,
#   'song': '"Lay Down (Candles in the Rain)"',
#   'url': '/wiki/Melanie_Safka'},
#  {'band_singer': 'The Temptations',
#   'ranking': 24,
#   'song': '"Ball of Confusion (That\'s What the World Is Today)"',
#   'url': '/wiki/The_Temptations'},
#  {'band_singer': 'The Moments',
#   'ranking': 25,
#   'song': '"Love on a Two-Way Street"',
#   'url': '/wiki/Ray,_Goodman_%26_Brown'},
#  {'band_singer': 'The Poppy Family',
#   'ranking': 26,
#   'song': '"Which Way You Goin\' Billy?"',
#   'url': '/wiki/The_Poppy_Family'},
#  {'band_singer': 'Free',
#   'ranking': 27,
#   'song': '"All Right Now"',
#   'url': '/wiki/Free_(band)'},
#  {'band_singer': 'The Jackson 5',
#   'ranking': 28,
#   'song': '"I Want You Back"',
#   'url': '/wiki/The_Jackson_5'},
#  {'band_singer': 'Bobby Sherman',
#   'ranking': 29,
#   'song': '"Julie, Do Ya Love Me"',
#   'url': '/wiki/Bobby_Sherman'},
#  {'band_singer': 'Sugarloaf',
#   'ranking': 30,
#   'song': '"Green-Eyed Lady"',
#   'url': '/wiki/Sugarloaf_(band)'},
#  {'band_singer': 'Stevie Wonder',
#   'ranking': 31,
#   'song': '"Signed, Sealed, Delivered I\'m Yours"',
#   'url': '/wiki/Stevie_Wonder'},
#  {'band_singer': 'Blues Image',
#   'ranking': 32,
#   'song': '"Ride Captain Ride"',
#   'url': '/wiki/Blues_Image'},
#  {'band_singer': 'Shocking Blue',
#   'ranking': 33,
#   'song': '"Venus"',
#   'url': '/wiki/Shocking_Blue'},
#  {'band_singer': 'John Lennon',
#   'ranking': 34,
#   'song': '"Instant Karma!"',
#   'url': '/wiki/John_Lennon'},
#  {'band_singer': 'Clarence Carter',
#   'ranking': 35,
#   'song': '"Patches"',
#   'url': '/wiki/Clarence_Carter'},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': 36,
#   'song': '"Lookin\' out My Back Door"',
#   'url': '/wiki/Creedence_Clearwater_Revival'},
#  {'band_singer': 'Brook Benton',
#   'ranking': 37,
#   'song': '"Rainy Night in Georgia"',
#   'url': '/wiki/Brook_Benton'},
#  {'band_singer': 'Kenny Rogers & The First Edition',
#   'ranking': 38,
#   'song': '"Something\'s Burning"',
#   'url': '/wiki/Kenny_Rogers'},
#  {'band_singer': 'Chairmen of the Board',
#   'ranking': 39,
#   'song': '"Give Me Just a Little More Time"',
#   'url': '/wiki/Chairmen_of_the_Board'},
#  {'band_singer': 'Edison Lighthouse',
#   'ranking': 40,
#   'song': '"Love Grows (Where My Rosemary Goes)"',
#   'url': '/wiki/Edison_Lighthouse'},
#  {'band_singer': 'The Beatles',
#   'ranking': 41,
#   'song': '"The Long and Winding Road"',
#   'url': '/wiki/The_Beatles'},
#  {'band_singer': 'Anne Murray',
#   'ranking': 42,
#   'song': '"Snowbird"',
#   'url': '/wiki/Anne_Murray'},
#  {'band_singer': 'Marmalade',
#   'ranking': 43,
#   'song': '"Reflections of My Life"',
#   'url': '/wiki/Marmalade_(band)'},
#  {'band_singer': 'Eddie Holman',
#   'ranking': 44,
#   'song': '"Hey There Lonely Girl"',
#   'url': '/wiki/Eddie_Holman'},
#  {'band_singer': 'The Jaggerz',
#   'ranking': 45,
#   'song': '"The Rapper"',
#   'url': '/wiki/The_Jaggerz'},
#  {'band_singer': 'The Hollies',
#   'ranking': 46,
#   'song': '"He Ain\'t Heavy, He\'s My Brother"',
#   'url': '/wiki/The_Hollies'},
#  {'band_singer': "Alive N Kickin'",
#   'ranking': 47,
#   'song': '"Tighter, Tighter"',
#   'url': '/wiki/Alive_N_Kickin%27'},
#  {'band_singer': 'Badfinger',
#   'ranking': 48,
#   'song': '"Come and Get It"',
#   'url': '/wiki/Badfinger'},
#  {'band_singer': 'Simon & Garfunkel',
#   'ranking': 49,
#   'song': '"Cecilia"',
#   'url': '/wiki/Simon_%26_Garfunkel'},
#  {'band_singer': 'Charles Wright & the Watts 103rd Street Rhythm Band',
#   'ranking': 50,
#   'song': '"Love Land"',
#   'url': '/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band'},
#  {'band_singer': 'Tyrone Davis',
#   'ranking': 51,
#   'song': '"Turn Back the Hands of Time"',
#   'url': '/wiki/Tyrone_Davis'},
#  {'band_singer': 'The Kinks',
#   'ranking': 52,
#   'song': '"Lola"',
#   'url': '/wiki/The_Kinks'},
#  {'band_singer': 'Mungo Jerry',
#   'ranking': 53,
#   'song': '"In the Summertime"',
#   'url': '/wiki/Mungo_Jerry'},
#  {'band_singer': 'R. Dean Taylor',
#   'ranking': 54,
#   'song': '"Indiana Wants Me"',
#   'url': '/wiki/R._Dean_Taylor'},
#  {'band_singer': 'Rare Earth',
#   'ranking': 55,
#   'song': '"(I Know) I\'m Losing You"',
#   'url': '/wiki/Rare_Earth_(band)'},
#  {'band_singer': 'Bobby Sherman',
#   'ranking': 56,
#   'song': '"Easy Come, Easy Go"',
#   'url': '/wiki/Bobby_Sherman'},
#  {'band_singer': 'Charles Wright & the Watts 103rd Street Rhythm Band',
#   'ranking': 57,
#   'song': '"Express Yourself"',
#   'url': '/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band'},
#  {'band_singer': 'The Four Tops',
#   'ranking': 58,
#   'song': '"Still Water (Love)"',
#   'url': '/wiki/The_Four_Tops'},
#  {'band_singer': 'Chicago',
#   'ranking': 59,
#   'song': '"Make Me Smile"',
#   'url': '/wiki/Chicago_(band)'},
#  {'band_singer': 'Frijid Pink',
#   'ranking': 60,
#   'song': '"The House of the Rising Sun"',
#   'url': '/wiki/Frijid_Pink'},
#  {'band_singer': 'Chicago',
#   'ranking': 61,
#   'song': '"25 or 6 to 4"',
#   'url': '/wiki/Chicago_(band)'},
#  {'band_singer': 'White Plains',
#   'ranking': 62,
#   'song': '"My Baby Loves Lovin\'"',
#   'url': '/wiki/White_Plains_(band)'},
#  {'band_singer': 'The Friends of Distinction',
#   'ranking': 63,
#   'song': '"Love or Let Me Be Lonely"',
#   'url': '/wiki/The_Friends_of_Distinction'},
#  {'band_singer': 'The Brotherhood of Man',
#   'ranking': 64,
#   'song': '"United We Stand"',
#   'url': '/wiki/The_Brotherhood_of_Man'},
#  {'band_singer': 'The Carpenters',
#   'ranking': 65,
#   'song': '"We\'ve Only Just Begun"',
#   'url': '/wiki/The_Carpenters'},
#  {'band_singer': 'Mark Lindsay',
#   'ranking': 66,
#   'song': '"Arizona"',
#   'url': '/wiki/Mark_Lindsay'},
#  {'band_singer': 'James Taylor',
#   'ranking': 67,
#   'song': '"Fire and Rain"',
#   'url': '/wiki/James_Taylor'},
#  {'band_singer': 'Gene Chandler',
#   'ranking': 68,
#   'song': '"Groovy Situation"',
#   'url': '/wiki/Gene_Chandler'},
#  {'band_singer': 'Santana',
#   'ranking': 69,
#   'song': '"Evil Ways"',
#   'url': '/wiki/Santana_(band)'},
#  {'band_singer': 'The Guess Who',
#   'ranking': 70,
#   'song': '"No Time"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'The Delfonics',
#   'ranking': 71,
#   'song': '"Didn\'t I (Blow Your Mind This Time)"',
#   'url': '/wiki/The_Delfonics'},
#  {'band_singer': 'Elvis Presley',
#   'ranking': 72,
#   'song': '"The Wonder of You"',
#   'url': '/wiki/Elvis_Presley'},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': 73,
#   'song': '"Up Around the Bend"',
#   'url': '/wiki/Creedence_Clearwater_Revival'},
#  {'band_singer': 'Ronnie Dyson',
#   'ranking': 74,
#   'song': '"(If You Let Me Make Love To You Then) Why Can\'t I Touch You?"',
#   'url': '/wiki/Ronnie_Dyson'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 75,
#   'song': '"I Just Can\'t Help Believing"',
#   'url': '/wiki/B.J._Thomas'},
#  {'band_singer': 'The Spinners',
#   'ranking': 76,
#   'song': '"It\'s a Shame"',
#   'url': '/wiki/The_Spinners_(American_band)'},
#  {'band_singer': 'Bobbi Martin',
#   'ranking': 77,
#   'song': '"For the Love of Him"',
#   'url': '/wiki/Bobbi_Martin'},
#  {'band_singer': 'Mountain',
#   'ranking': 78,
#   'song': '"Mississippi Queen"',
#   'url': '/wiki/Mountain_(band)'},
#  {'band_singer': 'Ike & Tina Turner',
#   'ranking': 79,
#   'song': '"I Want to Take You Higher"',
#   'url': '/wiki/Ike_%26_Tina_Turner'},
#  {'band_singer': 'Joe Cocker',
#   'ranking': 80,
#   'song': '"The Letter"',
#   'url': '/wiki/Joe_Cocker'},
#  {'band_singer': 'Tee Set',
#   'ranking': 81,
#   'song': '"Ma Belle Amie"',
#   'url': '/wiki/Tee_Set'},
#  {'band_singer': 'The Originals',
#   'ranking': 82,
#   'song': '"The Bells"',
#   'url': '/wiki/The_Originals_(band)'},
#  {'band_singer': 'Christie',
#   'ranking': 83,
#   'song': '"Yellow River"',
#   'url': '/wiki/Christie_(band)'},
#  {'band_singer': '100 Proof (Aged in Soul)',
#   'ranking': 84,
#   'song': '"Somebody\'s Been Sleeping"',
#   'url': '/wiki/100_Proof_(Aged_in_Soul)'},
#  {'band_singer': 'The Ides of March',
#   'ranking': 85,
#   'song': '"Vehicle"',
#   'url': '/wiki/The_Ides_of_March_(band)'},
#  {'band_singer': 'The Pipkins',
#   'ranking': 86,
#   'song': '"Gimme Dat Ding"',
#   'url': '/wiki/The_Pipkins'},
#  {'band_singer': 'Robin McNamara',
#   'ranking': 87,
#   'song': '"Lay a Little Lovin\' on Me"',
#   'url': '/wiki/Robin_McNamara'},
#  {'band_singer': 'The Supremes',
#   'ranking': 88,
#   'song': '"Up the Ladder to the Roof"',
#   'url': '/wiki/The_Supremes'},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': 89,
#   'song': '"Travelin\' Band"',
#   'url': '/wiki/Creedence_Clearwater_Revival'},
#  {'band_singer': 'The Sandpipers',
#   'ranking': 90,
#   'song': '"Come Saturday Morning"',
#   'url': '/wiki/The_Sandpipers'},
#  {'band_singer': 'The Temptations',
#   'ranking': 91,
#   'song': '"Psychedelic Shack"',
#   'url': '/wiki/The_Temptations'},
#  {'band_singer': 'Tom Jones',
#   'ranking': 92,
#   'song': '"Without Love (There Is Nothing)"',
#   'url': '/wiki/Tom_Jones_(singer)'},
#  {'band_singer': 'Pacific Gas & Electric',
#   'ranking': 93,
#   'song': '"Are You Ready?"',
#   'url': '/wiki/Pacific_Gas_%26_Electric_(band)'},
#  {'band_singer': 'Crosby, Stills, Nash & Young',
#   'ranking': 94,
#   'song': '"Woodstock"',
#   'url': '/wiki/Crosby,_Stills,_Nash_%26_Young'},
#  {'band_singer': 'Dionne Warwick',
#   'ranking': 95,
#   'song': '"I\'ll Never Fall in Love Again"',
#   'url': '/wiki/Dionne_Warwick'},
#  {'band_singer': 'The New Seekers',
#   'ranking': 96,
#   'song': '"Look What They\'ve Done to My Song Ma"',
#   'url': '/wiki/The_New_Seekers'},
#  {'band_singer': 'Joe South',
#   'ranking': 97,
#   'song': '"Walk A Mile In My Shoes"',
#   'url': '/wiki/Joe_South'},
#  {'band_singer': 'B.B. King',
#   'ranking': 98,
#   'song': '"The Thrill Is Gone"',
#   'url': '/wiki/B.B._King'},
#  {'band_singer': 'Glen Campbell',
#   'ranking': 99,
#   'song': '"It\'s Only Make Believe"',
#   'url': '/wiki/Glen_Campbell'},
#  {'band_singer': 'Aretha Franklin',
#   'ranking': 100,
#   'song': '"Call Me"',
#   'url': '/wiki/Aretha_Franklin'}]

# %% [markdown]
# #### 1.2 Generalize the previous: scrape Wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. (We choose these later years rather than 1970 as you might find music from this era more interesting.) Download these using Python's `requests` module and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second (look up `time.sleep` in Python) at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %% [markdown]
# *HINT: you might find `range` and string-interpolation useful to construct the URLs *.

# %%
years = range(1992,2015)
yearstext = {}
for y in years:
    print(y)
    page = requests.get('https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_%i' %y)
    yearstext[y] = page.text
    time.sleep(2)
# Out:
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014

# %% [markdown]
# #### 1.3 Parse and Clean data

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single.  Now write a function `parse_year(the_year, yeartext_dict)` which takes the year, prints it out, gets the text for the year from the just created `yearstext` dictionary, and return a list of dictionaries for that year, with one dictionary for each single. Store this list in the variable `yearinfo`.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %% [markdown]
# The spec of this function is provided below:

# %%
"""
Function
--------
parse_year

Inputs
------
the_year: the year you want the singles for
yeartext_dict: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""
def parse_year(year, yearstext_dict):
    text = yearstext_dict[year]
    soup = BeautifulSoup(text, 'html.parser')
    table = soup.find('table', 'wikitable')
    rows = table.find_all('tr')[1:]
    
    def get_data(row):
        data_1 = row.find_all('td')
        attri = data_1[0].find_all('a')
        song = [a.get('title') for a in attri if a.get('title')]
        songurl = [a.get('href') if a.get('href') else None for a in attri]
        songtext = ' / '.join(song)
        attri1 = data_1[1].find_all('a')
        band_singer = [a.get('title') for a in attri1 if a.get('title')]
        url = [a.get('href') for a in attri1 if a.get('href')]
        data_2 = row.find('th')
        ranking = int(data_2.get_text())
        return [band_singer, ranking, song, songurl, songtext, url]
    
    columns = ['band_singer', 'ranking', 'song', 'songurl', 'titletext', 'url']
    return [{col: val for col, val in zip(columns, get_data(row))} for row in rows]

    
parse_year(1997,yearstext)
# Out:
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': 'Something About the Way You Look Tonight / Candle in the Wind 1997',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel (singer)'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me (Jewel song)'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': 'Foolish Games / You Were Meant for Me (Jewel song)',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Sean Combs', 'Faith Evans', '112 (band)'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': "I'll Be Missing You",
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': 'Un-Break My Heart',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Sean Combs', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': "Can't Nobody Hold Me Down",
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']},
#  {'band_singer': ['R. Kelly'],
#   'ranking': 6,
#   'song': ['I Believe I Can Fly'],
#   'songurl': ['/wiki/I_Believe_I_Can_Fly'],
#   'titletext': 'I Believe I Can Fly',
#   'url': ['/wiki/R._Kelly']},
#  {'band_singer': ['En Vogue'],
#   'ranking': 7,
#   'song': ["Don't Let Go (Love)"],
#   'songurl': ['/wiki/Don%27t_Let_Go_(Love)'],
#   'titletext': "Don't Let Go (Love)",
#   'url': ['/wiki/En_Vogue']},
#  {'band_singer': ['Mark Morrison'],
#   'ranking': 8,
#   'song': ['Return of the Mack'],
#   'songurl': ['/wiki/Return_of_the_Mack'],
#   'titletext': 'Return of the Mack',
#   'url': ['/wiki/Mark_Morrison']},
#  {'band_singer': ['LeAnn Rimes'],
#   'ranking': 9,
#   'song': ['How Do I Live'],
#   'songurl': ['/wiki/How_Do_I_Live'],
#   'titletext': 'How Do I Live',
#   'url': ['/wiki/LeAnn_Rimes']},
#  {'band_singer': ['Spice Girls'],
#   'ranking': 10,
#   'song': ['Wannabe (song)'],
#   'songurl': ['/wiki/Wannabe_(song)'],
#   'titletext': 'Wannabe (song)',
#   'url': ['/wiki/Spice_Girls']},
#  {'band_singer': ['Backstreet Boys'],
#   'ranking': 11,
#   'song': ['Quit Playing Games (With My Heart)'],
#   'songurl': ['/wiki/Quit_Playing_Games_(With_My_Heart)'],
#   'titletext': 'Quit Playing Games (With My Heart)',
#   'url': ['/wiki/Backstreet_Boys']},
#  {'band_singer': ['Hanson (band)'],
#   'ranking': 12,
#   'song': ['MMMBop'],
#   'songurl': ['/wiki/MMMBop'],
#   'titletext': 'MMMBop',
#   'url': ['/wiki/Hanson_(band)']},
#  {'band_singer': ['Monica (singer)'],
#   'ranking': 13,
#   'song': ['For You I Will (Monica song)'],
#   'songurl': ['/wiki/For_You_I_Will_(Monica_song)'],
#   'titletext': 'For You I Will (Monica song)',
#   'url': ['/wiki/Monica_(singer)']},
#  {'band_singer': ['Usher (entertainer)'],
#   'ranking': 14,
#   'song': ['You Make Me Wanna...'],
#   'songurl': ['/wiki/You_Make_Me_Wanna...'],
#   'titletext': 'You Make Me Wanna...',
#   'url': ['/wiki/Usher_(entertainer)']},
#  {'band_singer': ['Meredith Brooks'],
#   'ranking': 15,
#   'song': ['Bitch (Meredith Brooks song)'],
#   'songurl': ['/wiki/Bitch_(Meredith_Brooks_song)'],
#   'titletext': 'Bitch (Meredith Brooks song)',
#   'url': ['/wiki/Meredith_Brooks']},
#  {'band_singer': ['Keith Sweat', 'Athena Cage'],
#   'ranking': 16,
#   'song': ['Nobody (Keith Sweat song)'],
#   'songurl': ['/wiki/Nobody_(Keith_Sweat_song)'],
#   'titletext': 'Nobody (Keith Sweat song)',
#   'url': ['/wiki/Keith_Sweat', '/wiki/Athena_Cage']},
#  {'band_singer': ['Third Eye Blind'],
#   'ranking': 17,
#   'song': ['Semi-Charmed Life'],
#   'songurl': ['/wiki/Semi-Charmed_Life'],
#   'titletext': 'Semi-Charmed Life',
#   'url': ['/wiki/Third_Eye_Blind']},
#  {'band_singer': ['Duncan Sheik'],
#   'ranking': 18,
#   'song': ['Barely Breathing'],
#   'songurl': ['/wiki/Barely_Breathing'],
#   'titletext': 'Barely Breathing',
#   'url': ['/wiki/Duncan_Sheik']},
#  {'band_singer': ['Az Yet', 'Peter Cetera'],
#   'ranking': 19,
#   'song': ["Hard to Say I'm Sorry"],
#   'songurl': ['/wiki/Hard_to_Say_I%27m_Sorry'],
#   'titletext': "Hard to Say I'm Sorry",
#   'url': ['/wiki/Az_Yet', '/wiki/Peter_Cetera']},
#  {'band_singer': ['The Notorious B.I.G.', 'Sean Combs', 'Mase'],
#   'ranking': 20,
#   'song': ['Mo Money Mo Problems'],
#   'songurl': ['/wiki/Mo_Money_Mo_Problems'],
#   'titletext': 'Mo Money Mo Problems',
#   'url': ['/wiki/The_Notorious_B.I.G.', '/wiki/Sean_Combs', '/wiki/Mase']},
#  {'band_singer': ['The Verve Pipe'],
#   'ranking': 21,
#   'song': ['The Freshmen (song)'],
#   'songurl': ['/wiki/The_Freshmen_(song)'],
#   'titletext': 'The Freshmen (song)',
#   'url': ['/wiki/The_Verve_Pipe']},
#  {'band_singer': ['Savage Garden'],
#   'ranking': 22,
#   'song': ['I Want You (Savage Garden song)'],
#   'songurl': ['/wiki/I_Want_You_(Savage_Garden_song)'],
#   'titletext': 'I Want You (Savage Garden song)',
#   'url': ['/wiki/Savage_Garden']},
#  {'band_singer': ['Blackstreet', 'Dr. Dre'],
#   'ranking': 23,
#   'song': ['No Diggity'],
#   'songurl': ['/wiki/No_Diggity'],
#   'titletext': 'No Diggity',
#   'url': ['/wiki/Blackstreet', '/wiki/Dr._Dre']},
#  {'band_singer': ['Rome (musician)'],
#   'ranking': 24,
#   'song': ['I Belong to You (Every Time I See Your Face)'],
#   'songurl': ['/wiki/I_Belong_to_You_(Every_Time_I_See_Your_Face)'],
#   'titletext': 'I Belong to You (Every Time I See Your Face)',
#   'url': ['/wiki/Rome_(musician)']},
#  {'band_singer': ['The Notorious B.I.G.'],
#   'ranking': 25,
#   'song': ['Hypnotize (The Notorious B.I.G. song)'],
#   'songurl': ['/wiki/Hypnotize_(The_Notorious_B.I.G._song)'],
#   'titletext': 'Hypnotize (The Notorious B.I.G. song)',
#   'url': ['/wiki/The_Notorious_B.I.G.']},
#  {'band_singer': ['Babyface (musician)'],
#   'ranking': 26,
#   'song': ['Every Time I Close My Eyes'],
#   'songurl': ['/wiki/Every_Time_I_Close_My_Eyes'],
#   'titletext': 'Every Time I Close My Eyes',
#   'url': ['/wiki/Babyface_(musician)']},
#  {'band_singer': ['Dru Hill'],
#   'ranking': 27,
#   'song': ['In My Bed'],
#   'songurl': ['/wiki/In_My_Bed'],
#   'titletext': 'In My Bed',
#   'url': ['/wiki/Dru_Hill']},
#  {'band_singer': ['Spice Girls'],
#   'ranking': 28,
#   'song': ["Say You'll Be There"],
#   'songurl': ['/wiki/Say_You%27ll_Be_There'],
#   'titletext': "Say You'll Be There",
#   'url': ['/wiki/Spice_Girls']},
#  {'band_singer': ['Robyn'],
#   'ranking': 29,
#   'song': ['Do You Know (What It Takes)'],
#   'songurl': ['/wiki/Do_You_Know_(What_It_Takes)'],
#   'titletext': 'Do You Know (What It Takes)',
#   'url': ['/wiki/Robyn']},
#  {'band_singer': ['Boyz II Men'],
#   'ranking': 30,
#   'song': ['4 Seasons of Loneliness'],
#   'songurl': ['/wiki/4_Seasons_of_Loneliness'],
#   'titletext': '4 Seasons of Loneliness',
#   'url': ['/wiki/Boyz_II_Men']},
#  {'band_singer': ['Changing Faces (group)'],
#   'ranking': 31,
#   'song': ['G.H.E.T.T.O.U.T.'],
#   'songurl': ['/wiki/G.H.E.T.T.O.U.T.'],
#   'titletext': 'G.H.E.T.T.O.U.T.',
#   'url': ['/wiki/Changing_Faces_(group)']},
#  {'band_singer': ['Mariah Carey'],
#   'ranking': 32,
#   'song': ['Honey (Mariah Carey song)'],
#   'songurl': ['/wiki/Honey_(Mariah_Carey_song)'],
#   'titletext': 'Honey (Mariah Carey song)',
#   'url': ['/wiki/Mariah_Carey']},
#  {'band_singer': ['Whitney Houston'],
#   'ranking': 33,
#   'song': ['I Believe in You and Me'],
#   'songurl': ['/wiki/I_Believe_in_You_and_Me'],
#   'titletext': 'I Believe in You and Me',
#   'url': ['/wiki/Whitney_Houston']},
#  {'band_singer': ['Freak Nasty'],
#   'ranking': 34,
#   'song': ["Da' Dip"],
#   'songurl': ['/wiki/Da%27_Dip'],
#   'titletext': "Da' Dip",
#   'url': ['/wiki/Freak_Nasty']},
#  {'band_singer': ['Spice Girls'],
#   'ranking': 35,
#   'song': ['2 Become 1'],
#   'songurl': ['/wiki/2_Become_1'],
#   'titletext': '2 Become 1',
#   'url': ['/wiki/Spice_Girls']},
#  {'band_singer': ['Sister Hazel'],
#   'ranking': 36,
#   'song': ['All for You (Sister Hazel song)'],
#   'songurl': ['/wiki/All_for_You_(Sister_Hazel_song)'],
#   'titletext': 'All for You (Sister Hazel song)',
#   'url': ['/wiki/Sister_Hazel']},
#  {'band_singer': ['112 (band)'],
#   'ranking': 37,
#   'song': ['Cupid (112 song)'],
#   'songurl': ['/wiki/Cupid_(112_song)'],
#   'titletext': 'Cupid (112 song)',
#   'url': ['/wiki/112_(band)']},
#  {'band_singer': ['Paula Cole'],
#   'ranking': 38,
#   'song': ['Where Have All the Cowboys Gone?'],
#   'songurl': ['/wiki/Where_Have_All_the_Cowboys_Gone%3F'],
#   'titletext': 'Where Have All the Cowboys Gone?',
#   'url': ['/wiki/Paula_Cole']},
#  {'band_singer': ['Shawn Colvin'],
#   'ranking': 39,
#   'song': ['Sunny Came Home'],
#   'songurl': ['/wiki/Sunny_Came_Home'],
#   'titletext': 'Sunny Came Home',
#   'url': ['/wiki/Shawn_Colvin']},
#  {'band_singer': ['Tim McGraw', 'Faith Hill'],
#   'ranking': 40,
#   'song': ["It's Your Love"],
#   'songurl': ['/wiki/It%27s_Your_Love'],
#   'titletext': "It's Your Love",
#   'url': ['/wiki/Tim_McGraw', '/wiki/Faith_Hill']},
#  {'band_singer': ['Gina G'],
#   'ranking': 41,
#   'song': ['Ooh Aah... Just a Little Bit'],
#   'songurl': ['/wiki/Ooh_Aah..._Just_a_Little_Bit'],
#   'titletext': 'Ooh Aah... Just a Little Bit',
#   'url': ['/wiki/Gina_G']},
#  {'band_singer': ['Merril Bainbridge'],
#   'ranking': 42,
#   'song': ['Mouth (song)'],
#   'songurl': ['/wiki/Mouth_(song)'],
#   'titletext': 'Mouth (song)',
#   'url': ['/wiki/Merril_Bainbridge']},
#  {'band_singer': ['Allure (group)', '112 (band)'],
#   'ranking': 43,
#   'song': ['All Cried Out (Lisa Lisa & Cult Jam song)'],
#   'songurl': ['/wiki/All_Cried_Out_(Lisa_Lisa_%26_Cult_Jam_song)'],
#   'titletext': 'All Cried Out (Lisa Lisa & Cult Jam song)',
#   'url': ['/wiki/Allure_(group)', '/wiki/112_(band)']},
#  {'band_singer': ['New Edition'],
#   'ranking': 44,
#   'song': ["I'm Still in Love with You (New Edition song)"],
#   'songurl': ['/wiki/I%27m_Still_in_Love_with_You_(New_Edition_song)'],
#   'titletext': "I'm Still in Love with You (New Edition song)",
#   'url': ['/wiki/New_Edition']},
#  {'band_singer': ['98 Degrees'],
#   'ranking': 45,
#   'song': ['Invisible Man (song)'],
#   'songurl': ['/wiki/Invisible_Man_(song)'],
#   'titletext': 'Invisible Man (song)',
#   'url': ['/wiki/98_Degrees']},
#  {'band_singer': ["Lil' Kim",
#    'Da Brat',
#    'Lisa Lopes',
#    'Missy Elliott',
#    'Angie Martinez'],
#   'ranking': 46,
#   'song': ['Not Tonight'],
#   'songurl': ['/wiki/Not_Tonight'],
#   'titletext': 'Not Tonight',
#   'url': ['/wiki/Lil%27_Kim',
#    '/wiki/Da_Brat',
#    '/wiki/Lisa_Lopes',
#    '/wiki/Missy_Elliott',
#    '/wiki/Angie_Martinez']},
#  {'band_singer': ['Bone Thugs-n-Harmony'],
#   'ranking': 47,
#   'song': ['Look into My Eyes (Bone Thugs-n-Harmony song)'],
#   'songurl': ['/wiki/Look_into_My_Eyes_(Bone_Thugs-n-Harmony_song)'],
#   'titletext': 'Look into My Eyes (Bone Thugs-n-Harmony song)',
#   'url': ['/wiki/Bone_Thugs-n-Harmony']},
#  {'band_singer': ['702 (band)'],
#   'ranking': 48,
#   'song': ['Get It Together (702 song)'],
#   'songurl': ['/wiki/Get_It_Together_(702_song)'],
#   'titletext': 'Get It Together (702 song)',
#   'url': ['/wiki/702_(band)']},
#  {'band_singer': ['Celine Dion'],
#   'ranking': 49,
#   'song': ['All by Myself'],
#   'songurl': ['/wiki/All_by_Myself#Céline_Dion_version'],
#   'titletext': 'All by Myself',
#   'url': ['/wiki/Celine_Dion']},
#  {'band_singer': ['Celine Dion'],
#   'ranking': 50,
#   'song': ["It's All Coming Back to Me Now"],
#   'songurl': ['/wiki/It%27s_All_Coming_Back_to_Me_Now'],
#   'titletext': "It's All Coming Back to Me Now",
#   'url': ['/wiki/Celine_Dion']},
#  {'band_singer': ["Somethin' for the People", 'Trina & Tamara'],
#   'ranking': 51,
#   'song': ['My Love Is the Shhh!'],
#   'songurl': ['/wiki/My_Love_Is_the_Shhh!'],
#   'titletext': 'My Love Is the Shhh!',
#   'url': ['/wiki/Somethin%27_for_the_People', '/wiki/Trina_%26_Tamara']},
#  {'band_singer': ['No Mercy (pop band)'],
#   'ranking': 52,
#   'song': ['Where Do You Go (No Mercy song)'],
#   'songurl': ['/wiki/Where_Do_You_Go_(No_Mercy_song)'],
#   'titletext': 'Where Do You Go (No Mercy song)',
#   'url': ['/wiki/No_Mercy_(pop_band)']},
#  {'band_singer': ['Barbra Streisand', 'Bryan Adams'],
#   'ranking': 53,
#   'song': ['I Finally Found Someone'],
#   'songurl': ['/wiki/I_Finally_Found_Someone'],
#   'titletext': 'I Finally Found Someone',
#   'url': ['/wiki/Barbra_Streisand', '/wiki/Bryan_Adams']},
#  {'band_singer': ['Foxy Brown (rapper)', 'Jay-Z'],
#   'ranking': 54,
#   'song': ["I'll Be (Foxy Brown song)"],
#   'songurl': ['/wiki/I%27ll_Be_(Foxy_Brown_song)'],
#   'titletext': "I'll Be (Foxy Brown song)",
#   'url': ['/wiki/Foxy_Brown_(rapper)', '/wiki/Jay-Z']},
#  {'band_singer': ['Sheryl Crow'],
#   'ranking': 55,
#   'song': ['If It Makes You Happy'],
#   'songurl': ['/wiki/If_It_Makes_You_Happy'],
#   'titletext': 'If It Makes You Happy',
#   'url': ['/wiki/Sheryl_Crow']},
#  {'band_singer': ['Dru Hill'],
#   'ranking': 56,
#   'song': ['Never Make a Promise'],
#   'songurl': ['/wiki/Never_Make_a_Promise'],
#   'titletext': 'Never Make a Promise',
#   'url': ['/wiki/Dru_Hill']},
#  {'band_singer': ['Journey (band)'],
#   'ranking': 57,
#   'song': ['When You Love a Woman'],
#   'songurl': ['/wiki/When_You_Love_a_Woman'],
#   'titletext': 'When You Love a Woman',
#   'url': ['/wiki/Journey_(band)']},
#  {'band_singer': ['Timbaland & Magoo', 'Missy Elliott', 'Aaliyah'],
#   'ranking': 58,
#   'song': ['Up Jumps da Boogie'],
#   'songurl': ['/wiki/Up_Jumps_da_Boogie'],
#   'titletext': 'Up Jumps da Boogie',
#   'url': ['/wiki/Timbaland_%26_Magoo',
#    '/wiki/Missy_Elliott',
#    '/wiki/Aaliyah']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 59,
#   'song': ["I Don't Want To", 'I Love Me Some Him'],
#   'songurl': ['/wiki/I_Don%27t_Want_To', '/wiki/I_Love_Me_Some_Him'],
#   'titletext': "I Don't Want To / I Love Me Some Him",
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Sheryl Crow'],
#   'ranking': 60,
#   'song': ['Everyday Is a Winding Road'],
#   'songurl': ['/wiki/Everyday_Is_a_Winding_Road'],
#   'titletext': 'Everyday Is a Winding Road',
#   'url': ['/wiki/Sheryl_Crow']},
#  {'band_singer': ['MC Lyte'],
#   'ranking': 61,
#   'song': ['Cold Rock a Party'],
#   'songurl': ['/wiki/Cold_Rock_a_Party'],
#   'titletext': 'Cold Rock a Party',
#   'url': ['/wiki/MC_Lyte']},
#  {'band_singer': ['Ginuwine'],
#   'ranking': 62,
#   'song': ['Pony (Ginuwine song)'],
#   'songurl': ['/wiki/Pony_(Ginuwine_song)'],
#   'titletext': 'Pony (Ginuwine song)',
#   'url': ['/wiki/Ginuwine']},
#  {'band_singer': ['Sarah McLachlan'],
#   'ranking': 63,
#   'song': ['Building a Mystery'],
#   'songurl': ['/wiki/Building_a_Mystery'],
#   'titletext': 'Building a Mystery',
#   'url': ['/wiki/Sarah_McLachlan']},
#  {'band_singer': ['Donna Lewis'],
#   'ranking': 64,
#   'song': ['I Love You Always Forever'],
#   'songurl': ['/wiki/I_Love_You_Always_Forever'],
#   'titletext': 'I Love You Always Forever',
#   'url': ['/wiki/Donna_Lewis']},
#  {'band_singer': ['White Town'],
#   'ranking': 65,
#   'song': ['Your Woman'],
#   'songurl': ['/wiki/Your_Woman'],
#   'titletext': 'Your Woman',
#   'url': ['/wiki/White_Town']},
#  {'band_singer': ['Coolio'],
#   'ranking': 66,
#   'song': ['C U When U Get There'],
#   'songurl': ['/wiki/C_U_When_U_Get_There'],
#   'titletext': 'C U When U Get There',
#   'url': ['/wiki/Coolio']},
#  {'band_singer': ['Eric Clapton'],
#   'ranking': 67,
#   'song': ['Change the World'],
#   'songurl': ['/wiki/Change_the_World'],
#   'titletext': 'Change the World',
#   'url': ['/wiki/Eric_Clapton']},
#  {'band_singer': ['B-Rock and the Bizz'],
#   'ranking': 68,
#   'song': ['My Baby Daddy'],
#   'songurl': ['/wiki/My_Baby_Daddy'],
#   'titletext': 'My Baby Daddy',
#   'url': ['/wiki/B-Rock_and_the_Bizz']},
#  {'band_singer': ['Chumbawamba'],
#   'ranking': 69,
#   'song': ['Tubthumping'],
#   'songurl': ['/wiki/Tubthumping'],
#   'titletext': 'Tubthumping',
#   'url': ['/wiki/Chumbawamba']},
#  {'band_singer': ['R. Kelly'],
#   'ranking': 70,
#   'song': ['Gotham City (song)'],
#   'songurl': ['/wiki/Gotham_City_(song)'],
#   'titletext': 'Gotham City (song)',
#   'url': ['/wiki/R._Kelly']},
#  {'band_singer': ['Az Yet'],
#   'ranking': 71,
#   'song': ['Last Night (Az Yet song)'],
#   'songurl': ['/wiki/Last_Night_(Az_Yet_song)'],
#   'titletext': 'Last Night (Az Yet song)',
#   'url': ['/wiki/Az_Yet']},
#  {'band_singer': [],
#   'ranking': 72,
#   'song': ['Jock Jam'],
#   'songurl': ['/wiki/Jock_Jam'],
#   'titletext': 'Jock Jam',
#   'url': []},
#  {'band_singer': ['Heavy D'],
#   'ranking': 73,
#   'song': ['Big Daddy (song)'],
#   'songurl': ['/wiki/Big_Daddy_(song)'],
#   'titletext': 'Big Daddy (song)',
#   'url': ['/wiki/Heavy_D']},
#  {'band_singer': ['Total (band)'],
#   'ranking': 74,
#   'song': ['What About Us? (Total song)'],
#   'songurl': ['/wiki/What_About_Us%3F_(Total_song)'],
#   'titletext': 'What About Us? (Total song)',
#   'url': ['/wiki/Total_(band)']},
#  {'band_singer': ['Scarface (rapper)', 'Tupac Shakur'],
#   'ranking': 75,
#   'song': ['Smile (Scarface song)'],
#   'songurl': ['/wiki/Smile_(Scarface_song)'],
#   'titletext': 'Smile (Scarface song)',
#   'url': ['/wiki/Scarface_(rapper)', '/wiki/Tupac_Shakur']},
#  {'band_singer': ['Montell Jordan'],
#   'ranking': 76,
#   'song': ["What's on Tonight"],
#   'songurl': ['/wiki/What%27s_on_Tonight'],
#   'titletext': "What's on Tonight",
#   'url': ['/wiki/Montell_Jordan']},
#  {'band_singer': ['Bruce Springsteen'],
#   'ranking': 77,
#   'song': ['Secret Garden (Bruce Springsteen song)'],
#   'songurl': ['/wiki/Secret_Garden_(Bruce_Springsteen_song)'],
#   'titletext': 'Secret Garden (Bruce Springsteen song)',
#   'url': ['/wiki/Bruce_Springsteen']},
#  {'band_singer': ['Aaliyah'],
#   'ranking': 78,
#   'song': ['The One I Gave My Heart To'],
#   'songurl': ['/wiki/The_One_I_Gave_My_Heart_To'],
#   'titletext': 'The One I Gave My Heart To',
#   'url': ['/wiki/Aaliyah']},
#  {'band_singer': ['Seal (musician)'],
#   'ranking': 79,
#   'song': ['Fly Like an Eagle (song)'],
#   'songurl': ['/wiki/Fly_Like_an_Eagle_(song)#Cover_versions'],
#   'titletext': 'Fly Like an Eagle (song)',
#   'url': ['/wiki/Seal_(musician)']},
#  {'band_singer': ["Lil' Kim", 'Sean Combs'],
#   'ranking': 80,
#   'song': ["No Time (Lil' Kim song)"],
#   'songurl': ['/wiki/No_Time_(Lil%27_Kim_song)'],
#   'titletext': "No Time (Lil' Kim song)",
#   'url': ['/wiki/Lil%27_Kim', '/wiki/Sean_Combs']},
#  {'band_singer': ['Luscious Jackson'],
#   'ranking': 81,
#   'song': ['Naked Eye (song)'],
#   'songurl': ['/wiki/Naked_Eye_(song)'],
#   'titletext': 'Naked Eye (song)',
#   'url': ['/wiki/Luscious_Jackson']},
#  {'band_singer': ['Los del Río'],
#   'ranking': 82,
#   'song': ['Macarena (song)'],
#   'songurl': ['/wiki/Macarena_(song)'],
#   'titletext': 'Macarena (song)',
#   'url': ['/wiki/Los_del_R%C3%ADo']},
#  {'band_singer': ['Erykah Badu'],
#   'ranking': 83,
#   'song': ['On & On (Erykah Badu song)'],
#   'songurl': ['/wiki/On_%26_On_(Erykah_Badu_song)'],
#   'titletext': 'On & On (Erykah Badu song)',
#   'url': ['/wiki/Erykah_Badu']},
#  {'band_singer': ['Joe (singer)'],
#   'ranking': 84,
#   'song': [],
#   'songurl': [],
#   'titletext': '',
#   'url': ['/wiki/Joe_(singer)']},
#  {'band_singer': ['Warren G'],
#   'ranking': 85,
#   'song': ['I Shot the Sheriff (Warren G song)'],
#   'songurl': ['/wiki/I_Shot_the_Sheriff_(Warren_G_song)'],
#   'titletext': 'I Shot the Sheriff (Warren G song)',
#   'url': ['/wiki/Warren_G']},
#  {'band_singer': ['Brian McKnight', 'Mase'],
#   'ranking': 86,
#   'song': ["You Should Be Mine (Don't Waste Your Time)"],
#   'songurl': ['/wiki/You_Should_Be_Mine_(Don%27t_Waste_Your_Time)'],
#   'titletext': "You Should Be Mine (Don't Waste Your Time)",
#   'url': ['/wiki/Brian_McKnight', '/wiki/Mase']},
#  {'band_singer': ['Madonna (entertainer)'],
#   'ranking': 87,
#   'song': ["Don't Cry for Me Argentina"],
#   'songurl': ['/wiki/Don%27t_Cry_for_Me_Argentina'],
#   'titletext': "Don't Cry for Me Argentina",
#   'url': ['/wiki/Madonna_(entertainer)']},
#  {'band_singer': ['SWV', 'Sean Combs'],
#   'ranking': 88,
#   'song': [],
#   'songurl': [],
#   'titletext': '',
#   'url': ['/wiki/SWV', '/wiki/Sean_Combs']},
#  {'band_singer': ['Michael Bolton'],
#   'ranking': 89,
#   'song': ['Go the Distance'],
#   'songurl': ['/wiki/Go_the_Distance'],
#   'titletext': 'Go the Distance',
#   'url': ['/wiki/Michael_Bolton']},
#  {'band_singer': ['Real McCoy (band)'],
#   'ranking': 90,
#   'song': ['One More Time (Real McCoy song)'],
#   'songurl': ['/wiki/One_More_Time_(Real_McCoy_song)'],
#   'titletext': 'One More Time (Real McCoy song)',
#   'url': ['/wiki/Real_McCoy_(band)']},
#  {'band_singer': ['Next (group)'],
#   'ranking': 91,
#   'song': [],
#   'songurl': [],
#   'titletext': '',
#   'url': ['/wiki/Next_(group)']},
#  {'band_singer': ['Mr. President (band)'],
#   'ranking': 92,
#   'song': ['Coco Jambo'],
#   'songurl': ['/wiki/Coco_Jambo'],
#   'titletext': 'Coco Jambo',
#   'url': ['/wiki/Mr._President_(band)']},
#  {'band_singer': ['Keith Sweat'],
#   'ranking': 93,
#   'song': ['Twisted (Keith Sweat song)'],
#   'songurl': ['/wiki/Twisted_(Keith_Sweat_song)'],
#   'titletext': 'Twisted (Keith Sweat song)',
#   'url': ['/wiki/Keith_Sweat']},
#  {'band_singer': ['Aqua (band)'],
#   'ranking': 94,
#   'song': ['Barbie Girl'],
#   'songurl': ['/wiki/Barbie_Girl'],
#   'titletext': 'Barbie Girl',
#   'url': ['/wiki/Aqua_(band)']},
#  {'band_singer': ['The Cranberries'],
#   'ranking': 95,
#   'song': ["When You're Gone (The Cranberries song)", 'Free to Decide'],
#   'songurl': ['/wiki/When_You%27re_Gone_(The_Cranberries_song)',
#    '/wiki/Free_to_Decide'],
#   'titletext': "When You're Gone (The Cranberries song) / Free to Decide",
#   'url': ['/wiki/The_Cranberries']},
#  {'band_singer': ['DJ Kool'],
#   'ranking': 96,
#   'song': ['Let Me Clear My Throat'],
#   'songurl': ['/wiki/Let_Me_Clear_My_Throat'],
#   'titletext': 'Let Me Clear My Throat',
#   'url': ['/wiki/DJ_Kool']},
#  {'band_singer': ['The Blackout All-Stars'],
#   'ranking': 97,
#   'song': ['I Like It Like That (Pete Rodriguez song)'],
#   'songurl': ['/wiki/I_Like_It_Like_That_(Pete_Rodriguez_song)#The_Blackout_All-Stars_version'],
#   'titletext': 'I Like It Like That (Pete Rodriguez song)',
#   'url': ['/wiki/The_Blackout_All-Stars']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 98,
#   'song': ["You're Makin' Me High", 'Let It Flow (song)'],
#   'songurl': ['/wiki/You%27re_Makin%27_Me_High', '/wiki/Let_It_Flow_(song)'],
#   'titletext': "You're Makin' Me High / Let It Flow (song)",
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Madonna (entertainer)'],
#   'ranking': 99,
#   'song': ['You Must Love Me'],
#   'songurl': ['/wiki/You_Must_Love_Me'],
#   'titletext': 'You Must Love Me',
#   'url': ['/wiki/Madonna_(entertainer)']},
#  {'band_singer': ['Ray J'],
#   'ranking': 100,
#   'song': ['Let It Go (Ray J song)'],
#   'songurl': ['/wiki/Let_It_Go_(Ray_J_song)'],
#   'titletext': 'Let It Go (Ray J song)',
#   'url': ['/wiki/Ray_J']}]

# %% [markdown]
# #### Helpful notes
#
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some singles don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# Thus there are some issues this function must handle:
#
# 1. There can be more than one  `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be two songs in a single, because of the way the industry works: there are two-sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for an example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that Wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a check, we can do this for 1997. We'll print the first 5 outputs: `parse_year(1997, yearstext)[:5]`

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [markdown]
# ```
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]
# ```

# %%
yearinfo = {}
for year in years:
    yearinfo[year] = parse_year(year, yearstext)
yearinfo
# Out:
# {1992: [{'band_singer': ['Boyz II Men'],
#    'ranking': 1,
#    'song': ['End of the Road'],
#    'songurl': ['/wiki/End_of_the_Road'],
#    'titletext': 'End of the Road',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Sir Mix-a-Lot'],
#    'ranking': 2,
#    'song': ['Baby Got Back'],
#    'songurl': ['/wiki/Baby_Got_Back'],
#    'titletext': 'Baby Got Back',
#    'url': ['/wiki/Sir_Mix-a-Lot']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': 3,
#    'song': ['Jump (Kris Kross song)'],
#    'songurl': ['/wiki/Jump_(Kris_Kross_song)'],
#    'titletext': 'Jump (Kris Kross song)',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Vanessa L. Williams'],
#    'ranking': 4,
#    'song': ['Save the Best for Last'],
#    'songurl': ['/wiki/Save_the_Best_for_Last'],
#    'titletext': 'Save the Best for Last',
#    'url': ['/wiki/Vanessa_L._Williams']},
#   {'band_singer': ['TLC (band)'],
#    'ranking': 5,
#    'song': ['Baby-Baby-Baby'],
#    'songurl': ['/wiki/Baby-Baby-Baby'],
#    'titletext': 'Baby-Baby-Baby',
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Eric Clapton'],
#    'ranking': 6,
#    'song': ['Tears in Heaven'],
#    'songurl': ['/wiki/Tears_in_Heaven'],
#    'titletext': 'Tears in Heaven',
#    'url': ['/wiki/Eric_Clapton']},
#   {'band_singer': ['En Vogue'],
#    'ranking': 7,
#    'song': ["My Lovin' (You're Never Gonna Get It)"],
#    'songurl': ['/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)'],
#    'titletext': "My Lovin' (You're Never Gonna Get It)",
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Red Hot Chili Peppers'],
#    'ranking': 8,
#    'song': ['Under the Bridge'],
#    'songurl': ['/wiki/Under_the_Bridge'],
#    'titletext': 'Under the Bridge',
#    'url': ['/wiki/Red_Hot_Chili_Peppers']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': 9,
#    'song': ['All 4 Love'],
#    'songurl': ['/wiki/All_4_Love'],
#    'titletext': 'All 4 Love',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': 10,
#    'song': ['Just Another Day (Jon Secada song)'],
#    'songurl': ['/wiki/Just_Another_Day_(Jon_Secada_song)'],
#    'titletext': 'Just Another Day (Jon Secada song)',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Shanice'],
#    'ranking': 11,
#    'song': ['I Love Your Smile'],
#    'songurl': ['/wiki/I_Love_Your_Smile'],
#    'titletext': 'I Love Your Smile',
#    'url': ['/wiki/Shanice']},
#   {'band_singer': ['Mr. Big (band)'],
#    'ranking': 12,
#    'song': ['To Be with You'],
#    'songurl': ['/wiki/To_Be_with_You'],
#    'titletext': 'To Be with You',
#    'url': ['/wiki/Mr._Big_(band)']},
#   {'band_singer': ['Right Said Fred'],
#    'ranking': 13,
#    'song': ["I'm Too Sexy"],
#    'songurl': ['/wiki/I%27m_Too_Sexy'],
#    'titletext': "I'm Too Sexy",
#    'url': ['/wiki/Right_Said_Fred']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': 14,
#    'song': ['Black or White'],
#    'songurl': ['/wiki/Black_or_White'],
#    'titletext': 'Black or White',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Billy Ray Cyrus'],
#    'ranking': 15,
#    'song': ['Achy Breaky Heart'],
#    'songurl': ['/wiki/Achy_Breaky_Heart'],
#    'titletext': 'Achy Breaky Heart',
#    'url': ['/wiki/Billy_Ray_Cyrus']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 16,
#    'song': ["I'll Be There (The Jackson 5 song)"],
#    'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version'],
#    'titletext': "I'll Be There (The Jackson 5 song)",
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ["Guns N' Roses"],
#    'ranking': 17,
#    'song': ['November Rain'],
#    'songurl': ['/wiki/November_Rain'],
#    'titletext': 'November Rain',
#    'url': ['/wiki/Guns_N%27_Roses']},
#   {'band_singer': ['Tom Cochrane'],
#    'ranking': 18,
#    'song': ['Life Is a Highway'],
#    'songurl': ['/wiki/Life_Is_a_Highway'],
#    'titletext': 'Life Is a Highway',
#    'url': ['/wiki/Tom_Cochrane']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': 19,
#    'song': ['Remember the Time'],
#    'songurl': ['/wiki/Remember_the_Time'],
#    'titletext': 'Remember the Time',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': 20,
#    'song': ['Finally (CeCe Peniston song)'],
#    'songurl': ['/wiki/Finally_(CeCe_Peniston_song)'],
#    'titletext': 'Finally (CeCe Peniston song)',
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Madonna (entertainer)'],
#    'ranking': 21,
#    'song': ['This Used to Be My Playground'],
#    'songurl': ['/wiki/This_Used_to_Be_My_Playground'],
#    'titletext': 'This Used to Be My Playground',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Patty Smyth', 'Don Henley'],
#    'ranking': 22,
#    'song': ["Sometimes Love Just Ain't Enough"],
#    'songurl': ['/wiki/Sometimes_Love_Just_Ain%27t_Enough'],
#    'titletext': "Sometimes Love Just Ain't Enough",
#    'url': ['/wiki/Patty_Smyth', '/wiki/Don_Henley']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 23,
#    'song': ["Can't Let Go (Mariah Carey song)"],
#    'songurl': ['/wiki/Can%27t_Let_Go_(Mariah_Carey_song)'],
#    'titletext': "Can't Let Go (Mariah Carey song)",
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['House of Pain'],
#    'ranking': 24,
#    'song': ['Jump Around'],
#    'songurl': ['/wiki/Jump_Around'],
#    'titletext': 'Jump Around',
#    'url': ['/wiki/House_of_Pain']},
#   {'band_singer': ['Prince (entertainer)', 'The New Power Generation'],
#    'ranking': 25,
#    'song': ['Diamonds and Pearls (song)'],
#    'songurl': ['/wiki/Diamonds_and_Pearls_(song)'],
#    'titletext': 'Diamonds and Pearls (song)',
#    'url': ['/wiki/Prince_(entertainer)', '/wiki/The_New_Power_Generation']},
#   {'band_singer': ['George Michael', 'Elton John'],
#    'ranking': 26,
#    'song': ["Don't Let the Sun Go Down on Me"],
#    'songurl': ['/wiki/Don%27t_Let_the_Sun_Go_Down_on_Me'],
#    'titletext': "Don't Let the Sun Go Down on Me",
#    'url': ['/wiki/George_Michael', '/wiki/Elton_John']},
#   {'band_singer': ['Atlantic Starr'],
#    'ranking': 27,
#    'song': ['Masterpiece (Atlantic Starr song)'],
#    'songurl': ['/wiki/Masterpiece_(Atlantic_Starr_song)'],
#    'titletext': 'Masterpiece (Atlantic Starr song)',
#    'url': ['/wiki/Atlantic_Starr']},
#   {'band_singer': ['Celine Dion'],
#    'ranking': 28,
#    'song': ['If You Asked Me To'],
#    'songurl': ['/wiki/If_You_Asked_Me_To'],
#    'titletext': 'If You Asked Me To',
#    'url': ['/wiki/Celine_Dion']},
#   {'band_singer': ['En Vogue'],
#    'ranking': 29,
#    'song': ['Something He Can Feel'],
#    'songurl': ['/wiki/Something_He_Can_Feel'],
#    'titletext': 'Something He Can Feel',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Joe Public (band)'],
#    'ranking': 30,
#    'song': ['Live and Learn (Joe Public song)'],
#    'songurl': ['/wiki/Live_and_Learn_(Joe_Public_song)'],
#    'titletext': 'Live and Learn (Joe Public song)',
#    'url': ['/wiki/Joe_Public_(band)']},
#   {'band_singer': ['Jodeci'],
#    'ranking': 31,
#    'song': ['Come and Talk to Me'],
#    'songurl': ['/wiki/Come_and_Talk_to_Me'],
#    'titletext': 'Come and Talk to Me',
#    'url': ['/wiki/Jodeci']},
#   {'band_singer': ['Nirvana (band)'],
#    'ranking': 32,
#    'song': ['Smells Like Teen Spirit'],
#    'songurl': ['/wiki/Smells_Like_Teen_Spirit'],
#    'titletext': 'Smells Like Teen Spirit',
#    'url': ['/wiki/Nirvana_(band)']},
#   {'band_singer': ['Bobby Brown'],
#    'ranking': 33,
#    'song': ["Humpin' Around"],
#    'songurl': ['/wiki/Humpin%27_Around'],
#    'titletext': "Humpin' Around",
#    'url': ['/wiki/Bobby_Brown']},
#   {'band_singer': ['Sophie B. Hawkins'],
#    'ranking': 34,
#    'song': ['Damn I Wish I Was Your Lover'],
#    'songurl': ['/wiki/Damn_I_Wish_I_Was_Your_Lover'],
#    'titletext': 'Damn I Wish I Was Your Lover',
#    'url': ['/wiki/Sophie_B._Hawkins']},
#   {'band_singer': ['Tevin Campbell'],
#    'ranking': 35,
#    'song': ['Tell Me What You Want Me to Do'],
#    'songurl': ['/wiki/Tell_Me_What_You_Want_Me_to_Do'],
#    'titletext': 'Tell Me What You Want Me to Do',
#    'url': ['/wiki/Tevin_Campbell']},
#   {'band_singer': ['TLC (band)'],
#    'ranking': 36,
#    'song': ["Ain't 2 Proud 2 Beg"],
#    'songurl': ['/wiki/Ain%27t_2_Proud_2_Beg'],
#    'titletext': "Ain't 2 Proud 2 Beg",
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': 37,
#    'song': ["It's So Hard to Say Goodbye to Yesterday"],
#    'songurl': ['/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday'],
#    'titletext': "It's So Hard to Say Goodbye to Yesterday",
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Technotronic', 'Ya Kid K'],
#    'ranking': 38,
#    'song': ['Move This'],
#    'songurl': ['/wiki/Move_This'],
#    'titletext': 'Move This',
#    'url': ['/wiki/Technotronic', '/wiki/Ya_Kid_K']},
#   {'band_singer': ['Queen (band)'],
#    'ranking': 39,
#    'song': ['Bohemian Rhapsody'],
#    'songurl': ['/wiki/Bohemian_Rhapsody'],
#    'titletext': 'Bohemian Rhapsody',
#    'url': ['/wiki/Queen_(band)']},
#   {'band_singer': ['Arrested Development (group)'],
#    'ranking': 40,
#    'song': ['Tennessee (Arrested Development song)'],
#    'songurl': ['/wiki/Tennessee_(Arrested_Development_song)'],
#    'titletext': 'Tennessee (Arrested Development song)',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Luther Vandross', 'Janet Jackson'],
#    'ranking': 41,
#    'song': ['The Best Things in Life Are Free'],
#    'songurl': ['/wiki/The_Best_Things_in_Life_Are_Free'],
#    'titletext': 'The Best Things in Life Are Free',
#    'url': ['/wiki/Luther_Vandross', '/wiki/Janet_Jackson']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 42,
#    'song': ['Make It Happen (Mariah Carey song)'],
#    'songurl': ['/wiki/Make_It_Happen_(Mariah_Carey_song)'],
#    'titletext': 'Make It Happen (Mariah Carey song)',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Elton John'],
#    'ranking': 43,
#    'song': ['The One (Elton John song)'],
#    'songurl': ['/wiki/The_One_(Elton_John_song)'],
#    'titletext': 'The One (Elton John song)',
#    'url': ['/wiki/Elton_John']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': 44,
#    'song': ['Set Adrift on Memory Bliss'],
#    'songurl': ['/wiki/Set_Adrift_on_Memory_Bliss'],
#    'titletext': 'Set Adrift on Memory Bliss',
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Shakespears Sister'],
#    'ranking': 45,
#    'song': ['Stay (Shakespears Sister song)'],
#    'songurl': ['/wiki/Stay_(Shakespears_Sister_song)'],
#    'titletext': 'Stay (Shakespears Sister song)',
#    'url': ['/wiki/Shakespears_Sister']},
#   {'band_singer': ['MC Hammer'],
#    'ranking': 46,
#    'song': ['Too Legit to Quit (song)'],
#    'songurl': ['/wiki/Too_Legit_to_Quit_(song)'],
#    'titletext': 'Too Legit to Quit (song)',
#    'url': ['/wiki/MC_Hammer']},
#   {'band_singer': ['KWS (band)'],
#    'ranking': 47,
#    'song': ["Please Don't Go (KC and the Sunshine Band song)"],
#    'songurl': ['/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version'],
#    'titletext': "Please Don't Go (KC and the Sunshine Band song)",
#    'url': ['/wiki/KWS_(band)']},
#   {'band_singer': ['Mint Condition'],
#    'ranking': 48,
#    'song': ["Breakin' My Heart (Pretty Brown Eyes)"],
#    'songurl': ['/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)'],
#    'titletext': "Breakin' My Heart (Pretty Brown Eyes)",
#    'url': ['/wiki/Mint_Condition']},
#   {'band_singer': ['The Cover Girls'],
#    'ranking': 49,
#    'song': ['Wishing on a Star'],
#    'songurl': ['/wiki/Wishing_on_a_Star'],
#    'titletext': 'Wishing on a Star',
#    'url': ['/wiki/The_Cover_Girls']},
#   {'band_singer': ['Hi-Five'],
#    'ranking': 50,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Hi-Five']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': 51,
#    'song': ["I'd Die Without You"],
#    'songurl': ['/wiki/I%27d_Die_Without_You'],
#    'titletext': "I'd Die Without You",
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': 52,
#    'song': ['Good for Me (song)'],
#    'songurl': ['/wiki/Good_for_Me_(song)'],
#    'titletext': 'Good for Me (song)',
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['Toad the Wet Sprocket'],
#    'ranking': 53,
#    'song': ['All I Want (Toad the Wet Sprocket song)'],
#    'songurl': ['/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)'],
#    'titletext': 'All I Want (Toad the Wet Sprocket song)',
#    'url': ['/wiki/Toad_the_Wet_Sprocket']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': 54,
#    'song': ['When a Man Loves a Woman (song)'],
#    'songurl': ['/wiki/When_a_Man_Loves_a_Woman_(song)'],
#    'titletext': 'When a Man Loves a Woman (song)',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['Genesis (band)'],
#    'ranking': 55,
#    'song': ["I Can't Dance"],
#    'songurl': ['/wiki/I_Can%27t_Dance'],
#    'titletext': "I Can't Dance",
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': 56,
#    'song': ['Hazard (song)'],
#    'songurl': ['/wiki/Hazard_(song)'],
#    'titletext': 'Hazard (song)',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['U2'],
#    'ranking': 57,
#    'song': ['Mysterious Ways (song)'],
#    'songurl': ['/wiki/Mysterious_Ways_(song)'],
#    'titletext': 'Mysterious Ways (song)',
#    'url': ['/wiki/U2']},
#   {'band_singer': ['George Michael'],
#    'ranking': 58,
#    'song': ['Too Funky'],
#    'songurl': ['/wiki/Too_Funky'],
#    'titletext': 'Too Funky',
#    'url': ['/wiki/George_Michael']},
#   {'band_singer': ['The Heights (TV series)'],
#    'ranking': 59,
#    'song': ['How Do You Talk to an Angel'],
#    'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#    'titletext': 'How Do You Talk to an Angel',
#    'url': ['/wiki/The_Heights_(TV_series)']},
#   {'band_singer': ['U2'],
#    'ranking': 60,
#    'song': ['One (U2 song)'],
#    'songurl': ['/wiki/One_(U2_song)'],
#    'titletext': 'One (U2 song)',
#    'url': ['/wiki/U2']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': 61,
#    'song': ["Keep on Walkin' (song)"],
#    'songurl': ['/wiki/Keep_on_Walkin%27_(song)'],
#    'titletext': "Keep on Walkin' (song)",
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Genesis (band)'],
#    'ranking': 62,
#    'song': ['Hold on My Heart'],
#    'songurl': ['/wiki/Hold_on_My_Heart'],
#    'titletext': 'Hold on My Heart',
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Karyn White'],
#    'ranking': 63,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Karyn_White']},
#   {'band_singer': ['Celine Dion', 'Peabo Bryson'],
#    'ranking': 64,
#    'song': ['Beauty and the Beast (Disney song)'],
#    'songurl': ['/wiki/Beauty_and_the_Beast_(Disney_song)'],
#    'titletext': 'Beauty and the Beast (Disney song)',
#    'url': ['/wiki/Celine_Dion', '/wiki/Peabo_Bryson']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': 65,
#    'song': ['Warm It Up'],
#    'songurl': ['/wiki/Warm_It_Up'],
#    'titletext': 'Warm It Up',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': 66,
#    'song': ['In the Closet'],
#    'songurl': ['/wiki/In_the_Closet'],
#    'titletext': 'In the Closet',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Arrested Development (group)'],
#    'ranking': 67,
#    'song': ['People Everyday'],
#    'songurl': ['/wiki/People_Everyday'],
#    'titletext': 'People Everyday',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Genesis (band)'],
#    'ranking': 68,
#    'song': ['No Son of Mine'],
#    'songurl': ['/wiki/No_Son_of_Mine'],
#    'titletext': 'No Son of Mine',
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Marky Mark and the Funky Bunch'],
#    'ranking': 69,
#    'song': ['Wildside (Marky Mark and the Funky Bunch song)'],
#    'songurl': ['/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)'],
#    'titletext': 'Wildside (Marky Mark and the Funky Bunch song)',
#    'url': ['/wiki/Marky_Mark_and_the_Funky_Bunch']},
#   {'band_singer': ['Bryan Adams'],
#    'ranking': 70,
#    'song': ['Do I Have to Say the Words?'],
#    'songurl': ['/wiki/Do_I_Have_to_Say_the_Words%3F'],
#    'titletext': 'Do I Have to Say the Words?',
#    'url': ['/wiki/Bryan_Adams']},
#   {'band_singer': ['The Cure'],
#    'ranking': 71,
#    'song': ["Friday I'm in Love"],
#    'songurl': ['/wiki/Friday_I%27m_in_Love'],
#    'titletext': "Friday I'm in Love",
#    'url': ['/wiki/The_Cure']},
#   {'band_singer': ['Ugly Kid Joe'],
#    'ranking': 72,
#    'song': ['Everything About You (Ugly Kid Joe song)'],
#    'songurl': ['/wiki/Everything_About_You_(Ugly_Kid_Joe_song)'],
#    'titletext': 'Everything About You (Ugly Kid Joe song)',
#    'url': ['/wiki/Ugly_Kid_Joe']},
#   {'band_singer': ['Paula Abdul'],
#    'ranking': 73,
#    'song': ['Blowing Kisses in the Wind'],
#    'songurl': ['/wiki/Blowing_Kisses_in_the_Wind'],
#    'titletext': 'Blowing Kisses in the Wind',
#    'url': ['/wiki/Paula_Abdul']},
#   {'band_singer': ['Bryan Adams'],
#    'ranking': 74,
#    'song': ["Thought I'd Died and Gone to Heaven"],
#    'songurl': ['/wiki/Thought_I%27d_Died_and_Gone_to_Heaven'],
#    'titletext': "Thought I'd Died and Gone to Heaven",
#    'url': ['/wiki/Bryan_Adams']},
#   {'band_singer': ['Snap!'],
#    'ranking': 75,
#    'song': ['Rhythm Is a Dancer'],
#    'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#    'titletext': 'Rhythm Is a Dancer',
#    'url': ['/wiki/Snap!']},
#   {'band_singer': ['MC Hammer'],
#    'ranking': 76,
#    'song': ['Addams Groove'],
#    'songurl': ['/wiki/Addams_Groove'],
#    'titletext': 'Addams Groove',
#    'url': ['/wiki/MC_Hammer']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': 77,
#    'song': ['Missing You Now'],
#    'songurl': ['/wiki/Missing_You_Now'],
#    'titletext': 'Missing You Now',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['N2Deep'],
#    'ranking': 78,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/N2Deep']},
#   {'band_singer': ['Kathy Troccoli'],
#    'ranking': 79,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Kathy_Troccoli']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': 80,
#    'song': ['Have You Ever Needed Someone So Bad'],
#    'songurl': ['/wiki/Have_You_Ever_Needed_Someone_So_Bad'],
#    'titletext': 'Have You Ever Needed Someone So Bad',
#    'url': ['/wiki/Def_Leppard']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': 81,
#    'song': ['Take This Heart'],
#    'songurl': ['/wiki/Take_This_Heart'],
#    'titletext': 'Take This Heart',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['FireHouse (band)'],
#    'ranking': 82,
#    'song': ['When I Look Into Your Eyes'],
#    'songurl': ['/wiki/When_I_Look_Into_Your_Eyes'],
#    'titletext': 'When I Look Into Your Eyes',
#    'url': ['/wiki/FireHouse_(band)']},
#   {'band_singer': ['Jade (American band)'],
#    'ranking': 83,
#    'song': ['I Wanna Love You (Jade song)'],
#    'songurl': ['/wiki/I_Wanna_Love_You_(Jade_song)'],
#    'titletext': 'I Wanna Love You (Jade song)',
#    'url': ['/wiki/Jade_(American_band)']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': 84,
#    'song': ['Uhh Ahh'],
#    'songurl': ['/wiki/Uhh_Ahh'],
#    'titletext': 'Uhh Ahh',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Mary J. Blige'],
#    'ranking': 85,
#    'song': ['Real Love (Mary J. Blige song)'],
#    'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#    'titletext': 'Real Love (Mary J. Blige song)',
#    'url': ['/wiki/Mary_J._Blige']},
#   {'band_singer': ['The KLF'],
#    'ranking': 86,
#    'song': ['Justified and Ancient'],
#    'songurl': ['/wiki/Justified_and_Ancient'],
#    'titletext': 'Justified and Ancient',
#    'url': ['/wiki/The_KLF']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': 87,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['TLC (band)'],
#    'ranking': 88,
#    'song': ['What About Your Friends'],
#    'songurl': ['/wiki/What_About_Your_Friends'],
#    'titletext': 'What About Your Friends',
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': 89,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['Charles & Eddie'],
#    'ranking': 90,
#    'song': ['Would I Lie to You? (Charles & Eddie song)'],
#    'songurl': ['/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)'],
#    'titletext': 'Would I Lie to You? (Charles & Eddie song)',
#    'url': ['/wiki/Charles_%26_Eddie']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': 91,
#    'song': ["That's What Love Is For"],
#    'songurl': ['/wiki/That%27s_What_Love_Is_For'],
#    'titletext': "That's What Love Is For",
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': 92,
#    'song': ['Keep Coming Back (song)'],
#    'songurl': ['/wiki/Keep_Coming_Back_(song)'],
#    'titletext': 'Keep Coming Back (song)',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['En Vogue'],
#    'ranking': 93,
#    'song': ['Free Your Mind (song)'],
#    'songurl': ['/wiki/Free_Your_Mind_(song)'],
#    'titletext': 'Free Your Mind (song)',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Keith Sweat'],
#    'ranking': 94,
#    'song': ["Keep It Comin' (song)"],
#    'songurl': ['/wiki/Keep_It_Comin%27_(song)'],
#    'titletext': "Keep It Comin' (song)",
#    'url': ['/wiki/Keith_Sweat']},
#   {'band_singer': ['Mr. Big (band)'],
#    'ranking': 95,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Mr._Big_(band)']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': 96,
#    'song': ['I Will Remember You (Amy Grant song)'],
#    'songurl': ['/wiki/I_Will_Remember_You_(Amy_Grant_song)'],
#    'titletext': 'I Will Remember You (Amy Grant song)',
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': 97,
#    'song': ['We Got a Love Thang'],
#    'songurl': ['/wiki/We_Got_a_Love_Thang'],
#    'titletext': 'We Got a Love Thang',
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': 98,
#    'song': ["Let's Get Rocked"],
#    'songurl': ['/wiki/Let%27s_Get_Rocked'],
#    'titletext': "Let's Get Rocked",
#    'url': ['/wiki/Def_Leppard']},
#   {'band_singer': ['Das EFX'],
#    'ranking': 99,
#    'song': ['They Want EFX'],
#    'songurl': ['/wiki/They_Want_EFX'],
#    'titletext': 'They Want EFX',
#    'url': ['/wiki/Das_EFX']},
#   {'band_singer': ['Bonnie Raitt'],
#    'ranking': 100,
#    'song': ["I Can't Make You Love Me"],
#    'songurl': ['/wiki/I_Can%27t_Make_You_Love_Me'],
#    'titletext': "I Can't Make You Love Me",
#    'url': ['/wiki/Bonnie_Raitt']}],
#  1993: [{'band_singer': ['Whitney Houston'],
#    'ranking': 1,
#    'song': ['I Will Always Love You'],
#    'songurl': ['/wiki/I_Will_Always_Love_You#Whitney_Houston_version'],
#    'titletext': 'I Will Always Love You',
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Tag Team (group)'],
#    'ranking': 2,
#    'song': ['Whoomp! (There It Is)'],
#    'songurl': ['/wiki/Whoomp!_(There_It_Is)'],
#    'titletext': 'Whoomp! (There It Is)',
#    'url': ['/wiki/Tag_Team_(group)']},
#   {'band_singer': ['UB40'],
#    'ranking': 3,
#    'song': ["Can't Help Falling in Love"],
#    'songurl': ['/wiki/Can%27t_Help_Falling_in_Love'],
#    'titletext': "Can't Help Falling in Love",
#    'url': ['/wiki/UB40']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': 4,
#    'song': ["That's the Way Love Goes (Janet Jackson song)"],
#    'songurl': ['/wiki/That%27s_the_Way_Love_Goes_(Janet_Jackson_song)'],
#    'titletext': "That's the Way Love Goes (Janet Jackson song)",
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['Silk (group)'],
#    'ranking': 5,
#    'song': ['Freak Me'],
#    'songurl': ['/wiki/Freak_Me'],
#    'titletext': 'Freak Me',
#    'url': ['/wiki/Silk_(group)']},
#   {'band_singer': ['SWV'],
#    'ranking': 6,
#    'song': ['Weak (SWV song)'],
#    'songurl': ['/wiki/Weak_(SWV_song)'],
#    'titletext': 'Weak (SWV song)',
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Shai (band)'],
#    'ranking': 7,
#    'song': ['If I Ever Fall in Love'],
#    'songurl': ['/wiki/If_I_Ever_Fall_in_Love'],
#    'titletext': 'If I Ever Fall in Love',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 8,
#    'song': ['Dreamlover (song)'],
#    'songurl': ['/wiki/Dreamlover_(song)'],
#    'titletext': 'Dreamlover (song)',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Wreckx-n-Effect'],
#    'ranking': 9,
#    'song': ['Rump Shaker (song)'],
#    'songurl': ['/wiki/Rump_Shaker_(song)'],
#    'titletext': 'Rump Shaker (song)',
#    'url': ['/wiki/Wreckx-n-Effect']},
#   {'band_singer': ['Snow (musician)'],
#    'ranking': 10,
#    'song': ['Informer (song)'],
#    'songurl': ['/wiki/Informer_(song)'],
#    'titletext': 'Informer (song)',
#    'url': ['/wiki/Snow_(musician)']},
#   {'band_singer': ['Dr. Dre'],
#    'ranking': 11,
#    'song': ["Nuthin' but a 'G' Thang"],
#    'songurl': ['/wiki/Nuthin%27_but_a_%27G%27_Thang'],
#    'titletext': "Nuthin' but a 'G' Thang",
#    'url': ['/wiki/Dr._Dre']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': 12,
#    'song': ['In the Still of the Night (1956 song)'],
#    'songurl': ['/wiki/In_the_Still_of_the_Night_(1956_song)#Boyz_II_Men_version'],
#    'titletext': 'In the Still of the Night (1956 song)',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Jade (American band)'],
#    'ranking': 13,
#    'song': ["Don't Walk Away (Jade song)"],
#    'songurl': ['/wiki/Don%27t_Walk_Away_(Jade_song)'],
#    'titletext': "Don't Walk Away (Jade song)",
#    'url': ['/wiki/Jade_(American_band)']},
#   {'band_singer': ['H-Town (band)'],
#    'ranking': 14,
#    'song': ["Knockin' da Boots"],
#    'songurl': ['/wiki/Knockin%27_da_Boots'],
#    'titletext': "Knockin' da Boots",
#    'url': ['/wiki/H-Town_(band)']},
#   {'band_singer': ['Jodeci'],
#    'ranking': 15,
#    'song': ['Lately (Jodeci song)'],
#    'songurl': ['/wiki/Lately_(Jodeci_song)'],
#    'titletext': 'Lately (Jodeci song)',
#    'url': ['/wiki/Jodeci']},
#   {'band_singer': ['Duice'],
#    'ranking': 16,
#    'song': ['Dazzey Duks'],
#    'songurl': ['/wiki/Dazzey_Duks'],
#    'titletext': 'Dazzey Duks',
#    'url': ['/wiki/Duice']},
#   {'band_singer': ['Robin S.'],
#    'ranking': 17,
#    'song': ['Show Me Love (Robin S. song)'],
#    'songurl': ['/wiki/Show_Me_Love_(Robin_S._song)'],
#    'titletext': 'Show Me Love (Robin S. song)',
#    'url': ['/wiki/Robin_S.']},
#   {'band_singer': ['Peabo Bryson', 'Regina Belle'],
#    'ranking': 18,
#    'song': ['A Whole New World'],
#    'songurl': ['/wiki/A_Whole_New_World'],
#    'titletext': 'A Whole New World',
#    'url': ['/wiki/Peabo_Bryson', '/wiki/Regina_Belle']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': 19,
#    'song': ['If (Janet Jackson song)'],
#    'songurl': ['/wiki/If_(Janet_Jackson_song)'],
#    'titletext': 'If (Janet Jackson song)',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['SWV'],
#    'ranking': 20,
#    'song': ["I'm So Into You"],
#    'songurl': ['/wiki/I%27m_So_Into_You'],
#    'titletext': "I'm So Into You",
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Vanessa L. Williams', 'Brian McKnight'],
#    'ranking': 21,
#    'song': ['Love Is (Vanessa Williams song)'],
#    'songurl': ['/wiki/Love_Is_(Vanessa_Williams_song)'],
#    'titletext': 'Love Is (Vanessa Williams song)',
#    'url': ['/wiki/Vanessa_L._Williams', '/wiki/Brian_McKnight']},
#   {'band_singer': ['Soul Asylum'],
#    'ranking': 22,
#    'song': ['Runaway Train (Soul Asylum song)'],
#    'songurl': ['/wiki/Runaway_Train_(Soul_Asylum_song)'],
#    'titletext': 'Runaway Train (Soul Asylum song)',
#    'url': ['/wiki/Soul_Asylum']},
#   {'band_singer': ['Exposé (group)'],
#    'ranking': 23,
#    'song': ["I'll Never Get Over You (Getting Over Me)"],
#    'songurl': ['/wiki/I%27ll_Never_Get_Over_You_(Getting_Over_Me)'],
#    'titletext': "I'll Never Get Over You (Getting Over Me)",
#    'url': ['/wiki/Expos%C3%A9_(group)']},
#   {'band_singer': ['Paperboy (rapper)'],
#    'ranking': 24,
#    'song': ['Ditty (Paperboy song)'],
#    'songurl': ['/wiki/Ditty_(Paperboy_song)'],
#    'titletext': 'Ditty (Paperboy song)',
#    'url': ['/wiki/Paperboy_(rapper)']},
#   {'band_singer': ['Snap!'],
#    'ranking': 25,
#    'song': ['Rhythm Is a Dancer'],
#    'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#    'titletext': 'Rhythm Is a Dancer',
#    'url': ['/wiki/Snap!']},
#   {'band_singer': ['Billy Joel'],
#    'ranking': 26,
#    'song': ['The River of Dreams'],
#    'songurl': ['/wiki/The_River_of_Dreams'],
#    'titletext': 'The River of Dreams',
#    'url': ['/wiki/Billy_Joel']},
#   {'band_singer': ['The Proclaimers'],
#    'ranking': 27,
#    'song': ["I'm Gonna Be (500 Miles)"],
#    'songurl': ['/wiki/I%27m_Gonna_Be_(500_Miles)'],
#    'titletext': "I'm Gonna Be (500 Miles)",
#    'url': ['/wiki/The_Proclaimers']},
#   {'band_singer': ['Spin Doctors'],
#    'ranking': 28,
#    'song': ['Two Princes'],
#    'songurl': ['/wiki/Two_Princes'],
#    'titletext': 'Two Princes',
#    'url': ['/wiki/Spin_Doctors']},
#   {'band_singer': ['SWV'],
#    'ranking': 29,
#    'song': ['Right Here (SWV song)'],
#    'songurl': ['/wiki/Right_Here_(SWV_song)'],
#    'titletext': 'Right Here (SWV song)',
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Whitney Houston'],
#    'ranking': 30,
#    'song': ['I Have Nothing'],
#    'songurl': ['/wiki/I_Have_Nothing'],
#    'titletext': 'I Have Nothing',
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Arrested Development (group)'],
#    'ranking': 31,
#    'song': ['Mr. Wendal'],
#    'songurl': ['/wiki/Mr._Wendal'],
#    'titletext': 'Mr. Wendal',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Rod Stewart'],
#    'ranking': 32,
#    'song': ['Have I Told You Lately'],
#    'songurl': ['/wiki/Have_I_Told_You_Lately'],
#    'titletext': 'Have I Told You Lately',
#    'url': ['/wiki/Rod_Stewart']},
#   {'band_singer': ['Shanice'],
#    'ranking': 33,
#    'song': ['Saving Forever for You'],
#    'songurl': ['/wiki/Saving_Forever_for_You'],
#    'titletext': 'Saving Forever for You',
#    'url': ['/wiki/Shanice']},
#   {'band_singer': ['Duran Duran'],
#    'ranking': 34,
#    'song': ['Ordinary World'],
#    'songurl': ['/wiki/Ordinary_World'],
#    'titletext': 'Ordinary World',
#    'url': ['/wiki/Duran_Duran']},
#   {'band_singer': ['Tony! Toni! Toné!'],
#    'ranking': 35,
#    'song': ['If I Had No Loot'],
#    'songurl': ['/wiki/If_I_Had_No_Loot'],
#    'titletext': 'If I Had No Loot',
#    'url': ['/wiki/Tony!_Toni!_Ton%C3%A9!']},
#   {'band_singer': ['Meat Loaf'],
#    'ranking': 36,
#    'song': ["I'd Do Anything for Love (But I Won't Do That)"],
#    'songurl': ['/wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27t_Do_That)'],
#    'titletext': "I'd Do Anything for Love (But I Won't Do That)",
#    'url': ['/wiki/Meat_Loaf']},
#   {'band_singer': ['Onyx (group)'],
#    'ranking': 37,
#    'song': ['Slam (Onyx song)'],
#    'songurl': ['/wiki/Slam_(Onyx_song)'],
#    'titletext': 'Slam (Onyx song)',
#    'url': ['/wiki/Onyx_(group)']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': 38,
#    'song': ['Looking Through Patient Eyes'],
#    'songurl': ['/wiki/Looking_Through_Patient_Eyes'],
#    'titletext': 'Looking Through Patient Eyes',
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Whitney Houston'],
#    'ranking': 39,
#    'song': ["I'm Every Woman"],
#    'songurl': ['/wiki/I%27m_Every_Woman#Whitney_Houston_version'],
#    'titletext': "I'm Every Woman",
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Shai (band)'],
#    'ranking': 40,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Duran Duran'],
#    'ranking': 41,
#    'song': ['Come Undone (Duran Duran song)'],
#    'songurl': ['/wiki/Come_Undone_(Duran_Duran_song)'],
#    'titletext': 'Come Undone (Duran Duran song)',
#    'url': ['/wiki/Duran_Duran']},
#   {'band_singer': ['Tina Turner'],
#    'ranking': 42,
#    'song': ["I Don't Wanna Fight"],
#    'songurl': ['/wiki/I_Don%27t_Wanna_Fight'],
#    'titletext': "I Don't Wanna Fight",
#    'url': ['/wiki/Tina_Turner']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': 43,
#    'song': ["I'd Die Without You"],
#    'songurl': ['/wiki/I%27d_Die_Without_You'],
#    'titletext': "I'd Die Without You",
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['95 South'],
#    'ranking': 44,
#    'song': ['Whoot, There It Is'],
#    'songurl': ['/wiki/Whoot,_There_It_Is'],
#    'titletext': 'Whoot, There It Is',
#    'url': ['/wiki/95_South']},
#   {'band_singer': ['Naughty by Nature'],
#    'ranking': 45,
#    'song': ['Hip Hop Hooray'],
#    'songurl': ['/wiki/Hip_Hop_Hooray'],
#    'titletext': 'Hip Hop Hooray',
#    'url': ['/wiki/Naughty_by_Nature']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': 46,
#    'song': ['Another Sad Love Song'],
#    'songurl': ['/wiki/Another_Sad_Love_Song'],
#    'titletext': 'Another Sad Love Song',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': 47,
#    'song': ['Will You Be There'],
#    'songurl': ['/wiki/Will_You_Be_There'],
#    'titletext': 'Will You Be There',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Shai (band)'],
#    'ranking': 48,
#    'song': ['Comforter (song)'],
#    'songurl': ['/wiki/Comforter_(song)'],
#    'titletext': 'Comforter (song)',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Bobby Brown'],
#    'ranking': 49,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Bobby_Brown']},
#   {'band_singer': ['4 Non Blondes'],
#    'ranking': 50,
#    'song': ["What's Up? (song)"],
#    'songurl': ['/wiki/What%27s_Up%3F_(song)'],
#    'titletext': "What's Up? (song)",
#    'url': ['/wiki/4_Non_Blondes']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': 51,
#    'song': ['All That She Wants'],
#    'songurl': ['/wiki/All_That_She_Wants'],
#    'titletext': 'All That She Wants',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['Prince (musician)', 'The New Power Generation'],
#    'ranking': 52,
#    'song': ['7 (song)'],
#    'songurl': ['/wiki/7_(song)'],
#    'titletext': '7 (song)',
#    'url': ['/wiki/Prince_(musician)', '/wiki/The_New_Power_Generation']},
#   {'band_singer': ['Dr. Dre', 'Snoop Dogg'],
#    'ranking': 53,
#    'song': ["Fuck wit Dre Day (And Everybody's Celebratin')"],
#    'songurl': ['/wiki/Fuck_wit_Dre_Day_(And_Everybody%27s_Celebratin%27)'],
#    'titletext': "Fuck wit Dre Day (And Everybody's Celebratin')",
#    'url': ['/wiki/Dr._Dre', '/wiki/Snoop_Dogg']},
#   {'band_singer': ['Brian McKnight'],
#    'ranking': 54,
#    'song': ['One Last Cry'],
#    'songurl': ['/wiki/One_Last_Cry'],
#    'titletext': 'One Last Cry',
#    'url': ['/wiki/Brian_McKnight']},
#   {'band_singer': ['Xscape (band)'],
#    'ranking': 55,
#    'song': ["Just Kickin' It"],
#    'songurl': ['/wiki/Just_Kickin%27_It'],
#    'titletext': "Just Kickin' It",
#    'url': ['/wiki/Xscape_(band)']},
#   {'band_singer': ['Tupac Shakur'],
#    'ranking': 56,
#    'song': ['I Get Around (Tupac Shakur song)'],
#    'songurl': ['/wiki/I_Get_Around_(Tupac_Shakur_song)'],
#    'titletext': 'I Get Around (Tupac Shakur song)',
#    'url': ['/wiki/Tupac_Shakur']},
#   {'band_singer': ['Bon Jovi'],
#    'ranking': 57,
#    'song': ['Bed of Roses (song)'],
#    'songurl': ['/wiki/Bed_of_Roses_(song)'],
#    'titletext': 'Bed of Roses (song)',
#    'url': ['/wiki/Bon_Jovi']},
#   {'band_singer': ['Mary J. Blige'],
#    'ranking': 58,
#    'song': ['Real Love (Mary J. Blige song)'],
#    'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#    'titletext': 'Real Love (Mary J. Blige song)',
#    'url': ['/wiki/Mary_J._Blige']},
#   {'band_singer': ['Portrait (group)'],
#    'ranking': 59,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Portrait_(group)']},
#   {'band_singer': ['Aerosmith'],
#    'ranking': 60,
#    'song': ["Cryin'"],
#    'songurl': ['/wiki/Cryin%27'],
#    'titletext': "Cryin'",
#    'url': ['/wiki/Aerosmith']},
#   {'band_singer': ['Ugly Kid Joe'],
#    'ranking': 61,
#    'song': ["Cat's in the Cradle"],
#    'songurl': ['/wiki/Cat%27s_in_the_Cradle'],
#    'titletext': "Cat's in the Cradle",
#    'url': ['/wiki/Ugly_Kid_Joe']},
#   {'band_singer': ['TLC (band)'],
#    'ranking': 62,
#    'song': ['What About Your Friends'],
#    'songurl': ['/wiki/What_About_Your_Friends'],
#    'titletext': 'What About Your Friends',
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Positive K'],
#    'ranking': 63,
#    'song': ['I Got a Man'],
#    'songurl': ['/wiki/I_Got_a_Man'],
#    'titletext': 'I Got a Man',
#    'url': ['/wiki/Positive_K']},
#   {'band_singer': ['Zhané'],
#    'ranking': 64,
#    'song': ['Hey Mr. D.J.'],
#    'songurl': ['/wiki/Hey_Mr._D.J.'],
#    'titletext': 'Hey Mr. D.J.',
#    'url': ['/wiki/Zhan%C3%A9']},
#   {'band_singer': ['Cypress Hill'],
#    'ranking': 65,
#    'song': ['Insane in the Brain'],
#    'songurl': ['/wiki/Insane_in_the_Brain'],
#    'titletext': 'Insane in the Brain',
#    'url': ['/wiki/Cypress_Hill']},
#   {'band_singer': ['Madonna (entertainer)'],
#    'ranking': 66,
#    'song': ['Deeper and Deeper'],
#    'songurl': ['/wiki/Deeper_and_Deeper'],
#    'titletext': 'Deeper and Deeper',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Madonna (entertainer)'],
#    'ranking': 67,
#    'song': ['Rain (Madonna song)'],
#    'songurl': ['/wiki/Rain_(Madonna_song)'],
#    'titletext': 'Rain (Madonna song)',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Jeremy Jordan (singer)'],
#    'ranking': 68,
#    'song': ['The Right Kind of Love'],
#    'songurl': ['/wiki/The_Right_Kind_of_Love'],
#    'titletext': 'The Right Kind of Love',
#    'url': ['/wiki/Jeremy_Jordan_(singer)']},
#   {'band_singer': ['Inner Circle (reggae band)'],
#    'ranking': 69,
#    'song': ['Bad Boys (Inner Circle song)'],
#    'songurl': ['/wiki/Bad_Boys_(Inner_Circle_song)'],
#    'titletext': 'Bad Boys (Inner Circle song)',
#    'url': ['/wiki/Inner_Circle_(reggae_band)']},
#   {'band_singer': ['Boy Krazy'],
#    'ranking': 70,
#    'song': ["That's What Love Can Do"],
#    'songurl': ['/wiki/That%27s_What_Love_Can_Do'],
#    'titletext': "That's What Love Can Do",
#    'url': ['/wiki/Boy_Krazy']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': 71,
#    'song': ['Do You Believe in Us'],
#    'songurl': ['/wiki/Do_You_Believe_in_Us'],
#    'titletext': 'Do You Believe in Us',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': 72,
#    'song': ['Angel (Jon Secada song)'],
#    'songurl': ['/wiki/Angel_(Jon_Secada_song)'],
#    'titletext': 'Angel (Jon Secada song)',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Kenny G'],
#    'ranking': 73,
#    'song': ['Forever in Love (instrumental)'],
#    'songurl': ['/wiki/Forever_in_Love_(instrumental)'],
#    'titletext': 'Forever in Love (instrumental)',
#    'url': ['/wiki/Kenny_G']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': 74,
#    'song': ['Again (Janet Jackson song)'],
#    'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#    'titletext': 'Again (Janet Jackson song)',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['DJ Jazzy Jeff & The Fresh Prince'],
#    'ranking': 75,
#    'song': ['Boom! Shake the Room'],
#    'songurl': ['/wiki/Boom!_Shake_the_Room'],
#    'titletext': 'Boom! Shake the Room',
#    'url': ['/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince']},
#   {'band_singer': ['Restless Heart'],
#    'ranking': 76,
#    'song': ['When She Cries'],
#    'songurl': ['/wiki/When_She_Cries'],
#    'titletext': 'When She Cries',
#    'url': ['/wiki/Restless_Heart']},
#   {'band_singer': ['Inner Circle (reggae band)'],
#    'ranking': 77,
#    'song': ['Sweat (A La La La La Long)'],
#    'songurl': ['/wiki/Sweat_(A_La_La_La_La_Long)'],
#    'titletext': 'Sweat (A La La La La Long)',
#    'url': ['/wiki/Inner_Circle_(reggae_band)']},
#   {'band_singer': ['Ice Cube'],
#    'ranking': 78,
#    'song': ['It Was a Good Day'],
#    'songurl': ['/wiki/It_Was_a_Good_Day'],
#    'titletext': 'It Was a Good Day',
#    'url': ['/wiki/Ice_Cube']},
#   {'band_singer': ['Captain Hollywood Project'],
#    'ranking': 79,
#    'song': ['More and More (Captain Hollywood Project song)'],
#    'songurl': ['/wiki/More_and_More_(Captain_Hollywood_Project_song)'],
#    'titletext': 'More and More (Captain Hollywood Project song)',
#    'url': ['/wiki/Captain_Hollywood_Project']},
#   {'band_singer': ['The Heights (TV series)'],
#    'ranking': 80,
#    'song': ['How Do You Talk to an Angel'],
#    'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#    'titletext': 'How Do You Talk to an Angel',
#    'url': ['/wiki/The_Heights_(TV_series)']},
#   {'band_singer': ['Digable Planets'],
#    'ranking': 81,
#    'song': ['Rebirth of Slick (Cool Like Dat)'],
#    'songurl': ['/wiki/Rebirth_of_Slick_(Cool_Like_Dat)'],
#    'titletext': 'Rebirth of Slick (Cool Like Dat)',
#    'url': ['/wiki/Digable_Planets']},
#   {'band_singer': ['Haddaway'],
#    'ranking': 82,
#    'song': ['What Is Love (Haddaway song)'],
#    'songurl': ['/wiki/What_Is_Love_(Haddaway_song)'],
#    'titletext': 'What Is Love (Haddaway song)',
#    'url': ['/wiki/Haddaway']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': 83,
#    'song': ['To Love Somebody (song)'],
#    'songurl': ['/wiki/To_Love_Somebody_(song)'],
#    'titletext': 'To Love Somebody (song)',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['En Vogue'],
#    'ranking': 84,
#    'song': ['Give It Up, Turn It Loose'],
#    'songurl': ['/wiki/Give_It_Up,_Turn_It_Loose'],
#    'titletext': 'Give It Up, Turn It Loose',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': 85,
#    'song': ['Alright (Kris Kross song)'],
#    'songurl': ['/wiki/Alright_(Kris_Kross_song)'],
#    'titletext': 'Alright (Kris Kross song)',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Ice Cube', 'Das EFX'],
#    'ranking': 86,
#    'song': ['Check Yo Self'],
#    'songurl': ['/wiki/Check_Yo_Self'],
#    'titletext': 'Check Yo Self',
#    'url': ['/wiki/Ice_Cube', '/wiki/Das_EFX']},
#   {'band_singer': ['Sting (musician)'],
#    'ranking': 87,
#    'song': ['Fields of Gold'],
#    'songurl': ['/wiki/Fields_of_Gold'],
#    'titletext': 'Fields of Gold',
#    'url': ['/wiki/Sting_(musician)']},
#   {'band_singer': ['Dino (singer)'],
#    'ranking': 88,
#    'song': ['Ooh Child'],
#    'songurl': ['/wiki/Ooh_Child'],
#    'titletext': 'Ooh Child',
#    'url': ['/wiki/Dino_(singer)']},
#   {'band_singer': ['Go West (band)'],
#    'ranking': 89,
#    'song': ['Faithful (Go West song)'],
#    'songurl': ['/wiki/Faithful_(Go_West_song)'],
#    'titletext': 'Faithful (Go West song)',
#    'url': ['/wiki/Go_West_(band)']},
#   {'band_singer': ['Rod Stewart'],
#    'ranking': 90,
#    'song': ['Reason to Believe'],
#    'songurl': ['/wiki/Reason_to_Believe'],
#    'titletext': 'Reason to Believe',
#    'url': ['/wiki/Rod_Stewart']},
#   {'band_singer': ['Tears for Fears'],
#    'ranking': 91,
#    'song': ['Break It Down Again'],
#    'songurl': ['/wiki/Break_It_Down_Again'],
#    'titletext': 'Break It Down Again',
#    'url': ['/wiki/Tears_for_Fears']},
#   {'band_singer': ['Joey Lawrence'],
#    'ranking': 92,
#    'song': ["Nothin' My Love Can't Fix"],
#    'songurl': ['/wiki/Nothin%27_My_Love_Can%27t_Fix'],
#    'titletext': "Nothin' My Love Can't Fix",
#    'url': ['/wiki/Joey_Lawrence']},
#   {'band_singer': ['Green Jellÿ'],
#    'ranking': 93,
#    'song': ['Three Little Pigs (song)'],
#    'songurl': ['/wiki/Three_Little_Pigs_(song)'],
#    'titletext': 'Three Little Pigs (song)',
#    'url': ['/wiki/Green_Jell%C3%BF']},
#   {'band_singer': ['Aerosmith'],
#    'ranking': 94,
#    'song': ["Livin' on the Edge"],
#    'songurl': ['/wiki/Livin%27_on_the_Edge'],
#    'titletext': "Livin' on the Edge",
#    'url': ['/wiki/Aerosmith']},
#   {'band_singer': ['Gin Blossoms'],
#    'ranking': 95,
#    'song': ['Hey Jealousy'],
#    'songurl': ['/wiki/Hey_Jealousy'],
#    'titletext': 'Hey Jealousy',
#    'url': ['/wiki/Gin_Blossoms']},
#   {'band_singer': ['Sting (musician)'],
#    'ranking': 96,
#    'song': ['If I Ever Lose My Faith in You'],
#    'songurl': ['/wiki/If_I_Ever_Lose_My_Faith_in_You'],
#    'titletext': 'If I Ever Lose My Faith in You',
#    'url': ['/wiki/Sting_(musician)']},
#   {'band_singer': ['Tony! Toni! Tone!'],
#    'ranking': 97,
#    'song': ['Anniversary'],
#    'songurl': ['/wiki/Anniversary'],
#    'titletext': 'Anniversary',
#    'url': ['/wiki/Tony!_Toni!_Tone!']},
#   {'band_singer': ['Jade (American band)'],
#    'ranking': 98,
#    'song': ['One Woman'],
#    'songurl': ['/wiki/One_Woman'],
#    'titletext': 'One Woman',
#    'url': ['/wiki/Jade_(American_band)']},
#   {'band_singer': ['Taylor Dayne'],
#    'ranking': 99,
#    'song': ["Can't Get Enough of Your Love"],
#    'songurl': ['/wiki/Can%27t_Get_Enough_of_Your_Love'],
#    'titletext': "Can't Get Enough of Your Love",
#    'url': ['/wiki/Taylor_Dayne']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': 100,
#    'song': ['Two Steps Behind'],
#    'songurl': ['/wiki/Two_Steps_Behind'],
#    'titletext': 'Two Steps Behind',
#    'url': ['/wiki/Def_Leppard']}],
#  1994: [{'band_singer': ['Ace of Base'],
#    'ranking': 1,
#    'song': ['The Sign (song)'],
#    'songurl': ['/wiki/The_Sign_(song)'],
#    'titletext': 'The Sign (song)',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['All-4-One'],
#    'ranking': 2,
#    'song': ['I Swear'],
#    'songurl': ['/wiki/I_Swear#All-4-One_version'],
#    'titletext': 'I Swear',
#    'url': ['/wiki/All-4-One']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': 3,
#    'song': ["I'll Make Love to You"],
#    'songurl': ['/wiki/I%27ll_Make_Love_to_You'],
#    'titletext': "I'll Make Love to You",
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Céline Dion'],
#    'ranking': 4,
#    'song': ['The Power of Love (Jennifer Rush song)'],
#    'songurl': ['/wiki/The_Power_of_Love_(Jennifer_Rush_song)#Céline_Dion_version'],
#    'titletext': 'The Power of Love (Jennifer Rush song)',
#    'url': ['/wiki/C%C3%A9line_Dion']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 5,
#    'song': ['Hero (Mariah Carey song)'],
#    'songurl': ['/wiki/Hero_(Mariah_Carey_song)'],
#    'titletext': 'Hero (Mariah Carey song)',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Lisa Loeb'],
#    'ranking': 6,
#    'song': ['Stay (I Missed You)'],
#    'songurl': ['/wiki/Stay_(I_Missed_You)'],
#    'titletext': 'Stay (I Missed You)',
#    'url': ['/wiki/Lisa_Loeb']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': 7,
#    'song': ['Breathe Again'],
#    'songurl': ['/wiki/Breathe_Again'],
#    'titletext': 'Breathe Again',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Bryan Adams', 'Rod Stewart', 'Sting (musician)'],
#    'ranking': 8,
#    'song': ['All for Love (song)'],
#    'songurl': ['/wiki/All_for_Love_(song)'],
#    'titletext': 'All for Love (song)',
#    'url': ['/wiki/Bryan_Adams',
#     '/wiki/Rod_Stewart',
#     '/wiki/Sting_(musician)']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': 9,
#    'song': ['All That She Wants'],
#    'songurl': ['/wiki/All_That_She_Wants'],
#    'titletext': 'All That She Wants',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': 10,
#    'song': ["Don't Turn Around"],
#    'songurl': ['/wiki/Don%27t_Turn_Around'],
#    'titletext': "Don't Turn Around",
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['R. Kelly'],
#    'ranking': 11,
#    'song': ["Bump n' Grind (R. Kelly song)"],
#    'songurl': ['/wiki/Bump_n%27_Grind_(R._Kelly_song)'],
#    'titletext': "Bump n' Grind (R. Kelly song)",
#    'url': ['/wiki/R._Kelly']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': 12,
#    'song': ['Again (Janet Jackson song)'],
#    'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#    'titletext': 'Again (Janet Jackson song)',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['Madonna (entertainer)'],
#    'ranking': 13,
#    'song': ["I'll Remember"],
#    'songurl': ['/wiki/I%27ll_Remember'],
#    'titletext': "I'll Remember",
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Salt-n-Pepa', 'En Vogue'],
#    'ranking': 14,
#    'song': ['Whatta Man'],
#    'songurl': ['/wiki/Whatta_Man'],
#    'titletext': 'Whatta Man',
#    'url': ['/wiki/Salt-n-Pepa', '/wiki/En_Vogue']},
#   {'band_singer': ['John Mellencamp', 'Meshell Ndegeocello'],
#    'ranking': 15,
#    'song': ['Wild Night'],
#    'songurl': ['/wiki/Wild_Night'],
#    'titletext': 'Wild Night',
#    'url': ['/wiki/John_Mellencamp', '/wiki/Meshell_Ndegeocello']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 16,
#    'song': ['Without You (Badfinger song)',
#     'Never Forget You (Mariah Carey song)'],
#    'songurl': ['/wiki/Without_You_(Badfinger_song)#Mariah_Carey_version',
#     '/wiki/Never_Forget_You_(Mariah_Carey_song)'],
#    'titletext': 'Without You (Badfinger song) / Never Forget You (Mariah Carey song)',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': 17,
#    'song': ['You Mean the World to Me'],
#    'songurl': ['/wiki/You_Mean_the_World_to_Me'],
#    'titletext': 'You Mean the World to Me',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Elton John'],
#    'ranking': 18,
#    'song': ['Can You Feel the Love Tonight'],
#    'songurl': ['/wiki/Can_You_Feel_the_Love_Tonight'],
#    'titletext': 'Can You Feel the Love Tonight',
# ...
#   {'band_singer': ['Tove Lo'],
#    'ranking': 32,
#    'song': ['Habits (Stay High)'],
#    'songurl': ['/wiki/Habits_(Stay_High)'],
#    'titletext': 'Habits (Stay High)',
#    'url': ['/wiki/Tove_Lo']},
#   {'band_singer': ['Calvin Harris'],
#    'ranking': 33,
#    'song': ['Summer (Calvin Harris song)'],
#    'songurl': ['/wiki/Summer_(Calvin_Harris_song)'],
#    'titletext': 'Summer (Calvin Harris song)',
#    'url': ['/wiki/Calvin_Harris']},
#   {'band_singer': ['Charli XCX'],
#    'ranking': 34,
#    'song': ['Boom Clap'],
#    'songurl': ['/wiki/Boom_Clap'],
#    'titletext': 'Boom Clap',
#    'url': ['/wiki/Charli_XCX']},
#   {'band_singer': ['Beyoncé', 'Jay Z'],
#    'ranking': 35,
#    'song': ['Drunk in Love'],
#    'songurl': ['/wiki/Drunk_in_Love'],
#    'titletext': 'Drunk in Love',
#    'url': ['/wiki/Beyonc%C3%A9', '/wiki/Jay_Z']},
#   {'band_singer': ['Nicki Minaj'],
#    'ranking': 36,
#    'song': ['Anaconda (Nicki Minaj song)'],
#    'songurl': ['/wiki/Anaconda_(Nicki_Minaj_song)'],
#    'titletext': 'Anaconda (Nicki Minaj song)',
#    'url': ['/wiki/Nicki_Minaj']},
#   {'band_singer': ['Ariana Grande', 'Zedd (musician)'],
#    'ranking': 37,
#    'song': ['Break Free (Ariana Grande song)'],
#    'songurl': ['/wiki/Break_Free_(Ariana_Grande_song)'],
#    'titletext': 'Break Free (Ariana Grande song)',
#    'url': ['/wiki/Ariana_Grande', '/wiki/Zedd_(musician)']},
#   {'band_singer': ['Enrique Iglesias', 'Descemer Bueno', 'Gente de Zona'],
#    'ranking': 38,
#    'song': ['Bailando (Enrique Iglesias song)'],
#    'songurl': ['/wiki/Bailando_(Enrique_Iglesias_song)'],
#    'titletext': 'Bailando (Enrique Iglesias song)',
#    'url': ['/wiki/Enrique_Iglesias',
#     '/wiki/Descemer_Bueno',
#     '/wiki/Gente_de_Zona']},
#   {'band_singer': ['Ellie Goulding'],
#    'ranking': 39,
#    'song': ['Burn (Ellie Goulding song)'],
#    'songurl': ['/wiki/Burn_(Ellie_Goulding_song)'],
#    'titletext': 'Burn (Ellie Goulding song)',
#    'url': ['/wiki/Ellie_Goulding']},
#   {'band_singer': ['Jason Derulo', 'Snoop Dogg'],
#    'ranking': 40,
#    'song': ['Wiggle (song)'],
#    'songurl': ['/wiki/Wiggle_(song)'],
#    'titletext': 'Wiggle (song)',
#    'url': ['/wiki/Jason_Derulo', '/wiki/Snoop_Dogg']},
#   {'band_singer': ['Clean Bandit', 'Jess Glynne'],
#    'ranking': 41,
#    'song': ['Rather Be (Clean Bandit song)'],
#    'songurl': ['/wiki/Rather_Be_(Clean_Bandit_song)'],
#    'titletext': 'Rather Be (Clean Bandit song)',
#    'url': ['/wiki/Clean_Bandit', '/wiki/Jess_Glynne']},
#   {'band_singer': ['Jeremih', 'YG (rapper)'],
#    'ranking': 42,
#    'song': ["Don't Tell 'Em"],
#    'songurl': ['/wiki/Don%27t_Tell_%27Em'],
#    'titletext': "Don't Tell 'Em",
#    'url': ['/wiki/Jeremih', '/wiki/YG_(rapper)']},
#   {'band_singer': ['Kid Ink', 'Chris Brown'],
#    'ranking': 43,
#    'song': ['Show Me (Kid Ink song)'],
#    'songurl': ['/wiki/Show_Me_(Kid_Ink_song)'],
#    'titletext': 'Show Me (Kid Ink song)',
#    'url': ['/wiki/Kid_Ink', '/wiki/Chris_Brown']},
#   {'band_singer': ['Miley Cyrus'],
#    'ranking': 44,
#    'song': ['Wrecking Ball (Miley Cyrus song)'],
#    'songurl': ['/wiki/Wrecking_Ball_(Miley_Cyrus_song)'],
#    'titletext': 'Wrecking Ball (Miley Cyrus song)',
#    'url': ['/wiki/Miley_Cyrus']},
#   {'band_singer': ['Justin Timberlake'],
#    'ranking': 45,
#    'song': ['Not a Bad Thing'],
#    'songurl': ['/wiki/Not_a_Bad_Thing'],
#    'titletext': 'Not a Bad Thing',
#    'url': ['/wiki/Justin_Timberlake']},
#   {'band_singer': ['Katy Perry'],
#    'ranking': 46,
#    'song': ['Roar (song)'],
#    'songurl': ['/wiki/Roar_(song)'],
#    'titletext': 'Roar (song)',
#    'url': ['/wiki/Katy_Perry']},
#   {'band_singer': ['Paramore'],
#    'ranking': 47,
#    'song': ["Ain't It Fun (Paramore song)"],
#    'songurl': ['/wiki/Ain%27t_It_Fun_(Paramore_song)'],
#    'titletext': "Ain't It Fun (Paramore song)",
#    'url': ['/wiki/Paramore']},
#   {'band_singer': ['Aloe Blacc'],
#    'ranking': 48,
#    'song': ['The Man (Aloe Blacc song)'],
#    'songurl': ['/wiki/The_Man_(Aloe_Blacc_song)'],
#    'titletext': 'The Man (Aloe Blacc song)',
#    'url': ['/wiki/Aloe_Blacc']},
#   {'band_singer': ['Florida Georgia Line', 'Luke Bryan'],
#    'ranking': 49,
#    'song': ['This Is How We Roll'],
#    'songurl': ['/wiki/This_Is_How_We_Roll'],
#    'titletext': 'This Is How We Roll',
#    'url': ['/wiki/Florida_Georgia_Line', '/wiki/Luke_Bryan']},
#   {'band_singer': ['MKTO'],
#    'ranking': 50,
#    'song': ['Classic (MKTO song)'],
#    'songurl': ['/wiki/Classic_(MKTO_song)'],
#    'titletext': 'Classic (MKTO song)',
#    'url': ['/wiki/MKTO']},
#   {'band_singer': ['Coldplay'],
#    'ranking': 51,
#    'song': ['A Sky Full of Stars'],
#    'songurl': ['/wiki/A_Sky_Full_of_Stars'],
#    'titletext': 'A Sky Full of Stars',
#    'url': ['/wiki/Coldplay']},
#   {'band_singer': ['Ed Sheeran'],
#    'ranking': 52,
#    'song': ["Don't (Ed Sheeran song)"],
#    'songurl': ['/wiki/Don%27t_(Ed_Sheeran_song)'],
#    'titletext': "Don't (Ed Sheeran song)",
#    'url': ['/wiki/Ed_Sheeran']},
#   {'band_singer': ['Trey Songz'],
#    'ranking': 53,
#    'song': ['Na Na (song)'],
#    'songurl': ['/wiki/Na_Na_(song)'],
#    'titletext': 'Na Na (song)',
#    'url': ['/wiki/Trey_Songz']},
#   {'band_singer': ['Bobby Shmurda'],
#    'ranking': 54,
#    'song': ['Hot Nigga'],
#    'songurl': ['/wiki/Hot_Nigga'],
#    'titletext': 'Hot Nigga',
#    'url': ['/wiki/Bobby_Shmurda']},
#   {'band_singer': ['Drake (rapper)', 'Majid Jordan'],
#    'ranking': 55,
#    'song': ["Hold On, We're Going Home"],
#    'songurl': ['/wiki/Hold_On,_We%27re_Going_Home'],
#    'titletext': "Hold On, We're Going Home",
#    'url': ['/wiki/Drake_(rapper)', '/wiki/Majid_Jordan']},
#   {'band_singer': ['Ed Sheeran'],
#    'ranking': 56,
#    'song': ['Sing (Ed Sheeran song)'],
#    'songurl': ['/wiki/Sing_(Ed_Sheeran_song)'],
#    'titletext': 'Sing (Ed Sheeran song)',
#    'url': ['/wiki/Ed_Sheeran']},
#   {'band_singer': ['Imagine Dragons'],
#    'ranking': 57,
#    'song': ['Radioactive (Imagine Dragons song)'],
#    'songurl': ['/wiki/Radioactive_(Imagine_Dragons_song)'],
#    'titletext': 'Radioactive (Imagine Dragons song)',
#    'url': ['/wiki/Imagine_Dragons']},
#   {'band_singer': ['YG (rapper)', 'Jeezy', 'Rich Homie Quan'],
#    'ranking': 58,
#    'song': ['My Nigga'],
#    'songurl': ['/wiki/My_Nigga'],
#    'titletext': 'My Nigga',
#    'url': ['/wiki/YG_(rapper)', '/wiki/Jeezy', '/wiki/Rich_Homie_Quan']},
#   {'band_singer': ['Echosmith'],
#    'ranking': 59,
#    'song': ['Cool Kids (Echosmith song)'],
#    'songurl': ['/wiki/Cool_Kids_(Echosmith_song)'],
#    'titletext': 'Cool Kids (Echosmith song)',
#    'url': ['/wiki/Echosmith']},
#   {'band_singer': ['Avicii'],
#    'ranking': 60,
#    'song': ['Hey Brother'],
#    'songurl': ['/wiki/Hey_Brother'],
#    'titletext': 'Hey Brother',
#    'url': ['/wiki/Avicii']},
#   {'band_singer': ['Jason Derulo'],
#    'ranking': 61,
#    'song': ['Trumpets (Jason Derulo song)'],
#    'songurl': ['/wiki/Trumpets_(Jason_Derulo_song)'],
#    'titletext': 'Trumpets (Jason Derulo song)',
#    'url': ['/wiki/Jason_Derulo']},
#   {'band_singer': ['Maroon 5'],
#    'ranking': 62,
#    'song': ['Animals (Maroon 5 song)'],
#    'songurl': ['/wiki/Animals_(Maroon_5_song)'],
#    'titletext': 'Animals (Maroon 5 song)',
#    'url': ['/wiki/Maroon_5']},
#   {'band_singer': ['Jason Aldean'],
#    'ranking': 63,
#    'song': ["Burnin' It Down"],
#    'songurl': ['/wiki/Burnin%27_It_Down'],
#    'titletext': "Burnin' It Down",
#    'url': ['/wiki/Jason_Aldean']},
#   {'band_singer': ['Luke Bryan'],
#    'ranking': 64,
#    'song': ['Play It Again (Luke Bryan song)'],
#    'songurl': ['/wiki/Play_It_Again_(Luke_Bryan_song)'],
#    'titletext': 'Play It Again (Luke Bryan song)',
#    'url': ['/wiki/Luke_Bryan']},
#   {'band_singer': ['Tinashe', 'ScHoolboy Q'],
#    'ranking': 65,
#    'song': ['2 On'],
#    'songurl': ['/wiki/2_On'],
#    'titletext': '2 On',
#    'url': ['/wiki/Tinashe', '/wiki/ScHoolboy_Q']},
#   {'band_singer': ['Florida Georgia Line'],
#    'ranking': 66,
#    'song': ['Dirt (Florida Georgia Line song)'],
#    'songurl': ['/wiki/Dirt_(Florida_Georgia_Line_song)'],
#    'titletext': 'Dirt (Florida Georgia Line song)',
#    'url': ['/wiki/Florida_Georgia_Line']},
#   {'band_singer': ['OneRepublic'],
#    'ranking': 67,
#    'song': ['Love Runs Out'],
#    'songurl': ['/wiki/Love_Runs_Out'],
#    'titletext': 'Love Runs Out',
#    'url': ['/wiki/OneRepublic']},
#   {'band_singer': ['Brantley Gilbert'],
#    'ranking': 68,
#    'song': ['Bottoms Up (Brantley Gilbert song)'],
#    'songurl': ['/wiki/Bottoms_Up_(Brantley_Gilbert_song)'],
#    'titletext': 'Bottoms Up (Brantley Gilbert song)',
#    'url': ['/wiki/Brantley_Gilbert']},
#   {'band_singer': ['Becky G'],
#    'ranking': 69,
#    'song': ['Shower (song)'],
#    'songurl': ['/wiki/Shower_(song)'],
#    'titletext': 'Shower (song)',
#    'url': ['/wiki/Becky_G']},
#   {'band_singer': ['Rixton (band)'],
#    'ranking': 70,
#    'song': ['Me and My Broken Heart'],
#    'songurl': ['/wiki/Me_and_My_Broken_Heart'],
#    'titletext': 'Me and My Broken Heart',
#    'url': ['/wiki/Rixton_(band)']},
#   {'band_singer': ['Martin Garrix'],
#    'ranking': 71,
#    'song': ['Animals (Martin Garrix composition)'],
#    'songurl': ['/wiki/Animals_(Martin_Garrix_composition)'],
#    'titletext': 'Animals (Martin Garrix composition)',
#    'url': ['/wiki/Martin_Garrix']},
#   {'band_singer': ['Rich Gang', 'Young Thug', 'Rich Homie Quan'],
#    'ranking': 72,
#    'song': ['Lifestyle (song)'],
#    'songurl': ['/wiki/Lifestyle_(song)'],
#    'titletext': 'Lifestyle (song)',
#    'url': ['/wiki/Rich_Gang', '/wiki/Young_Thug', '/wiki/Rich_Homie_Quan']},
#   {'band_singer': ['Kenny Chesney'],
#    'ranking': 73,
#    'song': ['American Kids'],
#    'songurl': ['/wiki/American_Kids'],
#    'titletext': 'American Kids',
#    'url': ['/wiki/Kenny_Chesney']},
#   {'band_singer': ['Sara Bareilles'],
#    'ranking': 74,
#    'song': ['Brave (Sara Bareilles song)'],
#    'songurl': ['/wiki/Brave_(Sara_Bareilles_song)'],
#    'titletext': 'Brave (Sara Bareilles song)',
#    'url': ['/wiki/Sara_Bareilles']},
#   {'band_singer': ['The Neighbourhood'],
#    'ranking': 75,
#    'song': ['Sweater Weather'],
#    'songurl': ['/wiki/Sweater_Weather'],
#    'titletext': 'Sweater Weather',
#    'url': ['/wiki/The_Neighbourhood']},
#   {'band_singer': ['Sam Hunt (musician)'],
#    'ranking': 76,
#    'song': ['Leave the Night On'],
#    'songurl': ['/wiki/Leave_the_Night_On'],
#    'titletext': 'Leave the Night On',
#    'url': ['/wiki/Sam_Hunt_(musician)']},
#   {'band_singer': ['Chris Brown', 'Usher (entertainer)', 'Rick Ross'],
#    'ranking': 77,
#    'song': ['New Flame'],
#    'songurl': ['/wiki/New_Flame'],
#    'titletext': 'New Flame',
#    'url': ['/wiki/Chris_Brown',
#     '/wiki/Usher_(entertainer)',
#     '/wiki/Rick_Ross']},
#   {'band_singer': ['Michael Jackson', 'Justin Timberlake'],
#    'ranking': 78,
#    'song': ['Love Never Felt So Good'],
#    'songurl': ['/wiki/Love_Never_Felt_So_Good'],
#    'titletext': 'Love Never Felt So Good',
#    'url': ['/wiki/Michael_Jackson', '/wiki/Justin_Timberlake']},
#   {'band_singer': ['Dierks Bentley'],
#    'ranking': 79,
#    'song': ['Drunk on a Plane'],
#    'songurl': ['/wiki/Drunk_on_a_Plane'],
#    'titletext': 'Drunk on a Plane',
#    'url': ['/wiki/Dierks_Bentley']},
#   {'band_singer': ['Katy Perry'],
#    'ranking': 80,
#    'song': ['Birthday (Katy Perry song)'],
#    'songurl': ['/wiki/Birthday_(Katy_Perry_song)'],
#    'titletext': 'Birthday (Katy Perry song)',
#    'url': ['/wiki/Katy_Perry']},
#   {'band_singer': ['Lady Antebellum'],
#    'ranking': 81,
#    'song': ['Bartender (Lady Antebellum song)'],
#    'songurl': ['/wiki/Bartender_(Lady_Antebellum_song)'],
#    'titletext': 'Bartender (Lady Antebellum song)',
#    'url': ['/wiki/Lady_Antebellum']},
#   {'band_singer': ['Naughty Boy', 'Sam Smith (singer)'],
#    'ranking': 82,
#    'song': ['La La La (Naughty Boy song)'],
#    'songurl': ['/wiki/La_La_La_(Naughty_Boy_song)'],
#    'titletext': 'La La La (Naughty Boy song)',
#    'url': ['/wiki/Naughty_Boy', '/wiki/Sam_Smith_(singer)']},
#   {'band_singer': ['Robin Thicke', 'T.I.', 'Pharrell Williams'],
#    'ranking': 83,
#    'song': ['Blurred Lines'],
#    'songurl': ['/wiki/Blurred_Lines'],
#    'titletext': 'Blurred Lines',
#    'url': ['/wiki/Robin_Thicke', '/wiki/T.I.', '/wiki/Pharrell_Williams']},
#   {'band_singer': ['Lady Gaga', 'R. Kelly'],
#    'ranking': 84,
#    'song': ['Do What U Want'],
#    'songurl': ['/wiki/Do_What_U_Want'],
#    'titletext': 'Do What U Want',
#    'url': ['/wiki/Lady_Gaga', '/wiki/R._Kelly']},
#   {'band_singer': ['Shakira', 'Rihanna'],
#    'ranking': 85,
#    'song': ["Can't Remember to Forget You"],
#    'songurl': ['/wiki/Can%27t_Remember_to_Forget_You'],
#    'titletext': "Can't Remember to Forget You",
#    'url': ['/wiki/Shakira', '/wiki/Rihanna']},
#   {'band_singer': ['5 Seconds of Summer'],
#    'ranking': 86,
#    'song': ['Amnesia (5 Seconds of Summer song)'],
#    'songurl': ['/wiki/Amnesia_(5_Seconds_of_Summer_song)'],
#    'titletext': 'Amnesia (5 Seconds of Summer song)',
#    'url': ['/wiki/5_Seconds_of_Summer']},
#   {'band_singer': ['T.I.', 'Iggy Azalea'],
#    'ranking': 87,
#    'song': ['No Mediocre'],
#    'songurl': ['/wiki/No_Mediocre'],
#    'titletext': 'No Mediocre',
#    'url': ['/wiki/T.I.', '/wiki/Iggy_Azalea']},
#   {'band_singer': ['Kongos (band)'],
#    'ranking': 88,
#    'song': ['Come with Me Now'],
#    'songurl': ['/wiki/Come_with_Me_Now'],
#    'titletext': 'Come with Me Now',
#    'url': ['/wiki/Kongos_(band)']},
#   {'band_singer': ['Lil Wayne', 'Drake (rapper)'],
#    'ranking': 89,
#    'song': ['Believe Me (Lil Wayne song)'],
#    'songurl': ['/wiki/Believe_Me_(Lil_Wayne_song)'],
#    'titletext': 'Believe Me (Lil Wayne song)',
#    'url': ['/wiki/Lil_Wayne', '/wiki/Drake_(rapper)']},
#   {'band_singer': ['Mike WiLL Made-It',
#     'Miley Cyrus',
#     'Wiz Khalifa',
#     'Juicy J'],
#    'ranking': 90,
#    'song': ['23 (song)'],
#    'songurl': ['/wiki/23_(song)'],
#    'titletext': '23 (song)',
#    'url': ['/wiki/Mike_WiLL_Made-It',
#     '/wiki/Miley_Cyrus',
#     '/wiki/Wiz_Khalifa',
#     '/wiki/Juicy_J']},
#   {'band_singer': ['Jake Owen'],
#    'ranking': 91,
#    'song': ["Beachin'"],
#    'songurl': ['/wiki/Beachin%27'],
#    'titletext': "Beachin'",
#    'url': ['/wiki/Jake_Owen']},
#   {'band_singer': ['Macklemore & Ryan Lewis',
#     'ScHoolboy Q',
#     'Hollis (singer)'],
#    'ranking': 92,
#    'song': ['White Walls'],
#    'songurl': ['/wiki/White_Walls'],
#    'titletext': 'White Walls',
#    'url': ['/wiki/Macklemore_%26_Ryan_Lewis',
#     '/wiki/ScHoolboy_Q',
#     '/wiki/Hollis_(singer)']},
#   {'band_singer': ['5 Seconds of Summer'],
#    'ranking': 93,
#    'song': ['She Looks So Perfect'],
#    'songurl': ['/wiki/She_Looks_So_Perfect'],
#    'titletext': 'She Looks So Perfect',
#    'url': ['/wiki/5_Seconds_of_Summer']},
#   {'band_singer': ['Zedd (musician)', 'Hayley Williams'],
#    'ranking': 94,
#    'song': ['Stay the Night (Zedd song)'],
#    'songurl': ['/wiki/Stay_the_Night_(Zedd_song)'],
#    'titletext': 'Stay the Night (Zedd song)',
#    'url': ['/wiki/Zedd_(musician)', '/wiki/Hayley_Williams']},
#   {'band_singer': ['Beyoncé'],
#    'ranking': 95,
#    'song': ['Partition (song)'],
#    'songurl': ['/wiki/Partition_(song)'],
#    'titletext': 'Partition (song)',
#    'url': ['/wiki/Beyonc%C3%A9']},
#   {'band_singer': ['ScHoolboy Q', 'BJ the Chicago Kid'],
#    'ranking': 96,
#    'song': ['Studio (song)'],
#    'songurl': ['/wiki/Studio_(song)'],
#    'titletext': 'Studio (song)',
#    'url': ['/wiki/ScHoolboy_Q', '/wiki/BJ_the_Chicago_Kid']},
#   {'band_singer': ['Drake (rapper)'],
#    'ranking': 97,
#    'song': ['0 to 100 / The Catch Up'],
#    'songurl': ['/wiki/0_to_100_/_The_Catch_Up'],
#    'titletext': '0 to 100 / The Catch Up',
#    'url': ['/wiki/Drake_(rapper)']},
#   {'band_singer': ['Lee Brice'],
#    'ranking': 98,
#    'song': ["I Don't Dance (Lee Brice song)"],
#    'songurl': ['/wiki/I_Don%27t_Dance_(Lee_Brice_song)'],
#    'titletext': "I Don't Dance (Lee Brice song)",
#    'url': ['/wiki/Lee_Brice']},
#   {'band_singer': ['Miranda Lambert', 'Carrie Underwood'],
#    'ranking': 99,
#    'song': ["Somethin' Bad"],
#    'songurl': ['/wiki/Somethin%27_Bad'],
#    'titletext': "Somethin' Bad",
#    'url': ['/wiki/Miranda_Lambert', '/wiki/Carrie_Underwood']},
#   {'band_singer': ['Miley Cyrus'],
#    'ranking': 100,
#    'song': ['Adore You'],
#    'songurl': ['/wiki/Adore_You'],
#    'titletext': 'Adore You',
#    'url': ['/wiki/Miley_Cyrus']}]}

# %% [markdown]
# #### Save a json file of information from the scraped files

# %% [markdown]
# We do not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run from here, you don't need to redo all these requests and parsing.
#
# DO NOT RERUN THE HTTP REQUESTS TO WIKIPEDIA WHEN SUBMITTING.
#
# *We **DO NOT** need to see these JSON files in your submission!*

# %%
import json

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
fd = open("yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# RERUN WHEN SUBMITTING
# Another way to deal with files. Has the advantage of closing the file for you.
with open("yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %% [markdown]
# #### 1.4 Construct a year-song-singer dataframe from the yearly information

# %% [markdown]
# Let's construct a dataframe `flatframe` from the `yearinfo`. The frame should be similar to the frame below.  Each row of the frame represents a song, and carries with it the chief properties of year, song, singer, and ranking.
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC1.png)

# %% [markdown]
# To construct the dataframe, we'll need to iterate over the years and the singles per year. Notice how, above, the dataframe is ordered by ranking and then year. While the exact order is up to you, note that you will have to come up with a scheme to order the information.
#
# Check that the dataframe has sensible data types. You will also likely find that the year field has become an "object" (Pandas treats strings as generic objects): this is due to the conversion to and back from JSON. Such conversions need special care. Fix any data type issues with `flatframe`. (See Pandas [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function.)
# We will use this `flatframe` in the next question.
#
# (As an aside, we used the name `flatframe` to indicate that this dataframe is flattened from a hierarchical dictionary structure with the keys being the years.)

# %%
yearinfo
# Out:
# {'1992': [{'band_singer': ['Boyz II Men'],
#    'ranking': 1,
#    'song': ['End of the Road'],
#    'songurl': ['/wiki/End_of_the_Road'],
#    'titletext': 'End of the Road',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Sir Mix-a-Lot'],
#    'ranking': 2,
#    'song': ['Baby Got Back'],
#    'songurl': ['/wiki/Baby_Got_Back'],
#    'titletext': 'Baby Got Back',
#    'url': ['/wiki/Sir_Mix-a-Lot']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': 3,
#    'song': ['Jump (Kris Kross song)'],
#    'songurl': ['/wiki/Jump_(Kris_Kross_song)'],
#    'titletext': 'Jump (Kris Kross song)',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Vanessa L. Williams'],
#    'ranking': 4,
#    'song': ['Save the Best for Last'],
#    'songurl': ['/wiki/Save_the_Best_for_Last'],
#    'titletext': 'Save the Best for Last',
#    'url': ['/wiki/Vanessa_L._Williams']},
#   {'band_singer': ['TLC (band)'],
#    'ranking': 5,
#    'song': ['Baby-Baby-Baby'],
#    'songurl': ['/wiki/Baby-Baby-Baby'],
#    'titletext': 'Baby-Baby-Baby',
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Eric Clapton'],
#    'ranking': 6,
#    'song': ['Tears in Heaven'],
#    'songurl': ['/wiki/Tears_in_Heaven'],
#    'titletext': 'Tears in Heaven',
#    'url': ['/wiki/Eric_Clapton']},
#   {'band_singer': ['En Vogue'],
#    'ranking': 7,
#    'song': ["My Lovin' (You're Never Gonna Get It)"],
#    'songurl': ['/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)'],
#    'titletext': "My Lovin' (You're Never Gonna Get It)",
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Red Hot Chili Peppers'],
#    'ranking': 8,
#    'song': ['Under the Bridge'],
#    'songurl': ['/wiki/Under_the_Bridge'],
#    'titletext': 'Under the Bridge',
#    'url': ['/wiki/Red_Hot_Chili_Peppers']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': 9,
#    'song': ['All 4 Love'],
#    'songurl': ['/wiki/All_4_Love'],
#    'titletext': 'All 4 Love',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': 10,
#    'song': ['Just Another Day (Jon Secada song)'],
#    'songurl': ['/wiki/Just_Another_Day_(Jon_Secada_song)'],
#    'titletext': 'Just Another Day (Jon Secada song)',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Shanice'],
#    'ranking': 11,
#    'song': ['I Love Your Smile'],
#    'songurl': ['/wiki/I_Love_Your_Smile'],
#    'titletext': 'I Love Your Smile',
#    'url': ['/wiki/Shanice']},
#   {'band_singer': ['Mr. Big (band)'],
#    'ranking': 12,
#    'song': ['To Be with You'],
#    'songurl': ['/wiki/To_Be_with_You'],
#    'titletext': 'To Be with You',
#    'url': ['/wiki/Mr._Big_(band)']},
#   {'band_singer': ['Right Said Fred'],
#    'ranking': 13,
#    'song': ["I'm Too Sexy"],
#    'songurl': ['/wiki/I%27m_Too_Sexy'],
#    'titletext': "I'm Too Sexy",
#    'url': ['/wiki/Right_Said_Fred']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': 14,
#    'song': ['Black or White'],
#    'songurl': ['/wiki/Black_or_White'],
#    'titletext': 'Black or White',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Billy Ray Cyrus'],
#    'ranking': 15,
#    'song': ['Achy Breaky Heart'],
#    'songurl': ['/wiki/Achy_Breaky_Heart'],
#    'titletext': 'Achy Breaky Heart',
#    'url': ['/wiki/Billy_Ray_Cyrus']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 16,
#    'song': ["I'll Be There (The Jackson 5 song)"],
#    'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version'],
#    'titletext': "I'll Be There (The Jackson 5 song)",
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ["Guns N' Roses"],
#    'ranking': 17,
#    'song': ['November Rain'],
#    'songurl': ['/wiki/November_Rain'],
#    'titletext': 'November Rain',
#    'url': ['/wiki/Guns_N%27_Roses']},
#   {'band_singer': ['Tom Cochrane'],
#    'ranking': 18,
#    'song': ['Life Is a Highway'],
#    'songurl': ['/wiki/Life_Is_a_Highway'],
#    'titletext': 'Life Is a Highway',
#    'url': ['/wiki/Tom_Cochrane']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': 19,
#    'song': ['Remember the Time'],
#    'songurl': ['/wiki/Remember_the_Time'],
#    'titletext': 'Remember the Time',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': 20,
#    'song': ['Finally (CeCe Peniston song)'],
#    'songurl': ['/wiki/Finally_(CeCe_Peniston_song)'],
#    'titletext': 'Finally (CeCe Peniston song)',
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Madonna (entertainer)'],
#    'ranking': 21,
#    'song': ['This Used to Be My Playground'],
#    'songurl': ['/wiki/This_Used_to_Be_My_Playground'],
#    'titletext': 'This Used to Be My Playground',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Patty Smyth', 'Don Henley'],
#    'ranking': 22,
#    'song': ["Sometimes Love Just Ain't Enough"],
#    'songurl': ['/wiki/Sometimes_Love_Just_Ain%27t_Enough'],
#    'titletext': "Sometimes Love Just Ain't Enough",
#    'url': ['/wiki/Patty_Smyth', '/wiki/Don_Henley']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 23,
#    'song': ["Can't Let Go (Mariah Carey song)"],
#    'songurl': ['/wiki/Can%27t_Let_Go_(Mariah_Carey_song)'],
#    'titletext': "Can't Let Go (Mariah Carey song)",
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['House of Pain'],
#    'ranking': 24,
#    'song': ['Jump Around'],
#    'songurl': ['/wiki/Jump_Around'],
#    'titletext': 'Jump Around',
#    'url': ['/wiki/House_of_Pain']},
#   {'band_singer': ['Prince (entertainer)', 'The New Power Generation'],
#    'ranking': 25,
#    'song': ['Diamonds and Pearls (song)'],
#    'songurl': ['/wiki/Diamonds_and_Pearls_(song)'],
#    'titletext': 'Diamonds and Pearls (song)',
#    'url': ['/wiki/Prince_(entertainer)', '/wiki/The_New_Power_Generation']},
#   {'band_singer': ['George Michael', 'Elton John'],
#    'ranking': 26,
#    'song': ["Don't Let the Sun Go Down on Me"],
#    'songurl': ['/wiki/Don%27t_Let_the_Sun_Go_Down_on_Me'],
#    'titletext': "Don't Let the Sun Go Down on Me",
#    'url': ['/wiki/George_Michael', '/wiki/Elton_John']},
#   {'band_singer': ['Atlantic Starr'],
#    'ranking': 27,
#    'song': ['Masterpiece (Atlantic Starr song)'],
#    'songurl': ['/wiki/Masterpiece_(Atlantic_Starr_song)'],
#    'titletext': 'Masterpiece (Atlantic Starr song)',
#    'url': ['/wiki/Atlantic_Starr']},
#   {'band_singer': ['Celine Dion'],
#    'ranking': 28,
#    'song': ['If You Asked Me To'],
#    'songurl': ['/wiki/If_You_Asked_Me_To'],
#    'titletext': 'If You Asked Me To',
#    'url': ['/wiki/Celine_Dion']},
#   {'band_singer': ['En Vogue'],
#    'ranking': 29,
#    'song': ['Something He Can Feel'],
#    'songurl': ['/wiki/Something_He_Can_Feel'],
#    'titletext': 'Something He Can Feel',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Joe Public (band)'],
#    'ranking': 30,
#    'song': ['Live and Learn (Joe Public song)'],
#    'songurl': ['/wiki/Live_and_Learn_(Joe_Public_song)'],
#    'titletext': 'Live and Learn (Joe Public song)',
#    'url': ['/wiki/Joe_Public_(band)']},
#   {'band_singer': ['Jodeci'],
#    'ranking': 31,
#    'song': ['Come and Talk to Me'],
#    'songurl': ['/wiki/Come_and_Talk_to_Me'],
#    'titletext': 'Come and Talk to Me',
#    'url': ['/wiki/Jodeci']},
#   {'band_singer': ['Nirvana (band)'],
#    'ranking': 32,
#    'song': ['Smells Like Teen Spirit'],
#    'songurl': ['/wiki/Smells_Like_Teen_Spirit'],
#    'titletext': 'Smells Like Teen Spirit',
#    'url': ['/wiki/Nirvana_(band)']},
#   {'band_singer': ['Bobby Brown'],
#    'ranking': 33,
#    'song': ["Humpin' Around"],
#    'songurl': ['/wiki/Humpin%27_Around'],
#    'titletext': "Humpin' Around",
#    'url': ['/wiki/Bobby_Brown']},
#   {'band_singer': ['Sophie B. Hawkins'],
#    'ranking': 34,
#    'song': ['Damn I Wish I Was Your Lover'],
#    'songurl': ['/wiki/Damn_I_Wish_I_Was_Your_Lover'],
#    'titletext': 'Damn I Wish I Was Your Lover',
#    'url': ['/wiki/Sophie_B._Hawkins']},
#   {'band_singer': ['Tevin Campbell'],
#    'ranking': 35,
#    'song': ['Tell Me What You Want Me to Do'],
#    'songurl': ['/wiki/Tell_Me_What_You_Want_Me_to_Do'],
#    'titletext': 'Tell Me What You Want Me to Do',
#    'url': ['/wiki/Tevin_Campbell']},
#   {'band_singer': ['TLC (band)'],
#    'ranking': 36,
#    'song': ["Ain't 2 Proud 2 Beg"],
#    'songurl': ['/wiki/Ain%27t_2_Proud_2_Beg'],
#    'titletext': "Ain't 2 Proud 2 Beg",
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': 37,
#    'song': ["It's So Hard to Say Goodbye to Yesterday"],
#    'songurl': ['/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday'],
#    'titletext': "It's So Hard to Say Goodbye to Yesterday",
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Technotronic', 'Ya Kid K'],
#    'ranking': 38,
#    'song': ['Move This'],
#    'songurl': ['/wiki/Move_This'],
#    'titletext': 'Move This',
#    'url': ['/wiki/Technotronic', '/wiki/Ya_Kid_K']},
#   {'band_singer': ['Queen (band)'],
#    'ranking': 39,
#    'song': ['Bohemian Rhapsody'],
#    'songurl': ['/wiki/Bohemian_Rhapsody'],
#    'titletext': 'Bohemian Rhapsody',
#    'url': ['/wiki/Queen_(band)']},
#   {'band_singer': ['Arrested Development (group)'],
#    'ranking': 40,
#    'song': ['Tennessee (Arrested Development song)'],
#    'songurl': ['/wiki/Tennessee_(Arrested_Development_song)'],
#    'titletext': 'Tennessee (Arrested Development song)',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Luther Vandross', 'Janet Jackson'],
#    'ranking': 41,
#    'song': ['The Best Things in Life Are Free'],
#    'songurl': ['/wiki/The_Best_Things_in_Life_Are_Free'],
#    'titletext': 'The Best Things in Life Are Free',
#    'url': ['/wiki/Luther_Vandross', '/wiki/Janet_Jackson']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 42,
#    'song': ['Make It Happen (Mariah Carey song)'],
#    'songurl': ['/wiki/Make_It_Happen_(Mariah_Carey_song)'],
#    'titletext': 'Make It Happen (Mariah Carey song)',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Elton John'],
#    'ranking': 43,
#    'song': ['The One (Elton John song)'],
#    'songurl': ['/wiki/The_One_(Elton_John_song)'],
#    'titletext': 'The One (Elton John song)',
#    'url': ['/wiki/Elton_John']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': 44,
#    'song': ['Set Adrift on Memory Bliss'],
#    'songurl': ['/wiki/Set_Adrift_on_Memory_Bliss'],
#    'titletext': 'Set Adrift on Memory Bliss',
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Shakespears Sister'],
#    'ranking': 45,
#    'song': ['Stay (Shakespears Sister song)'],
#    'songurl': ['/wiki/Stay_(Shakespears_Sister_song)'],
#    'titletext': 'Stay (Shakespears Sister song)',
#    'url': ['/wiki/Shakespears_Sister']},
#   {'band_singer': ['MC Hammer'],
#    'ranking': 46,
#    'song': ['Too Legit to Quit (song)'],
#    'songurl': ['/wiki/Too_Legit_to_Quit_(song)'],
#    'titletext': 'Too Legit to Quit (song)',
#    'url': ['/wiki/MC_Hammer']},
#   {'band_singer': ['KWS (band)'],
#    'ranking': 47,
#    'song': ["Please Don't Go (KC and the Sunshine Band song)"],
#    'songurl': ['/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version'],
#    'titletext': "Please Don't Go (KC and the Sunshine Band song)",
#    'url': ['/wiki/KWS_(band)']},
#   {'band_singer': ['Mint Condition'],
#    'ranking': 48,
#    'song': ["Breakin' My Heart (Pretty Brown Eyes)"],
#    'songurl': ['/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)'],
#    'titletext': "Breakin' My Heart (Pretty Brown Eyes)",
#    'url': ['/wiki/Mint_Condition']},
#   {'band_singer': ['The Cover Girls'],
#    'ranking': 49,
#    'song': ['Wishing on a Star'],
#    'songurl': ['/wiki/Wishing_on_a_Star'],
#    'titletext': 'Wishing on a Star',
#    'url': ['/wiki/The_Cover_Girls']},
#   {'band_singer': ['Hi-Five'],
#    'ranking': 50,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Hi-Five']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': 51,
#    'song': ["I'd Die Without You"],
#    'songurl': ['/wiki/I%27d_Die_Without_You'],
#    'titletext': "I'd Die Without You",
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': 52,
#    'song': ['Good for Me (song)'],
#    'songurl': ['/wiki/Good_for_Me_(song)'],
#    'titletext': 'Good for Me (song)',
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['Toad the Wet Sprocket'],
#    'ranking': 53,
#    'song': ['All I Want (Toad the Wet Sprocket song)'],
#    'songurl': ['/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)'],
#    'titletext': 'All I Want (Toad the Wet Sprocket song)',
#    'url': ['/wiki/Toad_the_Wet_Sprocket']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': 54,
#    'song': ['When a Man Loves a Woman (song)'],
#    'songurl': ['/wiki/When_a_Man_Loves_a_Woman_(song)'],
#    'titletext': 'When a Man Loves a Woman (song)',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['Genesis (band)'],
#    'ranking': 55,
#    'song': ["I Can't Dance"],
#    'songurl': ['/wiki/I_Can%27t_Dance'],
#    'titletext': "I Can't Dance",
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': 56,
#    'song': ['Hazard (song)'],
#    'songurl': ['/wiki/Hazard_(song)'],
#    'titletext': 'Hazard (song)',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['U2'],
#    'ranking': 57,
#    'song': ['Mysterious Ways (song)'],
#    'songurl': ['/wiki/Mysterious_Ways_(song)'],
#    'titletext': 'Mysterious Ways (song)',
#    'url': ['/wiki/U2']},
#   {'band_singer': ['George Michael'],
#    'ranking': 58,
#    'song': ['Too Funky'],
#    'songurl': ['/wiki/Too_Funky'],
#    'titletext': 'Too Funky',
#    'url': ['/wiki/George_Michael']},
#   {'band_singer': ['The Heights (TV series)'],
#    'ranking': 59,
#    'song': ['How Do You Talk to an Angel'],
#    'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#    'titletext': 'How Do You Talk to an Angel',
#    'url': ['/wiki/The_Heights_(TV_series)']},
#   {'band_singer': ['U2'],
#    'ranking': 60,
#    'song': ['One (U2 song)'],
#    'songurl': ['/wiki/One_(U2_song)'],
#    'titletext': 'One (U2 song)',
#    'url': ['/wiki/U2']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': 61,
#    'song': ["Keep on Walkin' (song)"],
#    'songurl': ['/wiki/Keep_on_Walkin%27_(song)'],
#    'titletext': "Keep on Walkin' (song)",
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Genesis (band)'],
#    'ranking': 62,
#    'song': ['Hold on My Heart'],
#    'songurl': ['/wiki/Hold_on_My_Heart'],
#    'titletext': 'Hold on My Heart',
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Karyn White'],
#    'ranking': 63,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Karyn_White']},
#   {'band_singer': ['Celine Dion', 'Peabo Bryson'],
#    'ranking': 64,
#    'song': ['Beauty and the Beast (Disney song)'],
#    'songurl': ['/wiki/Beauty_and_the_Beast_(Disney_song)'],
#    'titletext': 'Beauty and the Beast (Disney song)',
#    'url': ['/wiki/Celine_Dion', '/wiki/Peabo_Bryson']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': 65,
#    'song': ['Warm It Up'],
#    'songurl': ['/wiki/Warm_It_Up'],
#    'titletext': 'Warm It Up',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': 66,
#    'song': ['In the Closet'],
#    'songurl': ['/wiki/In_the_Closet'],
#    'titletext': 'In the Closet',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Arrested Development (group)'],
#    'ranking': 67,
#    'song': ['People Everyday'],
#    'songurl': ['/wiki/People_Everyday'],
#    'titletext': 'People Everyday',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Genesis (band)'],
#    'ranking': 68,
#    'song': ['No Son of Mine'],
#    'songurl': ['/wiki/No_Son_of_Mine'],
#    'titletext': 'No Son of Mine',
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Marky Mark and the Funky Bunch'],
#    'ranking': 69,
#    'song': ['Wildside (Marky Mark and the Funky Bunch song)'],
#    'songurl': ['/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)'],
#    'titletext': 'Wildside (Marky Mark and the Funky Bunch song)',
#    'url': ['/wiki/Marky_Mark_and_the_Funky_Bunch']},
#   {'band_singer': ['Bryan Adams'],
#    'ranking': 70,
#    'song': ['Do I Have to Say the Words?'],
#    'songurl': ['/wiki/Do_I_Have_to_Say_the_Words%3F'],
#    'titletext': 'Do I Have to Say the Words?',
#    'url': ['/wiki/Bryan_Adams']},
#   {'band_singer': ['The Cure'],
#    'ranking': 71,
#    'song': ["Friday I'm in Love"],
#    'songurl': ['/wiki/Friday_I%27m_in_Love'],
#    'titletext': "Friday I'm in Love",
#    'url': ['/wiki/The_Cure']},
#   {'band_singer': ['Ugly Kid Joe'],
#    'ranking': 72,
#    'song': ['Everything About You (Ugly Kid Joe song)'],
#    'songurl': ['/wiki/Everything_About_You_(Ugly_Kid_Joe_song)'],
#    'titletext': 'Everything About You (Ugly Kid Joe song)',
#    'url': ['/wiki/Ugly_Kid_Joe']},
#   {'band_singer': ['Paula Abdul'],
#    'ranking': 73,
#    'song': ['Blowing Kisses in the Wind'],
#    'songurl': ['/wiki/Blowing_Kisses_in_the_Wind'],
#    'titletext': 'Blowing Kisses in the Wind',
#    'url': ['/wiki/Paula_Abdul']},
#   {'band_singer': ['Bryan Adams'],
#    'ranking': 74,
#    'song': ["Thought I'd Died and Gone to Heaven"],
#    'songurl': ['/wiki/Thought_I%27d_Died_and_Gone_to_Heaven'],
#    'titletext': "Thought I'd Died and Gone to Heaven",
#    'url': ['/wiki/Bryan_Adams']},
#   {'band_singer': ['Snap!'],
#    'ranking': 75,
#    'song': ['Rhythm Is a Dancer'],
#    'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#    'titletext': 'Rhythm Is a Dancer',
#    'url': ['/wiki/Snap!']},
#   {'band_singer': ['MC Hammer'],
#    'ranking': 76,
#    'song': ['Addams Groove'],
#    'songurl': ['/wiki/Addams_Groove'],
#    'titletext': 'Addams Groove',
#    'url': ['/wiki/MC_Hammer']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': 77,
#    'song': ['Missing You Now'],
#    'songurl': ['/wiki/Missing_You_Now'],
#    'titletext': 'Missing You Now',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['N2Deep'],
#    'ranking': 78,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/N2Deep']},
#   {'band_singer': ['Kathy Troccoli'],
#    'ranking': 79,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Kathy_Troccoli']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': 80,
#    'song': ['Have You Ever Needed Someone So Bad'],
#    'songurl': ['/wiki/Have_You_Ever_Needed_Someone_So_Bad'],
#    'titletext': 'Have You Ever Needed Someone So Bad',
#    'url': ['/wiki/Def_Leppard']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': 81,
#    'song': ['Take This Heart'],
#    'songurl': ['/wiki/Take_This_Heart'],
#    'titletext': 'Take This Heart',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['FireHouse (band)'],
#    'ranking': 82,
#    'song': ['When I Look Into Your Eyes'],
#    'songurl': ['/wiki/When_I_Look_Into_Your_Eyes'],
#    'titletext': 'When I Look Into Your Eyes',
#    'url': ['/wiki/FireHouse_(band)']},
#   {'band_singer': ['Jade (American band)'],
#    'ranking': 83,
#    'song': ['I Wanna Love You (Jade song)'],
#    'songurl': ['/wiki/I_Wanna_Love_You_(Jade_song)'],
#    'titletext': 'I Wanna Love You (Jade song)',
#    'url': ['/wiki/Jade_(American_band)']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': 84,
#    'song': ['Uhh Ahh'],
#    'songurl': ['/wiki/Uhh_Ahh'],
#    'titletext': 'Uhh Ahh',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Mary J. Blige'],
#    'ranking': 85,
#    'song': ['Real Love (Mary J. Blige song)'],
#    'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#    'titletext': 'Real Love (Mary J. Blige song)',
#    'url': ['/wiki/Mary_J._Blige']},
#   {'band_singer': ['The KLF'],
#    'ranking': 86,
#    'song': ['Justified and Ancient'],
#    'songurl': ['/wiki/Justified_and_Ancient'],
#    'titletext': 'Justified and Ancient',
#    'url': ['/wiki/The_KLF']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': 87,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['TLC (band)'],
#    'ranking': 88,
#    'song': ['What About Your Friends'],
#    'songurl': ['/wiki/What_About_Your_Friends'],
#    'titletext': 'What About Your Friends',
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': 89,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['Charles & Eddie'],
#    'ranking': 90,
#    'song': ['Would I Lie to You? (Charles & Eddie song)'],
#    'songurl': ['/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)'],
#    'titletext': 'Would I Lie to You? (Charles & Eddie song)',
#    'url': ['/wiki/Charles_%26_Eddie']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': 91,
#    'song': ["That's What Love Is For"],
#    'songurl': ['/wiki/That%27s_What_Love_Is_For'],
#    'titletext': "That's What Love Is For",
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': 92,
#    'song': ['Keep Coming Back (song)'],
#    'songurl': ['/wiki/Keep_Coming_Back_(song)'],
#    'titletext': 'Keep Coming Back (song)',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['En Vogue'],
#    'ranking': 93,
#    'song': ['Free Your Mind (song)'],
#    'songurl': ['/wiki/Free_Your_Mind_(song)'],
#    'titletext': 'Free Your Mind (song)',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Keith Sweat'],
#    'ranking': 94,
#    'song': ["Keep It Comin' (song)"],
#    'songurl': ['/wiki/Keep_It_Comin%27_(song)'],
#    'titletext': "Keep It Comin' (song)",
#    'url': ['/wiki/Keith_Sweat']},
#   {'band_singer': ['Mr. Big (band)'],
#    'ranking': 95,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Mr._Big_(band)']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': 96,
#    'song': ['I Will Remember You (Amy Grant song)'],
#    'songurl': ['/wiki/I_Will_Remember_You_(Amy_Grant_song)'],
#    'titletext': 'I Will Remember You (Amy Grant song)',
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': 97,
#    'song': ['We Got a Love Thang'],
#    'songurl': ['/wiki/We_Got_a_Love_Thang'],
#    'titletext': 'We Got a Love Thang',
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': 98,
#    'song': ["Let's Get Rocked"],
#    'songurl': ['/wiki/Let%27s_Get_Rocked'],
#    'titletext': "Let's Get Rocked",
#    'url': ['/wiki/Def_Leppard']},
#   {'band_singer': ['Das EFX'],
#    'ranking': 99,
#    'song': ['They Want EFX'],
#    'songurl': ['/wiki/They_Want_EFX'],
#    'titletext': 'They Want EFX',
#    'url': ['/wiki/Das_EFX']},
#   {'band_singer': ['Bonnie Raitt'],
#    'ranking': 100,
#    'song': ["I Can't Make You Love Me"],
#    'songurl': ['/wiki/I_Can%27t_Make_You_Love_Me'],
#    'titletext': "I Can't Make You Love Me",
#    'url': ['/wiki/Bonnie_Raitt']}],
#  '1993': [{'band_singer': ['Whitney Houston'],
#    'ranking': 1,
#    'song': ['I Will Always Love You'],
#    'songurl': ['/wiki/I_Will_Always_Love_You#Whitney_Houston_version'],
#    'titletext': 'I Will Always Love You',
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Tag Team (group)'],
#    'ranking': 2,
#    'song': ['Whoomp! (There It Is)'],
#    'songurl': ['/wiki/Whoomp!_(There_It_Is)'],
#    'titletext': 'Whoomp! (There It Is)',
#    'url': ['/wiki/Tag_Team_(group)']},
#   {'band_singer': ['UB40'],
#    'ranking': 3,
#    'song': ["Can't Help Falling in Love"],
#    'songurl': ['/wiki/Can%27t_Help_Falling_in_Love'],
#    'titletext': "Can't Help Falling in Love",
#    'url': ['/wiki/UB40']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': 4,
#    'song': ["That's the Way Love Goes (Janet Jackson song)"],
#    'songurl': ['/wiki/That%27s_the_Way_Love_Goes_(Janet_Jackson_song)'],
#    'titletext': "That's the Way Love Goes (Janet Jackson song)",
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['Silk (group)'],
#    'ranking': 5,
#    'song': ['Freak Me'],
#    'songurl': ['/wiki/Freak_Me'],
#    'titletext': 'Freak Me',
#    'url': ['/wiki/Silk_(group)']},
#   {'band_singer': ['SWV'],
#    'ranking': 6,
#    'song': ['Weak (SWV song)'],
#    'songurl': ['/wiki/Weak_(SWV_song)'],
#    'titletext': 'Weak (SWV song)',
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Shai (band)'],
#    'ranking': 7,
#    'song': ['If I Ever Fall in Love'],
#    'songurl': ['/wiki/If_I_Ever_Fall_in_Love'],
#    'titletext': 'If I Ever Fall in Love',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 8,
#    'song': ['Dreamlover (song)'],
#    'songurl': ['/wiki/Dreamlover_(song)'],
#    'titletext': 'Dreamlover (song)',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Wreckx-n-Effect'],
#    'ranking': 9,
#    'song': ['Rump Shaker (song)'],
#    'songurl': ['/wiki/Rump_Shaker_(song)'],
#    'titletext': 'Rump Shaker (song)',
#    'url': ['/wiki/Wreckx-n-Effect']},
#   {'band_singer': ['Snow (musician)'],
#    'ranking': 10,
#    'song': ['Informer (song)'],
#    'songurl': ['/wiki/Informer_(song)'],
#    'titletext': 'Informer (song)',
#    'url': ['/wiki/Snow_(musician)']},
#   {'band_singer': ['Dr. Dre'],
#    'ranking': 11,
#    'song': ["Nuthin' but a 'G' Thang"],
#    'songurl': ['/wiki/Nuthin%27_but_a_%27G%27_Thang'],
#    'titletext': "Nuthin' but a 'G' Thang",
#    'url': ['/wiki/Dr._Dre']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': 12,
#    'song': ['In the Still of the Night (1956 song)'],
#    'songurl': ['/wiki/In_the_Still_of_the_Night_(1956_song)#Boyz_II_Men_version'],
#    'titletext': 'In the Still of the Night (1956 song)',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Jade (American band)'],
#    'ranking': 13,
#    'song': ["Don't Walk Away (Jade song)"],
#    'songurl': ['/wiki/Don%27t_Walk_Away_(Jade_song)'],
#    'titletext': "Don't Walk Away (Jade song)",
#    'url': ['/wiki/Jade_(American_band)']},
#   {'band_singer': ['H-Town (band)'],
#    'ranking': 14,
#    'song': ["Knockin' da Boots"],
#    'songurl': ['/wiki/Knockin%27_da_Boots'],
#    'titletext': "Knockin' da Boots",
#    'url': ['/wiki/H-Town_(band)']},
#   {'band_singer': ['Jodeci'],
#    'ranking': 15,
#    'song': ['Lately (Jodeci song)'],
#    'songurl': ['/wiki/Lately_(Jodeci_song)'],
#    'titletext': 'Lately (Jodeci song)',
#    'url': ['/wiki/Jodeci']},
#   {'band_singer': ['Duice'],
#    'ranking': 16,
#    'song': ['Dazzey Duks'],
#    'songurl': ['/wiki/Dazzey_Duks'],
#    'titletext': 'Dazzey Duks',
#    'url': ['/wiki/Duice']},
#   {'band_singer': ['Robin S.'],
#    'ranking': 17,
#    'song': ['Show Me Love (Robin S. song)'],
#    'songurl': ['/wiki/Show_Me_Love_(Robin_S._song)'],
#    'titletext': 'Show Me Love (Robin S. song)',
#    'url': ['/wiki/Robin_S.']},
#   {'band_singer': ['Peabo Bryson', 'Regina Belle'],
#    'ranking': 18,
#    'song': ['A Whole New World'],
#    'songurl': ['/wiki/A_Whole_New_World'],
#    'titletext': 'A Whole New World',
#    'url': ['/wiki/Peabo_Bryson', '/wiki/Regina_Belle']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': 19,
#    'song': ['If (Janet Jackson song)'],
#    'songurl': ['/wiki/If_(Janet_Jackson_song)'],
#    'titletext': 'If (Janet Jackson song)',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['SWV'],
#    'ranking': 20,
#    'song': ["I'm So Into You"],
#    'songurl': ['/wiki/I%27m_So_Into_You'],
#    'titletext': "I'm So Into You",
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Vanessa L. Williams', 'Brian McKnight'],
#    'ranking': 21,
#    'song': ['Love Is (Vanessa Williams song)'],
#    'songurl': ['/wiki/Love_Is_(Vanessa_Williams_song)'],
#    'titletext': 'Love Is (Vanessa Williams song)',
#    'url': ['/wiki/Vanessa_L._Williams', '/wiki/Brian_McKnight']},
#   {'band_singer': ['Soul Asylum'],
#    'ranking': 22,
#    'song': ['Runaway Train (Soul Asylum song)'],
#    'songurl': ['/wiki/Runaway_Train_(Soul_Asylum_song)'],
#    'titletext': 'Runaway Train (Soul Asylum song)',
#    'url': ['/wiki/Soul_Asylum']},
#   {'band_singer': ['Exposé (group)'],
#    'ranking': 23,
#    'song': ["I'll Never Get Over You (Getting Over Me)"],
#    'songurl': ['/wiki/I%27ll_Never_Get_Over_You_(Getting_Over_Me)'],
#    'titletext': "I'll Never Get Over You (Getting Over Me)",
#    'url': ['/wiki/Expos%C3%A9_(group)']},
#   {'band_singer': ['Paperboy (rapper)'],
#    'ranking': 24,
#    'song': ['Ditty (Paperboy song)'],
#    'songurl': ['/wiki/Ditty_(Paperboy_song)'],
#    'titletext': 'Ditty (Paperboy song)',
#    'url': ['/wiki/Paperboy_(rapper)']},
#   {'band_singer': ['Snap!'],
#    'ranking': 25,
#    'song': ['Rhythm Is a Dancer'],
#    'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#    'titletext': 'Rhythm Is a Dancer',
#    'url': ['/wiki/Snap!']},
#   {'band_singer': ['Billy Joel'],
#    'ranking': 26,
#    'song': ['The River of Dreams'],
#    'songurl': ['/wiki/The_River_of_Dreams'],
#    'titletext': 'The River of Dreams',
#    'url': ['/wiki/Billy_Joel']},
#   {'band_singer': ['The Proclaimers'],
#    'ranking': 27,
#    'song': ["I'm Gonna Be (500 Miles)"],
#    'songurl': ['/wiki/I%27m_Gonna_Be_(500_Miles)'],
#    'titletext': "I'm Gonna Be (500 Miles)",
#    'url': ['/wiki/The_Proclaimers']},
#   {'band_singer': ['Spin Doctors'],
#    'ranking': 28,
#    'song': ['Two Princes'],
#    'songurl': ['/wiki/Two_Princes'],
#    'titletext': 'Two Princes',
#    'url': ['/wiki/Spin_Doctors']},
#   {'band_singer': ['SWV'],
#    'ranking': 29,
#    'song': ['Right Here (SWV song)'],
#    'songurl': ['/wiki/Right_Here_(SWV_song)'],
#    'titletext': 'Right Here (SWV song)',
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Whitney Houston'],
#    'ranking': 30,
#    'song': ['I Have Nothing'],
#    'songurl': ['/wiki/I_Have_Nothing'],
#    'titletext': 'I Have Nothing',
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Arrested Development (group)'],
#    'ranking': 31,
#    'song': ['Mr. Wendal'],
#    'songurl': ['/wiki/Mr._Wendal'],
#    'titletext': 'Mr. Wendal',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Rod Stewart'],
#    'ranking': 32,
#    'song': ['Have I Told You Lately'],
#    'songurl': ['/wiki/Have_I_Told_You_Lately'],
#    'titletext': 'Have I Told You Lately',
#    'url': ['/wiki/Rod_Stewart']},
#   {'band_singer': ['Shanice'],
#    'ranking': 33,
#    'song': ['Saving Forever for You'],
#    'songurl': ['/wiki/Saving_Forever_for_You'],
#    'titletext': 'Saving Forever for You',
#    'url': ['/wiki/Shanice']},
#   {'band_singer': ['Duran Duran'],
#    'ranking': 34,
#    'song': ['Ordinary World'],
#    'songurl': ['/wiki/Ordinary_World'],
#    'titletext': 'Ordinary World',
#    'url': ['/wiki/Duran_Duran']},
#   {'band_singer': ['Tony! Toni! Toné!'],
#    'ranking': 35,
#    'song': ['If I Had No Loot'],
#    'songurl': ['/wiki/If_I_Had_No_Loot'],
#    'titletext': 'If I Had No Loot',
#    'url': ['/wiki/Tony!_Toni!_Ton%C3%A9!']},
#   {'band_singer': ['Meat Loaf'],
#    'ranking': 36,
#    'song': ["I'd Do Anything for Love (But I Won't Do That)"],
#    'songurl': ['/wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27t_Do_That)'],
#    'titletext': "I'd Do Anything for Love (But I Won't Do That)",
#    'url': ['/wiki/Meat_Loaf']},
#   {'band_singer': ['Onyx (group)'],
#    'ranking': 37,
#    'song': ['Slam (Onyx song)'],
#    'songurl': ['/wiki/Slam_(Onyx_song)'],
#    'titletext': 'Slam (Onyx song)',
#    'url': ['/wiki/Onyx_(group)']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': 38,
#    'song': ['Looking Through Patient Eyes'],
#    'songurl': ['/wiki/Looking_Through_Patient_Eyes'],
#    'titletext': 'Looking Through Patient Eyes',
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Whitney Houston'],
#    'ranking': 39,
#    'song': ["I'm Every Woman"],
#    'songurl': ['/wiki/I%27m_Every_Woman#Whitney_Houston_version'],
#    'titletext': "I'm Every Woman",
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Shai (band)'],
#    'ranking': 40,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Duran Duran'],
#    'ranking': 41,
#    'song': ['Come Undone (Duran Duran song)'],
#    'songurl': ['/wiki/Come_Undone_(Duran_Duran_song)'],
#    'titletext': 'Come Undone (Duran Duran song)',
#    'url': ['/wiki/Duran_Duran']},
#   {'band_singer': ['Tina Turner'],
#    'ranking': 42,
#    'song': ["I Don't Wanna Fight"],
#    'songurl': ['/wiki/I_Don%27t_Wanna_Fight'],
#    'titletext': "I Don't Wanna Fight",
#    'url': ['/wiki/Tina_Turner']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': 43,
#    'song': ["I'd Die Without You"],
#    'songurl': ['/wiki/I%27d_Die_Without_You'],
#    'titletext': "I'd Die Without You",
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['95 South'],
#    'ranking': 44,
#    'song': ['Whoot, There It Is'],
#    'songurl': ['/wiki/Whoot,_There_It_Is'],
#    'titletext': 'Whoot, There It Is',
#    'url': ['/wiki/95_South']},
#   {'band_singer': ['Naughty by Nature'],
#    'ranking': 45,
#    'song': ['Hip Hop Hooray'],
#    'songurl': ['/wiki/Hip_Hop_Hooray'],
#    'titletext': 'Hip Hop Hooray',
#    'url': ['/wiki/Naughty_by_Nature']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': 46,
#    'song': ['Another Sad Love Song'],
#    'songurl': ['/wiki/Another_Sad_Love_Song'],
#    'titletext': 'Another Sad Love Song',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': 47,
#    'song': ['Will You Be There'],
#    'songurl': ['/wiki/Will_You_Be_There'],
#    'titletext': 'Will You Be There',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Shai (band)'],
#    'ranking': 48,
#    'song': ['Comforter (song)'],
#    'songurl': ['/wiki/Comforter_(song)'],
#    'titletext': 'Comforter (song)',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Bobby Brown'],
#    'ranking': 49,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Bobby_Brown']},
#   {'band_singer': ['4 Non Blondes'],
#    'ranking': 50,
#    'song': ["What's Up? (song)"],
#    'songurl': ['/wiki/What%27s_Up%3F_(song)'],
#    'titletext': "What's Up? (song)",
#    'url': ['/wiki/4_Non_Blondes']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': 51,
#    'song': ['All That She Wants'],
#    'songurl': ['/wiki/All_That_She_Wants'],
#    'titletext': 'All That She Wants',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['Prince (musician)', 'The New Power Generation'],
#    'ranking': 52,
#    'song': ['7 (song)'],
#    'songurl': ['/wiki/7_(song)'],
#    'titletext': '7 (song)',
#    'url': ['/wiki/Prince_(musician)', '/wiki/The_New_Power_Generation']},
#   {'band_singer': ['Dr. Dre', 'Snoop Dogg'],
#    'ranking': 53,
#    'song': ["Fuck wit Dre Day (And Everybody's Celebratin')"],
#    'songurl': ['/wiki/Fuck_wit_Dre_Day_(And_Everybody%27s_Celebratin%27)'],
#    'titletext': "Fuck wit Dre Day (And Everybody's Celebratin')",
#    'url': ['/wiki/Dr._Dre', '/wiki/Snoop_Dogg']},
#   {'band_singer': ['Brian McKnight'],
#    'ranking': 54,
#    'song': ['One Last Cry'],
#    'songurl': ['/wiki/One_Last_Cry'],
#    'titletext': 'One Last Cry',
#    'url': ['/wiki/Brian_McKnight']},
#   {'band_singer': ['Xscape (band)'],
#    'ranking': 55,
#    'song': ["Just Kickin' It"],
#    'songurl': ['/wiki/Just_Kickin%27_It'],
#    'titletext': "Just Kickin' It",
#    'url': ['/wiki/Xscape_(band)']},
#   {'band_singer': ['Tupac Shakur'],
#    'ranking': 56,
#    'song': ['I Get Around (Tupac Shakur song)'],
#    'songurl': ['/wiki/I_Get_Around_(Tupac_Shakur_song)'],
#    'titletext': 'I Get Around (Tupac Shakur song)',
#    'url': ['/wiki/Tupac_Shakur']},
#   {'band_singer': ['Bon Jovi'],
#    'ranking': 57,
#    'song': ['Bed of Roses (song)'],
#    'songurl': ['/wiki/Bed_of_Roses_(song)'],
#    'titletext': 'Bed of Roses (song)',
#    'url': ['/wiki/Bon_Jovi']},
#   {'band_singer': ['Mary J. Blige'],
#    'ranking': 58,
#    'song': ['Real Love (Mary J. Blige song)'],
#    'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#    'titletext': 'Real Love (Mary J. Blige song)',
#    'url': ['/wiki/Mary_J._Blige']},
#   {'band_singer': ['Portrait (group)'],
#    'ranking': 59,
#    'song': [],
#    'songurl': [],
#    'titletext': '',
#    'url': ['/wiki/Portrait_(group)']},
#   {'band_singer': ['Aerosmith'],
#    'ranking': 60,
#    'song': ["Cryin'"],
#    'songurl': ['/wiki/Cryin%27'],
#    'titletext': "Cryin'",
#    'url': ['/wiki/Aerosmith']},
#   {'band_singer': ['Ugly Kid Joe'],
#    'ranking': 61,
#    'song': ["Cat's in the Cradle"],
#    'songurl': ['/wiki/Cat%27s_in_the_Cradle'],
#    'titletext': "Cat's in the Cradle",
#    'url': ['/wiki/Ugly_Kid_Joe']},
#   {'band_singer': ['TLC (band)'],
#    'ranking': 62,
#    'song': ['What About Your Friends'],
#    'songurl': ['/wiki/What_About_Your_Friends'],
#    'titletext': 'What About Your Friends',
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Positive K'],
#    'ranking': 63,
#    'song': ['I Got a Man'],
#    'songurl': ['/wiki/I_Got_a_Man'],
#    'titletext': 'I Got a Man',
#    'url': ['/wiki/Positive_K']},
#   {'band_singer': ['Zhané'],
#    'ranking': 64,
#    'song': ['Hey Mr. D.J.'],
#    'songurl': ['/wiki/Hey_Mr._D.J.'],
#    'titletext': 'Hey Mr. D.J.',
#    'url': ['/wiki/Zhan%C3%A9']},
#   {'band_singer': ['Cypress Hill'],
#    'ranking': 65,
#    'song': ['Insane in the Brain'],
#    'songurl': ['/wiki/Insane_in_the_Brain'],
#    'titletext': 'Insane in the Brain',
#    'url': ['/wiki/Cypress_Hill']},
#   {'band_singer': ['Madonna (entertainer)'],
#    'ranking': 66,
#    'song': ['Deeper and Deeper'],
#    'songurl': ['/wiki/Deeper_and_Deeper'],
#    'titletext': 'Deeper and Deeper',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Madonna (entertainer)'],
#    'ranking': 67,
#    'song': ['Rain (Madonna song)'],
#    'songurl': ['/wiki/Rain_(Madonna_song)'],
#    'titletext': 'Rain (Madonna song)',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Jeremy Jordan (singer)'],
#    'ranking': 68,
#    'song': ['The Right Kind of Love'],
#    'songurl': ['/wiki/The_Right_Kind_of_Love'],
#    'titletext': 'The Right Kind of Love',
#    'url': ['/wiki/Jeremy_Jordan_(singer)']},
#   {'band_singer': ['Inner Circle (reggae band)'],
#    'ranking': 69,
#    'song': ['Bad Boys (Inner Circle song)'],
#    'songurl': ['/wiki/Bad_Boys_(Inner_Circle_song)'],
#    'titletext': 'Bad Boys (Inner Circle song)',
#    'url': ['/wiki/Inner_Circle_(reggae_band)']},
#   {'band_singer': ['Boy Krazy'],
#    'ranking': 70,
#    'song': ["That's What Love Can Do"],
#    'songurl': ['/wiki/That%27s_What_Love_Can_Do'],
#    'titletext': "That's What Love Can Do",
#    'url': ['/wiki/Boy_Krazy']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': 71,
#    'song': ['Do You Believe in Us'],
#    'songurl': ['/wiki/Do_You_Believe_in_Us'],
#    'titletext': 'Do You Believe in Us',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': 72,
#    'song': ['Angel (Jon Secada song)'],
#    'songurl': ['/wiki/Angel_(Jon_Secada_song)'],
#    'titletext': 'Angel (Jon Secada song)',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Kenny G'],
#    'ranking': 73,
#    'song': ['Forever in Love (instrumental)'],
#    'songurl': ['/wiki/Forever_in_Love_(instrumental)'],
#    'titletext': 'Forever in Love (instrumental)',
#    'url': ['/wiki/Kenny_G']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': 74,
#    'song': ['Again (Janet Jackson song)'],
#    'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#    'titletext': 'Again (Janet Jackson song)',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['DJ Jazzy Jeff & The Fresh Prince'],
#    'ranking': 75,
#    'song': ['Boom! Shake the Room'],
#    'songurl': ['/wiki/Boom!_Shake_the_Room'],
#    'titletext': 'Boom! Shake the Room',
#    'url': ['/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince']},
#   {'band_singer': ['Restless Heart'],
#    'ranking': 76,
#    'song': ['When She Cries'],
#    'songurl': ['/wiki/When_She_Cries'],
#    'titletext': 'When She Cries',
#    'url': ['/wiki/Restless_Heart']},
#   {'band_singer': ['Inner Circle (reggae band)'],
#    'ranking': 77,
#    'song': ['Sweat (A La La La La Long)'],
#    'songurl': ['/wiki/Sweat_(A_La_La_La_La_Long)'],
#    'titletext': 'Sweat (A La La La La Long)',
#    'url': ['/wiki/Inner_Circle_(reggae_band)']},
#   {'band_singer': ['Ice Cube'],
#    'ranking': 78,
#    'song': ['It Was a Good Day'],
#    'songurl': ['/wiki/It_Was_a_Good_Day'],
#    'titletext': 'It Was a Good Day',
#    'url': ['/wiki/Ice_Cube']},
#   {'band_singer': ['Captain Hollywood Project'],
#    'ranking': 79,
#    'song': ['More and More (Captain Hollywood Project song)'],
#    'songurl': ['/wiki/More_and_More_(Captain_Hollywood_Project_song)'],
#    'titletext': 'More and More (Captain Hollywood Project song)',
#    'url': ['/wiki/Captain_Hollywood_Project']},
#   {'band_singer': ['The Heights (TV series)'],
#    'ranking': 80,
#    'song': ['How Do You Talk to an Angel'],
#    'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#    'titletext': 'How Do You Talk to an Angel',
#    'url': ['/wiki/The_Heights_(TV_series)']},
#   {'band_singer': ['Digable Planets'],
#    'ranking': 81,
#    'song': ['Rebirth of Slick (Cool Like Dat)'],
#    'songurl': ['/wiki/Rebirth_of_Slick_(Cool_Like_Dat)'],
#    'titletext': 'Rebirth of Slick (Cool Like Dat)',
#    'url': ['/wiki/Digable_Planets']},
#   {'band_singer': ['Haddaway'],
#    'ranking': 82,
#    'song': ['What Is Love (Haddaway song)'],
#    'songurl': ['/wiki/What_Is_Love_(Haddaway_song)'],
#    'titletext': 'What Is Love (Haddaway song)',
#    'url': ['/wiki/Haddaway']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': 83,
#    'song': ['To Love Somebody (song)'],
#    'songurl': ['/wiki/To_Love_Somebody_(song)'],
#    'titletext': 'To Love Somebody (song)',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['En Vogue'],
#    'ranking': 84,
#    'song': ['Give It Up, Turn It Loose'],
#    'songurl': ['/wiki/Give_It_Up,_Turn_It_Loose'],
#    'titletext': 'Give It Up, Turn It Loose',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': 85,
#    'song': ['Alright (Kris Kross song)'],
#    'songurl': ['/wiki/Alright_(Kris_Kross_song)'],
#    'titletext': 'Alright (Kris Kross song)',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Ice Cube', 'Das EFX'],
#    'ranking': 86,
#    'song': ['Check Yo Self'],
#    'songurl': ['/wiki/Check_Yo_Self'],
#    'titletext': 'Check Yo Self',
#    'url': ['/wiki/Ice_Cube', '/wiki/Das_EFX']},
#   {'band_singer': ['Sting (musician)'],
#    'ranking': 87,
#    'song': ['Fields of Gold'],
#    'songurl': ['/wiki/Fields_of_Gold'],
#    'titletext': 'Fields of Gold',
#    'url': ['/wiki/Sting_(musician)']},
#   {'band_singer': ['Dino (singer)'],
#    'ranking': 88,
#    'song': ['Ooh Child'],
#    'songurl': ['/wiki/Ooh_Child'],
#    'titletext': 'Ooh Child',
#    'url': ['/wiki/Dino_(singer)']},
#   {'band_singer': ['Go West (band)'],
#    'ranking': 89,
#    'song': ['Faithful (Go West song)'],
#    'songurl': ['/wiki/Faithful_(Go_West_song)'],
#    'titletext': 'Faithful (Go West song)',
#    'url': ['/wiki/Go_West_(band)']},
#   {'band_singer': ['Rod Stewart'],
#    'ranking': 90,
#    'song': ['Reason to Believe'],
#    'songurl': ['/wiki/Reason_to_Believe'],
#    'titletext': 'Reason to Believe',
#    'url': ['/wiki/Rod_Stewart']},
#   {'band_singer': ['Tears for Fears'],
#    'ranking': 91,
#    'song': ['Break It Down Again'],
#    'songurl': ['/wiki/Break_It_Down_Again'],
#    'titletext': 'Break It Down Again',
#    'url': ['/wiki/Tears_for_Fears']},
#   {'band_singer': ['Joey Lawrence'],
#    'ranking': 92,
#    'song': ["Nothin' My Love Can't Fix"],
#    'songurl': ['/wiki/Nothin%27_My_Love_Can%27t_Fix'],
#    'titletext': "Nothin' My Love Can't Fix",
#    'url': ['/wiki/Joey_Lawrence']},
#   {'band_singer': ['Green Jellÿ'],
#    'ranking': 93,
#    'song': ['Three Little Pigs (song)'],
#    'songurl': ['/wiki/Three_Little_Pigs_(song)'],
#    'titletext': 'Three Little Pigs (song)',
#    'url': ['/wiki/Green_Jell%C3%BF']},
#   {'band_singer': ['Aerosmith'],
#    'ranking': 94,
#    'song': ["Livin' on the Edge"],
#    'songurl': ['/wiki/Livin%27_on_the_Edge'],
#    'titletext': "Livin' on the Edge",
#    'url': ['/wiki/Aerosmith']},
#   {'band_singer': ['Gin Blossoms'],
#    'ranking': 95,
#    'song': ['Hey Jealousy'],
#    'songurl': ['/wiki/Hey_Jealousy'],
#    'titletext': 'Hey Jealousy',
#    'url': ['/wiki/Gin_Blossoms']},
#   {'band_singer': ['Sting (musician)'],
#    'ranking': 96,
#    'song': ['If I Ever Lose My Faith in You'],
#    'songurl': ['/wiki/If_I_Ever_Lose_My_Faith_in_You'],
#    'titletext': 'If I Ever Lose My Faith in You',
#    'url': ['/wiki/Sting_(musician)']},
#   {'band_singer': ['Tony! Toni! Tone!'],
#    'ranking': 97,
#    'song': ['Anniversary'],
#    'songurl': ['/wiki/Anniversary'],
#    'titletext': 'Anniversary',
#    'url': ['/wiki/Tony!_Toni!_Tone!']},
#   {'band_singer': ['Jade (American band)'],
#    'ranking': 98,
#    'song': ['One Woman'],
#    'songurl': ['/wiki/One_Woman'],
#    'titletext': 'One Woman',
#    'url': ['/wiki/Jade_(American_band)']},
#   {'band_singer': ['Taylor Dayne'],
#    'ranking': 99,
#    'song': ["Can't Get Enough of Your Love"],
#    'songurl': ['/wiki/Can%27t_Get_Enough_of_Your_Love'],
#    'titletext': "Can't Get Enough of Your Love",
#    'url': ['/wiki/Taylor_Dayne']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': 100,
#    'song': ['Two Steps Behind'],
#    'songurl': ['/wiki/Two_Steps_Behind'],
#    'titletext': 'Two Steps Behind',
#    'url': ['/wiki/Def_Leppard']}],
#  '1994': [{'band_singer': ['Ace of Base'],
#    'ranking': 1,
#    'song': ['The Sign (song)'],
#    'songurl': ['/wiki/The_Sign_(song)'],
#    'titletext': 'The Sign (song)',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['All-4-One'],
#    'ranking': 2,
#    'song': ['I Swear'],
#    'songurl': ['/wiki/I_Swear#All-4-One_version'],
#    'titletext': 'I Swear',
#    'url': ['/wiki/All-4-One']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': 3,
#    'song': ["I'll Make Love to You"],
#    'songurl': ['/wiki/I%27ll_Make_Love_to_You'],
#    'titletext': "I'll Make Love to You",
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Céline Dion'],
#    'ranking': 4,
#    'song': ['The Power of Love (Jennifer Rush song)'],
#    'songurl': ['/wiki/The_Power_of_Love_(Jennifer_Rush_song)#Céline_Dion_version'],
#    'titletext': 'The Power of Love (Jennifer Rush song)',
#    'url': ['/wiki/C%C3%A9line_Dion']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 5,
#    'song': ['Hero (Mariah Carey song)'],
#    'songurl': ['/wiki/Hero_(Mariah_Carey_song)'],
#    'titletext': 'Hero (Mariah Carey song)',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Lisa Loeb'],
#    'ranking': 6,
#    'song': ['Stay (I Missed You)'],
#    'songurl': ['/wiki/Stay_(I_Missed_You)'],
#    'titletext': 'Stay (I Missed You)',
#    'url': ['/wiki/Lisa_Loeb']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': 7,
#    'song': ['Breathe Again'],
#    'songurl': ['/wiki/Breathe_Again'],
#    'titletext': 'Breathe Again',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Bryan Adams', 'Rod Stewart', 'Sting (musician)'],
#    'ranking': 8,
#    'song': ['All for Love (song)'],
#    'songurl': ['/wiki/All_for_Love_(song)'],
#    'titletext': 'All for Love (song)',
#    'url': ['/wiki/Bryan_Adams',
#     '/wiki/Rod_Stewart',
#     '/wiki/Sting_(musician)']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': 9,
#    'song': ['All That She Wants'],
#    'songurl': ['/wiki/All_That_She_Wants'],
#    'titletext': 'All That She Wants',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': 10,
#    'song': ["Don't Turn Around"],
#    'songurl': ['/wiki/Don%27t_Turn_Around'],
#    'titletext': "Don't Turn Around",
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['R. Kelly'],
#    'ranking': 11,
#    'song': ["Bump n' Grind (R. Kelly song)"],
#    'songurl': ['/wiki/Bump_n%27_Grind_(R._Kelly_song)'],
#    'titletext': "Bump n' Grind (R. Kelly song)",
#    'url': ['/wiki/R._Kelly']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': 12,
#    'song': ['Again (Janet Jackson song)'],
#    'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#    'titletext': 'Again (Janet Jackson song)',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['Madonna (entertainer)'],
#    'ranking': 13,
#    'song': ["I'll Remember"],
#    'songurl': ['/wiki/I%27ll_Remember'],
#    'titletext': "I'll Remember",
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Salt-n-Pepa', 'En Vogue'],
#    'ranking': 14,
#    'song': ['Whatta Man'],
#    'songurl': ['/wiki/Whatta_Man'],
#    'titletext': 'Whatta Man',
#    'url': ['/wiki/Salt-n-Pepa', '/wiki/En_Vogue']},
#   {'band_singer': ['John Mellencamp', 'Meshell Ndegeocello'],
#    'ranking': 15,
#    'song': ['Wild Night'],
#    'songurl': ['/wiki/Wild_Night'],
#    'titletext': 'Wild Night',
#    'url': ['/wiki/John_Mellencamp', '/wiki/Meshell_Ndegeocello']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': 16,
#    'song': ['Without You (Badfinger song)',
#     'Never Forget You (Mariah Carey song)'],
#    'songurl': ['/wiki/Without_You_(Badfinger_song)#Mariah_Carey_version',
#     '/wiki/Never_Forget_You_(Mariah_Carey_song)'],
#    'titletext': 'Without You (Badfinger song) / Never Forget You (Mariah Carey song)',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': 17,
#    'song': ['You Mean the World to Me'],
#    'songurl': ['/wiki/You_Mean_the_World_to_Me'],
#    'titletext': 'You Mean the World to Me',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Elton John'],
#    'ranking': 18,
#    'song': ['Can You Feel the Love Tonight'],
#    'songurl': ['/wiki/Can_You_Feel_the_Love_Tonight'],
#    'titletext': 'Can You Feel the Love Tonight',
# ...
#   {'band_singer': ['Tove Lo'],
#    'ranking': 32,
#    'song': ['Habits (Stay High)'],
#    'songurl': ['/wiki/Habits_(Stay_High)'],
#    'titletext': 'Habits (Stay High)',
#    'url': ['/wiki/Tove_Lo']},
#   {'band_singer': ['Calvin Harris'],
#    'ranking': 33,
#    'song': ['Summer (Calvin Harris song)'],
#    'songurl': ['/wiki/Summer_(Calvin_Harris_song)'],
#    'titletext': 'Summer (Calvin Harris song)',
#    'url': ['/wiki/Calvin_Harris']},
#   {'band_singer': ['Charli XCX'],
#    'ranking': 34,
#    'song': ['Boom Clap'],
#    'songurl': ['/wiki/Boom_Clap'],
#    'titletext': 'Boom Clap',
#    'url': ['/wiki/Charli_XCX']},
#   {'band_singer': ['Beyoncé', 'Jay Z'],
#    'ranking': 35,
#    'song': ['Drunk in Love'],
#    'songurl': ['/wiki/Drunk_in_Love'],
#    'titletext': 'Drunk in Love',
#    'url': ['/wiki/Beyonc%C3%A9', '/wiki/Jay_Z']},
#   {'band_singer': ['Nicki Minaj'],
#    'ranking': 36,
#    'song': ['Anaconda (Nicki Minaj song)'],
#    'songurl': ['/wiki/Anaconda_(Nicki_Minaj_song)'],
#    'titletext': 'Anaconda (Nicki Minaj song)',
#    'url': ['/wiki/Nicki_Minaj']},
#   {'band_singer': ['Ariana Grande', 'Zedd (musician)'],
#    'ranking': 37,
#    'song': ['Break Free (Ariana Grande song)'],
#    'songurl': ['/wiki/Break_Free_(Ariana_Grande_song)'],
#    'titletext': 'Break Free (Ariana Grande song)',
#    'url': ['/wiki/Ariana_Grande', '/wiki/Zedd_(musician)']},
#   {'band_singer': ['Enrique Iglesias', 'Descemer Bueno', 'Gente de Zona'],
#    'ranking': 38,
#    'song': ['Bailando (Enrique Iglesias song)'],
#    'songurl': ['/wiki/Bailando_(Enrique_Iglesias_song)'],
#    'titletext': 'Bailando (Enrique Iglesias song)',
#    'url': ['/wiki/Enrique_Iglesias',
#     '/wiki/Descemer_Bueno',
#     '/wiki/Gente_de_Zona']},
#   {'band_singer': ['Ellie Goulding'],
#    'ranking': 39,
#    'song': ['Burn (Ellie Goulding song)'],
#    'songurl': ['/wiki/Burn_(Ellie_Goulding_song)'],
#    'titletext': 'Burn (Ellie Goulding song)',
#    'url': ['/wiki/Ellie_Goulding']},
#   {'band_singer': ['Jason Derulo', 'Snoop Dogg'],
#    'ranking': 40,
#    'song': ['Wiggle (song)'],
#    'songurl': ['/wiki/Wiggle_(song)'],
#    'titletext': 'Wiggle (song)',
#    'url': ['/wiki/Jason_Derulo', '/wiki/Snoop_Dogg']},
#   {'band_singer': ['Clean Bandit', 'Jess Glynne'],
#    'ranking': 41,
#    'song': ['Rather Be (Clean Bandit song)'],
#    'songurl': ['/wiki/Rather_Be_(Clean_Bandit_song)'],
#    'titletext': 'Rather Be (Clean Bandit song)',
#    'url': ['/wiki/Clean_Bandit', '/wiki/Jess_Glynne']},
#   {'band_singer': ['Jeremih', 'YG (rapper)'],
#    'ranking': 42,
#    'song': ["Don't Tell 'Em"],
#    'songurl': ['/wiki/Don%27t_Tell_%27Em'],
#    'titletext': "Don't Tell 'Em",
#    'url': ['/wiki/Jeremih', '/wiki/YG_(rapper)']},
#   {'band_singer': ['Kid Ink', 'Chris Brown'],
#    'ranking': 43,
#    'song': ['Show Me (Kid Ink song)'],
#    'songurl': ['/wiki/Show_Me_(Kid_Ink_song)'],
#    'titletext': 'Show Me (Kid Ink song)',
#    'url': ['/wiki/Kid_Ink', '/wiki/Chris_Brown']},
#   {'band_singer': ['Miley Cyrus'],
#    'ranking': 44,
#    'song': ['Wrecking Ball (Miley Cyrus song)'],
#    'songurl': ['/wiki/Wrecking_Ball_(Miley_Cyrus_song)'],
#    'titletext': 'Wrecking Ball (Miley Cyrus song)',
#    'url': ['/wiki/Miley_Cyrus']},
#   {'band_singer': ['Justin Timberlake'],
#    'ranking': 45,
#    'song': ['Not a Bad Thing'],
#    'songurl': ['/wiki/Not_a_Bad_Thing'],
#    'titletext': 'Not a Bad Thing',
#    'url': ['/wiki/Justin_Timberlake']},
#   {'band_singer': ['Katy Perry'],
#    'ranking': 46,
#    'song': ['Roar (song)'],
#    'songurl': ['/wiki/Roar_(song)'],
#    'titletext': 'Roar (song)',
#    'url': ['/wiki/Katy_Perry']},
#   {'band_singer': ['Paramore'],
#    'ranking': 47,
#    'song': ["Ain't It Fun (Paramore song)"],
#    'songurl': ['/wiki/Ain%27t_It_Fun_(Paramore_song)'],
#    'titletext': "Ain't It Fun (Paramore song)",
#    'url': ['/wiki/Paramore']},
#   {'band_singer': ['Aloe Blacc'],
#    'ranking': 48,
#    'song': ['The Man (Aloe Blacc song)'],
#    'songurl': ['/wiki/The_Man_(Aloe_Blacc_song)'],
#    'titletext': 'The Man (Aloe Blacc song)',
#    'url': ['/wiki/Aloe_Blacc']},
#   {'band_singer': ['Florida Georgia Line', 'Luke Bryan'],
#    'ranking': 49,
#    'song': ['This Is How We Roll'],
#    'songurl': ['/wiki/This_Is_How_We_Roll'],
#    'titletext': 'This Is How We Roll',
#    'url': ['/wiki/Florida_Georgia_Line', '/wiki/Luke_Bryan']},
#   {'band_singer': ['MKTO'],
#    'ranking': 50,
#    'song': ['Classic (MKTO song)'],
#    'songurl': ['/wiki/Classic_(MKTO_song)'],
#    'titletext': 'Classic (MKTO song)',
#    'url': ['/wiki/MKTO']},
#   {'band_singer': ['Coldplay'],
#    'ranking': 51,
#    'song': ['A Sky Full of Stars'],
#    'songurl': ['/wiki/A_Sky_Full_of_Stars'],
#    'titletext': 'A Sky Full of Stars',
#    'url': ['/wiki/Coldplay']},
#   {'band_singer': ['Ed Sheeran'],
#    'ranking': 52,
#    'song': ["Don't (Ed Sheeran song)"],
#    'songurl': ['/wiki/Don%27t_(Ed_Sheeran_song)'],
#    'titletext': "Don't (Ed Sheeran song)",
#    'url': ['/wiki/Ed_Sheeran']},
#   {'band_singer': ['Trey Songz'],
#    'ranking': 53,
#    'song': ['Na Na (song)'],
#    'songurl': ['/wiki/Na_Na_(song)'],
#    'titletext': 'Na Na (song)',
#    'url': ['/wiki/Trey_Songz']},
#   {'band_singer': ['Bobby Shmurda'],
#    'ranking': 54,
#    'song': ['Hot Nigga'],
#    'songurl': ['/wiki/Hot_Nigga'],
#    'titletext': 'Hot Nigga',
#    'url': ['/wiki/Bobby_Shmurda']},
#   {'band_singer': ['Drake (rapper)', 'Majid Jordan'],
#    'ranking': 55,
#    'song': ["Hold On, We're Going Home"],
#    'songurl': ['/wiki/Hold_On,_We%27re_Going_Home'],
#    'titletext': "Hold On, We're Going Home",
#    'url': ['/wiki/Drake_(rapper)', '/wiki/Majid_Jordan']},
#   {'band_singer': ['Ed Sheeran'],
#    'ranking': 56,
#    'song': ['Sing (Ed Sheeran song)'],
#    'songurl': ['/wiki/Sing_(Ed_Sheeran_song)'],
#    'titletext': 'Sing (Ed Sheeran song)',
#    'url': ['/wiki/Ed_Sheeran']},
#   {'band_singer': ['Imagine Dragons'],
#    'ranking': 57,
#    'song': ['Radioactive (Imagine Dragons song)'],
#    'songurl': ['/wiki/Radioactive_(Imagine_Dragons_song)'],
#    'titletext': 'Radioactive (Imagine Dragons song)',
#    'url': ['/wiki/Imagine_Dragons']},
#   {'band_singer': ['YG (rapper)', 'Jeezy', 'Rich Homie Quan'],
#    'ranking': 58,
#    'song': ['My Nigga'],
#    'songurl': ['/wiki/My_Nigga'],
#    'titletext': 'My Nigga',
#    'url': ['/wiki/YG_(rapper)', '/wiki/Jeezy', '/wiki/Rich_Homie_Quan']},
#   {'band_singer': ['Echosmith'],
#    'ranking': 59,
#    'song': ['Cool Kids (Echosmith song)'],
#    'songurl': ['/wiki/Cool_Kids_(Echosmith_song)'],
#    'titletext': 'Cool Kids (Echosmith song)',
#    'url': ['/wiki/Echosmith']},
#   {'band_singer': ['Avicii'],
#    'ranking': 60,
#    'song': ['Hey Brother'],
#    'songurl': ['/wiki/Hey_Brother'],
#    'titletext': 'Hey Brother',
#    'url': ['/wiki/Avicii']},
#   {'band_singer': ['Jason Derulo'],
#    'ranking': 61,
#    'song': ['Trumpets (Jason Derulo song)'],
#    'songurl': ['/wiki/Trumpets_(Jason_Derulo_song)'],
#    'titletext': 'Trumpets (Jason Derulo song)',
#    'url': ['/wiki/Jason_Derulo']},
#   {'band_singer': ['Maroon 5'],
#    'ranking': 62,
#    'song': ['Animals (Maroon 5 song)'],
#    'songurl': ['/wiki/Animals_(Maroon_5_song)'],
#    'titletext': 'Animals (Maroon 5 song)',
#    'url': ['/wiki/Maroon_5']},
#   {'band_singer': ['Jason Aldean'],
#    'ranking': 63,
#    'song': ["Burnin' It Down"],
#    'songurl': ['/wiki/Burnin%27_It_Down'],
#    'titletext': "Burnin' It Down",
#    'url': ['/wiki/Jason_Aldean']},
#   {'band_singer': ['Luke Bryan'],
#    'ranking': 64,
#    'song': ['Play It Again (Luke Bryan song)'],
#    'songurl': ['/wiki/Play_It_Again_(Luke_Bryan_song)'],
#    'titletext': 'Play It Again (Luke Bryan song)',
#    'url': ['/wiki/Luke_Bryan']},
#   {'band_singer': ['Tinashe', 'ScHoolboy Q'],
#    'ranking': 65,
#    'song': ['2 On'],
#    'songurl': ['/wiki/2_On'],
#    'titletext': '2 On',
#    'url': ['/wiki/Tinashe', '/wiki/ScHoolboy_Q']},
#   {'band_singer': ['Florida Georgia Line'],
#    'ranking': 66,
#    'song': ['Dirt (Florida Georgia Line song)'],
#    'songurl': ['/wiki/Dirt_(Florida_Georgia_Line_song)'],
#    'titletext': 'Dirt (Florida Georgia Line song)',
#    'url': ['/wiki/Florida_Georgia_Line']},
#   {'band_singer': ['OneRepublic'],
#    'ranking': 67,
#    'song': ['Love Runs Out'],
#    'songurl': ['/wiki/Love_Runs_Out'],
#    'titletext': 'Love Runs Out',
#    'url': ['/wiki/OneRepublic']},
#   {'band_singer': ['Brantley Gilbert'],
#    'ranking': 68,
#    'song': ['Bottoms Up (Brantley Gilbert song)'],
#    'songurl': ['/wiki/Bottoms_Up_(Brantley_Gilbert_song)'],
#    'titletext': 'Bottoms Up (Brantley Gilbert song)',
#    'url': ['/wiki/Brantley_Gilbert']},
#   {'band_singer': ['Becky G'],
#    'ranking': 69,
#    'song': ['Shower (song)'],
#    'songurl': ['/wiki/Shower_(song)'],
#    'titletext': 'Shower (song)',
#    'url': ['/wiki/Becky_G']},
#   {'band_singer': ['Rixton (band)'],
#    'ranking': 70,
#    'song': ['Me and My Broken Heart'],
#    'songurl': ['/wiki/Me_and_My_Broken_Heart'],
#    'titletext': 'Me and My Broken Heart',
#    'url': ['/wiki/Rixton_(band)']},
#   {'band_singer': ['Martin Garrix'],
#    'ranking': 71,
#    'song': ['Animals (Martin Garrix composition)'],
#    'songurl': ['/wiki/Animals_(Martin_Garrix_composition)'],
#    'titletext': 'Animals (Martin Garrix composition)',
#    'url': ['/wiki/Martin_Garrix']},
#   {'band_singer': ['Rich Gang', 'Young Thug', 'Rich Homie Quan'],
#    'ranking': 72,
#    'song': ['Lifestyle (song)'],
#    'songurl': ['/wiki/Lifestyle_(song)'],
#    'titletext': 'Lifestyle (song)',
#    'url': ['/wiki/Rich_Gang', '/wiki/Young_Thug', '/wiki/Rich_Homie_Quan']},
#   {'band_singer': ['Kenny Chesney'],
#    'ranking': 73,
#    'song': ['American Kids'],
#    'songurl': ['/wiki/American_Kids'],
#    'titletext': 'American Kids',
#    'url': ['/wiki/Kenny_Chesney']},
#   {'band_singer': ['Sara Bareilles'],
#    'ranking': 74,
#    'song': ['Brave (Sara Bareilles song)'],
#    'songurl': ['/wiki/Brave_(Sara_Bareilles_song)'],
#    'titletext': 'Brave (Sara Bareilles song)',
#    'url': ['/wiki/Sara_Bareilles']},
#   {'band_singer': ['The Neighbourhood'],
#    'ranking': 75,
#    'song': ['Sweater Weather'],
#    'songurl': ['/wiki/Sweater_Weather'],
#    'titletext': 'Sweater Weather',
#    'url': ['/wiki/The_Neighbourhood']},
#   {'band_singer': ['Sam Hunt (musician)'],
#    'ranking': 76,
#    'song': ['Leave the Night On'],
#    'songurl': ['/wiki/Leave_the_Night_On'],
#    'titletext': 'Leave the Night On',
#    'url': ['/wiki/Sam_Hunt_(musician)']},
#   {'band_singer': ['Chris Brown', 'Usher (entertainer)', 'Rick Ross'],
#    'ranking': 77,
#    'song': ['New Flame'],
#    'songurl': ['/wiki/New_Flame'],
#    'titletext': 'New Flame',
#    'url': ['/wiki/Chris_Brown',
#     '/wiki/Usher_(entertainer)',
#     '/wiki/Rick_Ross']},
#   {'band_singer': ['Michael Jackson', 'Justin Timberlake'],
#    'ranking': 78,
#    'song': ['Love Never Felt So Good'],
#    'songurl': ['/wiki/Love_Never_Felt_So_Good'],
#    'titletext': 'Love Never Felt So Good',
#    'url': ['/wiki/Michael_Jackson', '/wiki/Justin_Timberlake']},
#   {'band_singer': ['Dierks Bentley'],
#    'ranking': 79,
#    'song': ['Drunk on a Plane'],
#    'songurl': ['/wiki/Drunk_on_a_Plane'],
#    'titletext': 'Drunk on a Plane',
#    'url': ['/wiki/Dierks_Bentley']},
#   {'band_singer': ['Katy Perry'],
#    'ranking': 80,
#    'song': ['Birthday (Katy Perry song)'],
#    'songurl': ['/wiki/Birthday_(Katy_Perry_song)'],
#    'titletext': 'Birthday (Katy Perry song)',
#    'url': ['/wiki/Katy_Perry']},
#   {'band_singer': ['Lady Antebellum'],
#    'ranking': 81,
#    'song': ['Bartender (Lady Antebellum song)'],
#    'songurl': ['/wiki/Bartender_(Lady_Antebellum_song)'],
#    'titletext': 'Bartender (Lady Antebellum song)',
#    'url': ['/wiki/Lady_Antebellum']},
#   {'band_singer': ['Naughty Boy', 'Sam Smith (singer)'],
#    'ranking': 82,
#    'song': ['La La La (Naughty Boy song)'],
#    'songurl': ['/wiki/La_La_La_(Naughty_Boy_song)'],
#    'titletext': 'La La La (Naughty Boy song)',
#    'url': ['/wiki/Naughty_Boy', '/wiki/Sam_Smith_(singer)']},
#   {'band_singer': ['Robin Thicke', 'T.I.', 'Pharrell Williams'],
#    'ranking': 83,
#    'song': ['Blurred Lines'],
#    'songurl': ['/wiki/Blurred_Lines'],
#    'titletext': 'Blurred Lines',
#    'url': ['/wiki/Robin_Thicke', '/wiki/T.I.', '/wiki/Pharrell_Williams']},
#   {'band_singer': ['Lady Gaga', 'R. Kelly'],
#    'ranking': 84,
#    'song': ['Do What U Want'],
#    'songurl': ['/wiki/Do_What_U_Want'],
#    'titletext': 'Do What U Want',
#    'url': ['/wiki/Lady_Gaga', '/wiki/R._Kelly']},
#   {'band_singer': ['Shakira', 'Rihanna'],
#    'ranking': 85,
#    'song': ["Can't Remember to Forget You"],
#    'songurl': ['/wiki/Can%27t_Remember_to_Forget_You'],
#    'titletext': "Can't Remember to Forget You",
#    'url': ['/wiki/Shakira', '/wiki/Rihanna']},
#   {'band_singer': ['5 Seconds of Summer'],
#    'ranking': 86,
#    'song': ['Amnesia (5 Seconds of Summer song)'],
#    'songurl': ['/wiki/Amnesia_(5_Seconds_of_Summer_song)'],
#    'titletext': 'Amnesia (5 Seconds of Summer song)',
#    'url': ['/wiki/5_Seconds_of_Summer']},
#   {'band_singer': ['T.I.', 'Iggy Azalea'],
#    'ranking': 87,
#    'song': ['No Mediocre'],
#    'songurl': ['/wiki/No_Mediocre'],
#    'titletext': 'No Mediocre',
#    'url': ['/wiki/T.I.', '/wiki/Iggy_Azalea']},
#   {'band_singer': ['Kongos (band)'],
#    'ranking': 88,
#    'song': ['Come with Me Now'],
#    'songurl': ['/wiki/Come_with_Me_Now'],
#    'titletext': 'Come with Me Now',
#    'url': ['/wiki/Kongos_(band)']},
#   {'band_singer': ['Lil Wayne', 'Drake (rapper)'],
#    'ranking': 89,
#    'song': ['Believe Me (Lil Wayne song)'],
#    'songurl': ['/wiki/Believe_Me_(Lil_Wayne_song)'],
#    'titletext': 'Believe Me (Lil Wayne song)',
#    'url': ['/wiki/Lil_Wayne', '/wiki/Drake_(rapper)']},
#   {'band_singer': ['Mike WiLL Made-It',
#     'Miley Cyrus',
#     'Wiz Khalifa',
#     'Juicy J'],
#    'ranking': 90,
#    'song': ['23 (song)'],
#    'songurl': ['/wiki/23_(song)'],
#    'titletext': '23 (song)',
#    'url': ['/wiki/Mike_WiLL_Made-It',
#     '/wiki/Miley_Cyrus',
#     '/wiki/Wiz_Khalifa',
#     '/wiki/Juicy_J']},
#   {'band_singer': ['Jake Owen'],
#    'ranking': 91,
#    'song': ["Beachin'"],
#    'songurl': ['/wiki/Beachin%27'],
#    'titletext': "Beachin'",
#    'url': ['/wiki/Jake_Owen']},
#   {'band_singer': ['Macklemore & Ryan Lewis',
#     'ScHoolboy Q',
#     'Hollis (singer)'],
#    'ranking': 92,
#    'song': ['White Walls'],
#    'songurl': ['/wiki/White_Walls'],
#    'titletext': 'White Walls',
#    'url': ['/wiki/Macklemore_%26_Ryan_Lewis',
#     '/wiki/ScHoolboy_Q',
#     '/wiki/Hollis_(singer)']},
#   {'band_singer': ['5 Seconds of Summer'],
#    'ranking': 93,
#    'song': ['She Looks So Perfect'],
#    'songurl': ['/wiki/She_Looks_So_Perfect'],
#    'titletext': 'She Looks So Perfect',
#    'url': ['/wiki/5_Seconds_of_Summer']},
#   {'band_singer': ['Zedd (musician)', 'Hayley Williams'],
#    'ranking': 94,
#    'song': ['Stay the Night (Zedd song)'],
#    'songurl': ['/wiki/Stay_the_Night_(Zedd_song)'],
#    'titletext': 'Stay the Night (Zedd song)',
#    'url': ['/wiki/Zedd_(musician)', '/wiki/Hayley_Williams']},
#   {'band_singer': ['Beyoncé'],
#    'ranking': 95,
#    'song': ['Partition (song)'],
#    'songurl': ['/wiki/Partition_(song)'],
#    'titletext': 'Partition (song)',
#    'url': ['/wiki/Beyonc%C3%A9']},
#   {'band_singer': ['ScHoolboy Q', 'BJ the Chicago Kid'],
#    'ranking': 96,
#    'song': ['Studio (song)'],
#    'songurl': ['/wiki/Studio_(song)'],
#    'titletext': 'Studio (song)',
#    'url': ['/wiki/ScHoolboy_Q', '/wiki/BJ_the_Chicago_Kid']},
#   {'band_singer': ['Drake (rapper)'],
#    'ranking': 97,
#    'song': ['0 to 100 / The Catch Up'],
#    'songurl': ['/wiki/0_to_100_/_The_Catch_Up'],
#    'titletext': '0 to 100 / The Catch Up',
#    'url': ['/wiki/Drake_(rapper)']},
#   {'band_singer': ['Lee Brice'],
#    'ranking': 98,
#    'song': ["I Don't Dance (Lee Brice song)"],
#    'songurl': ['/wiki/I_Don%27t_Dance_(Lee_Brice_song)'],
#    'titletext': "I Don't Dance (Lee Brice song)",
#    'url': ['/wiki/Lee_Brice']},
#   {'band_singer': ['Miranda Lambert', 'Carrie Underwood'],
#    'ranking': 99,
#    'song': ["Somethin' Bad"],
#    'songurl': ['/wiki/Somethin%27_Bad'],
#    'titletext': "Somethin' Bad",
#    'url': ['/wiki/Miranda_Lambert', '/wiki/Carrie_Underwood']},
#   {'band_singer': ['Miley Cyrus'],
#    'ranking': 100,
#    'song': ['Adore You'],
#    'songurl': ['/wiki/Adore_You'],
#    'titletext': 'Adore You',
#    'url': ['/wiki/Miley_Cyrus']}]}

# %%
yeardict = {}
for y in yearinfo.keys():
    yearlist = yearinfo[y] #yearlist is a list of song dictionaries in a particular year
    yearlist2 = []
    for singledict in yearlist:
        #singledict is a song dictionary
        singers = singledict['band_singer'] #a list of singers
        for i, singer in enumerate(singers):
            songs = singledict['song'] #a list of songs
            for j, song in enumerate(songs):
                nd = {}
                nd['band_singer'] = singer
                nd['url'] = singledict['url'][i]
                nd['song'] = song
                nd['songurl'] = singledict['songurl'][j]
                nd['ranking'] = singledict['ranking']
                yearlist2.append(nd)
    yeardict[y] = pd.DataFrame(yearlist2) #a dataframe for each year

flatframe = pd.concat(yeardict)

# %%
flatframe = flatframe.reset_index()
flatframe.rename(columns = {'level_0': 'year'}, inplace = True)
del flatframe['level_1']
flatframe
# Out:
#       year               band_singer  ranking                                   song                                            songurl                              url
# 0     1992               Boyz II Men        1                        End of the Road                              /wiki/End_of_the_Road                /wiki/Boyz_II_Men
# 1     1992             Sir Mix-a-Lot        2                          Baby Got Back                                /wiki/Baby_Got_Back              /wiki/Sir_Mix-a-Lot
# 2     1992                Kris Kross        3                 Jump (Kris Kross song)                       /wiki/Jump_(Kris_Kross_song)                 /wiki/Kris_Kross
# 3     1992       Vanessa L. Williams        4                 Save the Best for Last                       /wiki/Save_the_Best_for_Last        /wiki/Vanessa_L._Williams
# 4     1992                TLC (band)        5                         Baby-Baby-Baby                               /wiki/Baby-Baby-Baby                 /wiki/TLC_(band)
# 5     1992              Eric Clapton        6                        Tears in Heaven                              /wiki/Tears_in_Heaven               /wiki/Eric_Clapton
# 6     1992                  En Vogue        7  My Lovin' (You're Never Gonna Get It)    /wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)                   /wiki/En_Vogue
# 7     1992     Red Hot Chili Peppers        8                       Under the Bridge                             /wiki/Under_the_Bridge      /wiki/Red_Hot_Chili_Peppers
# 8     1992             Color Me Badd        9                             All 4 Love                                   /wiki/All_4_Love              /wiki/Color_Me_Badd
# 9     1992                Jon Secada       10     Just Another Day (Jon Secada song)           /wiki/Just_Another_Day_(Jon_Secada_song)                 /wiki/Jon_Secada
# 10    1992                   Shanice       11                      I Love Your Smile                            /wiki/I_Love_Your_Smile                    /wiki/Shanice
# 11    1992            Mr. Big (band)       12                         To Be with You                               /wiki/To_Be_with_You             /wiki/Mr._Big_(band)
# 12    1992           Right Said Fred       13                           I'm Too Sexy                               /wiki/I%27m_Too_Sexy            /wiki/Right_Said_Fred
# 13    1992           Michael Jackson       14                         Black or White                               /wiki/Black_or_White            /wiki/Michael_Jackson
# 14    1992           Billy Ray Cyrus       15                      Achy Breaky Heart                            /wiki/Achy_Breaky_Heart            /wiki/Billy_Ray_Cyrus
# 15    1992              Mariah Carey       16     I'll Be There (The Jackson 5 song)  /wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mar...               /wiki/Mariah_Carey
# 16    1992             Guns N' Roses       17                          November Rain                                /wiki/November_Rain            /wiki/Guns_N%27_Roses
# 17    1992              Tom Cochrane       18                      Life Is a Highway                            /wiki/Life_Is_a_Highway               /wiki/Tom_Cochrane
# 18    1992           Michael Jackson       19                      Remember the Time                            /wiki/Remember_the_Time            /wiki/Michael_Jackson
# 19    1992             CeCe Peniston       20           Finally (CeCe Peniston song)                 /wiki/Finally_(CeCe_Peniston_song)              /wiki/CeCe_Peniston
# 20    1992     Madonna (entertainer)       21          This Used to Be My Playground                /wiki/This_Used_to_Be_My_Playground      /wiki/Madonna_(entertainer)
# 21    1992               Patty Smyth       22       Sometimes Love Just Ain't Enough           /wiki/Sometimes_Love_Just_Ain%27t_Enough                /wiki/Patty_Smyth
# 22    1992                Don Henley       22       Sometimes Love Just Ain't Enough           /wiki/Sometimes_Love_Just_Ain%27t_Enough                 /wiki/Don_Henley
# 23    1992              Mariah Carey       23       Can't Let Go (Mariah Carey song)           /wiki/Can%27t_Let_Go_(Mariah_Carey_song)               /wiki/Mariah_Carey
# 24    1992             House of Pain       24                            Jump Around                                  /wiki/Jump_Around              /wiki/House_of_Pain
# 25    1992      Prince (entertainer)       25             Diamonds and Pearls (song)                   /wiki/Diamonds_and_Pearls_(song)       /wiki/Prince_(entertainer)
# 26    1992  The New Power Generation       25             Diamonds and Pearls (song)                   /wiki/Diamonds_and_Pearls_(song)   /wiki/The_New_Power_Generation
# 27    1992            George Michael       26        Don't Let the Sun Go Down on Me            /wiki/Don%27t_Let_the_Sun_Go_Down_on_Me             /wiki/George_Michael
# 28    1992                Elton John       26        Don't Let the Sun Go Down on Me            /wiki/Don%27t_Let_the_Sun_Go_Down_on_Me                 /wiki/Elton_John
# 29    1992            Atlantic Starr       27      Masterpiece (Atlantic Starr song)            /wiki/Masterpiece_(Atlantic_Starr_song)             /wiki/Atlantic_Starr
# ...    ...                       ...      ...                                    ...                                                ...                              ...
# 2934  2014         Pharrell Williams       83                          Blurred Lines                                /wiki/Blurred_Lines          /wiki/Pharrell_Williams
# 2935  2014                 Lady Gaga       84                         Do What U Want                               /wiki/Do_What_U_Want                  /wiki/Lady_Gaga
# 2936  2014                  R. Kelly       84                         Do What U Want                               /wiki/Do_What_U_Want                   /wiki/R._Kelly
# 2937  2014                   Shakira       85           Can't Remember to Forget You               /wiki/Can%27t_Remember_to_Forget_You                    /wiki/Shakira
# 2938  2014                   Rihanna       85           Can't Remember to Forget You               /wiki/Can%27t_Remember_to_Forget_You                    /wiki/Rihanna
# 2939  2014       5 Seconds of Summer       86     Amnesia (5 Seconds of Summer song)           /wiki/Amnesia_(5_Seconds_of_Summer_song)        /wiki/5_Seconds_of_Summer
# 2940  2014                      T.I.       87                            No Mediocre                                  /wiki/No_Mediocre                       /wiki/T.I.
# 2941  2014               Iggy Azalea       87                            No Mediocre                                  /wiki/No_Mediocre                /wiki/Iggy_Azalea
# 2942  2014             Kongos (band)       88                       Come with Me Now                             /wiki/Come_with_Me_Now              /wiki/Kongos_(band)
# 2943  2014                 Lil Wayne       89            Believe Me (Lil Wayne song)                  /wiki/Believe_Me_(Lil_Wayne_song)                  /wiki/Lil_Wayne
# 2944  2014            Drake (rapper)       89            Believe Me (Lil Wayne song)                  /wiki/Believe_Me_(Lil_Wayne_song)             /wiki/Drake_(rapper)
# 2945  2014         Mike WiLL Made-It       90                              23 (song)                                    /wiki/23_(song)          /wiki/Mike_WiLL_Made-It
# 2946  2014               Miley Cyrus       90                              23 (song)                                    /wiki/23_(song)                /wiki/Miley_Cyrus
# 2947  2014               Wiz Khalifa       90                              23 (song)                                    /wiki/23_(song)                /wiki/Wiz_Khalifa
# 2948  2014                   Juicy J       90                              23 (song)                                    /wiki/23_(song)                    /wiki/Juicy_J
# 2949  2014                 Jake Owen       91                               Beachin'                                   /wiki/Beachin%27                  /wiki/Jake_Owen
# 2950  2014   Macklemore & Ryan Lewis       92                            White Walls                                  /wiki/White_Walls  /wiki/Macklemore_%26_Ryan_Lewis
# 2951  2014               ScHoolboy Q       92                            White Walls                                  /wiki/White_Walls                /wiki/ScHoolboy_Q
# 2952  2014           Hollis (singer)       92                            White Walls                                  /wiki/White_Walls            /wiki/Hollis_(singer)
# 2953  2014       5 Seconds of Summer       93                   She Looks So Perfect                         /wiki/She_Looks_So_Perfect        /wiki/5_Seconds_of_Summer
# 2954  2014           Zedd (musician)       94             Stay the Night (Zedd song)                   /wiki/Stay_the_Night_(Zedd_song)            /wiki/Zedd_(musician)
# 2955  2014           Hayley Williams       94             Stay the Night (Zedd song)                   /wiki/Stay_the_Night_(Zedd_song)            /wiki/Hayley_Williams
# 2956  2014                   Beyoncé       95                       Partition (song)                             /wiki/Partition_(song)               /wiki/Beyonc%C3%A9
# 2957  2014               ScHoolboy Q       96                          Studio (song)                                /wiki/Studio_(song)                /wiki/ScHoolboy_Q
# 2958  2014        BJ the Chicago Kid       96                          Studio (song)                                /wiki/Studio_(song)         /wiki/BJ_the_Chicago_Kid
# 2959  2014            Drake (rapper)       97                0 to 100 / The Catch Up                      /wiki/0_to_100_/_The_Catch_Up             /wiki/Drake_(rapper)
# 2960  2014                 Lee Brice       98         I Don't Dance (Lee Brice song)             /wiki/I_Don%27t_Dance_(Lee_Brice_song)                  /wiki/Lee_Brice
# 2961  2014           Miranda Lambert       99                          Somethin' Bad                              /wiki/Somethin%27_Bad            /wiki/Miranda_Lambert
# 2962  2014          Carrie Underwood       99                          Somethin' Bad                              /wiki/Somethin%27_Bad           /wiki/Carrie_Underwood
# 2963  2014               Miley Cyrus      100                              Adore You                                    /wiki/Adore_You                /wiki/Miley_Cyrus
#
# [2964 rows x 6 columns]

# %%
flatframe.year = flatframe.year.astype(int)
flatframe.dtypes
# Out:
# year            int32
# band_singer    object
# ranking         int64
# song           object
# songurl        object
# url            object
# dtype: object

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# #### 1.5 Find highest quality singers according to how prolific they are
#
# What do we mean by highest quality? This is of course open to interpretation, but let's define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If a singer appears twice in a year (for different songs), this is counted as two appearances, not one.
#
# Make a bar-plot of the most prolific singers. Singers on this chart should have appeared at-least more than 15 times. (HINT: look at the docs for the pandas method `value_counts`.)

# %%
prolific = flatframe.url.value_counts()
prolific[prolific > 15].plot(kind="barh", figsize = (12,10));

# %% [markdown]
# #### 1.6 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer should to be scored higher if the singer appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %%
scores = flatframe.groupby('url').apply(lambda f: np.sum(101 - f.ranking))
scores = scores.sort_values(ascending = False)
scores[:20].plot(kind='barh', figsize = (12,10))

# %% [markdown]
# #### 1.7 Do you notice any major differences when you change the metric?
#
# How have the singers at the top shifted places? Why do you think this happens?

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those band/singer urls we collected under `flatframe.url` and get information about singers and/or bands.

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. We create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Once we have fetched information about an artist, we don't need to do it again. The caching also helps if the network goes down, or the target website is having some problems. You simply need to run the `get_page` function below again, and the `urlcache` dictionary will continue to be filled.
#
# If the request gets an HTTP return code different from 200, (such as a 404 not found or 500 Internal Server Error) the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Think why.

# %%
flatframe=flatframe.sort_values('year')
flatframe.head()
# Out:
#     year                     band_singer  ranking                                            song                                            songurl                                   url
# 0   1992                     Boyz II Men        1                                 End of the Road                              /wiki/End_of_the_Road                     /wiki/Boyz_II_Men
# 72  1992  Marky Mark and the Funky Bunch       69  Wildside (Marky Mark and the Funky Bunch song)  /wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch...  /wiki/Marky_Mark_and_the_Funky_Bunch
# 71  1992                  Genesis (band)       68                                  No Son of Mine                               /wiki/No_Son_of_Mine                  /wiki/Genesis_(band)
# 70  1992    Arrested Development (group)       67                                 People Everyday                              /wiki/People_Everyday    /wiki/Arrested_Development_(group)
# 69  1992                 Michael Jackson       66                                   In the Closet                                /wiki/In_the_Closet                 /wiki/Michael_Jackson

# %% [markdown]
# #### Pulling and saving the data

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
# NOTE this function will take quite some time to run (about 30 mins for me), since we sleep 1 second before
# making a request. If you run it again it will be almost instantaneous, save requests that might have failed
# (you will need to run it again if requests fail..see cell below for how to test this)
flatframe["url"].apply(get_page)
# Out:
# 0       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 72      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 71      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 70      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 69      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 68      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 67      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 66      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 65      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 64      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 63      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 62      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 61      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 60      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 59      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 58      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 57      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 56      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 55      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 54      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 53      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 52      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 73      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 51      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 75      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 77      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 98      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 97      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 96      <!DOCTYPE html>\n<html class="client-nojs" lan...
# 95      <!DOCTYPE html>\n<html class="client-nojs" lan...
#                               ...
# 2878    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2879    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2880    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2881    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2882    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2883    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2884    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2885    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2886    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2871    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2851    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2870    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2868    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2853    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2854    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2855    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2856    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2857    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2858    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2859    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2860    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2861    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2862    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2863    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2864    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2865    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2866    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2867    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2869    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2963    <!DOCTYPE html>\n<html class="client-nojs" lan...
# Name: url, Length: 2964, dtype: object

# %% [markdown]
# You may have to run this function again and again, in case there were network problems. Note that, because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it attempts to make sure that there are no unresolved pages remaining. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
print("Number of bad requests:",np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])) # no one or 0's)
print("Did we get all urls?", len(flatframe.url.unique())==len(urlcache)) # we got all of the urls
# Out:
# Number of bad requests: 0
# Did we get all urls? True

# %% [markdown]
# Let's save the `urlcache` to disk, just in case we need it again.

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
with open("artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
# RERUN WHEN SUBMITTING
with open("artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If the page doesn't contain "Born", store `False`.  Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 2. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/sandg.png).

# %% [markdown]
# Write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""

def singer_band_info(url, page_text):
    page_text = page_text.replace('&#160;', ' ')
    soup = BeautifulSoup(page_text, 'html.parser')
    infotable = soup.find('table', class_= 'infobox')
    born, ya = False, False
    if infotable != None:
        try:    
            rows = infotable.find_all('tr')
            for row in rows:
                if row.find(string = 'Born'):
                    born = infotable.find(class_='bday').get_text()            
                if row.find(string = 'Years active'):
                    temp = row.find('td')
                    ya = temp.get_text().strip()
        except:
            born = False
            ya = False
    return {'url': url, 'born': born, 'ya': ya}

url = 'https://en.wikipedia.org/wiki/112_(band)'
req = requests.get(url)
text = req.text
singer_band_info(url, text)
# Out:
# {'born': False,
#  'url': 'https://en.wikipedia.org/wiki/112_(band)',
#  'ya': '1993–present (1993–present)'}

# %% [markdown]
# #### 2.2  Merging this information in

# %% [markdown]
# Iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there with columns `url`, `born`, and `ya`. Merge this dataframe on the `url` key with `flatframe`, creating a rather wide dataframe that we shall call `largedf`. It should look something like this:
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC3.png)
#
# Notice how the `born` and `ya` and `url` are repeated every time a different song from a given band is represented in a row.

# %%
infodict = [singer_band_info(url, page_text) for url, page_text in urlcache.items()]
df_info = pd.DataFrame(infodict)

# %%
df_info
# Out:
#             born                                   url                                                 ya
# 0          False                     /wiki/Boyz_II_Men                                       1985–present
# 1          False  /wiki/Marky_Mark_and_the_Funky_Bunch                                          1989–1993
# 2          False                  /wiki/Genesis_(band)                         1967–1998[4][5]\n2006–2007
# 3          False    /wiki/Arrested_Development_(group)                            1988–1996, 2000–present
# 4     1958-08-29                 /wiki/Michael_Jackson                                          1964–2009
# 5          False                      /wiki/Kris_Kross                                          1991–2013
# 6     1951-04-13                    /wiki/Peabo_Bryson                                       1976–present
# 7     1968-03-30                     /wiki/Celine_Dion                                       1980–present
# 8     1969-09-06                   /wiki/CeCe_Peniston                                       1991–present
# 9          False                              /wiki/U2                                       1976–present
# 10         False         /wiki/The_Heights_(TV_series)                                              False
# 11    1963-06-25                  /wiki/George_Michael                                          1981–2016
# 12    1963-09-16                    /wiki/Richard_Marx                                       1980–present
# 13    1953-02-26                  /wiki/Michael_Bolton                                       1975–present
# 14         False           /wiki/Toad_the_Wet_Sprocket                      1986–1998, 2002, 2006–present
# 15    1960-11-25                       /wiki/Amy_Grant                                       1976–present
# 16         False                       /wiki/P.M._Dawn                                          1988–2016
# 17         False                 /wiki/The_Cover_Girls                            1986–1996, 2001–present
# 18         False                  /wiki/Mint_Condition                                       1984–present
# 19    1959-11-05                     /wiki/Bryan_Adams                                       1975–present
# 20         False                      /wiki/KWS_(band)                                          1992–1994
# 21         False                    /wiki/Ugly_Kid_Joe                            1987–1997\n2010–present
# 22    1949-11-08                    /wiki/Bonnie_Raitt                                       1971–present
# 23         False                         /wiki/Das_EFX                                       1988–present
# 24         False                     /wiki/Def_Leppard                                       1977–present
# 25    1961-07-22                     /wiki/Keith_Sweat                                       1975–present
# 26         False                        /wiki/En_Vogue                                       1989–present
# 27         False               /wiki/Charles_%26_Eddie                                          1990–1995
# 28         False                      /wiki/TLC_(band)                 1990–2002, 2004-2005, 2014-present
# 29         False                         /wiki/The_KLF  1987–1992\n1995\n1997\n(reunion performance in...
# ...          ...                                   ...                                                ...
# 999   1993-02-06                         /wiki/Tinashe                                       2007–present
# 1000  1975-04-05                         /wiki/Juicy_J                                       1991–present
# 1001       False       /wiki/Macklemore_%26_Ryan_Lewis                           2008–2017 (on hiatus)[1]
# 1002       False                 /wiki/Hollis_(singer)                                              False
# 1003       False             /wiki/5_Seconds_of_Summer                                       2011–present
# 1004  1984-11-23              /wiki/BJ_the_Chicago_Kid                                       2001–present
# 1005  1989-03-23               /wiki/Mike_WiLL_Made-It                                       2005–present
# 1006  1985-01-01                     /wiki/Naughty_Boy                                       2005–present
# 1007  1992-05-19              /wiki/Sam_Smith_(singer)                                       2007–present
# 1008  1990-06-07                     /wiki/Iggy_Azalea                                       2011–present
# 1009       False                   /wiki/Kongos_(band)                                2007 (2007)–present
# 1010       False                            /wiki/MKTO                                       2010–present
# 1011  1986-06-13                        /wiki/DJ_Snake                                       2009–present
# 1012       False               /wiki/A_Great_Big_World                                       2011–present
# 1013  1971-05-30                    /wiki/Idina_Menzel                                       1986–present
# 1014       False                   /wiki/Nico_%26_Vinz                                       2010–present
# 1015  1990-11-26                        /wiki/Rita_Ora                                       2007–present
# 1016       False                          /wiki/Magic!                                2012 (2012)–present
# 1017  1993-12-22                  /wiki/Meghan_Trainor                                       2009–present
# 1018       False                 /wiki/Bastille_(band)                                              False
# 1019       False                   /wiki/Gente_de_Zona                                       2000–present
# 1020       False                    /wiki/Clean_Bandit                                       2008–present
# 1021  1989-10-20                     /wiki/Jess_Glynne                                       2012–present
# 1022  1986-04-01                         /wiki/Kid_Ink                                       2010–present
# 1023  1979-01-07                      /wiki/Aloe_Blacc                                       1995–present
# 1024  1971-07-05                  /wiki/Descemer_Bueno                                       1990–present
# 1025       False               /wiki/Disclosure_(band)                                       2010–present
# 1026  1984-11-09                  /wiki/French_Montana                                       2002–present
# 1027       False                /wiki/American_Authors                                       2006–present
# 1028  1987-10-29                         /wiki/Tove_Lo                                       2006–present
#
# [1029 rows x 3 columns]

# %%
largedf = pd.merge(flatframe, df_info, how = 'outer', left_on = 'url', right_on = 'url')
largedf
# Out:
#       year              band_singer  ranking                                       song                                            songurl                              url        born                                  ya
# 0     1992              Boyz II Men        1                            End of the Road                              /wiki/End_of_the_Road                /wiki/Boyz_II_Men       False                        1985–present
# 1     1992              Boyz II Men       37   It's So Hard to Say Goodbye to Yesterday   /wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday                /wiki/Boyz_II_Men       False                        1985–present
# 2     1992              Boyz II Men       84                                    Uhh Ahh                                      /wiki/Uhh_Ahh                /wiki/Boyz_II_Men       False                        1985–present
# 3     1993              Boyz II Men       12      In the Still of the Night (1956 song)  /wiki/In_the_Still_of_the_Night_(1956_song)#Bo...                /wiki/Boyz_II_Men       False                        1985–present
# 4     1994              Boyz II Men        3                      I'll Make Love to You                      /wiki/I%27ll_Make_Love_to_You                /wiki/Boyz_II_Men       False                        1985–present
# 5     1995              Boyz II Men        5                             On Bended Knee                               /wiki/On_Bended_Knee                /wiki/Boyz_II_Men       False                        1985–present
# 6     1995              Boyz II Men       12                             Water Runs Dry                               /wiki/Water_Runs_Dry                /wiki/Boyz_II_Men       False                        1985–present
# 7     1995              Boyz II Men       50                      I'll Make Love to You                      /wiki/I%27ll_Make_Love_to_You                /wiki/Boyz_II_Men       False                        1985–present
# 8     1995              Boyz II Men       94               Thank You (Boyz II Men song)                 /wiki/Thank_You_(Boyz_II_Men_song)                /wiki/Boyz_II_Men       False                        1985–present
# 9     1996              Boyz II Men        2                              One Sweet Day                                /wiki/One_Sweet_Day                /wiki/Boyz_II_Men       False                        1985–present
# 10    1997              Boyz II Men       30                    4 Seasons of Loneliness                      /wiki/4_Seasons_of_Loneliness                /wiki/Boyz_II_Men       False                        1985–present
# 11    1998              Boyz II Men       30                            A Song for Mama                              /wiki/A_Song_for_Mama                /wiki/Boyz_II_Men       False                        1985–present
# 12    1998              Boyz II Men       96                    4 Seasons of Loneliness                      /wiki/4_Seasons_of_Loneliness                /wiki/Boyz_II_Men       False                        1985–present
# 13    1992            Sir Mix-a-Lot        2                              Baby Got Back                                /wiki/Baby_Got_Back              /wiki/Sir_Mix-a-Lot  1963-08-12             1983–2003, 2010–Present
# 14    1992               Kris Kross        3                     Jump (Kris Kross song)                       /wiki/Jump_(Kris_Kross_song)                 /wiki/Kris_Kross       False                           1991–2013
# 15    1992               Kris Kross       65                                 Warm It Up                                   /wiki/Warm_It_Up                 /wiki/Kris_Kross       False                           1991–2013
# 16    1993               Kris Kross       85                  Alright (Kris Kross song)                    /wiki/Alright_(Kris_Kross_song)                 /wiki/Kris_Kross       False                           1991–2013
# 17    1996               Kris Kross       64                         Tonite's tha Night                         /wiki/Tonite%27s_tha_Night                 /wiki/Kris_Kross       False                           1991–2013
# 18    1992      Vanessa L. Williams        4                     Save the Best for Last                       /wiki/Save_the_Best_for_Last        /wiki/Vanessa_L._Williams  1963-03-18                        1982–present
# 19    1993      Vanessa L. Williams       21            Love Is (Vanessa Williams song)              /wiki/Love_Is_(Vanessa_Williams_song)        /wiki/Vanessa_L._Williams  1963-03-18                        1982–present
# 20    1995      Vanessa L. Williams       31                         Colors of the Wind                           /wiki/Colors_of_the_Wind        /wiki/Vanessa_L._Williams  1963-03-18                        1982–present
# 21    1995      Vanessa L. Williams       75  The Sweetest Days (Vanessa Williams song)    /wiki/The_Sweetest_Days_(Vanessa_Williams_song)        /wiki/Vanessa_L._Williams  1963-03-18                        1982–present
# 22    1992               TLC (band)        5                             Baby-Baby-Baby                               /wiki/Baby-Baby-Baby                 /wiki/TLC_(band)       False  1990–2002, 2004-2005, 2014-present
# 23    1992               TLC (band)       36                        Ain't 2 Proud 2 Beg                        /wiki/Ain%27t_2_Proud_2_Beg                 /wiki/TLC_(band)       False  1990–2002, 2004-2005, 2014-present
# 24    1992               TLC (band)       88                    What About Your Friends                      /wiki/What_About_Your_Friends                 /wiki/TLC_(band)       False  1990–2002, 2004-2005, 2014-present
# 25    1993               TLC (band)       62                    What About Your Friends                      /wiki/What_About_Your_Friends                 /wiki/TLC_(band)       False  1990–2002, 2004-2005, 2014-present
# 26    1995               TLC (band)        2                      Waterfalls (TLC song)                        /wiki/Waterfalls_(TLC_song)                 /wiki/TLC_(band)       False  1990–2002, 2004-2005, 2014-present
# 27    1995               TLC (band)        3                           Creep (TLC song)                             /wiki/Creep_(TLC_song)                 /wiki/TLC_(band)       False  1990–2002, 2004-2005, 2014-present
# 28    1995               TLC (band)       28                          Red Light Special                            /wiki/Red_Light_Special                 /wiki/TLC_(band)       False  1990–2002, 2004-2005, 2014-present
# 29    1996               TLC (band)       45                             Diggin' on You                             /wiki/Diggin%27_on_You                 /wiki/TLC_(band)       False  1990–2002, 2004-2005, 2014-present
# ...    ...                      ...      ...                                        ...                                                ...                              ...         ...                                 ...
# 2934  2014              YG (rapper)       42                             Don't Tell 'Em                           /wiki/Don%27t_Tell_%27Em                /wiki/YG_(rapper)  1990-03-09                        2009–present
# 2935  2014              YG (rapper)       58                                   My Nigga                                     /wiki/My_Nigga                /wiki/YG_(rapper)  1990-03-09                        2009–present
# 2936  2014                  Kid Ink       43                     Show Me (Kid Ink song)                       /wiki/Show_Me_(Kid_Ink_song)                    /wiki/Kid_Ink  1986-04-01                        2010–present
# 2937  2014               Aloe Blacc       48                  The Man (Aloe Blacc song)                    /wiki/The_Man_(Aloe_Blacc_song)                 /wiki/Aloe_Blacc  1979-01-07                        1995–present
# 2938  2014                     MKTO       50                        Classic (MKTO song)                          /wiki/Classic_(MKTO_song)                       /wiki/MKTO       False                        2010–present
# 2939  2014            Bobby Shmurda       54                                  Hot Nigga                                    /wiki/Hot_Nigga              /wiki/Bobby_Shmurda  1994-08-04                           2004–2016
# 2940  2014                    Jeezy       58                                   My Nigga                                     /wiki/My_Nigga                      /wiki/Jeezy  1977-09-28                        2001–present
# 2941  2014          Rich Homie Quan       58                                   My Nigga                                     /wiki/My_Nigga            /wiki/Rich_Homie_Quan  1989-10-04                        2007–present
# 2942  2014          Rich Homie Quan       72                           Lifestyle (song)                             /wiki/Lifestyle_(song)            /wiki/Rich_Homie_Quan  1989-10-04                        2007–present
# 2943  2014                Echosmith       59                 Cool Kids (Echosmith song)                   /wiki/Cool_Kids_(Echosmith_song)                  /wiki/Echosmith       False                        2009–present
# 2944  2014                  Tinashe       65                                       2 On                                         /wiki/2_On                    /wiki/Tinashe  1993-02-06                        2007–present
# 2945  2014              ScHoolboy Q       65                                       2 On                                         /wiki/2_On                /wiki/ScHoolboy_Q  1986-10-26                        2008–present
# 2946  2014              ScHoolboy Q       92                                White Walls                                  /wiki/White_Walls                /wiki/ScHoolboy_Q  1986-10-26                        2008–present
# 2947  2014              ScHoolboy Q       96                              Studio (song)                                /wiki/Studio_(song)                /wiki/ScHoolboy_Q  1986-10-26                        2008–present
# 2948  2014         Brantley Gilbert       68         Bottoms Up (Brantley Gilbert song)           /wiki/Bottoms_Up_(Brantley_Gilbert_song)           /wiki/Brantley_Gilbert  1985-01-20                        2005–present
# 2949  2014                  Becky G       69                              Shower (song)                                /wiki/Shower_(song)                    /wiki/Becky_G  1997-03-02                        2008–present
# 2950  2014            Rixton (band)       70                     Me and My Broken Heart                       /wiki/Me_and_My_Broken_Heart              /wiki/Rixton_(band)       False                        2012–present
# 2951  2014            Martin Garrix       71        Animals (Martin Garrix composition)          /wiki/Animals_(Martin_Garrix_composition)              /wiki/Martin_Garrix  1996-05-14                        2012–present
# 2952  2014                Rich Gang       72                           Lifestyle (song)                             /wiki/Lifestyle_(song)                  /wiki/Rich_Gang       False                               False
# 2953  2014               Young Thug       72                           Lifestyle (song)                             /wiki/Lifestyle_(song)                 /wiki/Young_Thug  1991-08-16                        2011–present
# 2954  2014        The Neighbourhood       75                            Sweater Weather                              /wiki/Sweater_Weather          /wiki/The_Neighbourhood       False                     2011–present[1]
# 2955  2014      Sam Hunt (musician)       76                         Leave the Night On                           /wiki/Leave_the_Night_On        /wiki/Sam_Hunt_(musician)  1984-12-08                        2009–present
# 2956  2014              Naughty Boy       82                La La La (Naughty Boy song)                  /wiki/La_La_La_(Naughty_Boy_song)                /wiki/Naughty_Boy  1985-01-01                        2005–present
# 2957  2014      5 Seconds of Summer       86         Amnesia (5 Seconds of Summer song)           /wiki/Amnesia_(5_Seconds_of_Summer_song)        /wiki/5_Seconds_of_Summer       False                        2011–present
# 2958  2014      5 Seconds of Summer       93                       She Looks So Perfect                         /wiki/She_Looks_So_Perfect        /wiki/5_Seconds_of_Summer       False                        2011–present
# 2959  2014            Kongos (band)       88                           Come with Me Now                             /wiki/Come_with_Me_Now              /wiki/Kongos_(band)       False                 2007 (2007)–present
# 2960  2014        Mike WiLL Made-It       90                                  23 (song)                                    /wiki/23_(song)          /wiki/Mike_WiLL_Made-It  1989-03-23                        2005–present
# 2961  2014  Macklemore & Ryan Lewis       92                                White Walls                                  /wiki/White_Walls  /wiki/Macklemore_%26_Ryan_Lewis       False            2008–2017 (on hiatus)[1]
# 2962  2014          Hollis (singer)       92                                White Walls                                  /wiki/White_Walls            /wiki/Hollis_(singer)       False                               False
# 2963  2014       BJ the Chicago Kid       96                              Studio (song)                                /wiki/Studio_(song)         /wiki/BJ_the_Chicago_Kid  1984-11-23                        2001–present
#
# [2964 rows x 8 columns]

# %% [markdown]
# #### 2.3 What is the age at which singers achieve their top ranking?

# %% [markdown]
# Plot a histogram of the age at which singers achieve their top ranking. What conclusions can you draw from this distribution of ages?
#
# *HINT: You will need to do some manipulation of the `born` column, and find the song for which a band or an artist achieves their top ranking. You will then need to put these rows together into another dataframe or array to make the plot.*

# %%
dfsinger = largedf[largedf.born != False]
dfsinger.loc[:, 'byear'] = dfsinger.loc[:,'born'].apply(lambda f: int(f.split('-')[0]))
grouped = dfsinger.groupby('url')
framesinger = []
for index, val in grouped:
    minrank = val.ranking.min()
    framesinger.append(val[val['ranking'] == minrank])
ranksinger = pd.concat(framesinger)
(ranksinger.year - ranksinger.byear).hist(bins = np.arange(10,70,2), figsize = (12,10))
# Out:
# C:\Users\Hoang\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Hoang\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# #### 2.4 At what year since inception do bands reach their top rankings?

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking. What conclusions can you draw?

# %%
dfband = largedf[largedf['born'] == False]
dfband = dfband[dfband['ya'] != False]
dfband['start'] = dfband['ya'].apply(lambda f: int(f[:4]))
groupedband = dfband.groupby('url')
frameband = []
for index, val in groupedband:
    minrank = val.ranking.min()
    frameband.append(val[val['ranking'] == minrank])
rankband = pd.concat(frameband)
(rankband.year - rankband.start).hist(bins = 20, figsize = (12,10))
